# %%
import pandas as pd
import numpy as np

# %%
mm_input = pd.read_excel('mm_input.xlsx', sheet_name = 'mm_input_nominations')
mm_input.head()
# Out:
#    ssmm_id  convocation_no  iteration_no                           name  \
# 0      1.0               1           NaN                   Левин Андрей
# 1      2.0               1           NaN  Матвеев Дмитрий Александрович
# 2      3.0               1           NaN         Власов Артем Андреевич
# 3      4.0               1           NaN               Кириллова Полина
# 4      5.0               1           NaN                  Семенов Павел
#
#    group_no year_stream_no  votes_cnt  mandate_flg  \
# 0     101.0            1.1       48.0            1
# 1     101.0            1.1       49.0            1
# 2     107.0            1.2       36.0            1
# 3     112.0            1.2       40.0            1
# 4     112.0            1.2       20.0            0
#
#    rejection_before_1_iteration_flg  rejection_after_this_iteration_flg  ...  \
# 0                               NaN                                 NaN  ...
# ...
