# %%
# все ссылки тут https://vk.com/pages?oid=-33327655&p=%D0%A1%D0%9E%D0%A1%D0%A2%D0%90%D0%92_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0

# все имена до 10 созыва вкл тут:
# 1 - https://vk.com/pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2012-03
# 2 - https://vk.com/pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2012-11
# 3 - https://vk.com/pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2013-12

# %%
# РУКОВОДСТВО

# 1 - https://vk.com/topic-33327655_26214681
# 2 - https://vk.com/wall-33327655_733
# 3 - https://vk.com/wall-33327655_1603


# 8 - https://vk.com/wall-33327655_7774
# 9 - https://vk.com/wall-33327655_8432
# 10 - https://vk.com/wall-33327655_9402
# 11 - https://vk.com/wall-33327655_10064

# %%
# КООРДИНАТОРЫ

# 1 - https://vk.com/topic-33327655_26162739 - НЕ ПОЛНО, РУКАМИ
# 2 - https://vk.com/wall-33327655_733
# 3 - https://vk.com/wall-33327655_1603
# 4 - https://vk.com/wall-33327655_2354 - НЕТ ТЕКСТА
# Избраны были также и координаторы всех рабочих групп совета.
# 5 - https://vk.com/wall-33327655_3524
# 6 - https://vk.com/wall-33327655_5487
# На первом собрании Студсовета были также избраны и координаторы рабочих групп совета.
# 7 - https://vk.com/wall-33327655_6755
# 8 - https://vk.com/wall-33327655_7776
# 9 - 
# Координаторы рабочих групп
# 10 - https://vk.com/wall-33327655_9421
# 11 - https://vk.com/wall-33327655_10092

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
import re
from datetime import datetime, date, time

import pandas as pd

# %%
# 

# req_announcement = requests.get('https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_10_%D0%BC%D0%B0%D1%80%D1%82_21')
# html_doc = req_announcement.text
# print(html_doc)

# %%
req_link = requests.get('https://vk.com/pages?oid=-33327655&p=%D0%A1%D0%9E%D0%A1%D0%A2%D0%90%D0%92_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0')

html_doc = req_link.text
soup = BeautifulSoup(html_doc, 'html.parser')

strings = soup.find_all('span', attrs={'class': 'l'})

menu_dict = {}

for s in strings:
    key = [line for line in s.stripped_strings][0]
    menu_dict[key] = 'https://vk.com/' + s.find('a', attrs={'href': True})['href']

# menu_dict

# %%
# <table cellpadding="0" cellspacing="0" class="wk_table">

# %%
def menu_page_to_dict(vk_menu_link):
    req_link = requests.get(vk_menu_link)
    html_doc = req_link.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    strings = soup.find_all('table', attrs={'class': 'wk_table'})
    return strings

# menu_page_to_dict(menu_dict['4 состав — ноябрь 2014'])

# %%
# import copy

menu_dict_upd = {}

for key in menu_dict.keys():
    if "'" not in key:
        menu_dict_upd[key] = menu_dict[key]

# menu_dict_upd = copy.deepcopy(menu_dict)
del menu_dict_upd['0 («нелегитимный») состав - декабрь 2011']
del menu_dict_upd['10 состав — март 2021 (после пятого собрания Студсовета)']

menu_dict_upd
# Out:
# {'10 состав — ноябрь 2020': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_10_%D0%BD%D0%BE%D1%8F%D0%B1%D1%80%D1%8C_20',
#  '9 состав — ноябрь 2019': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2019-11',
#  '8 состав — ноябрь 2018': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2018-11',
#  '7 состав — ноябрь 2017': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2017-10',
#  '6 состав — ноябрь 2016': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2016-11',
#  '5 состав — октябрь 2015': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2015-10',
#  '4 состав — ноябрь 2014': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2014-11',
#  '3 состав — декабрь 2013': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2013-12',
#  '2 состав — ноябрь 2012': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2012-11',
#  '1 состав — март 2012': 'https://vk.com//pages?oid=-33327655&p=%D0%A1%D0%BE%D1%81%D1%82%D0%B0%D0%B2_%D0%A1%D1%82%D1%83%D0%B4%D1%81%D0%BE%D0%B2%D0%B5%D1%82%D0%B0_%D0%BC%D0%B5%D1%85%D0%BC%D0%B0%D1%82%D0%B0%2C_2012-03'}

# %%
# wrong : correct

def replace_position(position):
    replace_position_names = {
        'Ответственный секретарь': 'Секретарь',
        'Представители в Студсовет МГУ': 'Представитель в Студсовете МГУ',
        'Представители в Студсовете МГУ': 'Представитель в Студсовете МГУ',
        'Представитель в Учёном совете': 'Представитель в Учёном совете мехмата',
        'Представитель в Учёный совет мехмата': 'Представитель в Учёном совете мехмата',
        'Представитель в Учёном совете мехмата МГУ': 'Представитель в Учёном совете мехмата',
        'Заместители представителей': 'Заместитель представителей в Студсовете МГУ',
        'Бытовые вопросы (ГЗ А, Б, Г, Е, ДСЛ, ФДС, экология)': 'Бытовые вопросы',
        'Бытовые вопросы (сектора «А» и «Б», ФДС, экология)': 'Бытовые вопросы'
    }
    if position in replace_position_names.keys():
        return replace_position_names[position]
    else:
        return position

# %%
from functools import reduce

managemant_dict = {}

for key in menu_dict_upd.keys():
    aaa = {}
    table = menu_page_to_dict(menu_dict_upd[key])
    for s in table[0]:
        lul = [line for line in s.stripped_strings]
        if replace_position(lul[0]) in ['Представитель в Студсовете МГУ','Заместитель представителей в Студсовете МГУ']:
            aaa[replace_position(lul[0])] = [nn.strip() for nn in reduce(lambda x,y: x+y, [name.split(',') for name in lul[1:] if len(name) > 2])]
        else:
            aaa[replace_position(lul[0])] = lul[1]
    del aaa['Должность']
    for s in table[1]:
        lul = [line for line in s.stripped_strings]
        if 'рабочей группы' not in lul[0]:
            if len(lul) > 1:
                aaa[replace_position(lul[0])] = lul[1]
            else:
                aaa[replace_position(lul[0])] = '-'
#     print(aaa)
    managemant_dict[int(key[:key.index(' ')])] = aaa

managemant_dict
# Out:
# {10: {'Председатель': 'Малиновский Г.А.',
#   'Заместитель председателя': 'Шишков А.А.',
#   'Секретарь': 'Мельникова Д.В.',
#   'Представитель в Студсовете МГУ': ['Сулейкин А.О.', 'Третьяков П.М.'],
#   'Заместитель представителей в Студсовете МГУ': ['Кухарчук И.А.',
#    'Скурихин Д.А.'],
#   'Представитель в Учёном совете мехмата': 'Клюев А.И.',
#   'Бытовые вопросы': 'Дехнич К.А.',
#   'Образование': 'Кухарчук И.А.',
#   'Оповещение': 'Третьяков П.М.',
#   'Спорт': 'Евдокимова С.А.',
#   'Праздники': 'Манахова А.Н.',
#   'Связи': 'Чуб В.В.',
#   'Распределение стипендий': 'Шишков А.А.'},
#  9: {'Председатель': 'Клюев А.И.',
#   'Заместитель председателя': 'Фенелонов Д.И.',
#   'Секретарь': 'Попова А.Р.',
#   'Представитель в Студсовете МГУ': ['Клюев А.И.', 'Кухарчук И.А.'],
#   'Заместитель представителей в Студсовете МГУ': ['Малахов Н.С.'],
#   'Представитель в Учёном совете мехмата': 'Третьяков П.М.',
#   'Бытовые вопросы': 'Фенелонов Д.И.',
#   'Образование': 'Саметов М.А.',
#   'Оповещение': 'Малиновский Г.А.',
#   'Спорт': 'Определится на собрании рабочей группы',
#   'Праздники': 'Евдокимова С.А.',
#   'Распределение стипендий': 'Кухарчук И.А.'},
#  8: {'Председатель': 'Сенотов В.Д.',
#   'Заместитель председателя': 'Хахова М.А.',
#   'Секретарь': 'Малиновский Г.А.',
#   'Представитель в Студсовете МГУ': ['Сенотов В.Д.', 'Денисов И.О.'],
#   'Заместитель представителей в Студсовете МГУ': ['Тонконогов А.В.',
#    'Малахов Н.С.'],
#   'Бытовые вопросы': 'Корж Д.С.',
#   'Образование': 'Промыслов П.В.',
#   'Оповещение': 'Краснова А.А.',
#   'Спорт': 'Малахов Н.С.',
#   'Праздники': 'Вихорева Н. Д.',
#   'Работа с партнёрами': 'Определится на собрании рабочей группы',
#   'Распределение стипендий': 'Кухарчук И.А.'},
#  7: {'Председатель': 'Тонконогов А.В.',
#   'Заместитель председателя': 'Сенотов В.Д.',
#   'Секретарь': 'Кудасов М.Д.',
#   'Представитель в Студсовете МГУ': ['Тонконогов А.В.', 'Денисов И.О.'],
#   'Заместитель представителей в Студсовете МГУ': ['Сенотов В.Д.', 'Корж Д.С.'],
#   'Бытовые вопросы': 'Корж Д.С.',
#   'Образование': 'Воробьева Н.Д.',
#   'Оповещение': 'Сенотов В.Д.',
#   'Спорт': 'Малахов Н.С.',
#   'Праздники': 'Гигин И.С.',
#   'Работа с партнёрами': 'Змиевский Л.В.',
#   'Распределение стипендий': 'Определится на собрании рабочей группы'},
#  6: {'Председатель': 'Денисов И.О.',
#   'Заместитель председателя': 'Бекбулатов Р.Л.',
#   'Секретарь': 'Чернова А.А.',
#   'Представитель в Студсовете МГУ': ['Денисов И.О.', 'Бекбулатов Р.Л.'],
#   'Заместитель представителей в Студсовете МГУ': ['Семенюк П. И.',
#    'Корж Д.С.'],
#   'Бытовые вопросы': 'Авилова Е.М.',
#   'Образование': 'Нагорных Я.И.',
#   'Оповещение': 'Саакян В.Р.',
#   'Спорт': 'Семенюк П.И.',
#   'Праздники': 'Муравьёва А.С.',
#   'Работа с партнёрами': 'Тонконогов А.В.',
#   'Распределение стипендий': '(временная до выполнения целей)'},
#  5: {'Председатель': 'Бекбулатов Р.Л.',
#   'Заместитель председателя': 'Денисов И.О.',
#   'Секретарь': 'Савин П.А.',
#   'Представитель в Студсовете МГУ': ['Бекбулатов Р.Л.', 'Шведов К.А.'],
#   'Заместитель представителей в Студсовете МГУ': ['Морозов С.С.',
#    'Суркова А.Ю.'],
#   'Бытовые вопросы': 'Денисов И.О.',
#   'Образование': 'Савин П.А.',
#   'Оповещение': 'Глунчадзе И.В.',
#   'Спорт': 'Семенюк П.И.',
#   'Праздники': 'Суркова А.Ю.',
#   'Работа с партнёрами': 'Тюрина Т.И.',
#   'Распределение стипендий': '(временная до выполнения целей)'},
#  4: {'Председатель': 'Глунчадзе И.В.',
#   'Заместитель председателя': 'Быстрицкая В.В.',
#   'Секретарь': 'Дяченко М.И.',
#   'Представитель в Студсовете МГУ': ['Глунчадзе И.В.', 'Матвеев А.В.'],
#   'Заместитель представителей в Студсовете МГУ': ['Митькина М.А.',
#    'Шведов К.А.'],
#   'Бытовые вопросы': 'Денисов И.О.',
#   'Образование': 'Савин П.А.',
#   'Оповещение': 'Бекбулатов Р.Л.',
#   'Спорт': 'Шведов К.А.',
#   'Праздники': 'Дорман Е.В.',
#   'Работа с партнёрами': 'Тюрина Т.И.',
#   'Распределение стипендий': '(временная до выполнения целей)'},
#  3: {'Председатель': 'Матвеев А.В.',
#   'Заместитель председателя': 'Быстрицкая В.В.',
#   'Секретарь': 'Дяченко М.И.',
#   'Представитель в Студсовете МГУ': ['Матвеев А.В.', 'Сапунов К.В.'],
#   'Заместитель представителей в Студсовете МГУ': ['Осин Р.В.', 'Ватутин К.А.'],
#   'Бытовые вопросы (сектор "А", экология)': 'Митькина М.А.',
#   'Образование': 'Медведева Я.Г.',
#   'Оповещение': 'Матвеев Д.А.',
#   'Проблемы общежитий (сектор "Б", ФДС)': 'Короткин В.В.',
#   'Спорт': 'Антонов С.В.',
#   'Праздники': 'Быстрицкая В.В.',
#   'Работа с партнёрами': 'Осин Р.В.'},
#  2: {'Председатель': 'Сапунов К.В.',
#   'Заместитель председателя': 'Попов Л.А.',
#   'Секретарь': 'Тропин А.М.',
#   'Представитель в Учёном совете мехмата': 'Владыкина В.Е.',
#   'Представитель в Студсовете МГУ': ['Сапунов К.В.', 'Тропин А.М.'],
#   'Заместитель представителей в Студсовете МГУ': ['Осин Р.В.', 'Ватутин К.А.'],
#   'Бытовые вопросы': 'Котляров Н.В.',
#   'Образование': 'Владыкина В.Е.',
#   'Спорт и праздники': 'Тен А.Б.',
#   'Оповещение': 'Матвеев Д.А.',
#   'Трудоустройство': 'Осин Р.В.'},
#  1: {'Председатель': 'Котляров Н.В.',
#   'Заместитель председателя': 'Асташов Д.С.',
#   'Секретарь': 'Тропин А.М.',
#   'Представитель в Учёном совете мехмата': 'Владыкина В.Е.',
#   'Представитель в Студсовете МГУ': ['Котляров Н.В.', 'Савушкин Н.М.'],
#   'Заместитель представителей в Студсовете МГУ': ['Тропин А.М.',
#    'Владыкина В.Е.'],
#   'Бытовые вопросы': 'Котляров Н.В.',
#   'Образование': 'Владыкина В.Е.',
#   'Спорт и праздники': 'Попов Л.А.',
#   'Оповещение': 'Сапунов К.В.',
#   'Трудоустройство': 'Коновалов А.А.',
#   'Разработка Устава и Положения': 'Тропин А.М.'}}

# %%
# добавить 11 созыв:
# https://vk.com/wall-33327655_10064
# https://vk.com/wall-33327655_10092

def text_by_link(link):
    req_link = requests.get(link)
    html_doc = req_link.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    wi_body = soup.find('div', attrs={'class': 'wi_body'})
    pi_text = wi_body.find('div', attrs={'class': 'pi_text'})

    conv_11_dict = {}
    flg = 0

    for s in pi_text.stripped_strings:
        if '—' in s:
            position = replace_position(s[:s.index('—')].strip())
            flg = 1
        elif '–' in s:
            position = replace_position(s[:s.index('–')].strip())
            flg = 1
        elif flg == 1:
            conv_11_dict[position] = s
            flg = 0
    return conv_11_dict

conv_11_dict = {**text_by_link('https://vk.com/wall-33327655_10064'), **text_by_link('https://vk.com/wall-33327655_10092')}
conv_11_dict
# Out:
# {'Председатель': 'Георгий Малиновский',
#  'Заместитель председателя': 'Кирилл Дехнич',
#  'Секретарь': 'Дарья Мельникова',
#  'Первый представитель в Студсовете МГУ': 'Кирилл Дехнич',
#  'Второй представитель в Студсовете МГУ': 'Петр Третьяков',
#  'Представитель в Учёном совете мехмата': 'Вячеслав Чуб',
#  'Бытовые вопросы': 'Макар Приходко',
#  'Образование': 'Никита Лоншаков',
#  'Оповещение': 'Екатерина Алёшечкина',
#  'Праздники': 'Анастасия Манахова',
#  'Спорт': 'Екатерина Шевченко'}

# %%
# заполнить пробелы:

managemant_dict[4]['Распределение стипендий'] = 'Матвеев Д.А.'
managemant_dict[5]['Распределение стипендий'] = 'Подкользина Е.Б.'
managemant_dict[6]['Распределение стипендий'] = 'Глунчадзе И.В.'
managemant_dict[7]['Распределение стипендий'] = '???'
managemant_dict[8]['Работа с партнёрами'] = '???'
managemant_dict[9]['Спорт'] = '???'

# managemant_dict[11] = {}
# for key in conv_11_dict.keys():
#     managemant_dict[11][key] = conv_11_dict[key]

# %%
managemant_df =  pd.DataFrame(managemant_dict.items(), columns=['convocation_no', 'params'])
managemant_df_2 = pd.concat([managemant_df.drop(['params'], axis=1), managemant_df['params'].apply(pd.Series)], axis=1)
# managemant_df_2 = managemant_df_2.drop([8],axis=0)
managemant_df_2[['Первый представитель в Студсовете МГУ','Второй представитель в Студсовете МГУ']] = pd.DataFrame(managemant_df_2['Представитель в Студсовете МГУ'].tolist(), index= managemant_df_2.index)
managemant_df_2 = managemant_df_2.drop(['Представитель в Студсовете МГУ'], axis=1)
managemant_df_2 = managemant_df_2.sort_values(['convocation_no'],
              ascending = [True]).reset_index().drop(['index'], axis=1)

managemant_df_2
# Out:
#    convocation_no      Председатель Заместитель председателя  \
# 0               1     Котляров Н.В.             Асташов Д.С.
# 1               2      Сапунов К.В.               Попов Л.А.
# 2               3      Матвеев А.В.          Быстрицкая В.В.
# 3               4    Глунчадзе И.В.          Быстрицкая В.В.
# 4               5   Бекбулатов Р.Л.             Денисов И.О.
# 5               6      Денисов И.О.          Бекбулатов Р.Л.
# 6               7   Тонконогов А.В.             Сенотов В.Д.
# 7               8      Сенотов В.Д.              Хахова М.А.
# 8               9        Клюев А.И.           Фенелонов Д.И.
# 9              10  Малиновский Г.А.              Шишков А.А.
#
#           Секретарь Заместитель представителей в Студсовете МГУ  \
# 0       Тропин А.М.               [Тропин А.М., Владыкина В.Е.]
# 1       Тропин А.М.                   [Осин Р.В., Ватутин К.А.]
# 2      Дяченко М.И.                   [Осин Р.В., Ватутин К.А.]
# 3      Дяченко М.И.                [Митькина М.А., Шведов К.А.]
# 4        Савин П.А.                [Морозов С.С., Суркова А.Ю.]
# 5      Чернова А.А.                  [Семенюк П. И., Корж Д.С.]
# 6      Кудасов М.Д.                   [Сенотов В.Д., Корж Д.С.]
# 7  Малиновский Г.А.             [Тонконогов А.В., Малахов Н.С.]
# 8       Попова А.Р.                              [Малахов Н.С.]
# 9   Мельникова Д.В.              [Кухарчук И.А., Скурихин Д.А.]
#
#   Представитель в Учёном совете мехмата Бытовые вопросы     Образование  \
# 0                        Владыкина В.Е.   Котляров Н.В.  Владыкина В.Е.
# 1                        Владыкина В.Е.   Котляров Н.В.  Владыкина В.Е.
# 2                                   NaN             NaN  Медведева Я.Г.
# 3                                   NaN    Денисов И.О.      Савин П.А.
# 4                                   NaN    Денисов И.О.      Савин П.А.
# 5                                   NaN    Авилова Е.М.   Нагорных Я.И.
# 6                                   NaN       Корж Д.С.  Воробьева Н.Д.
# 7                                   NaN       Корж Д.С.  Промыслов П.В.
# 8                        Третьяков П.М.  Фенелонов Д.И.    Саметов М.А.
# 9                            Клюев А.И.     Дехнич К.А.   Кухарчук И.А.
#
#          Оповещение            Спорт  ...     Связи Распределение стипендий  \
# 0      Сапунов К.В.              NaN  ...       NaN                     NaN
# 1      Матвеев Д.А.              NaN  ...       NaN                     NaN
# 2      Матвеев Д.А.     Антонов С.В.  ...       NaN                     NaN
# 3   Бекбулатов Р.Л.      Шведов К.А.  ...       NaN            Матвеев Д.А.
# 4    Глунчадзе И.В.     Семенюк П.И.  ...       NaN        Подкользина Е.Б.
# 5       Саакян В.Р.     Семенюк П.И.  ...       NaN          Глунчадзе И.В.
# 6      Сенотов В.Д.     Малахов Н.С.  ...       NaN                     ???
# 7     Краснова А.А.     Малахов Н.С.  ...       NaN           Кухарчук И.А.
# 8  Малиновский Г.А.              ???  ...       NaN           Кухарчук И.А.
# 9    Третьяков П.М.  Евдокимова С.А.  ...  Чуб В.В.             Шишков А.А.
#
#   Работа с партнёрами Бытовые вопросы (сектор "А", экология)  \
# 0                 NaN                                    NaN
# 1                 NaN                                    NaN
# 2           Осин Р.В.                          Митькина М.А.
# 3         Тюрина Т.И.                                    NaN
# 4         Тюрина Т.И.                                    NaN
# 5     Тонконогов А.В.                                    NaN
# 6      Змиевский Л.В.                                    NaN
# 7                 ???                                    NaN
# 8                 NaN                                    NaN
# 9                 NaN                                    NaN
#
#   Проблемы общежитий (сектор "Б", ФДС) Спорт и праздники Трудоустройство  \
# 0                                  NaN        Попов Л.А.  Коновалов А.А.
# 1                                  NaN          Тен А.Б.       Осин Р.В.
# 2                        Короткин В.В.               NaN             NaN
# 3                                  NaN               NaN             NaN
# 4                                  NaN               NaN             NaN
# 5                                  NaN               NaN             NaN
# 6                                  NaN               NaN             NaN
# 7                                  NaN               NaN             NaN
# 8                                  NaN               NaN             NaN
# 9                                  NaN               NaN             NaN
#
#   Разработка Устава и Положения Первый представитель в Студсовете МГУ  \
# 0                   Тропин А.М.                         Котляров Н.В.
# 1                           NaN                          Сапунов К.В.
# 2                           NaN                          Матвеев А.В.
# 3                           NaN                        Глунчадзе И.В.
# 4                           NaN                       Бекбулатов Р.Л.
# 5                           NaN                          Денисов И.О.
# 6                           NaN                       Тонконогов А.В.
# 7                           NaN                          Сенотов В.Д.
# 8                           NaN                            Клюев А.И.
# 9                           NaN                         Сулейкин А.О.
#
#   Второй представитель в Студсовете МГУ
# 0                         Савушкин Н.М.
# 1                           Тропин А.М.
# 2                          Сапунов К.В.
# 3                          Матвеев А.В.
# 4                           Шведов К.А.
# 5                       Бекбулатов Р.Л.
# 6                          Денисов И.О.
# 7                          Денисов И.О.
# 8                         Кухарчук И.А.
# 9                        Третьяков П.М.
#
# [10 rows x 21 columns]

# %%
# position_names = sorted(list(managemant_df_2))
# position_names

# original list:
# 'Бытовые вопросы',
#  'Бытовые вопросы (ГЗ А, Б, Г, Е, ДСЛ, ФДС, экология)',
#  'Бытовые вопросы (сектор "А", экология)',
#  'Бытовые вопросы (сектора «А» и «Б», ФДС, экология)',
#  'Заместители представителей',
#  'Заместитель председателя',
#  'Образование',
#  'Оповещение',
#  'Праздники',
#  'Председатель',
#  'Представители в Студсовет МГУ',
#  'Представители в Студсовете МГУ',
#  'Представитель в Учёном совете',
#  'Представитель в Учёный совет мехмата',
#  'Проблемы общежитий (сектор "Б", ФДС)',
#  'Работа с партнёрами',
#  'Разработка Устава и Положения',
#  'Распределение стипендий',
#  'Связи',
#  'Секретарь',
#  'Спорт',
#  'Спорт и праздники',
#  'Трудоустройство'

# %%
'''
ПЛАН РАБОТ:
- заполнить пробелы в 1-10 созывах (спорт-9, партнеры-8, стипендии-7)
- добавить 11 созыв из постов
- заменить имена членов на полные
- развернуть таблицу
- составить словарик должностей руководства
- составить словарик названий рабочих групп
'''

# %%
# table_MN = pd.read_html(menu_dict['10 состав — ноябрь 2020'], match='wk_table')
# df = table_MN[0]
# df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 table_MN = pd.read_html(menu_dict['10 состав — ноябрь 2020'], match='wk_table')
#       2 df = table_MN[0]
#       3 df
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913 retained = None
#     914 for flav in flavor:
# --> 915     parser = _parser_dispatch(flav)
#     916     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918     try:
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/io/html.py:872, in _parser_dispatch(flavor)
#     870 else:
#     871     if not _HAS_LXML:
# --> 872         raise ImportError("lxml not found, please install it")
#     873 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it
