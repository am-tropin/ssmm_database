# %%
'''
БАГИ:
- научиться тянуть время коммента (реплая) - НЕТ ТАКОЙ ИНФЫ 
(можно прописать руками для 2-3 комментов, взяв время между дат соседних постов)
'''

# %%
import pandas as pd

# %%
# https://docs.python.org/3/library/datetime.html

from datetime import datetime, date, time

# поле дата-время по полям даты и времени
def dttm_by_date_time(link_date, link_time):
    link_dt = datetime.fromisoformat(link_date)
    if link_time in [None, '']:
        link_time_list = [23,59]
    else:
        link_time_list = list(map(int, link_time.split(':')))
    return datetime.combine(link_dt, time(link_time_list[0], link_time_list[1]))

# link_date = date(2012, 3, 7)
link_date = '2012-03-07'
link_time = '20:55'
link_dttm = dttm_by_date_time(link_date, link_time)
link_dttm
# Out:
# datetime.datetime(2012, 3, 7, 20, 55)

# %% [markdown]
# # 1. To fix CANDIDATE tables

# %%
candidates_conv_1_3 = pd.read_csv('ssmm_candidates_info_conv_1_3.csv', sep='\t', encoding='utf-8')
candidates_conv_1_3 = candidates_conv_1_3[['name','convocation_no','year_stream_no','year_no','stream_no','academic_group_no','program_txt','link_date','link_time','link']]

candidates_conv_1_3
# Out:
#                               name  convocation_no year_stream_no  year_no  \
# 0                     Левин Андрей               1            1.1        1
# 1    Матвеев Дмитрий Александрович               1            1.1        1
# 2           Власов Артем Андреевич               1            1.2        1
# 3                 Кириллова Полина               1            1.2        1
# 4                    Семенов Павел               1            1.2        1
# ..                             ...             ...            ...      ...
# 126    Сапунов Кирилл Вячеславович               3            5.3        5
# 127  Самонов Алексей Александрович               3            5.3        5
# 128  Короткин Виталий Владимирович               3             m1        1
# 129           Буряк Анна Андреевна               3             m1        1
# 130       Морозов Сергей Сергеевич               3             m2        2
#
#      stream_no  academic_group_no  \
# 0            1              101.0
# 1            1              101.0
# 2            2              107.0
# 3            2              112.0
# 4            2              112.0
# ..         ...                ...
# 126          3              525.0
# 127          3              526.0
# 128          0                NaN
# 129          0                NaN
# 130          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 126                                                NaN  2013-11-17     14:21
# 127  "Я студент 5 курса, есть опыт в организации ра...  2013-11-17     14:21
# 128  "с сентября 2012-н.в. являюсь председателем СК...  2013-11-17     14:16
# 129  "Состояла в студсовете в 2010-2011 годах, на п...  2013-11-17     14:16
# 130                                                NaN  2013-11-17     14:13
#
#                                        link
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 126  https://vk.com/topic-33327655_29117817
# 127  https://vk.com/topic-33327655_29117817
# 128  https://vk.com/topic-33327655_29117788
# 129  https://vk.com/topic-33327655_29117788
# 130  https://vk.com/topic-33327655_29117770
#
# [131 rows x 10 columns]

# %%
ssmm_announcements_conv_4_11 = pd.read_csv('ssmm_announcement_info_conv_4_11.csv', sep='\t', encoding='utf-8')
# ssmm_announcements_conv_4_11.head()

# %%
def conv_no_by_year(year):
    if year >= 2013:
        return year-2010
    else:
        return -1

candidates_conv_4_11 = pd.read_csv('ssmm_candidates_info_conv_4_11.csv', sep='\t', encoding='utf-8')
candidates_conv_4_11['convocation_no'] = candidates_conv_4_11['link_year_no'].apply(lambda x: conv_no_by_year(x))
candidates_conv_4_11 = candidates_conv_4_11.merge(ssmm_announcements_conv_4_11[['link','link_date','link_time']], left_on='link',right_on='link',how='left')
candidates_conv_4_11 = candidates_conv_4_11[['name','convocation_no','year_stream_no','year_no','stream_no','academic_group_no','program_txt','link_date','link_time','link']]

candidates_conv_4_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0               Суркова Анастасия Юрьевна               4            2.2
# 1                   Денисов Илья Олегович               4            2.2
# 2                 Тюрина Татьяна Игоревна               4            2.2
# 3               Дорман Елена Вячеславовна               4            2.3
# 4              Оськин Александр Андреевич               4            2.3
# ..                                    ...             ...            ...
# 385              Терехов Михаил Сергеевич              11            6.1
# 386       Поликарпов Александр Валерьевич              11            6.3
# 387            Каляев Тимур Джанбулатович              11             m1
# 388  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 389       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          2          2              209.0
# 1          2          2              207.0
# 2          2          2              209.0
# 3          2          3              226.0
# 4          2          3              225.0
# ..       ...        ...                ...
# 385        6          1              602.0
# 386        6          3              621.0
# 387        1          0                NaN
# 388        1          0                NaN
# 389        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    «Подавая заявку в прошлом году в студсовет, яв...  2014-11-13     21:39
# 1    «Вечер добрый, коллеги!\nЯ бы хотел подать зая...  2014-11-13     21:39
# 2    «Уже во второй раз избираюсь в студенческий со...  2014-11-13     21:39
# 3    «По моему мнению, за прошедший год я не плохо ...  2014-11-13     21:40
# 4    «Прежде всего здравствуйте:)\nНа протяжении по...  2014-11-13     21:40
# ..                                                 ...         ...       ...
# 385                                         За правду!  2021-10-16     10:25
# 386  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 387  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 388  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 389  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                   link
# 0    https://vk.com/wall-33327655_2202
# 1    https://vk.com/wall-33327655_2202
# 2    https://vk.com/wall-33327655_2202
# 3    https://vk.com/wall-33327655_2203
# 4    https://vk.com/wall-33327655_2203
# ..                                 ...
# 385  https://vk.com/wall-33327655_9978
# 386  https://vk.com/wall-33327655_9982
# 387  https://vk.com/wall-33327655_9983
# 388  https://vk.com/wall-33327655_9983
# 389  https://vk.com/wall-33327655_9983
#
# [390 rows x 10 columns]

# %%
list_of_df = [candidates_conv_1_3,candidates_conv_4_11]
candidates_conv_1_11 = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
candidates_conv_1_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0                            Левин Андрей               1            1.1
# 1           Матвеев Дмитрий Александрович               1            1.1
# 2                  Власов Артем Андреевич               1            1.2
# 3                        Кириллова Полина               1            1.2
# 4                           Семенов Павел               1            1.2
# ..                                    ...             ...            ...
# 516              Терехов Михаил Сергеевич              11            6.1
# 517       Поликарпов Александр Валерьевич              11            6.3
# 518            Каляев Тимур Джанбулатович              11             m1
# 519  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 520       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          1          1              101.0
# 1          1          1              101.0
# 2          1          2              107.0
# 3          1          2              112.0
# 4          1          2              112.0
# ..       ...        ...                ...
# 516        6          1              602.0
# 517        6          3              621.0
# 518        1          0                NaN
# 519        1          0                NaN
# 520        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 516                                         За правду!  2021-10-16     10:25
# 517  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 518  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 519  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 520  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                        link
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 516       https://vk.com/wall-33327655_9978
# 517       https://vk.com/wall-33327655_9982
# 518       https://vk.com/wall-33327655_9983
# 519       https://vk.com/wall-33327655_9983
# 520       https://vk.com/wall-33327655_9983
#
# [521 rows x 10 columns]

# %%
def key_by_2_fields(f1, f2):
    return str(f1)+'_'+'_'.join(str(f2).split())

# %%
candidates_conv_1_11['conv_x_name'] = candidates_conv_1_11.apply(lambda x: key_by_2_fields(x['convocation_no'],x['name']), axis=1)

candidates_conv_1_11 = candidates_conv_1_11.fillna(value={'link_time': '23:59'})
candidates_conv_1_11['link_dttm'] = candidates_conv_1_11.apply(lambda x: dttm_by_date_time(x['link_date'],str(x['link_time'])), axis=1)
candidates_conv_1_11 = candidates_conv_1_11.drop_duplicates()
candidates_conv_1_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0                            Левин Андрей               1            1.1
# 1           Матвеев Дмитрий Александрович               1            1.1
# 2                  Власов Артем Андреевич               1            1.2
# 3                        Кириллова Полина               1            1.2
# 4                           Семенов Павел               1            1.2
# ..                                    ...             ...            ...
# 516              Терехов Михаил Сергеевич              11            6.1
# 517       Поликарпов Александр Валерьевич              11            6.3
# 518            Каляев Тимур Джанбулатович              11             m1
# 519  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 520       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          1          1              101.0
# 1          1          1              101.0
# 2          1          2              107.0
# 3          1          2              112.0
# 4          1          2              112.0
# ..       ...        ...                ...
# 516        6          1              602.0
# 517        6          3              621.0
# 518        1          0                NaN
# 519        1          0                NaN
# 520        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 516                                         За правду!  2021-10-16     10:25
# 517  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 518  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 519  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 520  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                        link  \
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 516       https://vk.com/wall-33327655_9978
# 517       https://vk.com/wall-33327655_9982
# 518       https://vk.com/wall-33327655_9983
# 519       https://vk.com/wall-33327655_9983
# 520       https://vk.com/wall-33327655_9983
#
#                                  conv_x_name           link_dttm
# 0                             1_Левин_Андрей 2012-02-26 00:16:00
# 1            1_Матвеев_Дмитрий_Александрович 2012-02-26 00:16:00
# 2                   1_Власов_Артем_Андреевич 2012-02-26 00:16:00
# 3                         1_Кириллова_Полина 2012-02-26 00:16:00
# 4                            1_Семенов_Павел 2012-02-26 00:16:00
# ..                                       ...                 ...
# 516              11_Терехов_Михаил_Сергеевич 2021-10-16 10:25:00
# 517       11_Поликарпов_Александр_Валерьевич 2021-10-16 10:50:00
# 518            11_Каляев_Тимур_Джанбулатович 2021-10-16 11:20:00
# 519  11_Маммагаджиев_Руслан_Гаджимагомедович 2021-10-16 11:20:00
# 520       11_Третьякова_Екатерина_Алексеевна 2021-10-16 11:20:00
#
# [521 rows x 12 columns]

# %%
candidates_conv_1_11.to_csv('ssmm_candidates_info_conv_1_11.csv', sep='\t', encoding='utf-8', index=False)
# candidates_conv_1_11.to_csv('../library: main/ssmm_candidates_info_conv_1_11.csv', sep='\t', encoding='utf-8', index=False)

# ПЕРВАЯ ГЛАВНАЯ ТАБЛИЦА

# %% [markdown]
# # 2. To fix VOTES tables

# %%
ssmm_votes_conv_1 = pd.read_csv('ssmm_votes_info_conv_1.csv', sep='\t', encoding='utf-8')
ssmm_votes_conv_2 = pd.read_csv('ssmm_votes_info_conv_2.csv', sep='\t', encoding='utf-8')
ssmm_votes_conv_3 = pd.read_csv('ssmm_votes_info_conv_3.csv', sep='\t', encoding='utf-8')
ssmm_votes_conv_4_11 = pd.read_csv('ssmm_votes_info_conv_4_11.csv', sep='\t', encoding='utf-8')

# %%
# ssmm_votes_conv_4_11.head()

# %%
ssmm_results_conv_4_11 = pd.read_csv('ssmm_results_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_results_conv_4_11.head()
# Out:
#                                 link year_x_year_stream   link_date  \
# 0  https://vk.com/wall-33327655_2250           2014_1.1  2014-11-21
# 1  https://vk.com/wall-33327655_2252           2014_1.2  2014-11-21
# 2  https://vk.com/wall-33327655_2254           2014_1.3  2014-11-21
# 3  https://vk.com/wall-33327655_2329           2014_2.1  2014-11-27
# 4  https://vk.com/wall-33327655_2215           2014_2.2  2014-11-17
#
#    link_year_no  link_month_no  link_day_no link_time year_stream_no  year_no  \
# 0          2014             11           21     22:15            1.1        1
# 1          2014             11           21     22:25            1.2        1
# 2          2014             11           21     22:35            1.3        1
# 3          2014             11           27     23:15            2.1        2
# 4          2014             11           17     21:06            2.2        2
#
#    stream_no  stream_size  voted_cnt  invalid_cnt  NOTA_cnt  \
# 0          1          166        129           10         5
# 1          2          136         95            4         6
# 2          3          138         83            1         2
# 3          1          135         89            1         1
# 4          2          135         87            0         7
#
#                                       organizers
# 0     ['Ильёй Денисовым', 'Анастасией Сурковой']
# 1  ['Ираклием Глунчадзе', 'Анастасией Сурковой']
# 2  ['Ираклием Глунчадзе', 'Анастасией Савченко']
# 3  ['Ираклием Глунчадзе', 'Анастасией Сурковой']
# 4                         ['Глунчадзе Ираклием']

# %%
ssmm_votes_conv_1.head()

temp_df = ssmm_votes_conv_1

temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg','link_date','link_time','link']] # , 'link'
temp_votes_conv_1 = temp_df

temp_votes_conv_1.head()
# Out:
#    convocation_no                           name  year_stream_no  votes_cnt  \
# 0               1  Матвеев Дмитрий Александрович             1.1       49.0
# 1               1                   Левин Андрей             1.1       48.0
# 2               1               Кириллова Полина             1.2       40.0
# 3               1         Власов Артем Андреевич             1.2       36.0
# 4               1                Кузнецова Алёна             1.2       28.0
#
#    elected_flg   link_date link_time                                    link
# 0          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953

# %%
def full_name_by_short_name1(short_name):
#     ЗАВИСИТ ОТ ВНЕШНЕЙ ТАБЛИЦЫ candidates_conv_1_11
    names_conv3 = list(candidates_conv_1_11['name'][candidates_conv_1_11['convocation_no']==1])
    for full_name in names_conv3:
        if short_name in full_name:
            return full_name

temp_df = temp_votes_conv_1
temp_df['full_name'] = temp_df['name'].apply(lambda x: full_name_by_short_name1(x))
temp_df['max_name'] = temp_df['full_name'].combine_first(temp_df['name'])
temp_df = temp_df.drop(['full_name','name'],axis=1).rename(columns={'max_name':'name'})
# temp_df[:20]

temp_votes_conv_1_upd = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg','link_date','link_time','link']] # , 'link'
temp_votes_conv_1_upd.head()
# Out:
# /var/folders/zh/mnvg84rj3_7413ycjzpn5y8r0000gp/T/ipykernel_81187/1272966670.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['full_name'] = temp_df['name'].apply(lambda x: full_name_by_short_name1(x))
# /var/folders/zh/mnvg84rj3_7413ycjzpn5y8r0000gp/T/ipykernel_81187/1272966670.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['max_name'] = temp_df['full_name'].combine_first(temp_df['name'])
#    convocation_no                           name  year_stream_no  votes_cnt  \
# 0               1  Матвеев Дмитрий Александрович             1.1       49.0
# 1               1                   Левин Андрей             1.1       48.0
# 2               1               Кириллова Полина             1.2       40.0
# 3               1         Власов Артем Андреевич             1.2       36.0
# 4               1                Кузнецова Алёна             1.2       28.0
#
#    elected_flg   link_date link_time                                    link
# 0          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953

# %%
# ssmm_votes_conv_2.head()

temp_df = ssmm_votes_conv_2

temp_df['votes_cnt'] = temp_df.apply(lambda x: None)
temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]
temp_votes_conv_2 = temp_df

temp_votes_conv_2.head()
# Out:
#    convocation_no                             name year_stream_no votes_cnt  \
# 0               2  Остроухова Наталья Владимировна            1.1       NaN
# 1               2      Габидов Александр Сергеевич            1.1       NaN
# 2               2           Дяченко Мария Игоревна            1.1       NaN
# 3               2     Ватутин Кирилл Александрович            1.3       NaN
# 4               2        Никифоров Сергей Игоревич            1.3       NaN
#
#    elected_flg   link_date link_time                              link
# 0            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 1            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 2            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 3            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 4            1  2012-11-19     16:13  https://vk.com/wall-33327655_725

# %%
# ssmm_votes_conv_3.head()

temp_df = ssmm_votes_conv_3

temp_df['votes_cnt'] = temp_df.apply(lambda x: None)
temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]
temp_votes_conv_3 = temp_df

temp_votes_conv_3.head()
# Out:
#    convocation_no       name year_stream_no votes_cnt  elected_flg  \
# 0               3  Алекберов            1.1       NaN            1
# 1               3     Бурнус            1.1       NaN            1
# 2               3    Денисов            1.2       NaN            1
# 3               3    Суркова            1.2       NaN            1
# 4               3     Тюрина            1.2       NaN            1
#
#     link_date link_time                               link
# 0  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 1  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 2  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 3  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 4  2013-12-10      1:46  https://vk.com/wall-33327655_1600

# %%
def full_name_by_short_name3(short_name):
#     ЗАВИСИТ ОТ ВНЕШНЕЙ ТАБЛИЦЫ candidates_conv_1_11
    names_conv3 = list(candidates_conv_1_11['name'][candidates_conv_1_11['convocation_no']==3])
    for full_name in names_conv3:
        if short_name in full_name:
            return full_name

temp_votes_conv_3_upd = temp_votes_conv_3
temp_votes_conv_3_upd['full_name'] = temp_votes_conv_3_upd['name'].apply(lambda x: full_name_by_short_name3(x))
temp_votes_conv_3_upd['max_name'] = temp_votes_conv_3_upd['full_name'].combine_first(temp_votes_conv_3_upd['name'])
temp_votes_conv_3_upd = temp_votes_conv_3_upd[['convocation_no', 'max_name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']].rename(columns={'max_name':'name'})
temp_votes_conv_3_upd.head()
# Out:
# /var/folders/zh/mnvg84rj3_7413ycjzpn5y8r0000gp/T/ipykernel_81187/4129198660.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_votes_conv_3_upd['full_name'] = temp_votes_conv_3_upd['name'].apply(lambda x: full_name_by_short_name3(x))
#    convocation_no                       name year_stream_no votes_cnt  \
# 0               3                  Алекберов            1.1       NaN
# 1               3  Бурнус Артём Владимирович            1.1       NaN
# 2               3      Денисов Илья Олегович            1.2       NaN
# 3               3  Суркова Анастасия Юрьевна            1.2       NaN
# 4               3    Тюрина Татьяна Игоревна            1.2       NaN
#
#    elected_flg   link_date link_time                               link
# 0            1  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 1            1  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 2            1  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 3            1  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 4            1  2013-12-10      1:46  https://vk.com/wall-33327655_1600

# %%
list_of_df = [temp_votes_conv_1_upd,temp_votes_conv_2,temp_votes_conv_3_upd]
temp_votes_conv_1_3 = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
temp_votes_conv_1_3 = temp_votes_conv_1_3[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]

final_votes_conv_1_3 = temp_votes_conv_1_3
final_votes_conv_1_3.head()
# Out:
#    convocation_no                           name year_stream_no votes_cnt  \
# 0               1  Матвеев Дмитрий Александрович            1.1      49.0
# 1               1                   Левин Андрей            1.1      48.0
# 2               1               Кириллова Полина            1.2      40.0
# 3               1         Власов Артем Андреевич            1.2      36.0
# 4               1                Кузнецова Алёна            1.2      28.0
#
#    elected_flg   link_date link_time                                    link
# 0          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953

# %%
# reorder

temp_df = ssmm_votes_conv_4_11.merge(ssmm_results_conv_4_11[['link','link_date','link_time']], left_on='link', right_on='link',how='outer')
# temp_df

temp_df['convocation_no'] = temp_df['link_year_no'].apply(lambda x: conv_no_by_year(x))
temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]
final_votes_conv_4_11 = temp_df

final_votes_conv_4_11.head()
# Out:
#    convocation_no                        name year_stream_no  votes_cnt  \
# 0               4   Суркова Анастасия Юрьевна            2.2         53
# 1               4       Денисов Илья Олегович            2.2         61
# 2               4     Тюрина Татьяна Игоревна            2.2         48
# 3               4   Дорман Елена Вячеславовна            2.3         71
# 4               4  Оськин Александр Андреевич            2.3         45
#
#    elected_flg   link_date link_time                               link
# 0            1  2014-11-17     21:06  https://vk.com/wall-33327655_2215
# 1            1  2014-11-17     21:06  https://vk.com/wall-33327655_2215
# 2            1  2014-11-17     21:06  https://vk.com/wall-33327655_2215
# 3            1  2014-11-17     21:21  https://vk.com/wall-33327655_2216
# 4            1  2014-11-17     21:21  https://vk.com/wall-33327655_2216

# %%
list_of_df = [final_votes_conv_1_3,final_votes_conv_4_11]
final_votes_conv_1_11 = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)

final_votes_conv_1_11['conv_x_name'] = final_votes_conv_1_11.apply(lambda x: key_by_2_fields(x['convocation_no'],x['name']), axis=1)

final_votes_conv_1_11 = final_votes_conv_1_11.fillna(value={'link_time': '23:59'})
final_votes_conv_1_11['link_dttm'] = final_votes_conv_1_11.apply(lambda x: dttm_by_date_time(x['link_date'],str(x['link_time'])), axis=1)
final_votes_conv_1_11 = final_votes_conv_1_11.drop_duplicates()

final_votes_conv_1_11
# Out:
#      convocation_no                                  name year_stream_no  \
# 0                 1         Матвеев Дмитрий Александрович            1.1
# 1                 1                          Левин Андрей            1.1
# 2                 1                      Кириллова Полина            1.2
# 3                 1                Власов Артем Андреевич            1.2
# 4                 1                       Кузнецова Алёна            1.2
# ..              ...                                   ...            ...
# 507              11  Маммагаджиев Руслан Гаджимагомедович             m1
# 508              11       Третьякова Екатерина Алексеевна             m1
# 509              11          Мазитова Вероника Рустэмовна            6.1
# 510              11              Терехов Михаил Сергеевич            6.1
# 511              11       Поликарпов Александр Валерьевич            6.3
#
#     votes_cnt  elected_flg   link_date link_time  \
# 0        49.0          1.0  2012-03-07     20:55
# 1        48.0          1.0  2012-03-07     20:55
# 2        40.0          1.0  2012-03-07     20:55
# 3        36.0          1.0  2012-03-07     20:55
# 4        28.0          1.0  2012-03-07     20:55
# ..        ...          ...         ...       ...
# 507        10          1.0  2021-10-20     20:21
# 508        19          1.0  2021-10-20     20:21
# 509        27          1.0  2021-10-21     15:44
# 510        16          1.0  2021-10-21     15:44
# 511        43          1.0  2021-10-21     22:02
#
#                                        link  \
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 507      https://vk.com/wall-33327655_10018
# 508      https://vk.com/wall-33327655_10018
# 509      https://vk.com/wall-33327655_10026
# 510      https://vk.com/wall-33327655_10026
# 511      https://vk.com/wall-33327655_10031
#
#                                  conv_x_name           link_dttm
# 0            1_Матвеев_Дмитрий_Александрович 2012-03-07 20:55:00
# 1                             1_Левин_Андрей 2012-03-07 20:55:00
# 2                         1_Кириллова_Полина 2012-03-07 20:55:00
# 3                   1_Власов_Артем_Андреевич 2012-03-07 20:55:00
# 4                          1_Кузнецова_Алёна 2012-03-07 20:55:00
# ..                                       ...                 ...
# 507  11_Маммагаджиев_Руслан_Гаджимагомедович 2021-10-20 20:21:00
# 508       11_Третьякова_Екатерина_Алексеевна 2021-10-20 20:21:00
# 509          11_Мазитова_Вероника_Рустэмовна 2021-10-21 15:44:00
# 510              11_Терехов_Михаил_Сергеевич 2021-10-21 15:44:00
# 511       11_Поликарпов_Александр_Валерьевич 2021-10-21 22:02:00
#
# [512 rows x 10 columns]

# %%
final_votes_conv_1_11.to_csv('ssmm_votes_info_conv_1_11.csv', sep='\t', encoding='utf-8', index=False)

# ВТОРАЯ ГЛАВНАЯ ТАБЛИЦА

# %% [markdown]
# # 3. To create UNITED CANDIDATE table

# %%
ssmm_candidates_info_conv_1_11 = pd.read_csv('ssmm_candidates_info_conv_1_11.csv', sep='\t', encoding='utf-8')
ssmm_candidates_info_conv_1_11.head()
# Out:
#                             name  convocation_no year_stream_no  year_no  \
# 0                   Левин Андрей               1            1.1        1
# 1  Матвеев Дмитрий Александрович               1            1.1        1
# 2         Власов Артем Андреевич               1            1.2        1
# 3               Кириллова Полина               1            1.2        1
# 4                  Семенов Павел               1            1.2        1
#
#    stream_no  academic_group_no  \
# 0          1              101.0
# 1          1              101.0
# 2          2              107.0
# 3          2              112.0
# 4          2              112.0
#
#                                          program_txt   link_date link_time  \
# 0  Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                NaN  2012-02-26      0:16
# 2                                                NaN  2012-02-26      0:16
# 3  Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4  "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
#
#                                      link                      conv_x_name  \
# 0  https://vk.com/topic-33327655_26089953                   1_Левин_Андрей
# 1  https://vk.com/topic-33327655_26089953  1_Матвеев_Дмитрий_Александрович
# 2  https://vk.com/topic-33327655_26089953         1_Власов_Артем_Андреевич
# 3  https://vk.com/topic-33327655_26089953               1_Кириллова_Полина
# 4  https://vk.com/topic-33327655_26089953                  1_Семенов_Павел
#
#              link_dttm
# 0  2012-02-26 00:16:00
# 1  2012-02-26 00:16:00
# 2  2012-02-26 00:16:00
# 3  2012-02-26 00:16:00
# 4  2012-02-26 00:16:00

# %%
ssmm_votes_info_conv_1_11 = pd.read_csv('ssmm_votes_info_conv_1_11.csv', sep='\t', encoding='utf-8')
ssmm_votes_info_conv_1_11.head()
# Out:
#    convocation_no                           name year_stream_no  votes_cnt  \
# 0               1  Матвеев Дмитрий Александрович            1.1       49.0
# 1               1                   Левин Андрей            1.1       48.0
# 2               1               Кириллова Полина            1.2       40.0
# 3               1         Власов Артем Андреевич            1.2       36.0
# 4               1                Кузнецова Алёна            1.2       28.0
#
#    elected_flg   link_date link_time                                    link  \
# 0          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
#
#                        conv_x_name            link_dttm
# 0  1_Матвеев_Дмитрий_Александрович  2012-03-07 20:55:00
# 1                   1_Левин_Андрей  2012-03-07 20:55:00
# 2               1_Кириллова_Полина  2012-03-07 20:55:00
# 3         1_Власов_Артем_Андреевич  2012-03-07 20:55:00
# 4                1_Кузнецова_Алёна  2012-03-07 20:55:00

# %%
df1 = ssmm_candidates_info_conv_1_11[['conv_x_name','name']]
df2 = ssmm_votes_info_conv_1_11[['conv_x_name','name']]

df1_x_d2 = df1.merge(df2, left_on='conv_x_name', right_on='conv_x_name',how='outer')
df1_x_d2_nan = df1_x_d2[df1_x_d2.isna().any(axis=1)]
df1_x_d2_nan
# Out:
#                             conv_x_name                            name_x  \
# 46       2_Николаева_Наталия_Михайловна      Николаева Наталия Михайловна
# 49            2_Ванунц_Арсений_Ашотович           Ванунц Арсений Ашотович
# 56          2_Медведева_Яна_Григорьевна         Медведева Яна Григорьевна
# 60              2_Сафина_Диана_Ураловна             Сафина Диана Ураловна
# 74       2_Ласкин_Алексей_Александрович      Ласкин Алексей Александрович
# 89            3_Корно_Дмитрий_Сергеевич           Корно Дмитрий Сергеевич
# 90          3_Изимова_Анна_Мирбулатовна         Изимова Анна Мирбулатовна
# 91          3_Чистяков_Михаил_Сергеевич         Чистяков Михаил Сергеевич
# 109     3_Заболотский_Леонид_Дмитриевич     Заболотский Леонид Дмитриевич
# 110    3_Скопинцев_Алексей_Владимирович    Скопинцев Алексей Владимирович
# 262  6_Думаревский_Александр_Дмитриевич  Думаревский Александр Дмитриевич
# 396             9_Воронин_Вадим_Юрьевич             Воронин Вадим Юрьевич
# 521           1_Федорова_Елена_Игоревна                               NaN
# 522                         3_Алекберов                               NaN
# 523           4_Вергазов_Марат_Марсович                               NaN
#
#                       name_y
# 46                       NaN
# 49                       NaN
# 56                       NaN
# 60                       NaN
# 74                       NaN
# 89                       NaN
# 90                       NaN
# 91                       NaN
# 109                      NaN
# 110                      NaN
# 262                      NaN
# 396                      NaN
# 521  Федорова Елена Игоревна
# 522                Алекберов
# 523  Вергазов Марат Марсович

# %%
# ОБЩАЯ ТАБЛИЦА КАНДИДАТОВ С АНОНСАМИ И ГОЛОСАМИ

temp_df = ssmm_candidates_info_conv_1_11[['conv_x_name','name','convocation_no','year_stream_no','academic_group_no','program_txt','link','link_dttm']].merge(ssmm_votes_info_conv_1_11[['conv_x_name','name','convocation_no','year_stream_no','votes_cnt','elected_flg','link','link_dttm']], left_on='conv_x_name',right_on='conv_x_name',how='outer')

for word in ['name','convocation_no','year_stream_no']:
    temp_df[word] = temp_df[word+'_x'].combine_first(temp_df[word+'_y'])
    temp_df = temp_df.drop([word+'_x', word+'_y'],axis=1)

# temp_df['academic_group_no'] = temp_df['academic_group_no'].apply(lambda x: int(x))
temp_df['convocation_no'] = temp_df['convocation_no'].apply(lambda x: int(x))

temp_df = temp_df.rename(columns={'link_x':'announcement_link','link_y':'result_link','link_dttm_x':'announcement_dttm','link_dttm_y':'result_dttm'})
temp_df['appearance_dttm'] = temp_df['announcement_dttm'].combine_first(temp_df['result_dttm'])

# ДОБАВИТЬ elected_flg = 1 для 5 курса 1 созыва
# temp_df['elected_flg'].mask((temp_df['year_stream_no'].apply(lambda x: x[0] == '5')) & (temp_df['convocation_no'] == 1), 1, inplace=True)

temp_df['elected_flg'] = temp_df['elected_flg'].fillna(0)
temp_df['elected_flg'] = temp_df['elected_flg'].apply(lambda x: int(x))
# temp_df['classic_year_no'] = temp_df['year_stream_no'].apply(lambda x: define_classic_year_no(x))
# temp_df['votes_cnt'] = temp_df['votes_cnt'].apply(lambda x: int(x))
# temp_df['elected_flg'] = temp_df['elected_flg'][temp_df['elected_flg'].notna()].astype('int')
# temp_df['votes_cnt'] = temp_df['votes_cnt'][temp_df['votes_cnt'].notna()].astype('int')
# temp_df['votes_cnt'] = temp_df['votes_cnt'].notna().astype('int')
# temp_df['academic_group_no'] = temp_df['academic_group_no'].notna().astype('int')

ssmm_candidates_x_votes_info_conv_1_11 = temp_df[['conv_x_name','name','convocation_no','year_stream_no','academic_group_no','program_txt','announcement_link','announcement_dttm','votes_cnt','elected_flg','result_link','result_dttm','appearance_dttm']].drop_duplicates()
ssmm_candidates_x_votes_info_conv_1_11
# Out:
#                                  conv_x_name  \
# 0                             1_Левин_Андрей
# 1            1_Матвеев_Дмитрий_Александрович
# 2                   1_Власов_Артем_Андреевич
# 3                         1_Кириллова_Полина
# 4                            1_Семенов_Павел
# ..                                       ...
# 519  11_Маммагаджиев_Руслан_Гаджимагомедович
# 520       11_Третьякова_Екатерина_Алексеевна
# 521                1_Федорова_Елена_Игоревна
# 522                              3_Алекберов
# 523                4_Вергазов_Марат_Марсович
#
#                                      name  convocation_no year_stream_no  \
# 0                            Левин Андрей               1            1.1
# 1           Матвеев Дмитрий Александрович               1            1.1
# 2                  Власов Артем Андреевич               1            1.2
# 3                        Кириллова Полина               1            1.2
# 4                           Семенов Павел               1            1.2
# ..                                    ...             ...            ...
# 519  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 520       Третьякова Екатерина Алексеевна              11             m1
# 521               Федорова Елена Игоревна               1            4.4
# 522                             Алекберов               3            1.1
# 523               Вергазов Марат Марсович               4             m2
#
#      academic_group_no                                        program_txt  \
# 0                101.0  Активный участник и организатор различных меро...
# 1                101.0                                                NaN
# 2                107.0                                                NaN
# 3                112.0  Мне нравится заниматься общественной деятельно...
# 4                112.0  "Здравствуйте. Я так понимаю, что я уже поздно...
# ..                 ...                                                ...
# 519                NaN  Долгое время был пикчером профкома мехмата. Се...
# 520                NaN  Я как человек с немалым опытом в делах организ...
# 521                NaN                                                NaN
# 522                NaN                                                NaN
# 523                NaN                                                NaN
#
#                           announcement_link    announcement_dttm  votes_cnt  \
# 0    https://vk.com/topic-33327655_26089953  2012-02-26 00:16:00       48.0
# 1    https://vk.com/topic-33327655_26089953  2012-02-26 00:16:00       49.0
# 2    https://vk.com/topic-33327655_26089953  2012-02-26 00:16:00       36.0
# 3    https://vk.com/topic-33327655_26089953  2012-02-26 00:16:00       40.0
# 4    https://vk.com/topic-33327655_26089953  2012-02-26 00:16:00       20.0
# ..                                      ...                  ...        ...
# 519       https://vk.com/wall-33327655_9983  2021-10-16 11:20:00       10.0
# 520       https://vk.com/wall-33327655_9983  2021-10-16 11:20:00       19.0
# 521                                     NaN                  NaN       20.0
# 522                                     NaN                  NaN        NaN
# 523                                     NaN                  NaN        5.0
#
#      elected_flg                             result_link          result_dttm  \
# 0              1  https://vk.com/topic-33327655_26089953  2012-03-07 20:55:00
# 1              1  https://vk.com/topic-33327655_26089953  2012-03-07 20:55:00
# 2              1  https://vk.com/topic-33327655_26089953  2012-03-07 20:55:00
# 3              1  https://vk.com/topic-33327655_26089953  2012-03-07 20:55:00
# 4              0  https://vk.com/topic-33327655_26089953  2012-03-07 20:55:00
# ..           ...                                     ...                  ...
# 519            1      https://vk.com/wall-33327655_10018  2021-10-20 20:21:00
# 520            1      https://vk.com/wall-33327655_10018  2021-10-20 20:21:00
# 521            1  https://vk.com/topic-33327655_26089874  2012-03-07 18:55:00
# 522            1       https://vk.com/wall-33327655_1600  2013-12-10 01:46:00
# 523            1       https://vk.com/wall-33327655_2313  2014-11-25 23:24:00
#
#          appearance_dttm
# 0    2012-02-26 00:16:00
# 1    2012-02-26 00:16:00
# 2    2012-02-26 00:16:00
# 3    2012-02-26 00:16:00
# 4    2012-02-26 00:16:00
# ..                   ...
# 519  2021-10-16 11:20:00
# 520  2021-10-16 11:20:00
# 521  2012-03-07 18:55:00
# 522  2013-12-10 01:46:00
# 523  2014-11-25 23:24:00
#
# [524 rows x 13 columns]

# %%
ssmm_candidates_x_votes_info_conv_1_11.to_csv('ssmm_candidates_x_votes_info_conv_1_11.csv', sep='\t', encoding='utf-8', index=False)
ssmm_candidates_x_votes_info_conv_1_11.to_csv('../library: main/ssmm_candidates_1_11.csv', sep='\t', encoding='utf-8', index=False)

# САМАЯ ГЛАВНАЯ ТАБЛИЦА

# %% [markdown]
# # 4. To fix ORGANIZER table

# %%
ssmm_organizers_info = pd.read_csv('ssmm_organizers_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_organizers_info.head()
# Out:
#   year_x_year_stream           organizers
# 0           2014_1.1      Ильёй Денисовым
# 1           2014_1.1  Анастасией Сурковой
# 2           2014_1.2   Ираклием Глунчадзе
# 3           2014_1.2  Анастасией Сурковой
# 4           2014_1.3   Ираклием Глунчадзе

# %%
def find_organizer_origin(organizer_name):
#     ИСПОЛЬЗУЕТСЯ ВНЕШНЯЯ ТАБЛИЦА ssmm_candidates_x_votes_info_conv_1_11
    full_name_list = list(ssmm_candidates_x_votes_info_conv_1_11['name'])
    organizer_name = organizer_name.replace('Воробьевой Наталией','Воробьёвой Натальей')
    organizer_name_list = [word.replace('Павлом','Павел').replace('Корней','Провидухина')[:-2].replace('Петр','Пётр') for word in organizer_name.split()]
#     print(organizer_name_list)
    correct_full_name = None
    for full_name in full_name_list:
        k = 0
        for word in organizer_name_list:
            if word in full_name:
                k += 1
        if k == len(organizer_name_list):
            correct_full_name = full_name
            break
    return correct_full_name

# organizer_name = 'Анастасией Сурковой'
# find_organizer_origin(organizer_name)

# %%
ssmm_organizers_info_names = ssmm_organizers_info.groupby(['organizers']).agg({'year_x_year_stream':'count'}).reset_index().rename(columns={'year_x_year_stream':'elections_cnt'}).sort_values(['elections_cnt'],
              ascending = [False]).reset_index().drop(['index'], axis=1)

ssmm_organizers_info_names['full_name'] = ssmm_organizers_info_names['organizers'].apply(lambda x: find_organizer_origin(x))
# ssmm_organizers_info_names[:60]
# ssmm_organizers_info_names[60:]

# баг распознавания в organizers (костыльно преодолен):
# Владиславом Бун

# %%
ssmm_organizers_info_upd = ssmm_organizers_info.merge(ssmm_organizers_info_names[['organizers','full_name']],left_on='organizers',right_on='organizers',how='left').rename(columns={'full_name':'organizer_name'}).drop(['organizers'],axis=1)
ssmm_organizers_info_upd = ssmm_organizers_info_upd[ssmm_organizers_info_upd['organizer_name'] != None] # не работает

ssmm_organizers_info_upd.head()
# [:60]
# Out:
#   year_x_year_stream                 organizer_name
# 0           2014_1.1          Денисов Илья Олегович
# 1           2014_1.1      Суркова Анастасия Юрьевна
# 2           2014_1.2  Глунчадзе Ираклий Вахтангович
# 3           2014_1.2      Суркова Анастасия Юрьевна
# 4           2014_1.3  Глунчадзе Ираклий Вахтангович

# %%
ssmm_organizers_info_upd.to_csv('ssmm_organizers_info_conv_4_11_upd.csv', sep='\t', encoding='utf-8', index=False)
ssmm_organizers_info_upd.to_csv('../library: main/ssmm_organizers_1_11.csv', sep='\t', encoding='utf-8', index=False)

# %%
# НЕ ХВАТАЕТ СВОДНЫХ ПО ПОТОКАМ:
#     - announcements
#     - results

# %% [markdown]
# # 5. To fix RESULTS table

# %%
ssmm_results_info_conv_4_11 = pd.read_csv('ssmm_results_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_results_info_conv_4_11.head()
# Out:
#    convocation_no year_stream_no  stream_size  voted_cnt  NOTA_cnt  \
# 0               4            1.1          166        129         5
# 1               4            1.2          136         95         6
# 2               4            1.3          138         83         2
# 3               4            2.1          135         89         1
# 4               4            2.2          135         87         7
#
#    invalid_cnt                               link   link_date link_time
# 0           10  https://vk.com/wall-33327655_2250  2014-11-21     22:15
# 1            4  https://vk.com/wall-33327655_2252  2014-11-21     22:25
# 2            1  https://vk.com/wall-33327655_2254  2014-11-21     22:35
# 3            1  https://vk.com/wall-33327655_2329  2014-11-27     23:15
# 4            0  https://vk.com/wall-33327655_2215  2014-11-17     21:06

# %%
ssmm_results_info_conv_1 = pd.read_csv('ssmm_results_info_conv_1.csv', sep='\t', encoding='utf-8')
ssmm_results_info_conv_1.head()
# Out:
#    convocation_no  year_stream_no  stream_size  voted_cnt  NOTA_cnt  \
# 0               1             1.1          139         68         6
# 1               1             1.2          138         60         2
# 2               1             1.3          115         73         5
# 3               1             2.1          133         91         5
# 4               1             2.2          111         60         3
#
#                                      link   link_date link_time
# 0  https://vk.com/topic-33327655_26089953  2012-03-07     20:55
# 1  https://vk.com/topic-33327655_26089953  2012-03-07     20:55
# 2  https://vk.com/topic-33327655_26089953  2012-03-07     20:55
# 3  https://vk.com/topic-33327655_26089854  2012-02-28     22:34
# 4  https://vk.com/topic-33327655_26089854  2012-02-28     22:34

# %%
list_of_df = [ssmm_results_info_conv_1,ssmm_results_info_conv_4_11]
df = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
df = df[['convocation_no','year_stream_no','stream_size','voted_cnt','NOTA_cnt','invalid_cnt','link','link_date','link_time']]

ssmm_results_info_conv_1_and_4_11 = df
ssmm_results_info_conv_1_and_4_11
# Out:
#      convocation_no year_stream_no  stream_size  voted_cnt  NOTA_cnt  \
# 0                 1            1.1          139         68         6
# 1                 1            1.2          138         60         2
# 2                 1            1.3          115         73         5
# 3                 1            2.1          133         91         5
# 4                 1            2.2          111         60         3
# ..              ...            ...          ...        ...       ...
# 155              11            5.3           89         46         1
# 156              11            5.4           37         21         0
# 157              11            6.1           87         44         6
# 158              11            6.3           93         47         3
# 159              11             m1           51         26         3
#
#      invalid_cnt                                    link   link_date link_time
# 0            NaN  https://vk.com/topic-33327655_26089953  2012-03-07     20:55
# 1            NaN  https://vk.com/topic-33327655_26089953  2012-03-07     20:55
# 2            NaN  https://vk.com/topic-33327655_26089953  2012-03-07     20:55
# 3            NaN  https://vk.com/topic-33327655_26089854  2012-02-28     22:34
# 4            NaN  https://vk.com/topic-33327655_26089854  2012-02-28     22:34
# ..           ...                                     ...         ...       ...
# 155          0.0       https://vk.com/wall-33327655_9912  2021-10-12     20:20
# 156          0.0       https://vk.com/wall-33327655_9878  2021-10-06     20:36
# 157          0.0      https://vk.com/wall-33327655_10026  2021-10-21     15:44
# 158          0.0      https://vk.com/wall-33327655_10031  2021-10-21     22:02
# 159          0.0      https://vk.com/wall-33327655_10018  2021-10-20     20:21
#
# [160 rows x 9 columns]

# %%
ssmm_results_info_conv_1_and_4_11.to_csv('ssmm_results_1_and_4_11.csv', sep='\t', encoding='utf-8', index=False)
ssmm_results_info_conv_1_and_4_11.to_csv('../library: main/ssmm_results_1_and_4_11.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# # 6. To fix ANNOUNCEMENTS table

# %%
ssmm_announcements_conv_4_11 = pd.read_csv('ssmm_announcement_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_announcements_conv_4_11.head()

# %% [markdown]
# # 7. СДЕЛАТЬ ОБЩУЮ ТАБЛИЦУ ПО ПОТОКАМ

# %% [markdown]
# # ПРОВЕРКИ

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

string1 = "abc"
string2 = "aef"

print(levenshtein(string1, string2))
# Out:
# 2

# %%
names = list(candidates_conv_1_11_upd['name']) + list(temp_votes_conv_1_3['name']) + list(final_votes_conv_4_11['name'])

from collections import Counter

names_stat = Counter(names) #.most_common()
# names_stat

# names_uniq = list(set(names))
# names_uniq

# %%
# выявляем похожие имена, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a, b) <= 4 and names_stat[a] >= names_stat[b]:
            print(levenshtein(a, b), ' - ', a, names_stat[a], ' : ', names_stat[b], b)

# %%
# выявляем имена без отчества, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if len(a) > len(b) and levenshtein(a[:len(b)], b) <= 4:
            print(a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# Семенюк Павел Игоревич 4  :  2 Семенов Павел
# Белан Андрей Владимирович 2  :  2 Левин Андрей

# %%
# выявляем имена с перепутанными отчествами, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a[:12], b[:12]) <= 2 and names_stat[a] >= names_stat[b]:
            print(a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# Коновалов Антон Александрович 2  :  1 Коновалов Дмитрий Игоревич
# Семенюк Павел Игоревич 2  :  1 Семенов Павел
# Порфирьева Наталия Алексеевна 1  :  1 Перфильева Нелли Андреевна
# Федотов Константин Алексеевич 1  :  1 Фёдоров Константин Дмитриевич
# Алиев Рамиль Камиль Оглы 1  :  1 Алеев Дамиль Павлович
# Перфильева Нелли Андреевна 1  :  1 Порфирьева Наталия Алексеевна
# Фёдоров Константин Дмитриевич 1  :  1 Федотов Константин Алексеевич
# Третьяков Пётр Максимович 3  :  2 Третьяков Артём Алексеевич
# Саметов Максим Алексеевич 2  :  1 Савелов Максим Павлович
# Лобанова Алёна Валерьевна 3  :  1 Лобанова Анастасия Алексеевна
# Алеев Дамиль Павлович 1  :  1 Алиев Рамиль Камиль Оглы
