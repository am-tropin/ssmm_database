# %%
#     В ЭТОМ КОДЕ:

#     + кластеризуем посты в группе ССММ (про выборы/нет, анонсы/результаты выборов)
#     + посты с анонсами выборов конвертируем в словарики (имя, курс-поток-группа, текст программы)
#     + посты с результатами выборов конвертируем в словарики со всей информацией об итогах выборов
#     + всё это выгружаем в несколько таблиц и дальше работаем с ними в других ноутах

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
import re
from datetime import datetime, date, time

import pandas as pd

# %%
'''
ЧТО ПОФИКСИТЬ:
- БАГ: путает блок текста в шапке репоста с блоком текста в самом репосте (пример: https://vk.com/wall-33327655_2261)
- находить посты с перечнем избранных должностей
- https://vk.com/wall-33327655_5491 - запись удалена, но код этого не видит
- https://vk.com/wall-33327655_5492 - запись не найдена, а код сломался
- https://vk.com/wall-33327655_9414 - код сломался
- были парные кандидаты, найти и расщепить

- ВЫТАЩИТЬ 1-3 СОЗЫВЫ ИЗ ТРЕДОВ
- прогнать 1-3 созывы через сравнение имен
- сделать СКВОЗНУЮ НУМЕРАЦИЮ ssmm_id по мере публикации заявок
'''

# СДЕЛАТЬ ПАРСИНГ ОБСУЖДЕНИЙ В ГРУППЕ:
#     треды с кандидатами 1-3 созывов
#     треды с отчетами о собраний 1-2(3?) созывов

# %%
# ссылка на репост без шапки, репостнутая запись - без текста (обновление аватарки):

# req_announcement = requests.get('https://vk.com/wall-33327655_9846')
# html_doc = req_announcement.text
# print(html_doc)

# типы постов:

#     https://vk.com/wall-33327655_2250 -- пост с тегом
#     https://vk.com/wall-33327655_2261 -- пост без тега
#     https://vk.com/wall-33327655_2255 -- post not found
#     https://vk.com/wall-33327655_2262 -- коммент под постом с тегом
#     https://vk.com/wall-33327655_3330 -- репост без шапки поста с адресом 104154624_1
#     https://vk.com/wall-33327655_8489 -- репост с шапкой поста по адресу 77014399_6331

# %% [markdown]
# ## CREATING A DICTIONARY WITH FULL DATA ABOUT POST/REPLY BY VK-LINK

# %%
'''
CREATING A DICTIONARY WITH FULL DATA ABOUT POST/REPLY BY VK-LINK
'''

def vk_post_info_by_link(link_vk, language):
    req_link = requests.get(link_vk)
    html_doc = req_link.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    
#     дефолтные значения
    content_type = 'no text'
    content_subtype = 'other'
    parent_link = ''
    text_lines = []
    link_year_no = 0
    link_month_no = 0
    link_day_no = 0
    link_date = date(1970, 1, 1)
    link_date_time = ''
    link_time = ''
    months_dict = {
        'russian': ['янв', 'фев', 'мар', 'апр', 'мая', 'июн', 'июл', 'авг', 'сен', 'окт', 'ноя', 'дек'],
        'english': ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'],
#         https://en.wikipedia.org/wiki/Georgian_calendar
        'georgian': ['იან', 'თებ', 'მარ', 'აპრ', 'მაი', 'ივნ', 'ივლ', 'აგვ', 'სექ', 'ოქტ', 'ნოე', 'დეკ']
    }
    months = months_dict[language]

    # ПРОВЕРЯЮ, СУЩЕСТВУЕТ ЛИ ПОСТ
    #     <div class="service_msg service_msg_error">Запись не найдена.</div>
    flg_service_msg_error = soup.find('div', attrs={'class': 'service_msg service_msg_error'})
    if flg_service_msg_error:
        link_type = 'page not found'
    else:
        link_type = 'post'
        # когда ссылка на пост: <link rel="canonical" href="https://vk.com/wall-33327655_2225" />
        # когда ссылка на коммент: <link rel="canonical" href="https://vk.com/wall-33327655_8793?reply=8800" />
        
        # ПРОВЕРЯЮ, НЕ КОММЕНТ ЛИ ЭТО
        rel_canonical = soup.find('link', attrs={'rel': 'canonical'})
        flg_rel_canonical_reply = re.findall('reply=', str(rel_canonical))
#             + ДОБАВИТЬ ПОЛЕ МАТЕРИНСКОЙ ССЫЛКИ
        if flg_rel_canonical_reply:
            link_type = 'comment'
            
        # ПРОВЕРЯЮ, НЕ РЕПОСТ ЛИ ЭТО
        flg_repost = soup.find('div', attrs={'data-copy': True})
        if flg_repost:
            link_type = 'repost'
#             <div class="wall_item single_wall_item bl_item mark_top_verified" data-copy='-77014399_6331'>
            parent_link = 'https://vk.com/wall' + flg_repost['data-copy']
    
    if link_type in ['post','repost']:
        # ВЫТАСКИВАЮ БЛОК С ТЕКСТОМ ПОСТА ПОСТРОЧНО    
        # <div class="wi_body">
        #     <div class="pi_text">

        wi_body = soup.find('div', attrs={'class': 'wi_body'})
        if wi_body is None:
            announcement_list = []
            result_list = []
        else:
            pi_text = wi_body.find('div', attrs={'class': 'pi_text'})
            if pi_text is None:
                announcement_list = []
                result_list = []
            else:
                text_lines = [line for line in pi_text.stripped_strings]
                    # определить тип контента
                    # анонсы: 'Орфография и пунктуация сохранены.'
                    # результаты: 'Таким образом, выборы признаются состоявшимися'
                announcement_list = ['announcement' for line in pi_text.stripped_strings if line.find('Орфография и пунктуация сохранены.') >= 0]
                result_list = ['result' for line in pi_text.stripped_strings if line.find('Таким образом, выборы признаются состоявшимися.') >= 0]
                content_type = 'text'
                if any(election_tag in text_lines for election_tag in ['#выборы@stud_mm','#выборы_ссмм']):
                    content_type = 'election'
    
                if len(announcement_list) > 0:
                    content_subtype = 'announcement'
                elif len(result_list) > 0:
                    content_subtype = 'result'
        
        # ВЫТАСКИВАЮ ДАТУ
        # <div class="wi_info">
        #     <span class="wi_date">
        wi_info = soup.find('div', attrs={'class': 'wi_info'})
        if wi_info:
            wi_date = wi_info.find('span', attrs={'class': 'wi_date'})
            date_list = [date for date in wi_date.stripped_strings]
            link_year_no = int(re.findall(r'[\d]{4}', date_list[0])[0])
            link_month_no = months.index(re.findall(r'[\w]{3}', date_list[0])[0]) + 1
            link_day_no = int((re.findall(r'[\d]+\s', date_list[0])[0]).strip())
            link_date = date(link_year_no, link_month_no, link_day_no)
            link_date_time = date_list[0]
            link_time = re.findall(r'[\d]+\:[\d]+', date_list[0])[0]
        
    if link_type == 'comment':
        reply_link = link_vk[link_vk.index('_')+1:]
        # ВЫТАСКИВАЮ БЛОК С ТЕКСТОМ КОММЕНТА ПОСТРОЧНО    
#             <div class="ReplyItem__body">    180% голосов. Это выборы на мехмате? Это проценты чего?</div>
#             <div class="ReplyItem__date">
#             <a class="item_date" href="https://m.vk.com/wall-33327655_2254?reply=2262#reply2262" rel="noopener">22 &#4316;&#4317;&#4308;&#4315; 2014</a></div>
#         reply_body = soup.find('div', attrs={'class': 'ReplyItem__body'})
        reply_bodies = soup.find_all('div', attrs={'class': 'ReplyItem__body'})
        reply_dates = soup.find_all('a', attrs={'class': 'item_date'})
        reply_links = [ff['href'][ff['href'].index('#reply')+6:] for ff in soup.find_all('a', attrs={'class': 'item_date'})]
        if reply_link in reply_links:
            reply_no = reply_links.index(reply_link)
            content_type = 'text'
            text_lines = [line for line in reply_bodies[reply_no].stripped_strings]
            date_list = [date for date in reply_dates[reply_no].stripped_strings]
            link_year_no = int(re.findall(r'[\d]{4}', date_list[0])[0])
            link_month_no = months.index(re.findall(r'[\w]{3}', date_list[0])[0]) + 1
            link_day_no = int((re.findall(r'[\d]+\s', date_list[0])[0]).strip())
            link_date = date(link_year_no, link_month_no, link_day_no)
        else:
            content_subtype = 'deleted (?)'
            
        parent_link = rel_canonical['href'][: rel_canonical['href'].index('?')]
        
#     баг с переводом строки
    if link_vk == 'https://vk.com/wall-33327655_10007':
        text_lines = text_lines[:5] + [text_lines[5]+' '+text_lines[6]] + text_lines[7:]
    
    dict_link = {}
    dict_link[link_vk] = {
        'link_type': link_type, 
        'content_type': content_type,
        'content_subtype': content_subtype,
        'parent_link': parent_link,
        
        'link_date': link_date, 
        'link_year_no': link_year_no, 
        'link_month_no': link_month_no, 
        'link_day_no': link_day_no, 
        'link_date_time': link_date_time, 
        'link_time': link_time, 
        
        'list_of_lines': text_lines
    }
    
    return dict_link

# %%
# тест
# vk_post_info_by_link('https://vk.com/wall-33327655_5106', 'georgian') # -- пост с анонсом +
# vk_post_info_by_link('https://vk.com/wall-33327655_2262', 'georgian') # -- коммент под постом +
# vk_post_info_by_link('https://vk.com/wall-33327655_2263', 'georgian') # -- коммент под постом +
# vk_post_info_by_link('https://vk.com/wall-33327655_3330', 'georgian') # -- репост без шапки +
# vk_post_info_by_link('https://vk.com/wall-33327655_2261', 'georgian') # -- репост без шапки - ПОЧЕМУ ТУТ text, а не no text
# vk_post_info_by_link('https://vk.com/wall-33327655_8489', 'georgian') # -- репост с шапкой +
# vk_post_info_by_link('https://vk.com/wall-33327655_9846', 'georgian') # -- удаленный коммент (?)
# vk_post_info_by_link('https://vk.com/wall-33327655_2225', 'georgian') # -- пост с кандидатами в КОММЕНТЕ 2232
# vk_post_info_by_link('https://vk.com/wall-33327655_2232', 'georgian') # -- коммент с кандидатами

# vk_post_info_by_link('https://vk.com/wall-33327655_10007', 'georgian') # -- РАЗНОЕ
# https://vk.com/wall-33327655_10007

# %% [markdown]
# ## functions for processing of posts about elections

# %% [markdown]
# ### functions for posts with announcements

# %%
# вытаскивает из строки номера курса и потока (в предположении, что они в этой строке есть)

# для обычных потоков
def year_stream_no_by_line(line):
    if re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', line):
        year_stream_line = (re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', line))[0]
        year_stream_line_d = re.sub('\D', '', year_stream_line)
        year_no = int(year_stream_line_d[0])
        stream_no = int(year_stream_line_d[1])
    elif re.findall(r'\D(\d\.\d)\D', line):
        year_stream_line = (re.findall(r'\D(\d\.\d)\D', line))[0]
        year_no = year_stream_line[0]
        stream_no = year_stream_line[2]
    
    year_stream_no = str(year_no) + '.' + str(stream_no)
    return year_stream_no, year_no, stream_no

# для магистратуры
def magister_year_by_line(line):
#     если номер года записан цифрами
    if re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', line):
        year_stream_line = (re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', line))[0]
        year_no = int(year_stream_line[1])
        year_stream_no = 'm' + str(year_no)
#     если номер года записан буквами
    elif re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', line):
        year_stream_line = (re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', line))[0]
        year_no = 0
        if str.lower(year_stream_line[1]) == 'перв':
            year_no = 1
        elif str.lower(year_stream_line[1]) == 'втор':
            year_no = 2
        year_stream_no = 'm' + str(year_no)
    return year_stream_no, year_no

# примеры для магистратуры:
# МАГИСТРЫ ПЕРВОГО ГОДА ОБУЧЕНИЯ (выборы завтра на второй паре в аудитории 12-03) +
# МАГИСТРЫ, 2 ГОД ОБУЧЕНИЯ +
# МАГИСТРЫ 2 ГОДА ОБУЧЕНИЯ +
# МАГИСТРЫ 1-ГО ГОДА ОБУЧЕНИЯ +
# МАГИСТРЫ, 1 КУРС +

# line = 'МАГИСТРЫ, 1 КУРС'
# magister_year_by_line(line)

# %%
# line1 = '— ЯНКОВА Маргарита Михайловна' +
# line1 = '— ОСТРОУХОВА Наталья Владимировна, группа 402' 
# line1 = '— ЧЕБОТАЕВА Виктория Алексеевна, 332 группа' +
# line1 = '— ПРОМЫСЛОВ Платон Валерьевич, гр.409' +
# line1 = '— БУН-ЯН-ТУН Владислав Владимирович, группа 125' +
# line1 = 'Перейдём к старшим курсам. Есть две новости, хорошая и плохая. Плохая: от механиков 5 курса до сих пор не поступило ни одной заявки. Поторопитесь, не оставляйте свой поток без представителя — время до полуночи ещё есть! Хорошая: на экономпотоке четверокурсников кандидат в наличии, с ним и знакомим.'

# # r'\—([\w\s\-]+)[\,\.\s\w]*([\d]*)'

# if len(re.findall(r'\—([\w\s\-]+)', line1)) > 0 and re.search(r'\—([\w\s\-]+)', line1).start() == 0:
#     name_line = (re.findall(r'\—([\w\s\-]+)', line1))
#     print(name_line)
#     name = (re.sub('\W\s', '', name_line[0])).strip().title()
#     if re.sub('\D', '', line1):
#         academic_group_no = int(re.sub('\D', '', line1))
#         print(academic_group_no)

# print(name)

# %%
# СЛОВАРЬ ИНФОРМАЦИИ ПРО КАНДИДАТОВ (по списку строк с текстом)

def nomination_dict_by_name_line(nominated_dict, nomination_pattern, line, i):
        if (
            len(re.findall(nomination_pattern, line)) > 0  # если в строке есть такой паттерн
            and re.search(nomination_pattern, line).start() == 0  # с начала строки
            and len(re.findall(nomination_pattern, line)[0].strip().split(' ')) <= 6 # не более чем из 6 слов
        ):
            name_line_no = i
            name_line = re.findall(nomination_pattern, line)
            name = (re.sub('\W\s', '', name_line[0])).strip().title()
            if re.sub('\D', '', line):
                academic_group_no = int(re.sub('\D', '', line))
            else:
                academic_group_no = ''
            another_one_dict = {}
            another_one_dict[name] = {
                'academic_group_no': academic_group_no, 
                'name_line_no': name_line_no
            }
            nominated_dict = {**nominated_dict, **another_one_dict}
        return nominated_dict

# по списку строк с текстом составляем СЛОВАРЬ: имя: курс-поток, группа, номер первой строки в тексте
def stream_nomination_by_list(list_of_lines):
    nominated_dict = {}
    bug_patterns = [r'(ШИШКИН Игнат Владимирович), группа 122', r'(УСТИНОВ Никита Евгеньевич), группа 310.']
    
    for i in range(len(list_of_lines)):
#         В НАЧАЛЕ ШАБЛОНА БЫЛО \s (убрал, так как иногда забывают пробел, а алгоритм всё равно жадный)
#         r'[\w\s]+,\sгруппа\s[\d]{3}' - для фиксированного написания группы (и не для маги)
        nomination_pattern = r'[\—\–]([\w\s\-]+)'  # на первой позиции два тире: длинный или средний
        nominated_dict = nomination_dict_by_name_line(nominated_dict, nomination_pattern, list_of_lines[i], i)
        
        for nomination_pattern in bug_patterns:
            if (
                len(re.findall(nomination_pattern, list_of_lines[i])) > 0  # если в строке есть такой паттерн
                and re.search(nomination_pattern, list_of_lines[i]).start() == 0  # с начала строки
                and len(re.findall(nomination_pattern, list_of_lines[i])[0].strip().split(' ')) <= 6 # не более чем из 6 слов
            ):
                nominated_dict = nomination_dict_by_name_line(nominated_dict, nomination_pattern, list_of_lines[i], i)
                
    # первый и последний индексы программы кандидата в списке
    name_list = list(nominated_dict.keys())
    start_index_list = [nominated_dict[key]['name_line_no'] for key in list(nominated_dict.keys())]
    last_index_list = [i-1 for i in start_index_list if start_index_list.index(i) > 0]
    last_index_list.append(len(list_of_lines)-1)
    
    dict_of_nominated_upd = {}
    
    for name in name_list:
        dict_of_nominated_upd[name] = [start_index_list[name_list.index(name)], last_index_list[name_list.index(name)]]
    
    # обновить словарь: имя: номер группы, текст программы
    for name in dict_of_nominated_upd:
        program_lines = []

        for k in range(dict_of_nominated_upd[name][0]+1, dict_of_nominated_upd[name][1]+1):
            program_lines.append(list_of_lines[k])
        program_txt = '\n'.join(program_lines)

        nominated_dict[name].update({'program_txt': program_txt})
        del nominated_dict[name]['name_line_no']

    return nominated_dict


# вся инфа про номинации на потоке
def stream_nomination_info_by_dict(list_of_lines):
    year_stream_no = ''
    year_no, stream_no = 0, 0
    
    for i in range(len(list_of_lines)):
        if re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', list_of_lines[i]):
            year_stream_no, year_no, stream_no = year_stream_no_by_line(list_of_lines[i])
        if re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', list_of_lines[i]) or re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', list_of_lines[i]):
            year_stream_no, year_no = magister_year_by_line(list_of_lines[i])
                
    dict_nominations = stream_nomination_by_list(list_of_lines)
    
    dict_stream_elections = {
        'year_stream_no': year_stream_no,
        'year_no': year_no, 
        'stream_no': stream_no, 
        'dict_nominations': dict_nominations
    }
    
    return dict_stream_elections

# %% [markdown]
# ### functions for posts with results

# %%
# СЛОВАРЬ ИНФОРМАЦИИ ПРО РЕЗУЛЬТАТЫ ВЫБОРОВ (по списку строк с текстом)

# ДОБАВИТЬ МАГИСТРАТУРУ

# по списку строк с кандидатами составляем СЛОВАРЬ: имя: голоса, статус
def stream_election_result_by_list(nominated_with_votes):
    dict_nominated = {}

    for line in nominated_with_votes:
        kek = (re.findall(r'[\—\s]*([\w\-\s]+)[\:\;]\s([\d]+)\sголос', line))[0]
        name = kek[0].strip().title()
        votes_cnt = kek[1]
        dict_nominated[name] = {'votes_cnt': votes_cnt}
        if (re.findall(r' избран', line)) and not (re.findall(r' не избран', line)):
            elected_flg = 1
        else:
            elected_flg = 0
        dict_nominated[name].update({'elected_flg': elected_flg})
    return dict_nominated


# вся инфа про результаты выборов на потоке
def stream_election_info_by_dict(list_of_lines):
    nominated_with_votes = []
    year_stream_no = ''
    year_no, stream_no = 0, 0
    voted_cnt, stream_size, invalid_cnt, NOTA_cnt = 0, 0, 0, 0
    
    for i in range(len(list_of_lines)):
                    
        if re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', list_of_lines[i]) or re.findall(r'\D(\d\.\d)\D', list_of_lines[i]):
            year_stream_no, year_no, stream_no = year_stream_no_by_line(list_of_lines[i])
        if re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', list_of_lines[i]) or re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', list_of_lines[i]):
            year_stream_no, year_no = magister_year_by_line(list_of_lines[i])
            
        if re.findall('Явка: ', list_of_lines[i]):
            turnout_line = (re.findall(r'[\d]+\s[\w]+\sиз\s[\d]+', list_of_lines[i]))[0]
            voted_cnt = int(((re.findall(r'[\d]+\s', turnout_line))[0]).strip())
            stream_size = int(((re.findall(r'\s[\d]+', turnout_line))[0]).strip())
            
        if len(re.findall(r'\s[\d]+\sнедействительн', list_of_lines[i])) == 0: # отдельно, т.к. может такой записи не быть
            pass
        else:
            invalid_line_no = i
            invalid_line = (re.findall(r'\s[\d]+\sнедействительн', list_of_lines[i]))[0]
            invalid_cnt = re.sub('\D', '', invalid_line)
            
        if re.findall('Против всех', list_of_lines[i]):
            NOTA_line_no = i
            NOTA_line = (re.findall(r'\s[\d]+\sголос', list_of_lines[i]))[0]
            NOTA_cnt = re.sub('\D', '', NOTA_line)
            
        if re.findall('[\—\s]*([\w\-\s]+)[\:\;]\s([\d]+)\sголос', list_of_lines[i]) and not (re.findall('Против всех', list_of_lines[i])):
            nominated_with_votes.append(list_of_lines[i])
            
        if re.findall('Подтверждено ответственн', list_of_lines[i]):
            organizer_line = (re.findall(r'за\sвыборы\s[\w\s,]+', list_of_lines[i]))[0]
            organizer_line = organizer_line[10::]
            organizer_list = re.split(', | и ',organizer_line)
    
    dict_nominated_with_votes = stream_election_result_by_list(nominated_with_votes)
    
    dict_stream_elections = {
        'year_stream_no': year_stream_no,
        'year_no': year_no, 
        'stream_no': stream_no, 
        'stream_size': stream_size, 
        'voted_cnt': voted_cnt,
        'invalid_cnt': invalid_cnt,
        'NOTA_cnt': NOTA_cnt,
        'organizers': organizer_list,
        'dict_nominated_with_votes': dict_nominated_with_votes
    }
    
    return dict_stream_elections

# %%
def fix_main_dict(test_dict):
#     поправка из-за коммента с доп.кандидатами
    if 'https://vk.com/wall-33327655_2232' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_2232']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_2232']['content_subtype'] = 'announcement'
#     поправка из-за коммента с доп.кандидатами
    if 'https://vk.com/wall-33327655_2305' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_2305']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_2305']['content_subtype'] = 'announcement'
#     поправка из-за коммента с доп.кандидатами
    if 'https://vk.com/wall-33327655_7650' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_7650']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_7650']['content_subtype'] = 'announcement'
        
#     поправка из-за отсутствия кодовой фразы
    if 'https://vk.com/wall-33327655_2230' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_2230']['content_subtype'] = 'announcement'
#     поправка из-за отсутствия выборного хэштега
    if 'https://vk.com/wall-33327655_7509' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_7509']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_7509']['content_subtype'] = 'result'
#     поправка из-за отсутствия кодовой фразы
    if 'https://vk.com/wall-33327655_7657' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_7657']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_7657']['content_subtype'] = 'announcement'

    return test_dict

def fix_announcement_links(announcement_links):
# поправки из-за единичных нестандартных случаев
    if 'https://vk.com/wall-33327655_2232' in announcement_links.keys():
        announcement_links['https://vk.com/wall-33327655_2232']['nominated_info']['year_stream_no'] = '1.2'
        announcement_links['https://vk.com/wall-33327655_2232']['nominated_info']['year_no'] = 1
        announcement_links['https://vk.com/wall-33327655_2232']['nominated_info']['stream_no'] = 2
    if 'https://vk.com/wall-33327655_2305' in announcement_links.keys():
        announcement_links['https://vk.com/wall-33327655_2305']['nominated_info']['year_stream_no'] = '3.1'
        announcement_links['https://vk.com/wall-33327655_2305']['nominated_info']['year_no'] = 3
        announcement_links['https://vk.com/wall-33327655_2305']['nominated_info']['stream_no'] = 1
    if 'https://vk.com/wall-33327655_7650' in announcement_links.keys():
        announcement_links['https://vk.com/wall-33327655_7650']['nominated_info']['year_stream_no'] = '1.3'
        announcement_links['https://vk.com/wall-33327655_7650']['nominated_info']['year_no'] = 1
        announcement_links['https://vk.com/wall-33327655_7650']['nominated_info']['stream_no'] = 3
    return announcement_links

def fix_result_links(result_links):
    if 'https://vk.com/wall-33327655_7695' in result_links.keys():
        result_links['https://vk.com/wall-33327655_7695']['stream_election_info']['year_stream_no'] = 'm1'
        result_links['https://vk.com/wall-33327655_7695']['stream_election_info']['year_no'] = 1
    if 'https://vk.com/wall-33327655_9205' in result_links.keys():
        result_links['https://vk.com/wall-33327655_9205']['stream_election_info']['year_stream_no'] = '6.3'
        result_links['https://vk.com/wall-33327655_9205']['stream_election_info']['year_no'] = 6
        result_links['https://vk.com/wall-33327655_9205']['stream_election_info']['stream_no'] = 3
    if 'https://vk.com/wall-33327655_9267' in result_links.keys():
        result_links['https://vk.com/wall-33327655_9267']['stream_election_info']['year_stream_no'] = '6.1'
        result_links['https://vk.com/wall-33327655_9267']['stream_election_info']['year_no'] = 6
        result_links['https://vk.com/wall-33327655_9267']['stream_election_info']['stream_no'] = 1
    return result_links

# %%
# словарик для ручного исправления имен кандидатов

def fix_name(name):
    # incorrect: correct
    correct_names_dict = {
    #     из-за Е/Ё:
        'Муравьева Анна Сергеевна': 'Муравьёва Анна Сергеевна',
        'Третьяков Артем Алексеевич': 'Третьяков Артём Алексеевич',
        'Рогачев Александр Викторович': 'Рогачёв Александр Викторович',
        'Третьяков Петр Максимович': 'Третьяков Пётр Максимович',
        'Пушкарева Анна Константиновна': 'Пушкарёва Анна Константиновна',
    #     из-за других букв:
        'Порфирьева Наталья Алексеевна': 'Порфирьева Наталия Алексеевна',
        'Лобанова Елена Валерьевна': 'Лобанова Алёна Валерьевна',
        'Иллизаров Год Эмануилович': 'Илизаров Год Эмануилович',
        'Гусейнов Сеймур Элданизович': 'Гусейнов Сэймур Элданизович',
    #     из-за пропущенного отчества:
        'Лапина София': 'Лапина Софья Михайловна',   
    #     из-за перепутанного отчества:
        'Сакаев Роберт Викторович': 'Сакаев Роберт Марселевич',   
    }
    if name in correct_names_dict.keys():
        return correct_names_dict[name]
    else:
        return name

fix_name('Иллизаров Год Эмануилович')
# Out:
# 'Илизаров Год Эмануилович'

# %% [markdown]
# ## Processing of all election posts for 4-11 convocations

# %% [markdown]
# ### launching

# %%
# ГЕНЕРАТОР СЛОВАРЯ ДЛЯ ИНТЕРВАЛА ССЫЛОК НА ПОСТЫ С АНОНСАМИ ВЫБОРОВ
# ГЕНЕРАТОР СЛОВАРЯ ДЛЯ ИНТЕРВАЛА ССЫЛОК НА ПОСТЫ С РЕЗУЛЬТАТАМИ ВЫБОРОВ

from itertools import chain

announcement_links = {}
result_links = {}

for num in chain(
#     range(8330, 8331) #, # test
    
    range(2200, 2360) , # созыв 4 +
    range(3140, 3530) #, # созыв 5 +
#     range(5040, 5360) #, # созыв 6 +
#     range(6540, 6720) #, # созыв 7 +
#     range(7470, 7780), # созыв 8 +
#     range(8240, 8420), # созыв 9 +
#     range(9100, 9400), # созыв 10 +
#     range(9800, 10040) # созыв 11 +
):
    link = 'https://vk.com/wall-33327655_' + str(num)

    test_dict = vk_post_info_by_link(link, 'georgian')
    test_dict = fix_main_dict(test_dict)
    
    print('{0} : {1} \t\t/ {2} \t\t/ {3}'.format(link, test_dict[link]['link_type'], test_dict[link]['content_type'], test_dict[link]['content_subtype']))

    for d in test_dict.values():
        if d['content_type'] == 'election' and d['content_subtype'] == 'announcement':
            announcement_links = {**announcement_links, **test_dict}
        if d['content_type'] == 'election' and d['content_subtype'] == 'result':
            result_links = {**result_links, **test_dict}


for link in announcement_links:
    announcement_links[link].update({'nominated_info': stream_nomination_info_by_dict(announcement_links[link]['list_of_lines'])})
    del announcement_links[link]['list_of_lines']
    
for link in result_links:
    result_links[link].update({'stream_election_info': stream_election_info_by_dict(result_links[link]['list_of_lines'])})
    del result_links[link]['list_of_lines']

# поправки из-за единичных нестандартных случаев
announcement_links = fix_announcement_links(announcement_links)
result_links = fix_result_links(result_links)

# print(announcement_links)
# print(result_links)
# Out:
# https://vk.com/wall-33327655_2200 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2201 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2202 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2203 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2204 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2205 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2206 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2207 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2208 : post 		/ election 		/ other
# https://vk.com/wall-33327655_2209 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2210 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2211 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2212 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2213 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2214 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2215 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2216 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2217 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2218 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2219 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2220 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2221 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2222 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2223 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2224 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2225 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2226 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2227 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2228 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2229 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2230 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2231 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2232 : comment 		/ election 		/ announcement
# https://vk.com/wall-33327655_2233 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2234 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2235 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2236 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2237 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2238 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2239 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2240 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2241 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2242 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2243 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2244 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2245 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2246 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2247 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2248 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2249 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2250 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2251 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2252 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2253 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2254 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2255 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2256 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2257 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2258 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2259 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2260 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2261 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2262 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2263 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2264 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2265 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2266 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2267 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2268 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2269 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2270 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2271 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2272 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2273 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2274 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2275 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2276 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2277 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2278 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2279 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2280 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2281 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2282 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2283 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2284 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2285 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2286 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2287 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2288 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2289 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2290 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2291 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2292 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2293 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2294 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2295 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2296 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2297 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2298 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2299 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2300 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2301 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2302 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2303 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2304 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2305 : comment 		/ election 		/ announcement
# https://vk.com/wall-33327655_2306 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2307 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2308 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2309 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2310 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2311 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2312 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2313 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2314 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2315 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_2316 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2317 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2318 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2319 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2320 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2321 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2322 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2323 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2324 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2325 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2326 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2327 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2328 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2329 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2330 : post 		/ election 		/ result
# https://vk.com/wall-33327655_2331 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2332 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2333 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2334 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2335 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2336 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2337 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2338 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2339 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2340 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2341 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2342 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2343 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2344 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2345 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2346 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2347 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2348 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2349 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2350 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_2351 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2352 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_2353 : post 		/ election 		/ other
# https://vk.com/wall-33327655_2354 : post 		/ election 		/ other
# https://vk.com/wall-33327655_2355 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2356 : post 		/ text 		/ other
# https://vk.com/wall-33327655_2357 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2358 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_2359 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3140 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3141 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3142 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3143 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3144 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3145 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3146 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3147 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3148 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3149 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3150 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3151 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3152 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3153 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3154 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3155 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3156 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3157 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3158 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3159 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3160 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3161 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3162 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3163 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3164 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3165 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3166 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3167 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3168 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3169 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3170 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3171 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3172 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3173 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3174 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3175 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3176 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3177 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3178 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3179 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3180 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3181 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3182 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3183 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3184 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3185 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3186 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3187 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3188 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3189 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3190 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3191 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3192 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3193 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3194 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3195 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3196 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3197 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3198 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3199 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3200 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3201 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3202 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3203 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3204 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3205 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3206 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3207 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3208 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3209 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3210 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3211 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3212 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3213 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3214 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3215 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3216 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3217 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3218 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3219 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3220 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3221 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3222 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3223 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3224 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3225 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3226 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3227 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3228 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3229 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3230 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3231 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3232 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3233 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3234 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3235 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3236 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3237 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3238 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3239 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3240 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3241 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3242 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3243 : repost 		/ no text 		/ other
# https://vk.com/wall-33327655_3244 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3245 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3246 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3247 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3248 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3249 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3250 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3251 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3252 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3253 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3254 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3255 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3256 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3257 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3258 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3259 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3260 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3261 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3262 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3263 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3264 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3265 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3266 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3267 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3268 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3269 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3270 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3271 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3272 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3273 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3274 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3275 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3276 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3277 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3278 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3279 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3280 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3281 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3282 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3283 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3284 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3285 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3286 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3287 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3288 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3289 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3290 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3291 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3292 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3293 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3294 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3295 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3296 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3297 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3298 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3299 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3300 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3301 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3302 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3303 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3304 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3305 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3306 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3307 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3308 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3309 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3310 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3311 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3312 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3313 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3314 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3315 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3316 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3317 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3318 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3319 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3320 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3321 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3322 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3323 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3324 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3325 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3326 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3327 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3328 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3329 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3330 : repost 		/ no text 		/ other
# https://vk.com/wall-33327655_3331 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3332 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3333 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3334 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3335 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3336 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3337 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3338 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3339 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3340 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3341 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3342 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3343 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3344 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3345 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3346 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3347 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3348 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3349 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3350 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3351 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3352 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3353 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3354 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3355 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3356 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3357 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3358 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3359 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3360 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3361 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3362 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3363 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3364 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3365 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3366 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3367 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3368 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3369 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3370 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3371 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3372 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3373 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3374 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3375 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3376 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3377 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3378 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3379 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3380 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3381 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3382 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3383 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3384 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3385 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3386 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3387 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3388 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3389 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3390 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3391 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3392 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3393 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3394 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3395 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3396 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3397 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3398 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3399 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3400 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3401 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3402 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3403 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3404 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3405 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3406 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3407 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3408 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3409 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3410 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3411 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3412 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3413 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3414 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3415 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3416 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3417 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3418 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3419 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3420 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3421 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3422 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3423 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3424 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3425 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3426 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3427 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3428 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3429 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3430 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3431 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3432 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3433 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3434 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3435 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3436 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3437 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3438 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3439 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3440 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3441 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3442 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3443 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3444 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3445 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3446 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3447 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3448 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3449 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3450 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3451 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3452 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3453 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3454 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_3455 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3456 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3457 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3458 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3459 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3460 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3461 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3462 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3463 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3464 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3465 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3466 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3467 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3468 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3469 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3470 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3471 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3472 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3473 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3474 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3475 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3476 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3477 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3478 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3479 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3480 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3481 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3482 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3483 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3484 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3485 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3486 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3487 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3488 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3489 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3490 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3491 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3492 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3493 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3494 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3495 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3496 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3497 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3498 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3499 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3500 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3501 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3502 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3503 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3504 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_3505 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3506 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3507 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3508 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3509 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3510 : post 		/ election 		/ result
# https://vk.com/wall-33327655_3511 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3512 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3513 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3514 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3515 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3516 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3517 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3518 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3519 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3520 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3521 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3522 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3523 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3524 : post 		/ election 		/ other
# https://vk.com/wall-33327655_3525 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_3526 : post 		/ text 		/ other
# https://vk.com/wall-33327655_3527 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3528 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_3529 : comment 		/ text 		/ other

# %%
# announcement_links['https://vk.com/wall-33327655_7650']

# %% [markdown]
# ### creating tables about candidates and streams

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО ПОТОКАМ

announcement_streams = {}
for link in announcement_links.keys():
    announcement_streams[link] = {
        'year_x_year_stream': str(announcement_links[link]['link_year_no']) + '_' + announcement_links[link]['nominated_info']['year_stream_no'],
        'link_date': announcement_links[link]['link_date'],
        'link_year_no': announcement_links[link]['link_year_no'], 
        'link_month_no': announcement_links[link]['link_month_no'], 
        'link_day_no': announcement_links[link]['link_day_no'], 
        'link_time': announcement_links[link]['link_time'], 
        'year_stream_no': announcement_links[link]['nominated_info']['year_stream_no'], 
        'year_no': announcement_links[link]['nominated_info']['year_no'], 
        'stream_no': announcement_links[link]['nominated_info']['stream_no']
    }
# announcement_streams

announcement_streams_df =  pd.DataFrame(announcement_streams.items(), columns=['link', 'params'])
announcement_streams_df_2 = pd.concat([announcement_streams_df.drop(['params'], axis=1), announcement_streams_df['params'].apply(pd.Series)], axis=1)
announcement_streams_df_3 = announcement_streams_df_2.sort_values(['year_stream_no', 'link'],
              ascending = [True, True]).reset_index().drop(['index'], axis=1)
announcement_streams_df_3
# Out:
#                                  link year_x_year_stream   link_date  \
# 0   https://vk.com/wall-33327655_7621           2018_1.1  2018-10-23
# 1   https://vk.com/wall-33327655_7479           2018_1.2  2018-10-12
# 2   https://vk.com/wall-33327655_7645           2018_1.3  2018-10-23
# 3   https://vk.com/wall-33327655_7650           2018_1.3  2018-10-24
# 4   https://vk.com/wall-33327655_7622           2018_2.1  2018-10-23
# 5   https://vk.com/wall-33327655_7644           2018_2.3  2018-10-23
# 6   https://vk.com/wall-33327655_7619           2018_3.1  2018-10-21
# 7   https://vk.com/wall-33327655_7657           2018_3.2  2018-10-25
# 8   https://vk.com/wall-33327655_7552           2018_3.3  2018-10-17
# 9   https://vk.com/wall-33327655_7623           2018_3.4  2018-10-23
# 10  https://vk.com/wall-33327655_7667           2018_4.1  2018-10-25
# 11  https://vk.com/wall-33327655_7735           2018_4.2  2018-11-15
# 12  https://vk.com/wall-33327655_7602           2018_4.3  2018-10-18
# 13  https://vk.com/wall-33327655_7656           2018_5.3  2018-10-25
# 14  https://vk.com/wall-33327655_7620           2018_5.4  2018-10-21
# 15  https://vk.com/wall-33327655_7610           2018_6.1  2018-10-18
# 16  https://vk.com/wall-33327655_7606           2018_6.2  2018-10-18
# 17  https://vk.com/wall-33327655_7518            2018_m1  2018-10-16
#
#     link_year_no  link_month_no  link_day_no link_time year_stream_no  \
# 0           2018             10           23      0:00            1.1
# 1           2018             10           12     21:45            1.2
# 2           2018             10           23     23:38            1.3
# 3           2018             10           24                      1.3
# 4           2018             10           23      0:03            2.1
# 5           2018             10           23     23:19            2.3
# 6           2018             10           21     23:45            3.1
# 7           2018             10           25      0:10            3.2
# 8           2018             10           17     23:27            3.3
# 9           2018             10           23      0:06            3.4
# 10          2018             10           25     21:44            4.1
# 11          2018             11           15      0:02            4.2
# 12          2018             10           18     21:37            4.3
# 13          2018             10           25      0:01            5.3
# 14          2018             10           21     23:49            5.4
# 15          2018             10           18     23:17            6.1
# 16          2018             10           18     22:09            6.2
# 17          2018             10           16     21:30             m1
#
#     year_no  stream_no
# 0         1          1
# 1         1          2
# 2         1          3
# 3         1          3
# 4         2          1
# 5         2          3
# 6         3          1
# 7         3          2
# 8         3          3
# 9         3          4
# 10        4          1
# 11        4          2
# 12        4          3
# 13        5          3
# 14        5          4
# 15        6          1
# 16        6          2
# 17        1          0

# %%
announcement_streams_df_3.to_csv('ssmm_announcement_info_conv8.csv', sep='\t', encoding='utf-8', index=False)

# %%
'''
БАГ!!! РАБОТАЕТ ТОЛЬКО ПО ОТДЕЛЬНЫМ СОЗЫВОМ!!! ИНАЧЕ В СЛОВАРИКЕ ПЕРЕЗАПИСЫВАЕТСЯ ИНФА ПО КЛЮЧУ-ИМЕНИ
ДЛЯ КАНДИДАТОВ С НЕСКОЛЬКИМИ СОЗЫВАМИ
'''

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО КАНДИДАТАМ

announcement_names = {}
for link in announcement_links.keys():
    for name in announcement_links[link]['nominated_info']['dict_nominations'].keys():
        announcement_names[fix_name(name)] = {
            'link_year_no_x_name': str(announcement_links[link]['link_year_no']) + "_" + "_".join(fix_name(name).split()),
            'link_year_no': announcement_links[link]['link_year_no'], 
            'year_stream_no': announcement_links[link]['nominated_info']['year_stream_no'], 
            'year_no': announcement_links[link]['nominated_info']['year_no'], 
            'stream_no': announcement_links[link]['nominated_info']['stream_no'], 
            'academic_group_no': announcement_links[link]['nominated_info']['dict_nominations'][name]['academic_group_no'], 
            'program_txt': announcement_links[link]['nominated_info']['dict_nominations'][name]['program_txt'],
            'link': link
        }
# поправка из-за парной заявки
if 'Шишкин Игнат Владимирович' in announcement_names.keys() and 'Винокурова Алина Валерьевна' in announcement_names.keys() and announcement_names['Шишкин Игнат Владимирович']['link_year_no'] == 2019:
    announcement_names['Шишкин Игнат Владимирович']['program_txt'] = announcement_names['Винокурова Алина Валерьевна']['program_txt']

announcement_names_df =  pd.DataFrame(announcement_names.items(), columns=['name', 'params'])
announcement_names_df_2 = pd.concat([announcement_names_df.drop(['params'], axis=1), announcement_names_df['params'].apply(pd.Series)], axis=1)
announcement_names_df_2[60:120]
# .head(10)
# announcement_names
# Out:
#                                     name  \
# 60       Понфиленко Анастасия Николаевна
# 61         Александрина Марина Сергеевна
# 62             Проничкин Юрий Викторович
# 63         Матюнин Виталий Владиславович
# 64  Ариас-Альварес Владимир Владимирович
# 65                 Шигаев Иван Андреевич
# 66               Гулин Никита Викторович
# 67           Сергейчик Руслан Валерьевич
# 68     Бун-Ян-Тун Владислав Владимирович
# 69              Мотовилина Анна Олеговна
# 70            Провидухина Мария Игоревна
# 71              Сакаев Роберт Марселевич
# 72                Трошина Дарья Игоревна
# 73            Козлова Кира Александровна
# 74         Лебедев Виталий Александрович
# 75               Святкин Иван Леонидович
# 76                 Ким Нина Владимировна
# 77               Базанов Иван Алексеевич
# 78              Милютин Эдуард Сергеевич
#
#                           link_year_no_x_name  link_year_no year_stream_no  \
# 60       2015_Понфиленко_Анастасия_Николаевна          2015            4.1
# 61         2015_Александрина_Марина_Сергеевна          2015             m1
# 62             2015_Проничкин_Юрий_Викторович          2015            1.2
# 63         2015_Матюнин_Виталий_Владиславович          2015            1.3
# 64  2015_Ариас-Альварес_Владимир_Владимирович          2015            1.3
# 65                 2015_Шигаев_Иван_Андреевич          2015            1.3
# 66               2015_Гулин_Никита_Викторович          2015            1.3
# 67           2015_Сергейчик_Руслан_Валерьевич          2015            1.3
# 68     2015_Бун-Ян-Тун_Владислав_Владимирович          2015            1.3
# 69              2015_Мотовилина_Анна_Олеговна          2015            3.3
# 70            2015_Провидухина_Мария_Игоревна          2015            3.3
# 71              2015_Сакаев_Роберт_Марселевич          2015            3.3
# 72                2015_Трошина_Дарья_Игоревна          2015            1.1
# 73            2015_Козлова_Кира_Александровна          2015            1.1
# 74         2015_Лебедев_Виталий_Александрович          2015            1.1
# 75               2015_Святкин_Иван_Леонидович          2015            1.1
# 76                 2015_Ким_Нина_Владимировна          2015             m1
# 77               2015_Базанов_Иван_Алексеевич          2015            5.2
# 78              2015_Милютин_Эдуард_Сергеевич          2015            5.2
#
#     year_no  stream_no academic_group_no  \
# 60        4          1               404
# 61        1          0
# 62        1          2               111
# 63        1          3               125
# 64        1          3               125
# 65        1          3               125
# 66        1          3               124
# 67        1          3               125
# 68        1          3               125
# 69        3          3               324
# 70        3          3               323
# 71        3          3               321
# 72        1          1               106
# 73        1          1               103
# 74        1          1               105
# 75        1          1               105
# 76        1          0
# 77        5          2               508
# 78        5          2               511
#
#                                           program_txt  \
# 60  «Я еще не работала в студсовете, но готова при...
# 61  «Всем привет!\nЯ студентка 1 курса магистратур...
# 62  «Простой парень из Мурманска волей случая пост...
# 63  «Мне 19 лет, я уже почти обрёл статус легенды ...
# 64  «Эм... Мне снова лень что-либо писать, просто ...
# 65  «Профессионально занимаюсь диджеингом, имею не...
# 66  «Хотел бы заняться "хозяйственной" темой в раб...
# 67  «креативный, коммуникабельный, ответственный\n...
# 68  «Зелёный первокур, обеспокоенный благополучием...
# 69  «Привет всем! Пока участвовала лишь в проведен...
# 70          «Краткость сестра таланта. Инициативная.»
# 71  «Довольно интересный человек (с хорошим самомн...
# 72  «Считаю себя очень инициативный человеком , и ...
# 73  «В лицее "Вторая школа" (являюсь его выпускниц...
# 74  «Я закончил маткласс 179ой школы. Моя школа по...
# 75  «Опустим ставшую традиционной графоманию в сти...
# 76  «Считаю себя достаточно ответственным человеко...
# 77              «Наше будущее за котами! Всем котов!»
# 78  «У меня сейчас много свободного времени и я бы...
#
#                                  link
# 60  https://vk.com/wall-33327655_3264
# 61  https://vk.com/wall-33327655_3455
# 62  https://vk.com/wall-33327655_3365
# 63  https://vk.com/wall-33327655_3366
# 64  https://vk.com/wall-33327655_3366
# 65  https://vk.com/wall-33327655_3366
# 66  https://vk.com/wall-33327655_3366
# 67  https://vk.com/wall-33327655_3366
# 68  https://vk.com/wall-33327655_3366
# 69  https://vk.com/wall-33327655_3368
# 70  https://vk.com/wall-33327655_3368
# 71  https://vk.com/wall-33327655_3368
# 72  https://vk.com/wall-33327655_3417
# 73  https://vk.com/wall-33327655_3417
# 74  https://vk.com/wall-33327655_3417
# 75  https://vk.com/wall-33327655_3417
# 76  https://vk.com/wall-33327655_3455
# 77  https://vk.com/wall-33327655_3504
# 78  https://vk.com/wall-33327655_3504

# %%
announcement_names_df_2.to_csv('ssmm_candidates_info_conv9.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
#  ### creating tables about results

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО ПОТОКАМ

result_streams = {}
for link in result_links.keys():
    result_streams[link] = {
        'year_x_year_stream': str(result_links[link]['link_year_no']) + '_' + result_links[link]['stream_election_info']['year_stream_no'],
        'link_date': result_links[link]['link_date'],
        'link_year_no': result_links[link]['link_year_no'], 
        'link_month_no': result_links[link]['link_month_no'], 
        'link_day_no': result_links[link]['link_day_no'], 
        'link_time': result_links[link]['link_time'], 
        'year_stream_no': result_links[link]['stream_election_info']['year_stream_no'], 
        'year_no': result_links[link]['stream_election_info']['year_no'], 
        'stream_no': result_links[link]['stream_election_info']['stream_no'], 
        'stream_size': result_links[link]['stream_election_info']['stream_size'], 
        'voted_cnt': result_links[link]['stream_election_info']['voted_cnt'], 
        'invalid_cnt': result_links[link]['stream_election_info']['invalid_cnt'], 
        'NOTA_cnt': result_links[link]['stream_election_info']['NOTA_cnt'], 
        'organizers': result_links[link]['stream_election_info']['organizers']
    }
# announcement_streams

result_streams_df =  pd.DataFrame(result_streams.items(), columns=['link', 'params'])
result_streams_df_2 = pd.concat([result_streams_df.drop(['params'], axis=1), result_streams_df['params'].apply(pd.Series)], axis=1)
result_streams_df_3 = result_streams_df_2.sort_values(['year_stream_no', 'link'],
              ascending = [True, True]).reset_index().drop(['index'], axis=1)
result_streams_df_3
# Out:
#                                  link year_x_year_stream   link_date  \
# 0   https://vk.com/wall-33327655_7676           2018_1.1  2018-10-26
# 1   https://vk.com/wall-33327655_7509           2018_1.2  2018-10-14
# 2   https://vk.com/wall-33327655_7685           2018_1.3  2018-10-27
# 3   https://vk.com/wall-33327655_7677           2018_2.1  2018-10-26
# 4   https://vk.com/wall-33327655_7684           2018_2.3  2018-10-27
# 5   https://vk.com/wall-33327655_7675           2018_3.1  2018-10-26
# 6   https://vk.com/wall-33327655_7728           2018_3.2  2018-11-12
# 7   https://vk.com/wall-33327655_7670           2018_3.3  2018-10-25
# 8   https://vk.com/wall-33327655_7681           2018_3.4  2018-10-27
# 9   https://vk.com/wall-33327655_7694           2018_4.1  2018-11-02
# 10  https://vk.com/wall-33327655_7741           2018_4.2  2018-11-15
# 11  https://vk.com/wall-33327655_7674           2018_4.3  2018-10-26
# 12  https://vk.com/wall-33327655_7696           2018_5.3  2018-11-02
# 13  https://vk.com/wall-33327655_7707           2018_5.4  2018-11-10
# 14  https://vk.com/wall-33327655_7766           2018_6.1  2018-11-22
# 15  https://vk.com/wall-33327655_7704           2018_6.2  2018-11-09
# 16  https://vk.com/wall-33327655_7695            2018_m1  2018-11-02
#
#     link_year_no  link_month_no  link_day_no link_time year_stream_no  \
# 0           2018             10           26     17:00            1.1
# 1           2018             10           14     21:00            1.2
# 2           2018             10           27     14:00            1.3
# 3           2018             10           26     19:00            2.1
# 4           2018             10           27     12:00            2.3
# 5           2018             10           26     14:00            3.1
# 6           2018             11           12     22:56            3.2
# 7           2018             10           25     23:52            3.3
# 8           2018             10           27     10:00            3.4
# 9           2018             11            2     22:25            4.1
# 10          2018             11           15     20:20            4.2
# 11          2018             10           26     10:00            4.3
# 12          2018             11            2     22:39            5.3
# 13          2018             11           10     14:00            5.4
# 14          2018             11           22     22:15            6.1
# 15          2018             11            9     20:00            6.2
# 16          2018             11            2     22:33             m1
#
#     year_no  stream_no  stream_size  voted_cnt invalid_cnt NOTA_cnt  \
# 0         1          1          168        117           7        4
# 1         1          2          151        104           2        8
# 2         1          3          123         98           3        5
# 3         2          1          134         81           5        1
# 4         2          3          107         75           1        4
# 5         3          1          107         58           3       11
# 6         3          2           94         49           1        4
# 7         3          3          103         55           0        8
# 8         3          4           40         25           0        0
# 9         4          1           86         45           2       11
# 10        4          2           76         40           1        0
# 11        4          3           81         42           0        2
# 12        5          3           89         45           1        0
# 13        5          4           35         18           0        1
# 14        6          1           90         45           2        0
# 15        6          2           77         40           0        3
# 16        1          0           29         20           0        0
#
#                                         organizers
# 0        [Георгием Малиновским, Олегом Бузенковым]
# 1       [Георгием Малиновским, Кириллом Филатовым]
# 2       [Сенотовым Валерием, Малиновским Георгием]
# 3          [Валерией Фиткович, Николаем Малаховым]
# 4       [Сенотовым Валерием, Малиновским Георгием]
# 5   [Валерием Сенотовым, Александром Тонконоговым]
# 6               [Ильёй Денисовым, Дарьей Волковой]
# 7   [Валерием Сенотовым, Александром Тонконоговым]
# 8   [Валерием Сенотовым, Александром Тонконоговым]
# 9           [Денисовым Ильей, Воробьевой Наталией]
# 10      [Валерием Сенотовым, Анастасией Красновой]
# 11       [Вероникой Мазитовой, Николаем Малаховым]
# 12          [Георгием Малиновским, Марией Хаховой]
# 13         [Матвеем Кудасовым, Валерием Сенотовым]
# 14             [Валерием Сенотовым, Марией Корней]
# 15             [Марией Корней, Валерием Сенотовым]
# 16  [Сенотовым Валерием, Тонконоговым Александром]

# %%
result_streams_df_3.to_csv('ssmm_results_info_conv8.csv', sep='\t', encoding='utf-8', index=False)

# %%
# ОТДЕЛЬНАЯ ТАБЛИЦА ПО ОРГАНИЗАТОРАМ

organizers_df = result_streams_df_3[['year_x_year_stream','organizers']].apply(lambda x: x.explode()).reset_index().drop(['index'], axis=1)
# organizers_df

# %%
organizers_df.to_csv('ssmm_organizers_info_conv8.csv', sep='\t', encoding='utf-8', index=False)

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО КАНДИДАТАМ

result_names = {}
for link in result_links.keys():
    for name in result_links[link]['stream_election_info']['dict_nominated_with_votes'].keys():
        result_names[fix_name(name)] = {
            'link_year_no_x_name': str(result_links[link]['link_year_no']) + "_" + "_".join(fix_name(name).split()),
            'link_year_no': result_links[link]['link_year_no'], 
            'year_stream_no': result_links[link]['stream_election_info']['year_stream_no'], 
            'year_no': result_links[link]['stream_election_info']['year_no'], 
            'stream_no': result_links[link]['stream_election_info']['stream_no'], 
            'votes_cnt': result_links[link]['stream_election_info']['dict_nominated_with_votes'][name]['votes_cnt'],
            'elected_flg': result_links[link]['stream_election_info']['dict_nominated_with_votes'][name]['elected_flg'],
            'link': link
        }

result_names_df =  pd.DataFrame(result_names.items(), columns=['name', 'params'])
result_names_df_2 = pd.concat([result_names_df.drop(['params'], axis=1), result_names_df['params'].apply(pd.Series)], axis=1)
result_names_df_2
# .head(10)
# Out:
#                                     name  \
# 0          Мельникова Дарья Владимировна
# 1          Малиновский Георгий Андреевич
# 2        Бабаджанова Елена Александровна
# 3                Дехнич Кирилл Андреевич
# 4              Лоншаков Никита Артемович
# 5               Водолеев Марк Дмитриевич
# 6              Третьяков Пётр Максимович
# 7                  Клюев Андрей Игоревич
# 8         Евдокимова Софья Александровна
# 9             Пчельникова Елена Павловна
# 10       Шереметьев Владислав Валерьевич
# 11         Манахова Анастасия Николаевна
# 12             Лобанова Алёна Валерьевна
# 13          Шевченко Екатерина Романовна
# 14             Макаров Никита Михайлович
# 15             Янушкевич Иван Михайлович
# 16                Монина Дарья Ильинична
# 17             Белан Андрей Владимирович
# 18                  Бароян Аида Гришевна
# 19                Гаспарян Иосиф Жорович
# 20         Садовицкая Елизавета Петровна
# 21           Зенков Тимофей Владимирович
# 22               Чуб Вячеслав Валериевич
# 23        Алёшечкина Екатерина Сергеевна
# 24          Агуреева Екатерина Сергеевна
# 25          Приходко Макар Александрович
# 26          Арефьева Варвара Ярославовна
# 27                 Алеев Дамиль Павлович
# 28               Заводян Михаил Игоревич
# 29              Уваров Андрей Михайлович
# 30              Майданик Анна Кирилловна
# 31          Кадников Климентий Сергеевич
# 32        Вербовская Дарья Иннокентьевна
# 33       Витковский Андрей Владиславович
# 34            Абубакарова Лейла Арбиевна
# 35            Каляев Тимур Джанбулатович
# 36  Маммагаджиев Руслан Гаджимагомедович
# 37       Третьякова Екатерина Алексеевна
# 38          Мазитова Вероника Рустэмовна
# 39              Терехов Михаил Сергеевич
# 40       Поликарпов Александр Валерьевич
#
#                           link_year_no_x_name  link_year_no year_stream_no  \
# 0          2021_Мельникова_Дарья_Владимировна          2021            5.4
# 1          2021_Малиновский_Георгий_Андреевич          2021            5.4
# 2        2021_Бабаджанова_Елена_Александровна          2021            3.4
# 3                2021_Дехнич_Кирилл_Андреевич          2021            3.4
# 4              2021_Лоншаков_Никита_Артемович          2021            3.5
# 5               2021_Водолеев_Марк_Дмитриевич          2021            3.5
# 6              2021_Третьяков_Пётр_Максимович          2021            5.3
# 7                  2021_Клюев_Андрей_Игоревич          2021            5.3
# 8         2021_Евдокимова_Софья_Александровна          2021            5.3
# 9             2021_Пчельникова_Елена_Павловна          2021            5.2
# 10       2021_Шереметьев_Владислав_Валерьевич          2021            4.3
# 11         2021_Манахова_Анастасия_Николаевна          2021            4.3
# 12             2021_Лобанова_Алёна_Валерьевна          2021            3.3
# 13          2021_Шевченко_Екатерина_Романовна          2021            3.3
# 14             2021_Макаров_Никита_Михайлович          2021            3.3
# 15             2021_Янушкевич_Иван_Михайлович          2021            2.5
# 16                2021_Монина_Дарья_Ильинична          2021            2.2
# 17             2021_Белан_Андрей_Владимирович          2021            2.2
# 18                  2021_Бароян_Аида_Гришевна          2021            2.3
# 19                2021_Гаспарян_Иосиф_Жорович          2021            2.3
# 20         2021_Садовицкая_Елизавета_Петровна          2021            2.3
# 21           2021_Зенков_Тимофей_Владимирович          2021            3.2
# 22               2021_Чуб_Вячеслав_Валериевич          2021            3.2
# 23        2021_Алёшечкина_Екатерина_Сергеевна          2021            2.1
# 24          2021_Агуреева_Екатерина_Сергеевна          2021            2.1
# 25          2021_Приходко_Макар_Александрович          2021            2.1
# 26          2021_Арефьева_Варвара_Ярославовна          2021            1.3
# 27                 2021_Алеев_Дамиль_Павлович          2021            1.3
# 28               2021_Заводян_Михаил_Игоревич          2021            1.3
# 29              2021_Уваров_Андрей_Михайлович          2021            1.1
# 30              2021_Майданик_Анна_Кирилловна          2021            1.1
# 31          2021_Кадников_Климентий_Сергеевич          2021            1.1
# 32        2021_Вербовская_Дарья_Иннокентьевна          2021            3.1
# 33       2021_Витковский_Андрей_Владиславович          2021            3.1
# 34            2021_Абубакарова_Лейла_Арбиевна          2021            1.2
# 35            2021_Каляев_Тимур_Джанбулатович          2021             m1
# 36  2021_Маммагаджиев_Руслан_Гаджимагомедович          2021             m1
# 37       2021_Третьякова_Екатерина_Алексеевна          2021             m1
# 38          2021_Мазитова_Вероника_Рустэмовна          2021            6.1
# 39              2021_Терехов_Михаил_Сергеевич          2021            6.1
# 40       2021_Поликарпов_Александр_Валерьевич          2021            6.3
#
#     year_no  stream_no votes_cnt  elected_flg  \
# 0         5          4        21            1
# 1         5          4        20            1
# 2         3          4        22            1
# 3         3          4        22            1
# 4         3          5         5            1
# 5         3          5         3            0
# 6         5          3        37            1
# 7         5          3        34            1
# 8         5          3        38            1
# 9         5          2        36            1
# 10        4          3        37            1
# 11        4          3        30            1
# 12        3          3        19            1
# 13        3          3        40            1
# 14        3          3        26            1
# 15        2          5        11            1
# 16        2          2        39            1
# 17        2          2        50            1
# 18        2          3        34            1
# 19        2          3        20            1
# 20        2          3        23            1
# 21        3          2        28            1
# 22        3          2        38            1
# 23        2          1        27            1
# 24        2          1        35            1
# 25        2          1        44            1
# 26        1          3        22            1
# 27        1          3        31            1
# 28        1          3        44            1
# 29        1          1        22            1
# 30        1          1        35            1
# 31        1          1        27            1
# 32        3          1        38            1
# 33        3          1        36            1
# 34        1          2        58            1
# 35        1          0         6            1
# 36        1          0        10            1
# 37        1          0        19            1
# 38        6          1        27            1
# 39        6          1        16            1
# 40        6          3        43            1
#
#                                   link
# 0    https://vk.com/wall-33327655_9878
# 1    https://vk.com/wall-33327655_9878
# 2    https://vk.com/wall-33327655_9905
# 3    https://vk.com/wall-33327655_9905
# 4    https://vk.com/wall-33327655_9906
# 5    https://vk.com/wall-33327655_9906
# 6    https://vk.com/wall-33327655_9912
# 7    https://vk.com/wall-33327655_9912
# 8    https://vk.com/wall-33327655_9912
# 9    https://vk.com/wall-33327655_9945
# 10   https://vk.com/wall-33327655_9960
# 11   https://vk.com/wall-33327655_9960
# 12   https://vk.com/wall-33327655_9976
# 13   https://vk.com/wall-33327655_9976
# 14   https://vk.com/wall-33327655_9976
# 15   https://vk.com/wall-33327655_9984
# 16   https://vk.com/wall-33327655_9985
# 17   https://vk.com/wall-33327655_9985
# 18   https://vk.com/wall-33327655_9989
# 19   https://vk.com/wall-33327655_9989
# 20   https://vk.com/wall-33327655_9989
# 21   https://vk.com/wall-33327655_9992
# 22   https://vk.com/wall-33327655_9992
# 23   https://vk.com/wall-33327655_9998
# 24   https://vk.com/wall-33327655_9998
# 25   https://vk.com/wall-33327655_9998
# 26  https://vk.com/wall-33327655_10000
# 27  https://vk.com/wall-33327655_10000
# 28  https://vk.com/wall-33327655_10000
# 29  https://vk.com/wall-33327655_10001
# 30  https://vk.com/wall-33327655_10001
# 31  https://vk.com/wall-33327655_10001
# 32  https://vk.com/wall-33327655_10007
# 33  https://vk.com/wall-33327655_10007
# 34  https://vk.com/wall-33327655_10009
# 35  https://vk.com/wall-33327655_10018
# 36  https://vk.com/wall-33327655_10018
# 37  https://vk.com/wall-33327655_10018
# 38  https://vk.com/wall-33327655_10026
# 39  https://vk.com/wall-33327655_10026
# 40  https://vk.com/wall-33327655_10031

# %%
result_names_df_2.to_csv('ssmm_votes_info_conv11.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# ## Creating of final tables

# %%
# full table for 4-11 convocations:

def united_table_for_4_11(title_word):
    list_of_df = []
    for i in range(4,11+1):
        df = pd.read_csv('ssmm_'+title_word+'_info_conv'+str(i)+'.csv', sep='\t', encoding='utf-8')
        list_of_df.append(df)
    kek = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
    kek.to_csv('ssmm_'+title_word+'_info_conv_4_11.csv', sep='\t', encoding='utf-8', index=False)
    return None

title_words = ['announcement','candidates','results','organizers','votes']

for title_word in title_words:
    united_table_for_4_11(title_word)

# %% [markdown]
# ## Completeness testing

# %%
# ПОПРИДЖОЙНИВАТЬ АНОНСЫ НА РЕЗУЛЬТАТЫ, ЧТОБЫ ПОНЯТЬ, КАКИЕ ПОСТЫ С РЕЗУЛЬТАТАМИ НЕ РАСПОЗНАЛИСЬ

# - по созывам, внутри созывов:
#     - по потокам
#     - по кандидатам

# %%
ssmm_announcements_info = pd.read_csv('ssmm_announcement_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_candidates_info = pd.read_csv('ssmm_candidates_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_results_info = pd.read_csv('ssmm_results_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_organizers_info = pd.read_csv('ssmm_organizers_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_votes_info = pd.read_csv('ssmm_votes_info_conv_4_11.csv', sep='\t', encoding='utf-8')

# %%
# list(ssmm_candidates_info)

# %%
# проверка на пустые ячейки
ssmm_candidates_info[ssmm_candidates_info['program_txt'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, link_year_no_x_name, link_year_no, year_stream_no, year_no, stream_no, academic_group_no, program_txt, link]
# Index: []

# %%
# ssmm_candidates_info[ssmm_candidates_info['link'] == 'https://vk.com/wall-33327655_8330']
# https://vk.com/wall-33327655_8330

# %%
df1 = ssmm_announcements_info[['year_x_year_stream','link']]
df2 = ssmm_results_info[['year_x_year_stream','link']]

df1_x_d2 = df1.merge(df2, left_on='year_x_year_stream', right_on='year_x_year_stream',how='outer')
df1_x_d2_nan = df1_x_d2[df1_x_d2.isna().any(axis=1)]
df1_x_d2_nan
# df1_x_d2[120:180]

# ОСОБЕННОСТИ:
# 2014_m2 - нет в ssmm_announcements_info - не было анонса
# Out:
#     year_x_year_stream link_x                             link_y
# 164            2014_m2    NaN  https://vk.com/wall-33327655_2313

# %%
df1 = ssmm_candidates_info[['link_year_no_x_name','link']]
df2 = ssmm_votes_info[['link_year_no_x_name','link']]

df1_x_d2 = df1.merge(df2, left_on='link_year_no_x_name', right_on='link_year_no_x_name',how='outer')
df1_x_d2_nan = df1_x_d2[df1_x_d2.isna().any(axis=1)]
df1_x_d2_nan


# ОСОБЕННОСТИ (где-то как-то пометить):
# 	2016_Думаревский_Александр_Дмитриевич	https://vk.com/wall-33327655_5144	NaN	 - СНЯЛСЯ
# 	2019_Воронин_Вадим_Юрьевич	https://vk.com/wall-33327655_8323	NaN - СНЯЛСЯ
# 	2014_Вергазов_Марат_Марсович	NaN	https://vk.com/wall-33327655_2313 - НЕ БЫЛО АНОНСА

# ОШИБКИ:
# нет
# Out:
#                        link_year_no_x_name                             link_x  \
# 131  2016_Думаревский_Александр_Дмитриевич  https://vk.com/wall-33327655_5144
# 265             2019_Воронин_Вадим_Юрьевич  https://vk.com/wall-33327655_8323
# 390           2014_Вергазов_Марат_Марсович                                NaN
#
#                                 link_y
# 131                                NaN
# 265                                NaN
# 390  https://vk.com/wall-33327655_2313

# %% [markdown]
# ### finding similar names

# %%
# найти группы имен с минимальным расхождением по расстоянию левенштайна
# найти имена, являющиеся началом других имен (когда забыли про отчество)

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

string1 = "abc"
string2 = "aef"

print(levenshtein(string1, string2))

# %%
names = list(ssmm_candidates_info['name']) + list(ssmm_votes_info['name'])

from collections import Counter

names_stat = Counter(names) #.most_common()
# names_stat

# names_uniq = list(set(names))
# names_uniq

# %%
# выявляем похожие имена, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a, b) <= 4 and names_stat[a] >= names_stat[b]:
            print(levenshtein(a, b), ' - ', a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# 1  -  Муравьёва Анна Сергеевна 8  :  4 Муравьева Анна Сергеевна
# 1  -  Третьяков Артём Алексеевич 3  :  1 Третьяков Артем Алексеевич
# 1  -  Рогачёв Александр Викторович 3  :  1 Рогачев Александр Викторович
# 1  -  Порфирьева Наталия Алексеевна 1  :  1 Порфирьева Наталья Алексеевна
# 1  -  Гусейнов Сеймур Элданизович 2  :  2 Гусейнов Сэймур Элданизович
# 1  -  Гусейнов Сэймур Элданизович 2  :  2 Гусейнов Сеймур Элданизович
# 1  -  Третьяков Пётр Максимович 4  :  2 Третьяков Петр Максимович
# 1  -  Пушкарева Анна Константиновна 3  :  1 Пушкарёва Анна Константиновна
# 2  -  Лобанова Елена Валерьевна 3  :  3 Лобанова Алёна Валерьевна
# 1  -  Илизаров Год Эмануилович 1  :  1 Иллизаров Год Эмануилович
# 2  -  Лобанова Алёна Валерьевна 3  :  3 Лобанова Елена Валерьевна
# 1  -  Порфирьева Наталья Алексеевна 1  :  1 Порфирьева Наталия Алексеевна
# 1  -  Иллизаров Год Эмануилович 1  :  1 Илизаров Год Эмануилович

# %%
# выявляем имена без отчества, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if len(a) > len(b) and levenshtein(a[:len(b)], b) <= 4:
            print(a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# Лапина Софья Михайловна 4  :  2 Лапина София
# Иллизаров Год Эмануилович 1  :  1 Илизаров Год Эмануилович

# %%
# выявляем имена с перепутанными отчествами, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a[:12], b[:12]) <= 2 and names_stat[a] >= names_stat[b]:
            print(a, names_stat[a], ' : ', names_stat[b], b)

# Сакаев Роберт Марселевич 5  :  1 Сакаев Роберт Викторович
# Out:
# Муравьёва Анна Сергеевна 8  :  4 Муравьева Анна Сергеевна
# Лапина Софья Михайловна 4  :  2 Лапина София
# Сакаев Роберт Марселевич 5  :  1 Сакаев Роберт Викторович
# Третьяков Артём Алексеевич 3  :  1 Третьяков Артем Алексеевич
# Третьяков Артём Алексеевич 3  :  2 Третьяков Петр Максимович
# Рогачёв Александр Викторович 3  :  1 Рогачев Александр Викторович
# Порфирьева Наталия Алексеевна 1  :  1 Порфирьева Наталья Алексеевна
# Гусейнов Сеймур Элданизович 2  :  2 Гусейнов Сэймур Элданизович
# Федотов Константин Алексеевич 2  :  2 Фёдоров Константин Дмитриевич
# Алиев Рамиль Камиль Оглы 2  :  2 Алеев Дамиль Павлович
# Гусейнов Сэймур Элданизович 2  :  2 Гусейнов Сеймур Элданизович
# Перфильева Нелли Андреевна 2  :  1 Порфирьева Наталия Алексеевна
# Перфильева Нелли Андреевна 2  :  1 Порфирьева Наталья Алексеевна
# Фёдоров Константин Дмитриевич 2  :  2 Федотов Константин Алексеевич
# Третьяков Пётр Максимович 4  :  3 Третьяков Артём Алексеевич
# Третьяков Пётр Максимович 4  :  1 Третьяков Артем Алексеевич
# Третьяков Пётр Максимович 4  :  2 Третьяков Петр Максимович
# Пушкарева Анна Константиновна 3  :  1 Пушкарёва Анна Константиновна
# Лобанова Елена Валерьевна 3  :  3 Лобанова Алёна Валерьевна
# Илизаров Год Эмануилович 1  :  1 Иллизаров Год Эмануилович
# Третьяков Петр Максимович 2  :  1 Третьяков Артем Алексеевич
# Лобанова Алёна Валерьевна 3  :  3 Лобанова Елена Валерьевна
# Лобанова Алёна Валерьевна 3  :  2 Лобанова Анастасия Алексеевна
# Алеев Дамиль Павлович 2  :  2 Алиев Рамиль Камиль Оглы
# Порфирьева Наталья Алексеевна 1  :  1 Порфирьева Наталия Алексеевна
# Иллизаров Год Эмануилович 1  :  1 Илизаров Год Эмануилович

# %%
# incorrect: correct
correct_names_dict = {
#     из-за Е/Ё:
    'Муравьева Анна Сергеевна': 'Муравьёва Анна Сергеевна',
    'Третьяков Артем Алексеевич': 'Третьяков Артём Алексеевич',
    'Рогачев Александр Викторович': 'Рогачёв Александр Викторович',
    'Третьяков Петр Максимович': 'Третьяков Пётр Максимович',
    'Пушкарева Анна Константиновна': 'Пушкарёва Анна Константиновна',
#     из-за других букв:
    'Порфирьева Наталья Алексеевна': 'Порфирьева Наталия Алексеевна',
    'Лобанова Елена Валерьевна': 'Лобанова Алёна Валерьевна',
    'Иллизаров Год Эмануилович': 'Илизаров Год Эмануилович',
    'Гусейнов Сеймур Элданизович': 'Гусейнов Сэймур Элданизович',
#     из-за пропущенного отчества:
    'Лапина София': 'Лапина Софья Михайловна',   
#     из-за перепутанного отчества:
    'Сакаев Роберт Викторович': 'Сакаев Роберт Марселевич',   
}
# correct_names_dict

correct_names_df =  pd.DataFrame(correct_names_dict.items(), columns=['incorrect_name', 'correct_name'])
correct_names_df
# Out:
#                    incorrect_name                   correct_name
# 0        Муравьева Анна Сергеевна       Муравьёва Анна Сергеевна
# 1      Третьяков Артем Алексеевич     Третьяков Артём Алексеевич
# 2    Рогачев Александр Викторович   Рогачёв Александр Викторович
# 3       Третьяков Петр Максимович      Третьяков Пётр Максимович
# 4   Пушкарева Анна Константиновна  Пушкарёва Анна Константиновна
# 5   Порфирьева Наталья Алексеевна  Порфирьева Наталия Алексеевна
# 6       Лобанова Елена Валерьевна      Лобанова Алёна Валерьевна
# 7       Иллизаров Год Эмануилович       Илизаров Год Эмануилович
# 8     Гусейнов Сеймур Элданизович    Гусейнов Сэймур Элданизович
# 9                    Лапина София        Лапина Софья Михайловна
# 10       Сакаев Роберт Викторович       Сакаев Роберт Марселевич
