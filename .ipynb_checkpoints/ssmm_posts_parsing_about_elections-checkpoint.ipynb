# %%
#     В ЭТОМ КОДЕ:

#     + кластеризуем посты в группе ССММ (про выборы/нет, анонсы/результаты выборов)
#     + посты с анонсами выборов конвертируем в словарики (имя, курс-поток-группа, текст программы)
#     + посты с результатами выборов конвертируем в словарики со всей информацией об итогах выборов
#     + последние два пункта адаптировать для постов про магистров
#   !!! расставляем флаги предпочтений кандидатов, исходя из текста программ

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
import re
from datetime import datetime, date, time

import pandas as pd

# %%
'''
ЧТО ПОФИКСИТЬ:
- БАГ: путает блок текста в шапке репоста с блоком текста в самом репосте (пример: https://vk.com/wall-33327655_2261)
- находить посты с перечнем избранных должностей
- https://vk.com/wall-33327655_5491 - запись удалена, но код этого не видит
- https://vk.com/wall-33327655_5492 - запись не найдена, а код сломался
- https://vk.com/wall-33327655_9414 - код сломался
- были парные кандидаты, найти и расщепить

- ВЫТАЩИТЬ 1-3 СОЗЫВЫ ИЗ ТРЕДОВ
- прогнать 1-3 созывы через сравнение имен
- сделать СКВОЗНУЮ НУМЕРАЦИЮ ssmm_id по мере публикации заявок
'''

# СДЕЛАТЬ ПАРСИНГ ОБСУЖДЕНИЙ В ГРУППЕ:
#     треды с кандидатами 1-3 созывов
#     треды с отчетами о собраний 1-2(3?) созывов

# %%
# ссылка на репост без шапки, репостнутая запись - без текста (обновление аватарки):

req_announcement = requests.get('https://vk.com/wall-33327655_9846')
html_doc = req_announcement.text
print(html_doc)

# типы постов:

#     https://vk.com/wall-33327655_2250 -- пост с тегом
#     https://vk.com/wall-33327655_2261 -- пост без тега
#     https://vk.com/wall-33327655_2255 -- post not found
#     https://vk.com/wall-33327655_2262 -- коммент под постом с тегом
#     https://vk.com/wall-33327655_3330 -- репост без шапки поста с адресом 104154624_1
#     https://vk.com/wall-33327655_8489 -- репост с шапкой поста по адресу 77014399_6331
# Out:
#             <!DOCTYPE html>
#       <html lang="ka" class="vk vk_js_no vk_1x vk_flex_no r d h  vk_appAuth_no n vk_old  vk_schemes_no   ">
#       <head>
#               <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, minimal-ui, user-scalable=no" />
#         <meta name="format-detection" content="telephone=no" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <meta name="MobileOptimized" content="176" />
#         <meta name="HandheldFriendly" content="True" />
#         <base id="base">
#
#         <meta name="description" content="МФК в осеннем семестре    #образование_ссмм    Запись на Межфакультетские курсы в осеннем семестре 2021/2022 учебного года откроется 3 окт" />
#         <meta property="og:description" content="МФК в осеннем семестре    #образование_ссмм    Запись на Межфакультетские курсы в осеннем семестре 2021/2022 учебного года откроется 3 окт" />
#         <link rel="shortcut icon" href="/images/icons/favicons/fav_logo.ico?8"></link>
#             <link rel="icon" type="image/png" sizes="32x32" href="/images/icons/pwa/favicon_32.png?12">
#     <link rel="apple-touch-icon" href="/images/icons/pwa/apple/default.png?15">
#     <meta name="apple-mobile-web-app-title" content="VK">
#     <meta name="application-name" content="VK">
#     <meta name="mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#         <meta name="theme-color" content="#ffffff">
# <meta name="color-scheme" content="light">
#         <title>МФК в осеннем семестре #образование_ссмм.. | Студенческий совет мехмата МГУ | VK</title>
#         <meta http-equiv="origin-trial" content="Av8ECqeAAIiC9bF3N7aq2M/TaxNzzpPcFXnw0rRb9KRUQlbyHKYmPj6KeVUFVDk+S7W9RfJH2GsEOS8G99uJvgcAAABaeyJvcmlnaW4iOiJodHRwczovL3ZrLmNvbTo0NDMiLCJmZWF0dXJlIjoiQmFkZ2luZyIsImV4cGlyeSI6MTU2MTY2MTkxNCwiaXNTdWJkb21haW4iOnRydWV9">
#         <script nomodule>window.nomodules = true;</script>
#
#         <script>
#           (function() {
#             window.vk = {"id":0,"__debug":false,"__dev":false,"__domain":"vk.com","wsTransport":"https:\/\/stats.vk-portal.net","statsMeta":{"platform":"mvk","st":false,"time":1657555698,"hash":"Rvc7elw8lQOLBgOmZ6Zk2sbhKl7JqZ0CwCkrRzRePWP"},"tnsPixelType":"unauth","tnsPixelSocdem":"13","platform":"mvk","liteMode":{"enabled":false,"reminderDisabled":true,"hash":"4c29761952b8cfda89"},"apiConfigDomains":{"apiDomain":"api.vk.com","loginDomain":"login.vk.com","connectDomain":"id.vk.com"},"logoutUrl":"https:\/\/login.vk.com\/?act=logout_mobile&hash=68d3ee5700033fbe6b&_origin=https%3A%2F%2Fm.vk.com&lrt=47DEQpj8HBSa-_TImW-5JCeuQeRkm5NMpJWZG3hSuFU","selectorsToCheck":[],"rv":"111553","ts":1657555698,"sw":null,"stFiles":{"https:\/\/st1-20.vk.com\/css\/mobile\/legacy_fallback.2b95eba516fb588edffb.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/common_fallback.c7e26c39f561d12dde65.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/audio_fallback.f0707f6a56208de5d082.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/mail_fallback.e4b1aa23347675d2f4c7.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/wall_fallback.e52bfd9f821651fbbb72.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/reactions_fallback.038645428c5888d21864.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/vkui_fallback.2fdf9b711c5d22e6007a.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/qsearch_fallback.2a13b06297e7f1270f79.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/unauthorized_fallback.7a1171234b462153c7d1.css":"","https:\/\/st1-20.vk.com\/css\/mobile\/owner_photo_upload_fallback.1fb24145e70ab89dfe13.css":"","https:\/\/st1-20.vk.com\/dist\/mobile\/reactions_fallback.24b5ba093f9c156eee2b.js":"d77b36d1c64e75af8ddb5f56c0fc8ed5a8fdd6ce332495b71cb4a3307e3aa79c","https:\/\/st1-20.vk.com\/dist\/mobile\/vendor~icons_fallback.968ed1ced6e7de7b7bfc.js":"774d5d4cc4870a144bb1f317fddf085c5eef1a91e39f205865da091644bf019b","https:\/\/st1-20.vk.com\/dist\/mobile\/vendor~search_fallback.363937703e98146ce776.js":"551b93aca893e387d59e1802000431f8c79bda6c0289bcf54a2d3c5af8b25c34","https:\/\/st1-20.vk.com\/dist\/mobile\/qsearch_fallback.8fa44a5b4f71f8f3526f.js":"d7ca4dcfe8bc2761ac0274bfcff49f630afc5fdc9bfdd21e8d3d2154ce77ec54","https:\/\/st1-20.vk.com\/dist\/mobile\/grip_fallback.744678f4f1e36a7879d0.js":"1424dc70b197023365c1dbc9ec9ec0da7b2c41297b0469c68464ba41a0fef30b","https:\/\/st1-20.vk.com\/dist\/mobile\/icons_fallback.a1cf39d8c4bf3529f604.js":"2a32c327b622a45bf71fbadf0e2a7735538dfdde42f8cea49cf9c60df32dc315","https:\/\/st1-20.vk.com\/dist\/mobile\/unauthorized_fallback.1fe4c85f4c95ddf1bdd8.js":"f8e5202bd7b56380fc5b89ba15a9b7d404e696d8adf1389681d4755a0e9df74c","https:\/\/st1-20.vk.com\/dist\/mobile\/owner_photo_upload_fallback.2aa17ff77df9a522860b.js":"e793dafdfcd8276c55ae456698a284a18877ff8da16085bbe4162947095a0c77"},"stDomain":"https:\/\/st1-20.vk.com","stNavMap":{"^\\\/join":["https:\/\/st1-20.vk.com\/dist\/mobile\/join_fallback.f394d027fcb4988b43e0.js","https:\/\/st1-20.vk.com\/css\/mobile\/join_fallback.32b9a4f0f3a889ec7b6b.css"],"promocode(\\\/([0-9a-zA-Z-]+))?":["https:\/\/st1-20.vk.com\/dist\/mobile\/promocode_fallback.03bd8e63da85a179cb3c.js","https:\/\/st1-20.vk.com\/css\/mobile\/promocode_fallback.1aa8a4979f831f369e3c.css"],"^\\\/audio":["https:\/\/st1-20.vk.com\/dist\/mobile\/icons_fallback.a1cf39d8c4bf3529f604.js","https:\/\/st1-20.vk.com\/dist\/mobile\/vendor_fallback.e67c892f685a64e566c8.js","https:\/\/st1-20.vk.com\/dist\/mobile\/audio_fallback.f87cee6a8b5d9ebe2c42.js"],"^\\\/video":["https:\/\/st1-20.vk.com\/dist\/mobile\/icons_fallback.a1cf39d8c4bf3529f604.js","https:\/\/st1-20.vk.com\/dist\/mobile\/video_fallback.98187da4c79e44f35697.js","https:\/\/st1-20.vk.com\/css\/mobile\/video_fallback.8481fa805584ea96b1bb.css","https:\/\/st1-20.vk.com\/css\/mobile\/mail_fallback.e4b1aa23347675d2f4c7.css"],"^\\\/clip":["https:\/\/st1-20.vk.com\/dist\/mobile\/short_video_fallback.29bc7518fad4b5d1a2dd.js","https:\/\/st1-20.vk.com\/css\/mobile\/ShortVideoPage_fallback.17aff9be95df0678de63.css","htt ...
#             window.isMVK = true;
#             window.isNewMail = false;
#             window.isNewLongpoll = false;
#             window.audioSubscribe = false;
#             window.isArticleWebView = false;
#
#             var vkElem = document.querySelector('.vk');
#             var vkClass = vkElem.getAttribute('class');
#
#             function cssPropertySupported(pNames) {
#               var element = document.createElement('a');
#               var index = pNames.length;
#               try {
#                 while (index--) {
#                   var name = pNames[index];
#
#                   element.style.display = name;
#                   if (element.style.display === name) {
#                     return true;
#                   }
#                 }
#               } catch (pError) {}
#
#               return false;
#             }
#             var supports = {
#               js: true,
#               flex: cssPropertySupported('flex -webkit-flex -ms-flexbox -moz-box -webkit-box'.split(' ')),
#             };
#
#             supports.js && (vkClass = vkClass.replace('vk_js_no', 'vk_js_yes'));
#             supports.flex && (vkClass = vkClass.replace('vk_flex_no', 'vk_flex_yes'));
#             vkElem.setAttribute('class', vkClass);
#           })();
#         </script>
#
#
#         <script type="text/javascript">
# <!--
# ;/*top_script*/(function(){"use strict";var e=function e(){return Boolean(window.matchMedia)},t=function e(){return document.documentElement.classList.contains("vk_flex_yes")},o=function e(){return Boolean(document.createElementNS)&&Boolean(document.createElementNS("http://www.w3.org/2000/svg","svg").createSVGRect)},n=function e(){return"MutationObserver"in window},i=function e(){return!window.nomodules};function r(e){a(e),e.hash_redirect&&c(e),e.al_ver&&(window.al={ver:e.al_ver}),document.addEventListener("DOMContentLoaded",(function(){e.help_hints&&window.helpHints&&window.helpHints.initHelpHints&&window.helpHints.initHelpHints(e.help_hints),e.detect_broken_static&&s()}))}function a(r){var a=r.iospwa_cookie,c=r.device_cookie,s=r.cookie_secure,u=r.cookie_samesite,d=r.cookie_path,l=r.cookie_domain,p=r.need_reload,w=r.cookie_rewrite_enabled,m=new Date((new Date).getTime()+7776e6).toUTCString();!0===navigator.standalone&&-1===document.cookie.indexOf(a+"=1")&&(document.cookie=a+"=1; expires="+m+";"+s+u+" path="+d+"; domain="+l);var f=document,h=window,v="undefined",y="!",g="-",_=h.screen,k=_.width||0,M=_.height||0,T=h.devicePixelRatio||1,b=new RegExp("(^|;\\s+)"+c+"=([^;]+)"),H=(f.cookie.match(b)||[])[2]||"",R=H.split("/"),B=H&&k==R[0]&&M==R[1]&&T==R[2]&&9===R[3].length,L=!!B&&R[3][8],x=w&&"-"===L&&X()!==L;if(!B||x){var S=[k,M,T,j()].join("/");f.cookie=c+"=; expires="+new Date(0).toUTCString()+";"+s+u+" path="+d,f.cookie=c+"="+S+"; expires="+m+";"+s+u+" path="+d+"; domain="+l,""!==f.cookie&&p&&location.reload()}function X(){var i;return t()&&e()&&o()&&n()?"!":"-"}function j(){var e=(function(){var e;try{e=new XMLHttpRequest}catch(t){try{e=new ActiveXObject("Msxml2.XMLHTTP")}catch(t){try{e=new ActiveXObject("Microsoft.XMLHTTP")}catch(e){}}}return e?"!":"-"})(),t=((o=f.createElement("div")).innerHTML='<input type="file" />',"file"!==(o=o.getElementsByTagName("input")[0]).type||o.disabled?"-":"!"),o,n="ontouchstart"in h?"!":"-",r="-",a,c,s,u,d;try{(typeof navigator.geolocation!==v||typeof h.google!==v&&typeof google.gears!==v||typeof device!==v&&typeof device.getServiceObject!==v||typeof Mojo!==v&&"Mojo.Service.Request"!=typeof Mojo.Service.Request)&&(r="!")}catch(e){}return[e,t,n,r,(function(e){try{var t=h.Audio?new Audio:f.createElement("audio");if(t.canPlayType&&t.canPlayType(e)&&"no"!==t.canPlayType(e))return"!"}catch(e){}return"-"})("audio/mpeg"),(function(e){try{for(var t=f.createElement("div"),o=["","webkit","Moz","ms","O"],n=0,i=o.length;n<i;n++){var r=o[n],a=r?r+e:e.toLowerCase();if(typeof t.style[a]!==v)return"!"}return"-"}catch(e){return"-"}})("Transform"),(h.XMLHttpRequest||h.XDomainRequest)&&(h.FormData||h.FileReader&&(h.XMLHttpRequest&&XMLHttpRequest.sendAsBinary||h.ArrayBuffer&&h.Uint8Array&&(h.MozBlobBuilder||h.WebKitBlobBuilder||h.BlobBuilder)))?"!":"-",i()?"!":"-",X()].join("")}}function c(e){var t=e.cookie_secure,o=e.cookie_samesite,n=location,i=n.hash||"",r=i.substr(2);if("#/"===i.substr(0,2)){var a=window.locDomain,c=new Date;c.setTime(c.getTime()+864e5);var s="; expires="+c.toGMTString();document.cookie=["remixtmp_hash_nav","=",escape(n.href),s,"; path=/",""+t,""+o,a?"; domain=."+a:""].join(""),r.match(/^\/*(away|login)(\.php)?([^a-z0-9\.]|$)/)&&(r=""),n.replace(n.protocol+"//"+n.host+"/"+r)}}function s(){try{window.onDOMReady((function(){})),window.extend({},{})}catch(t){var e=new XMLHttpRequest;e.open("POST","/?act=broken_static_log&err="+encodeURIComponent(t.message),!0),e.send()}}return r})()({"hash_redirect":true,"device_cookie":"remixmdevice","iospwa_cookie":"remixmiospwa","cookie_path":"\/","cookie_domain":".vk.com","cookie_samesite":"","cookie_secure":" Secure;","need_reload":true,"help_hints":{"mvk:video_filters":{"id":"mvk:video_filters","active":false,"hash":null},"narratives:add_tooltip":{"id":"narratives:add_tooltip","active":false,"hash":null},"mvk:stories_archive:privacy_hint":{"id":"mvk:stories_archive:privacy_hint","active":false,"hash":null},"mvk:stories_archive:actions_hint":{"id":"mvk:storie ...
# //-->
# </script>
#
#         <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/legacy_fallback.2b95eba516fb588edffb.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/common_fallback.c7e26c39f561d12dde65.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/audio_fallback.f0707f6a56208de5d082.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/mail_fallback.e4b1aa23347675d2f4c7.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/wall_fallback.e52bfd9f821651fbbb72.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/reactions_fallback.038645428c5888d21864.css">
# <link rel="preload" as="style" href="https://st1-20.vk.com/css/mobile/vkui_fallback.2fdf9b711c5d22e6007a.css">
# <link rel="preload" as="style" href="https://st1-20.vk.com/css/mobile/qsearch_fallback.2a13b06297e7f1270f79.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/unauthorized_fallback.7a1171234b462153c7d1.css">
# <link rel="stylesheet" href="https://st1-20.vk.com/css/mobile/owner_photo_upload_fallback.1fb24145e70ab89dfe13.css">
# <!--defer:["https:\/\/st1-20.vk.com\/css\/mobile\/vkui_fallback.2fdf9b711c5d22e6007a.css","https:\/\/st1-20.vk.com\/css\/mobile\/qsearch_fallback.2a13b06297e7f1270f79.css"]-->
# <script src="https://st1-20.vk.com/dist/mobile/reactions_fallback.24b5ba093f9c156eee2b.js?d77b36d1c64e75af8ddb5f56c0fc8ed5a8fdd6ce332495b71cb4a3307e3aa79c"></script>
# <script src="https://st1-20.vk.com/dist/mobile/grip_fallback.744678f4f1e36a7879d0.js?1424dc70b197023365c1dbc9ec9ec0da7b2c41297b0469c68464ba41a0fef30b"></script>
# <script src="https://st1-20.vk.com/dist/mobile/icons_fallback.a1cf39d8c4bf3529f604.js?2a32c327b622a45bf71fbadf0e2a7735538dfdde42f8cea49cf9c60df32dc315"></script>
# <script src="https://st1-20.vk.com/dist/mobile/unauthorized_fallback.1fe4c85f4c95ddf1bdd8.js?f8e5202bd7b56380fc5b89ba15a9b7d404e696d8adf1389681d4755a0e9df74c"></script>
# <script src="https://st1-20.vk.com/dist/mobile/owner_photo_upload_fallback.2aa17ff77df9a522860b.js?e793dafdfcd8276c55ae456698a284a18877ff8da16085bbe4162947095a0c77"></script>
# <link rel="preload" as="script" href="https://st1-20.vk.com/dist/mobile/vendor~icons_fallback.968ed1ced6e7de7b7bfc.js" />
# <link rel="preload" as="script" href="https://st1-20.vk.com/dist/mobile/vendor~search_fallback.363937703e98146ce776.js" />
# <link rel="preload" as="script" href="https://st1-20.vk.com/dist/mobile/qsearch_fallback.8fa44a5b4f71f8f3526f.js" />
# <!--defer:["https:\/\/st1-20.vk.com\/dist\/mobile\/vendor~icons_fallback.968ed1ced6e7de7b7bfc.js","https:\/\/st1-20.vk.com\/dist\/mobile\/vendor~search_fallback.363937703e98146ce776.js","https:\/\/st1-20.vk.com\/dist\/mobile\/qsearch_fallback.8fa44a5b4f71f8f3526f.js"]-->
#         <link rel="canonical" href="https://vk.com/wall-33327655_9819?reply=9846" />
#         <link rel="alternate" href="android-app://com.vkontakte.android/vkontakte/m.vk.com/wall-33327655_9819?reply=9846" />
#       </head>
#
#       <body  class="vk__page _ivk _hover vk_ios_no vk_stickers_hints_support_no opera_mini_no vk_safari_no vk__page_singlePost vk_tabbar_static    vk_al_no ">
#         <script id="color-scheme-script" type="text/javascript">
# <!--
# ;/*body*/(function(){"use strict";function e(e){var o=e.colorSchemeMode,c=e.isForcedColorSchemeMode,r=e.isDarkSchemeGuideHidden,s=e.colorSchemesMap;if(window.colorScheme){var t=o;try{var i=sessionStorage.getItem("colorScheme");i&&(t=i,window.colorScheme.isModeSavingAllowed=!1),c&&(t=o,window.colorScheme.isModeSavingAllowed=!1,sessionStorage.setItem("colorScheme",o))}catch(e){}window.colorScheme.init({mode:t,schemesMap:s});var d=document.querySelector(".vk"),m=d.getAttribute("class");window.isSchemesSupported()&&(m=m.replace("vk_schemes_no","vk_schemes_yes")),d.setAttribute("class",m)}var n=document.getElementById("color-scheme-script");n.parentNode.removeChild(n)}return e})()({"colorSchemeMode":"auto","isForcedColorSchemeMode":false,"colorSchemesMap":null});
# //-->
# </script>
#
#             <div class="layout">
#
#           <div class="layout__header mhead" id="vk_head">
#       <div class="hb_wrap">
#         <div class="hb_btn">&nbsp;</div>
#       </div>
#     </div>
#       <div class="layout__body " id="vk_wrap">
#         <div class="layout__leftMenu" id="l">
#
#         </div>
#         <div class="layout__basis" id="m" role="main">
#               <div class="basis">
#       <div class="basis__header mhead basis__header_noBottomMenu basis__header_noshadow basis__header_noshadowAnim basis__header_unauthorized_actions basis__header_nohide" id="mhead">
#         <div class="header__center hb_wrap mhb_back header__title-wrapper">
#         <a class="header__back  al_back mh mh_noleftmenu" href="/stud_mm" rel="noopener"title="&#4323;&#4313;&#4304;&#4316;" onclick="return nav.backToTabHistory(this);" role="button" accesskey="0"><div aria-hidden="true" class="svgIcon svgIcon-back_outline_28"><svg width="28" height="28" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M28 0H0v28h28z"/><path d="M12.3 6.3a1 1 0 0 1 1.4 1.4L8.42 13H22a1 1 0 0 1 1 .88V14a1 1 0 0 1-1 1H8.41l5.3 5.3a1 1 0 0 1 .08 1.31l-.08.1a1 1 0 0 1-1.42 0l-7-7-.07-.09A1 1 0 0 1 5 14v.09a1 1 0 0 1 0-.07V14a1.02 1.02 0 0 1 .13-.48.88.88 0 0 1 .07-.11 1 1 0 0 1 .1-.12l-.09.1a.97.97 0 0 1 .08-.1z" fill="currentColor" fill-rule="nonzero"/></g></svg></div></a>
#         <div aria-labelledby="header__title" class="header__titleContainer">
#             <span class="header__title-inner" aria-hidden="true"><span class="header__title hb_btn mh_header"><span id="header__title" class="header__text">&#4329;&#4304;&#4316;&#4304;&#4332;&#4308;&#4320;&#4312; &#4313;&#4308;&#4307;&#4308;&#4314;&#4310;&#4308;</span></span></span>
#         </div>
#     </div>
#
#     </div>
#       <div class="basis__menu"><div class="VideoFilterBadgeFiller"></div></div>
#
#       <div class="basis__content mcont " id="mcont" data-canonical="https://vk.com/wall-33327655_9819?reply=9846">    <div class="pcont">
#       <div class="PageBlock">
#       <div class="Separator Separator--hideOnDesktop"><div></div></div>
#
#
#           <div class="wall_item single_wall_item bl_item mark_top_verified">
#
#
#       <div class="wi_head">
#         <a href="/stud_mm?from=post" data-post-id="-33327655_9819" data-post-click-type="post_owner_img" rel="noopener"><div class="PostHeader__avatarWrapper PostHeader__avatarWrapper--default"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-2 Avatar--size-48" role="img"  aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-22.userapi.com/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&quality=96&crop=0,0,827,827&ava=1&#39;)"><div></div></div><div class="Avatar__text">С</div></div></div></div></a>
# <div class="PostHeader__contentWrapper">
#   <div class="wi_cont">
#         <div class="wi_author"><a class="pi_author" href="/stud_mm?from=post" rel="noopener" data-post-id="-33327655_9819" data-post-click-type="post_owner_link"data-post-owner-type="group">Студенческий совет мехмата МГУ</a> </div>
#     <div class="wi_info"><span class="wi_date">30 &#4321;&#4308;&#4325; 2021  12:34</span></div>
#   </div>
#   <div class="wi_cont_side">
#
# </div>
# </div>
#       </div>
#       <div class="wi_body">
#
#               <div class="pi_text">МФК в осеннем семестре <br/> <br/><a href="/feed?section=search&q=%23%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D1%81%D1%81%D0%BC%D0%BC">#образование_ссмм</a> <br/> <br/>Запись на Межфакультетские курсы в осеннем семестре 2021/2022 учебного года откроется 3 октября в 12:00 на сайте <a href="/away.php?to=https%3A%2F%2Flk.msu.ru%2F&post=-33327655_9819" target="_blank" rel="noopener nofollow">https://lk.msu.ru/</a> <br/>Все МФК в этом семестре пройдут в дистанционном формате. Первая лекция запланирована на 6 октября и будет носить ознакомительный характер. Её материал не должен быть обязательным для получения зачёта по курсу. <br/> <br/>Мы напоминаем, что освоение МФК на нашем факультете обязательно в 6-9 семестрах. Отсутствие зачёта по МФК в указанный период приравнивается к академической задолженности. При желании все курсы можно пройти и раньше, но не более 2 курсов в один семестр. <br/> <br/>С этого семестра всем студентам, у которых освоение МФК ещё не завершено в соответствии с учебным планом, необходимо пройти хотя бы один курс по тематике искусственного интеллекта. Обращаем ваше внимание на то, что это касается и студентов 5 курса, даже если к началу этого семестра вы прошли все 4 обязательных курса. Таким образом, все пятикурсники в этом семестре обязаны пройти МФК по тематике искусственного интеллекта.<br/> <br/>Более подробно можно прочитать в прикреплённом файле.<br/><br/>Если у вас остались какие-то вопросы, можно оставить их в комментариях или в сообщениях группы, а мы постараемся оперативно на них ответить&#33;</div>
#     <div class="pi_medias thumbs_list thumbs_list1">  <div class="medias_thumbs medias_thumbs_map"><div class="thumbs_map_wrap" style="width: 100%;"><div class="thumbs_map_helper" style="padding-top: 66.4773%;"><div class="thumbs_map fill"><div style="width: 100%; height: 100%; margin: 0 0% 0% 0;" class="thumb_map thumb_map_wide thumb_map_l al_photo"><a  href="/photo-33327655_457240569?rev=1&post=-33327655_9819&from=post"  aria-label="&amp;#4324;&amp;#4317;&amp;#4322;&amp;#4317;&amp;#4321;&amp;#4323;&amp;#4320;&amp;#4304;&amp;#4311;&amp;#4312;" class="thumb_link "><div style="margin-left: -0.1005%; background-image: url(https://sun1-22.userapi.com/impf/2y0r6wVCP4TDMCKSTIaC1Rl8pDulqOKGh6-cKQ/79qNAgLsM0A.jpg?size=604x403&quality=96&sign=03f68b4eda84623b87622fc5087be5a9&type=album);"  class="thumb_map_img thumb_map_img_as_div"  data-id="-33327655_457240569" data-src_big="https://sun1-22.userapi.com/impf/2y0r6wVCP4TDMCKSTIaC1Rl8pDulqOKGh6-cKQ/79qNAgLsM0A.jpg?size=604x403&amp;quality=96&amp;sign=03f68b4eda84623b87622fc5087be5a9&amp;type=album|604|403" data-restriction="null"></div></a></div></div></div></div></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_613751310?hash=BKRTWkO4cLW7aemyDaLmq8mbT1khMCQZiiVrQluNr0D&dl=QXZ5hh4gLWvMBFAZLQDwi3Qa8KGMuAKkEA2oVf8ykZo" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">&#4324;&#4304;&#4312;&#4314;&#4312;</span><span class="medias_link_labeled medias_link_title"> МФК осень 2021.pdf</span><span class="medias_link_desc">&#4324;&#4304;&#4314;&#4312; PDF, 877 KB</span></span></a></div></div>
#         <div class="pi_signed">
#       <span class="PostSign__icon"><div aria-hidden="true" class="svgIcon svgIcon-user_16"><svg width="16" height="16" viewBox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><g id="id-user_16__Page-2" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd"><g id="id-user_16__user_16"><path id="id-user_16__Bounds" d="M0 0h16v16H0z"/><path d="M10.75 5.25a2.75 2.75 0 1 0-5.5 0 2.75 2.75 0 0 0 5.5 0ZM2.5 12.12v.71c0 .37.3.67.67.67h9.66c.37 0 .67-.3.67-.67v-.71C13.5 9.69 9.84 9 8 9c-1.84 0-5.5.7-5.5 3.12Z" id="id-user_16__Mask" fill="currentColor"/></g></g></svg></div></span><a class="user" href="/darya_059" rel="noopener">&#4307;&#4304;&#4320;&#4312;&#4304; &#4315;&#4308;&#4314;&#4316;&#4312;&#4313;&#4317;&#4309;&#4304;</a>
#     </div>
#
#         <div class="wi_like_wrap wi_like_wrap--actionStatusBar"><a class="ReactionsPreview" href="/like?act=members&object=wall-33327655_9819" title="&#4328;&#4308;&#4304;&#4324;&#4304;&#4321;&#4304; 10 &#4304;&#4307;&#4304;&#4315;&#4312;&#4304;&#4316;&#4315;&#4304;"><span class="ReactionsPreview__items"><div class="ReactionsPreview__item ReactionsPreview__item--stackOverlay" style="background-image: url(&#39;https://vk.com/reaction/1-reactions-0-48?c_uniq_tag=e6bee176471af6e4f7ca0f57ac099847d57b8101bf07944e47b42b097a6d8455&#39;)"></div><div class="ReactionsPreview__item ReactionsPreview__item--stackOverlay" style="background-image: url(&#39;https://vk.com/reaction/1-reactions-4-48?c_uniq_tag=c80e3224c299a73384c057ff065c9458dcd533d57a1458875eb98883c3a96783&#39;)"></div><div class="ReactionsPreview__item ReactionsPreview__item--stackOverlay" style="background-image: url(&#39;https://vk.com/reaction/1-reactions-2-48?c_uniq_tag=2a6544dce8827d216db7ea91eafc726cd3a823f5d465ba00216901a6de2801ad&#39;)"></div></span><span class="ReactionsPreview__label" aria-hidden="true">10</span></a></div>
#         <div class="PostRowBottomButtons Post__row _wi_buttons"><div class="PostRowBottomButtons__buttons"><div class="PostBottomButtons _post_bottom_like_wrap"><div class="_PostBottomButtonReactionContainer PostBottomButtonContainer PostBottomButtonContainer--with-textual" data-section-ref="reactions-button-container"><div class="Anchor ReactionsMenuAnchor" id="wall-33327655_9819-reaction"><div></div></div><div id="js-reactions-menu-wall-33327655_9819" class="_ReactionsMenuContainerRoot ReactionsMenuContainer" data-section-ref="reactions-menu-container"></div><a class="PostBottomButton PostBottomButtonReaction" href="/wall-33327655_9819?reactions_opened=wall-33327655_9819#wall-33327655_9819-reaction" rel="noopener" data-reaction-href="/like?act=set_reaction&from=wall-33327655_9819&hash=f9522b861d8b20fb24&object=wall-33327655_9819&one=1" data-reaction-set-id="reactions" data-reaction-target-object="wall-33327655_9819" onclick="Reactions.onButtonClick(this, event)" onmousedown="Reactions.onButtonMouseDown(this, event)" onmouseenter="Reactions.onButtonMouseEnter(this, event)" ontouchstart="Reactions.onButtonMouseDown(this, event)" role="button" title="&#4306;&#4304;&#4304;&#4306;&#4310;&#4304;&#4309;&#4316;&#4308;&#4311; &#4320;&#4308;&#4304;&#4325;&#4330;&#4312;&#4304; «&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;»" tabindex="0" style=""><span class="PostBottomButton__icon"><div aria-hidden="true" class="svgIcon svgIcon-like_outline_24"><svg height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z"/><path d="M16 4a5.95 5.95 0 0 0-3.89 1.7l-.12.11-.12-.11A5.96 5.96 0 0 0 7.73 4 5.73 5.73 0 0 0 2 9.72c0 3.08 1.13 4.55 6.18 8.54l2.69 2.1c.66.52 1.6.52 2.26 0l2.36-1.84.94-.74c4.53-3.64 5.57-5.1 5.57-8.06A5.73 5.73 0 0 0 16.27 4zm.27 1.8a3.93 3.93 0 0 1 3.93 3.92v.3c-.08 2.15-1.07 3.33-5.51 6.84l-2.67 2.08a.04.04 0 0 1-.04 0L9.6 17.1l-.87-.7C4.6 13.1 3.8 11.98 3.8 9.73A3.93 3.93 0 0 1 7.73 5.8c1.34 0 2.51.62 3.57 1.92a.9.9 0 0 0 1.4-.01c1.04-1.3 2.2-1.91 3.57-1.91z" fill="currentColor" fill-rule="nonzero"/></g></svg></div></span><span class="PostBottomButton__label PostBottomButton__label--with-textual" aria-hidden="true"><span class="PostBottomButtonReaction__label PostBottomButtonReaction__label--textual" aria-hidden="true">&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;</span></span></a><span class="visually-hidden" role="button" data-reaction-href="/like?act=set_reaction&from=wall-33327655_9819&hash=f9522b861d8b20fb24&object=wall-33327655_9819&one=1" data-reaction-set-id="reactions" data-reaction-target-object="wall-33327655_9819" aria-haspopup="true" aria-expanded="false" aria-controls="js-reactions-menu-wall-33327655_9819" onclick="Reactions.onButtonClick(this, event, {allowKeyboardMenuOpen: true})" title="&#4320;&#4308;&#4304;&#4325;&#4330;&#4312;&#4312;&#4321; &#4304;&#4320;&#4329;&#4308;&#4309;&#4304;" tabindex="0"></span></div><a class="PostBottomButton PostBottomButton--non-shrinkable" href="/like?act=publish&object=wall-33327655_9819&from=wall-33327655_9819&post_bottom=1" rel="noopener" aria-label="33 &#4306;&#4304;&#4323;&#4310;&#4312;&#4304;&#4320;&#4308;&#4311;" aria-pressed="false" onclick="window.Unauthorized2 && window.Unauthorized2.onActionClick(event, &#39;share&#39;, &#39;wall-33327655_9819&#39;)" role="button"><span class="PostBottomButton__icon"><div aria-hidden="true" class="svgIcon svgIcon-share_outline_24"><svg height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z"/><path d="M12 3.73c-1.12.07-2 1-2 2.14v2.12h-.02a9.9 9.9 0 0 0-7.83 10.72.9.9 0 0 0 1.61.46l.19-.24a9.08 9.08 0 0 1 5.84-3.26l.2-.03.01 2.5a2.15 2.15 0 0 0 3.48 1.69l7.82-6.14a2.15 2.15 0 0 0 0-3.38l-7.82-6.13c-.38-.3-.85-.46-1.33-.46zm.15 1.79c.08 0 .15.03.22.07l7.82 6.14a.35.35 0 0 1 0 .55l-7.82 6.13a.35.35 0 0 1-.57-.28V14.7a.9.9 0 0 0-.92-.9h-.23l-.34.02c-2.28.14-4.4.98-6.12 2. ...
#
#       </div>
#
#
#
#     </div>
#       <div class="Replies"><a id="comments" name="comments"></a><div id="wall-33327655_9819_replies" class="RepliesWrap wall_replies bl_cont closed_comments"><div id="" class="ReplyItem Post__rowPadding"><a name="reply9820" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/id558238931" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-6 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4309;&#4312;&#4304;&#4329;&#4308;&#4321;&#4314;&#4304;&#4309;&#4312; &#4308;&#4306;&#4317;&#4320;&#4317;&#4309;&#4312;" aria-label="id558238931"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;/images/camera_50.png&#39;)"><div></div></div><div class="Avatar__text">&#4309;&#4308;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/id558238931">&#4309;&#4312;&#4304;&#4329;&#4308;&#4321;&#4314;&#4304;&#4309;&#4312; &#4308;&#4306;&#4317;&#4320;&#4317;&#4309;&#4312;</a></div><div class="ReplyItem__body">    В прикрепленном документе написано, что прохождение МФК обязательно для студентов 3,4 курсов специалитета и так далее, но ничего не сказано про семестр. Где можно удостовериться, что для 3 курса МФК обязательны, начиная с 6 семестра.
#     </div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9820#reply9820" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like is_empty" aria-label="&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9820&from=wall-33327655_9819%3Freply%3D9846&hash=1197564229bf6e9b09"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div></a></div></div></div></div><div id="RepliesThread9820" class="RepliesThread"><div id="" class="ReplyItem Post__rowPadding"><a name="reply9821" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/georg_ml" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-1 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;" aria-label="georg_ml"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-57.userapi.com/s/v1/ig2/mZ-IBGpCCiYAYp7CFYzrHNGeBg0_gDpnMn20YrKJErenmIX6Lzt3dgUZ9nQbGm7iYKokpbdrpBpsWHYwRp1K8jO4.jpg?size=50x50&quality=95&crop=668,68,1472,1472&ava=1&#39;)"><div></div></div><div class="Avatar__text">&#4306;&#4315;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/georg_ml">&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;<span class="ImageStatus__status ImageStatus__status--normal" onclick="ImageStatus.open({&quot;user_id&quot;:121940016})"><img class="ImageStatus__statusImage" src="https://sun1-54.userapi.com/LKLvohyIn261Raui6k98oPcjQqVYXwSaSaUuEA/JGp3CRM1EOw.png" srcSet="https://sun1-17.userapi.com/MNqPk63chyg1Knj7aG_kagQ7aRBGACmx8mcinw/IDdiu82u3jg.png 2x" /></span></a></div><div class="ReplyItem__body">    <a href="/id558238931" class="mem_link" mention="" mention_id="id558238931">Вячеслав</a>, достаточно посмотреть рабочий план вашей специализации.
#     </div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9821&thread=9820#reply9821" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like is_empty" aria-label="&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9821&from=wall-33327655_9819%3Freply%3D9846&hash=7c10fd0d7a1989f930"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div></a></div></div></div></div></div><div id="" class="ReplyItem Post__rowPadding"><a name="reply9822" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/id33365628" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-1 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4306;&#4314;&#4308;&#4305;&#4312; &#4313;&#4317;&#4320;&#4317;&#4321;&#4322;&#4308;&#4314;&#4312;&#4317;&#4309;&#4312;" aria-label="id33365628"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-55.userapi.com/s/v1/ig2/i41CiIWdlhykERrzNK8rNwa7yjbFVjkhF6qOPmanNNfA9GNVuFs631i9aSYb_2rEEGvDOChLs_DwLol8TcMv0YnG.jpg?size=50x50&quality=95&crop=17,2,450,450&ava=1&#39;)"><div></div></div><div class="Avatar__text">&#4306;&#4313;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/id33365628">&#4306;&#4314;&#4308;&#4305;&#4312; &#4313;&#4317;&#4320;&#4317;&#4321;&#4322;&#4308;&#4314;&#4312;&#4317;&#4309;&#4312;</a></div><div class="ReplyItem__body">    Написано 5,6 факультативно, значит 5ый курс может не проходить этот мфк?
#     <div class="pi_medias thumbs_list thumbs_list1">  <div class="medias_thumbs medias_thumbs_map"><div class="thumbs_map_wrap" style="width: 100%;"><div class="thumbs_map_helper" style="padding-top: 33.5228%;"><div class="thumbs_map fill"><div style="width: 100%; height: 100%; margin: 0 0% 0% 0;" class="thumb_map thumb_map_wide thumb_map_l al_photo"><a  href="/photo-33327655_457240572?list=wall-33327655_9822&from=comments"  aria-label="&amp;#4324;&amp;#4317;&amp;#4322;&amp;#4317;&amp;#4321;&amp;#4323;&amp;#4320;&amp;#4304;&amp;#4311;&amp;#4312;" class="thumb_link "><div style="margin-left: -0.0703%; background-image: url(https://sun1-27.userapi.com/impf/cWk2PzyjW0NEpFUutxx7wJAQdaW6nt-jSRFWvA/mTVyTepCUDw.jpg?size=604x204&quality=96&sign=ebf0d410805a8a6c4c2346e03563d632&type=album);"  class="thumb_map_img thumb_map_img_as_div"  data-id="-33327655_457240572" data-src_big="https://sun1-27.userapi.com/impf/cWk2PzyjW0NEpFUutxx7wJAQdaW6nt-jSRFWvA/mTVyTepCUDw.jpg?size=604x204&amp;quality=96&amp;sign=ebf0d410805a8a6c4c2346e03563d632&amp;type=album|604|204" data-restriction="null"></div></a></div></div></div></div></div></div></div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9822#reply9822" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like is_empty" aria-label="&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9822&from=wall-33327655_9819%3Freply%3D9846&hash=a052ae0b5d86fb359a"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div></a></div></div></div></div><div id="RepliesThread9822" class="RepliesThread"><div id="" class="ReplyItem Post__rowPadding"><a name="reply9823" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/georg_ml" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-1 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;" aria-label="georg_ml"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-57.userapi.com/s/v1/ig2/mZ-IBGpCCiYAYp7CFYzrHNGeBg0_gDpnMn20YrKJErenmIX6Lzt3dgUZ9nQbGm7iYKokpbdrpBpsWHYwRp1K8jO4.jpg?size=50x50&quality=95&crop=668,68,1472,1472&ava=1&#39;)"><div></div></div><div class="Avatar__text">&#4306;&#4315;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/georg_ml">&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;<span class="ImageStatus__status ImageStatus__status--normal" onclick="ImageStatus.open({&quot;user_id&quot;:121940016})"><img class="ImageStatus__statusImage" src="https://sun1-54.userapi.com/LKLvohyIn261Raui6k98oPcjQqVYXwSaSaUuEA/JGp3CRM1EOw.png" srcSet="https://sun1-17.userapi.com/MNqPk63chyg1Knj7aG_kagQ7aRBGACmx8mcinw/IDdiu82u3jg.png 2x" /></span></a></div><div class="ReplyItem__body">    <a href="/id33365628" class="mem_link" mention="" mention_id="id33365628">Глеб</a>, это для тех факультетов, у которых МФК обязательны в 5-8 семестрах. У нас же освоение МФК в соответствии с учебным планом сдвинуто на  ...
#     </div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9823&thread=9822#reply9823" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like is_empty" aria-label="&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9823&from=wall-33327655_9819%3Freply%3D9846&hash=34be87e3f35436cd16"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div></a></div></div></div></div><div class="RepliesThreadNext Post__rowPadding"><a class="RepliesThreadNext__link" href="/wall-33327655_9819?offset=1&reply=9822#9822">&#4328;&#4308;&#4315;&#4307;&#4308;&#4306;&#4312; &#4313;&#4317;&#4315;&#4308;&#4316;&#4322;&#4304;&#4320;&#4308;&#4305;&#4312;&#4321; &#4329;&#4309;&#4308;&#4316;&#4308;&#4305;&#4304;</a></div></div><div id="" class="ReplyItem Post__rowPadding"><a name="reply9825" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/georg_ml" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-1 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;" aria-label="georg_ml"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-57.userapi.com/s/v1/ig2/mZ-IBGpCCiYAYp7CFYzrHNGeBg0_gDpnMn20YrKJErenmIX6Lzt3dgUZ9nQbGm7iYKokpbdrpBpsWHYwRp1K8jO4.jpg?size=50x50&quality=95&crop=668,68,1472,1472&ava=1&#39;)"><div></div></div><div class="Avatar__text">&#4306;&#4315;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/georg_ml">&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;<span class="ImageStatus__status ImageStatus__status--normal" onclick="ImageStatus.open({&quot;user_id&quot;:121940016})"><img class="ImageStatus__statusImage" src="https://sun1-54.userapi.com/LKLvohyIn261Raui6k98oPcjQqVYXwSaSaUuEA/JGp3CRM1EOw.png" srcSet="https://sun1-17.userapi.com/MNqPk63chyg1Knj7aG_kagQ7aRBGACmx8mcinw/IDdiu82u3jg.png 2x" /></span></a></div><div class="ReplyItem__body">    <a href="/id33365628" class="mem_link" mention="" mention_id="id33365628">Глеб</a>, эти семестры указаны в соответствии с учебным планом. Повторюсь, что у нас всё сдвинуто на один семестр. Всем старостам 5 курса должно было прийти письмо от учебной части, что всем пятикурсникам необходимо пройти МФК по искусственному интеллекту. Официальная информация также была опубликована в группе: <a href="https://vk.com/wall-204636234_99">https://vk.com/wall-204636234_99</a>
#     </div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9825#reply9825" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like is_empty" aria-label="&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9825&from=wall-33327655_9819%3Freply%3D9846&hash=725676ca6eea1a62c0"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div></a></div></div></div></div><div id="" class="ReplyItem Post__rowPadding"><a name="reply9826" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/id33365628" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-1 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4306;&#4314;&#4308;&#4305;&#4312; &#4313;&#4317;&#4320;&#4317;&#4321;&#4322;&#4308;&#4314;&#4312;&#4317;&#4309;&#4312;" aria-label="id33365628"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-55.userapi.com/s/v1/ig2/i41CiIWdlhykERrzNK8rNwa7yjbFVjkhF6qOPmanNNfA9GNVuFs631i9aSYb_2rEEGvDOChLs_DwLol8TcMv0YnG.jpg?size=50x50&quality=95&crop=17,2,450,450&ava=1&#39;)"><div></div></div><div class="Avatar__text">&#4306;&#4313;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/id33365628">&#4306;&#4314;&#4308;&#4305;&#4312; &#4313;&#4317;&#4320;&#4317;&#4321;&#4322;&#4308;&#4314;&#4312;&#4317;&#4309;&#4312;</a></div><div class="ReplyItem__body">    Извините, я просто не очень сообразительный :) А можете подсказать где увидеть &quot;привязку&quot; мфк к учебному плану, просто пока во всех приказах что я видел ИИ &quot;привязан&quot; к 5 6 7 8 семестру ( как например в пункте 5). Заранее спасибо.
#     </div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9826#reply9826" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like" aria-label="&#4315;&#4317;&#4321;&#4332;&#4317;&#4316;&#4321; 1 &#4304;&#4307;&#4304;&#4315;&#4312;&#4304;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9826&from=wall-33327655_9819%3Freply%3D9846&hash=127dca2d89cb4499fa"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div>1</a></div></div></div></div><div id="RepliesThread9826" class="RepliesThread"><div id="" class="ReplyItem Post__rowPadding"><a name="reply9827" class="ReplyItem__anchor"></a><div class="ReplyItem__wrap"><a href="/georg_ml" rel="noopener"><div class="Avatar Avatar--loaded Avatar--mode-both Avatar--images-1 Avatar--borderRadius-full Avatar--theme-1 ReplyItem__avatarImage Avatar--size-36" role="img"  alt="&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;" aria-label="georg_ml"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun1-57.userapi.com/s/v1/ig2/mZ-IBGpCCiYAYp7CFYzrHNGeBg0_gDpnMn20YrKJErenmIX6Lzt3dgUZ9nQbGm7iYKokpbdrpBpsWHYwRp1K8jO4.jpg?size=50x50&quality=95&crop=668,68,1472,1472&ava=1&#39;)"><div></div></div><div class="Avatar__text">&#4306;&#4315;</div></div></div></a><div class="ReplyItem__content"><div class="ReplyItem__header"><a class="ReplyItem__name" href="/georg_ml">&#4306;&#4308;&#4317;&#4320;&#4306;&#4312;&#4312; &#4315;&#4304;&#4314;&#4312;&#4316;&#4317;&#4309;&#4321;&#4313;&#4312;&#4312;<span class="ImageStatus__status ImageStatus__status--normal" onclick="ImageStatus.open({&quot;user_id&quot;:121940016})"><img class="ImageStatus__statusImage" src="https://sun1-54.userapi.com/LKLvohyIn261Raui6k98oPcjQqVYXwSaSaUuEA/JGp3CRM1EOw.png" srcSet="https://sun1-17.userapi.com/MNqPk63chyg1Knj7aG_kagQ7aRBGACmx8mcinw/IDdiu82u3jg.png 2x" /></span></a></div><div class="ReplyItem__body">    <a href="/id33365628" class="mem_link" mention="" mention_id="id33365628">Глеб</a>, посмотрите рабочий план любой специализации на сайте факультета.
#     </div><div class="ReplyItem__date"><a class="item_date" href="https://m.vk.com/wall-33327655_9819?reply=9827&thread=9826#reply9827" rel="noopener">30 &#4321;&#4308;&#4325; 2021</a></div><div class="ReplyItem__likeWrap"><a class="ReplyItem__like is_empty" aria-label="&#4315;&#4317;&#4315;&#4332;&#4317;&#4316;&#4321;" href="/like?act=add&object=wall_reply-33327655_9827&from=wall-33327655_9819%3Freply%3D9846&hash=b2cdc0372e1d427801"><div aria-hidden="true" class="svgIcon svgIcon-like-outline-16"><svg height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M0 0h16v16H0z" opacity=".4"/><path d="M10.96 2.5A4.04 4.04 0 0 1 15 6.54c0 2.21-.88 3.32-4.52 6.15l-1.1.85a2.25 2.25 0 0 1-2.76 0l-1.1-.85C1.88 9.86 1 8.75 1 6.54A4.04 4.04 0 0 1 5.04 2.5c1.11 0 2.1.48 2.96 1.4a3.97 3.97 0 0 1 2.96-1.4zM5.04 4A2.54 2.54 0 0 0 2.5 6.54c0 1.59.65 2.4 3.94 4.96l1.1.86c.27.2.65.2.92 0l1.1-.86c3.29-2.55 3.94-3.37 3.94-4.96A2.54 2.54 0 0 0 10.96 4c-.85 0-1.62.48-2.34 1.53l-.62.9-.62-.9C6.66 4.48 5.88 4 5.04 4z" fill="#aaaeb3" fill-rule="nonzero"/></g></svg></div></a></div></div></div></div><div class="RepliesThreadNext Post__rowPadding"><a class="RepliesThreadNext__link" href="/wall-33327655_9819?offset=1&reply=9826#9826">&#4328;&#4308;&#4315;&#4307;&#4308;&#4306;&#4312; &#4313;&#4317;&#4315;&#4308;&#4316;&#4322;&#4304;&#4320;&#4308;&#4305;&#4312;&#4321; &#4329;&#4309;&#4308;&#4316;&#4308;&#4305;&#4304;</a></div></div></div><a id="comments_end" name="comments_end"></a></div>
#       </div>
#     </div></div>
#
#
#           <div aria-hidden="true" class="_cntrs" style="height:0;overflow:hidden;">
#           <img width="1" height="1" src="https://sb.scorecardresearch.com/p?c1=2&c2=13765216&c3=&c4=https%3A%2F%2Fm.vk.com%2Fwall-33327655_9819%3Freply%3D9846&c5=&c9=&c15=&cv=2.0&cj=1&rn=68808619" alt="">
#
#       <noscript><img src="//top-fwz1.mail.ru/counter?id=2579437;pid=0;r=" style="border:0;" height="1" width="1" /></noscript>
#     </div>
#     </div>
#         </div>
#       </div>
#     </div>
#
#         <noscript><img style='display: none' src='/?act=no_js&hash=e4253bd8d41be69baa' /></noscript>
#         <script type="text/javascript">
# <!--
# parent&&parent!=window&&(document.getElementsByTagName('body')[0].innerHTML='');try{sessionStorage.set('is_mvk_tab', 1)}catch(e){};try {window.store.stickers = {"url_template":"https:\/\/vk.com\/sticker\/1-%id%-%size%"}}catch(e){};;(function (d, w) {
# var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true;
# ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
# var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
# if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window);
# //-->
# </script>
#         <div id="vk_utils"></div>
#         <div id="z"></div>
#         <div id="MediaView_container"></div>
#         <div id="vk_bottom"></div>
#         <div id="theme_color_shim"></div>
#
#
#       </body>
#     </html>

# %% [markdown]
# ## CREATING A DICTIONARY WITH FULL DATA ABOUT POST/REPLY BY VK-LINK

# %%
'''
CREATING A DICTIONARY WITH FULL DATA ABOUT POST/REPLY BY VK-LINK
'''

def vk_post_info_by_link(link_vk, language):
    req_link = requests.get(link_vk)
    html_doc = req_link.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    
#     дефолтные значения
    content_type = 'no text'
    content_subtype = 'other'
    parent_link = ''
    text_lines = []
    link_year_no = 0
    link_month_no = 0
    link_day_no = 0
    link_date = date(1970, 1, 1)
    link_date_time = ''
    link_time = ''
    months_dict = {
        'russian': ['янв', 'фев', 'мар', 'апр', 'мая', 'июн', 'июл', 'авг', 'сен', 'окт', 'ноя', 'дек'],
        'english': ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'],
#         https://en.wikipedia.org/wiki/Georgian_calendar
        'georgian': ['იან', 'თებ', 'მარ', 'აპრ', 'მაი', 'ივნ', 'ივლ', 'აგვ', 'სექ', 'ოქტ', 'ნოე', 'დეკ']
    }
    months = months_dict[language]

    # ПРОВЕРЯЮ, СУЩЕСТВУЕТ ЛИ ПОСТ
    #     <div class="service_msg service_msg_error">Запись не найдена.</div>
    flg_service_msg_error = soup.find('div', attrs={'class': 'service_msg service_msg_error'})
    if flg_service_msg_error:
        link_type = 'page not found'
    else:
        link_type = 'post'
        # когда ссылка на пост: <link rel="canonical" href="https://vk.com/wall-33327655_2225" />
        # когда ссылка на коммент: <link rel="canonical" href="https://vk.com/wall-33327655_8793?reply=8800" />
        
        # ПРОВЕРЯЮ, НЕ КОММЕНТ ЛИ ЭТО
        rel_canonical = soup.find('link', attrs={'rel': 'canonical'})
        flg_rel_canonical_reply = re.findall('reply=', str(rel_canonical))
#             + ДОБАВИТЬ ПОЛЕ МАТЕРИНСКОЙ ССЫЛКИ
        if flg_rel_canonical_reply:
            link_type = 'comment'
            
        # ПРОВЕРЯЮ, НЕ РЕПОСТ ЛИ ЭТО
        flg_repost = soup.find('div', attrs={'data-copy': True})
        if flg_repost:
            link_type = 'repost'
#             <div class="wall_item single_wall_item bl_item mark_top_verified" data-copy='-77014399_6331'>
            parent_link = 'https://vk.com/wall' + flg_repost['data-copy']
    
    if link_type in ['post','repost']:
        # ВЫТАСКИВАЮ БЛОК С ТЕКСТОМ ПОСТА ПОСТРОЧНО    
        # <div class="wi_body">
        #     <div class="pi_text">

        wi_body = soup.find('div', attrs={'class': 'wi_body'})
        if wi_body is None:
            announcement_list = []
            result_list = []
        else:
            pi_text = wi_body.find('div', attrs={'class': 'pi_text'})
            if pi_text is None:
                announcement_list = []
                result_list = []
            else:
                text_lines = [line for line in pi_text.stripped_strings]
                    # определить тип контента
                    # анонсы: 'Орфография и пунктуация сохранены.'
                    # результаты: 'Таким образом, выборы признаются состоявшимися'
                announcement_list = ['announcement' for line in pi_text.stripped_strings if line.find('Орфография и пунктуация сохранены.') >= 0]
                result_list = ['result' for line in pi_text.stripped_strings if line.find('Таким образом, выборы признаются состоявшимися.') >= 0]
                content_type = 'text'
                if any(election_tag in text_lines for election_tag in ['#выборы@stud_mm','#выборы_ссмм']):
                    content_type = 'election'
    
                if len(announcement_list) > 0:
                    content_subtype = 'announcement'
                elif len(result_list) > 0:
                    content_subtype = 'result'
        
        # ВЫТАСКИВАЮ ДАТУ
        # <div class="wi_info">
        #     <span class="wi_date">
        wi_info = soup.find('div', attrs={'class': 'wi_info'})
        if wi_info:
            wi_date = wi_info.find('span', attrs={'class': 'wi_date'})
            date_list = [date for date in wi_date.stripped_strings]
            link_year_no = int(re.findall(r'[\d]{4}', date_list[0])[0])
            link_month_no = months.index(re.findall(r'[\w]{3}', date_list[0])[0]) + 1
            link_day_no = int((re.findall(r'[\d]+\s', date_list[0])[0]).strip())
            link_date = date(link_year_no, link_month_no, link_day_no)
            link_date_time = date_list[0]
            link_time = re.findall(r'[\d]+\:[\d]+', date_list[0])[0]
        
    if link_type == 'comment':
        reply_link = link_vk[link_vk.index('_')+1:]
        # ВЫТАСКИВАЮ БЛОК С ТЕКСТОМ КОММЕНТА ПОСТРОЧНО    
#             <div class="ReplyItem__body">    180% голосов. Это выборы на мехмате? Это проценты чего?</div>
#             <div class="ReplyItem__date">
#             <a class="item_date" href="https://m.vk.com/wall-33327655_2254?reply=2262#reply2262" rel="noopener">22 &#4316;&#4317;&#4308;&#4315; 2014</a></div>
#         reply_body = soup.find('div', attrs={'class': 'ReplyItem__body'})
        reply_bodies = soup.find_all('div', attrs={'class': 'ReplyItem__body'})
        reply_dates = soup.find_all('a', attrs={'class': 'item_date'})
        reply_links = [ff['href'][ff['href'].index('#reply')+6:] for ff in soup.find_all('a', attrs={'class': 'item_date'})]
#         reply_no = reply_links.index(reply_link)
#         if reply_body is None:
#             announcement_list = []
#             result_list = []
#         else:
        if reply_link in reply_links:
            reply_no = reply_links.index(reply_link)
            content_type = 'text'
            text_lines = [line for line in reply_bodies[reply_no].stripped_strings]
            date_list = [date for date in reply_dates[reply_no].stripped_strings]
            link_year_no = int(re.findall(r'[\d]{4}', date_list[0])[0])
            link_month_no = months.index(re.findall(r'[\w]{3}', date_list[0])[0]) + 1
            link_day_no = int((re.findall(r'[\d]+\s', date_list[0])[0]).strip())
            link_date = date(link_year_no, link_month_no, link_day_no)
        else:
            content_subtype = 'deleted (?)'
            
        parent_link = rel_canonical['href'][: rel_canonical['href'].index('?')]
    
    dict_link = {}
    dict_link[link_vk] = {
        'link_type': link_type, 
        'content_type': content_type,
        'content_subtype': content_subtype,
        'parent_link': parent_link,
        
        'link_date': link_date, 
        'link_year_no': link_year_no, 
        'link_month_no': link_month_no, 
        'link_day_no': link_day_no, 
        'link_date_time': link_date_time, 
        'link_time': link_time, 
        
        'list_of_lines': text_lines
    }
    
    return dict_link

# %%
# тест
# vk_post_info_by_link('https://vk.com/wall-33327655_5106', 'georgian') # -- пост с анонсом +
# vk_post_info_by_link('https://vk.com/wall-33327655_2262', 'georgian') # -- коммент под постом +
# vk_post_info_by_link('https://vk.com/wall-33327655_2263', 'georgian') # -- коммент под постом +
# vk_post_info_by_link('https://vk.com/wall-33327655_3330', 'georgian') # -- репост без шапки +
# vk_post_info_by_link('https://vk.com/wall-33327655_2261', 'georgian') # -- репост без шапки - ПОЧЕМУ ТУТ text, а не no text
# vk_post_info_by_link('https://vk.com/wall-33327655_8489', 'georgian') # -- репост с шапкой +
# vk_post_info_by_link('https://vk.com/wall-33327655_9846', 'georgian') # -- удаленный коммент (?)
# vk_post_info_by_link('https://vk.com/wall-33327655_2225', 'georgian') # -- пост с кандидатами в КОММЕНТЕ 2232
# vk_post_info_by_link('https://vk.com/wall-33327655_2232', 'georgian') # -- коммент с кандидатами

vk_post_info_by_link('https://vk.com/wall-33327655_2218', 'georgian') # -- РАЗНОЕ
# Out:
# {'https://vk.com/wall-33327655_2218': {'link_type': 'post',
#   'content_type': 'election',
#   'content_subtype': 'announcement',
#   'parent_link': '',
#   'link_date': datetime.date(2014, 11, 18),
#   'link_year_no': 2014,
#   'link_month_no': 11,
#   'link_day_no': 18,
#   'link_date_time': '18 ნოემ 2014  1:42',
#   'link_time': '1:42',
#   'list_of_lines': ['#выборы@stud_mm',
#    'Напоминаем, что сегодня пройдут выборы в студсовет на двух потоках. С кандидатами с пятого курса мы уже познакомились, на очереди 4 поток 3 курса.',
#    'Орфография и пунктуация сохранены. Напомним, можно будет поставить подпись не более чем за одного кандидата либо одну подпись «против всех».',
#    '3 КУРС, 4 ПОТОК (выборы завтра на третей паре в аудитории 128 лабораторного корпуса А)',
#    '— ЧЕБОТАЕВА Виктория Алексеевна, 332 группа',
#    'Хочу представлять интересы своего потока, участвовать в распределении повышенных стипендий, защищать права студентов, помогать в организации праздников и студентам младших курсов.']}}

# %% [markdown]
# ## functions for processing of posts about elections

# %% [markdown]
# ### functions for posts with announcements

# %%
# вытаскивает из строки номера курса и потока (в предположении, что они в этой строке есть)

# для обычных потоков
def year_stream_no_by_line(line):
    if re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', line):
        year_stream_line = (re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', line))[0]
        year_stream_line_d = re.sub('\D', '', year_stream_line)
        year_no = int(year_stream_line_d[0])
        stream_no = int(year_stream_line_d[1])
    elif re.findall(r'\D(\d\.\d)\D', line):
        year_stream_line = (re.findall(r'\D(\d\.\d)\D', line))[0]
#         print(year_stream_line)
#         print(year_stream_line[0])
        year_no = year_stream_line[0]
        stream_no = year_stream_line[2]
    
    year_stream_no = str(year_no) + '.' + str(stream_no)
    return year_stream_no, year_no, stream_no

# для магистратуры
def magister_year_by_line(line):
#     если номер года записан цифрами
    if re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', line):
        year_stream_line = (re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', line))[0]
#         print(year_stream_line)
        year_no = int(year_stream_line[1])
        year_stream_no = 'm' + str(year_no)
#     если номер года записан буквами
    elif re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', line):
        year_stream_line = (re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', line))[0]
#         print(year_stream_line)
        year_no = 0
        if str.lower(year_stream_line[1]) == 'перв':
            year_no = 1
        elif str.lower(year_stream_line[1]) == 'втор':
            year_no = 2
        year_stream_no = 'm' + str(year_no)
    return year_stream_no, year_no

# примеры для магистратуры:
# МАГИСТРЫ ПЕРВОГО ГОДА ОБУЧЕНИЯ (выборы завтра на второй паре в аудитории 12-03) +
# МАГИСТРЫ, 2 ГОД ОБУЧЕНИЯ +
# МАГИСТРЫ 2 ГОДА ОБУЧЕНИЯ +
# МАГИСТРЫ 1-ГО ГОДА ОБУЧЕНИЯ +
# МАГИСТРЫ, 1 КУРС +

# line = 'МАГИСТРЫ, 1 КУРС'
# magister_year_by_line(line)

# %%
# line1 = '— ЯНКОВА Маргарита Михайловна' +
# line1 = '— ОСТРОУХОВА Наталья Владимировна, группа 402' 
# line1 = '— ЧЕБОТАЕВА Виктория Алексеевна, 332 группа' +
# line1 = '— ПРОМЫСЛОВ Платон Валерьевич, гр.409' +
# line1 = '— БУН-ЯН-ТУН Владислав Владимирович, группа 125' +
line1 = 'Перейдём к старшим курсам. Есть две новости, хорошая и плохая. Плохая: от механиков 5 курса до сих пор не поступило ни одной заявки. Поторопитесь, не оставляйте свой поток без представителя — время до полуночи ещё есть! Хорошая: на экономпотоке четверокурсников кандидат в наличии, с ним и знакомим.'

# r'\—([\w\s\-]+)[\,\.\s\w]*([\d]*)'

if len(re.findall(r'\—([\w\s\-]+)', line1)) > 0 and re.search(r'\—([\w\s\-]+)', line1).start() == 0:
    name_line = (re.findall(r'\—([\w\s\-]+)', line1))
    print(name_line)
    name = (re.sub('\W\s', '', name_line[0])).strip().title()
    if re.sub('\D', '', line1):
        academic_group_no = int(re.sub('\D', '', line1))
        print(academic_group_no)

print(name)
# Out:
# Бекбулатов Рамзан Ломалиевич

# %%
# СЛОВАРЬ ИНФОРМАЦИИ ПРО КАНДИДАТОВ (по списку строк с текстом)


# по списку строк с текстом составляем СЛОВАРЬ: имя: курс-поток, группа, номер первой строки в тексте
def stream_nomination_by_list(list_of_lines):
    nominated_dict = {}
#     year_stream_no, year_no, stream_no = '', 0, 0
    
    for i in range(len(list_of_lines)):
#         В НАЧАЛЕ ШАБЛОНА БЫЛО \s (убрал, так как иногда забывают пробел, а алгоритм всё равно жадный)
#         r'[\w\s]+,\sгруппа\s[\d]{3}' - для фиксированного написания группы (и не для маги)
        nomination_pattern = r'[\—\–]([\w\s\-]+)'
        if (
            len(re.findall(nomination_pattern, list_of_lines[i])) > 0 
            and re.search(nomination_pattern, list_of_lines[i]).start() == 0
            and len(re.findall(nomination_pattern, list_of_lines[i])[0].strip().split(' ')) <= 6
        ):
            name_line_no = i
            name_line = re.findall(nomination_pattern, list_of_lines[i])
            name = (re.sub('\W\s', '', name_line[0])).strip().title()
            if re.sub('\D', '', list_of_lines[i]):
                academic_group_no = int(re.sub('\D', '', list_of_lines[i]))
            else:
                academic_group_no = ''
            another_one_dict = {}
            another_one_dict[name] = {
                'academic_group_no': academic_group_no, 
                'name_line_no': name_line_no
            }
            nominated_dict = {**nominated_dict, **another_one_dict}
            
    # первый и последний индексы программы кандидата в списке
    name_list = list(nominated_dict.keys())
    start_index_list = [nominated_dict[key]['name_line_no'] for key in list(nominated_dict.keys())]
    last_index_list = [i-1 for i in start_index_list if start_index_list.index(i) > 0]
    last_index_list.append(len(list_of_lines)-1)
    
    dict_of_nominated_upd = {}
    
    for name in name_list:
        dict_of_nominated_upd[name] = [start_index_list[name_list.index(name)], last_index_list[name_list.index(name)]]
    
    # обновить словарь: имя: номер группы, текст программы
    for name in dict_of_nominated_upd:
        program_lines = []

        for k in range(dict_of_nominated_upd[name][0]+1, dict_of_nominated_upd[name][1]+1):
            program_lines.append(list_of_lines[k])
        program_txt = '\n'.join(program_lines)

        nominated_dict[name].update({'program_txt': program_txt})
        del nominated_dict[name]['name_line_no']

    return nominated_dict


# вся инфа про номинации на потоке
def stream_nomination_info_by_dict(list_of_lines):
    year_stream_no = ''
    year_no, stream_no = 0, 0
    
    for i in range(len(list_of_lines)):
        if re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', list_of_lines[i]):
            year_stream_no, year_no, stream_no = year_stream_no_by_line(list_of_lines[i])
        if re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', list_of_lines[i]) or re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', list_of_lines[i]):
            year_stream_no, year_no = magister_year_by_line(list_of_lines[i])
                
    dict_nominations = stream_nomination_by_list(list_of_lines)
    
    dict_stream_elections = {
        'year_stream_no': year_stream_no,
        'year_no': year_no, 
        'stream_no': stream_no, 
        'dict_nominations': dict_nominations
    }
    
    return dict_stream_elections

# %% [markdown]
# ### functions for posts with results

# %%
# СЛОВАРЬ ИНФОРМАЦИИ ПРО РЕЗУЛЬТАТЫ ВЫБОРОВ (по списку строк с текстом)

# ДОБАВИТЬ МАГИСТРАТУРУ

# по списку строк с кандидатами составляем СЛОВАРЬ: имя: голоса, статус
def stream_election_result_by_list(nominated_with_votes):
    dict_nominated = {}

    for line in nominated_with_votes:
        kek = (re.findall(r'[\—\s]*([\w\-\s]+)[\:\;]\s([\d]+)\sголос', line))[0]
        name = kek[0].strip().title()
        votes_cnt = kek[1]
#         name = ((re.findall(r'[\w\s]+', line))[0]).strip().title()
#         votes_line = (re.findall(r'\s[\d]+\sголос', line))[0]
#         votes_cnt = int(re.sub('\D', '', votes_line))
        dict_nominated[name] = {'votes_cnt': votes_cnt}
        if (re.findall(r' избран', line)) and not (re.findall(r' не избран', line)):
            elected_flg = 1
        else:
            elected_flg = 0
        dict_nominated[name].update({'elected_flg': elected_flg})
    return dict_nominated


# вся инфа про результаты выборов на потоке
def stream_election_info_by_dict(list_of_lines):
    nominated_with_votes = []
    year_stream_no = ''
    year_no, stream_no = 0, 0
    voted_cnt, stream_size, invalid_cnt, NOTA_cnt = 0, 0, 0, 0
    
    for i in range(len(list_of_lines)):
                    
        if re.findall(r'\d\s[\w]{4},\s\d\s[\w]{5}', list_of_lines[i]) or re.findall(r'\D(\d\.\d)\D', list_of_lines[i]):
            year_stream_no, year_no, stream_no = year_stream_no_by_line(list_of_lines[i])
        if re.findall(r'(МАГИСТРЫ)[\s,]{1,2}([\d])', list_of_lines[i]) or re.findall(r'(МАГИСТРЫ)[\W]+([\w]{4})', list_of_lines[i]):
            year_stream_no, year_no = magister_year_by_line(list_of_lines[i])
            
        if re.findall('Явка: ', list_of_lines[i]):
            turnout_line = (re.findall(r'[\d]+\s[\w]+\sиз\s[\d]+', list_of_lines[i]))[0]
            voted_cnt = int(((re.findall(r'[\d]+\s', turnout_line))[0]).strip())
            stream_size = int(((re.findall(r'\s[\d]+', turnout_line))[0]).strip())
            
        if len(re.findall(r'\s[\d]+\sнедействительн', list_of_lines[i])) == 0: # отдельно, т.к. может такой записи не быть
            pass
        else:
            invalid_line_no = i
            invalid_line = (re.findall(r'\s[\d]+\sнедействительн', list_of_lines[i]))[0]
            invalid_cnt = re.sub('\D', '', invalid_line)
            
        if re.findall('Против всех', list_of_lines[i]):
            NOTA_line_no = i
            NOTA_line = (re.findall(r'\s[\d]+\sголос', list_of_lines[i]))[0]
            NOTA_cnt = re.sub('\D', '', NOTA_line)
            
        if re.findall('[\—\s]*([\w\-\s]+)[\:\;]\s([\d]+)\sголос', list_of_lines[i]) and not (re.findall('Против всех', list_of_lines[i])):
            nominated_with_votes.append(list_of_lines[i])
            
        if re.findall('Подтверждено ответственн', list_of_lines[i]):
            organizer_line = (re.findall(r'за\sвыборы\s[\w\s,]+', list_of_lines[i]))[0]
            organizer_line = organizer_line[10::]
            organizer_list = re.split(', | и ',organizer_line)
    
    dict_nominated_with_votes = stream_election_result_by_list(nominated_with_votes)
    
    dict_stream_elections = {
        'year_stream_no': year_stream_no,
        'year_no': year_no, 
        'stream_no': stream_no, 
        'stream_size': stream_size, 
        'voted_cnt': voted_cnt,
        'invalid_cnt': invalid_cnt,
        'NOTA_cnt': NOTA_cnt,
        'organizers': organizer_list,
        'dict_nominated_with_votes': dict_nominated_with_votes
    }
    
    return dict_stream_elections

# %%
# словарик для ручного исправления имен кандидатов

def fix_name(name):
    # incorrect: correct
    correct_names_dict = {
    #     из-за Е/Ё:
        'Муравьева Анна Сергеевна': 'Муравьёва Анна Сергеевна',
        'Третьяков Артем Алексеевич': 'Третьяков Артём Алексеевич',
        'Рогачев Александр Викторович': 'Рогачёв Александр Викторович',
        'Третьяков Петр Максимович': 'Третьяков Пётр Максимович',
        'Пушкарева Анна Константиновна': 'Пушкарёва Анна Константиновна',
    #     из-за других букв:
        'Порфирьева Наталья Алексеевна': 'Порфирьева Наталия Алексеевна',
        'Лобанова Елена Валерьевна': 'Лобанова Алёна Валерьевна',
        'Иллизаров Год Эмануилович': 'Илизаров Год Эмануилович',
        'Гусейнов Сеймур Элданизович': 'Гусейнов Сэймур Элданизович',
    #     из-за пропущенного отчества:
        'Лапина София': 'Лапина Софья Михайловна',   
    #     из-за перепутанного отчества:
        'Сакаев Роберт Викторович': 'Сакаев Роберт Марселевич',   
    }
    if name in correct_names_dict.keys():
        return correct_names_dict[name]
    else:
        return name

fix_name('Иллизаров Год Эмануилович')
# Out:
# 'Илизаров Год Эмануилович'

# %% [markdown]
# ## Processing of all election posts for 4-11 convocations

# %% [markdown]
# ### launching

# %%
# ГЕНЕРАТОР СЛОВАРЯ ДЛЯ ИНТЕРВАЛА ССЫЛОК НА ПОСТЫ С АНОНСАМИ ВЫБОРОВ
# ГЕНЕРАТОР СЛОВАРЯ ДЛЯ ИНТЕРВАЛА ССЫЛОК НА ПОСТЫ С РЕЗУЛЬТАТАМИ ВЫБОРОВ

from itertools import chain

announcement_links = {}
result_links = {}

for num in chain(
#     range(9850, 9860) #, # test
#     range(2200, 2360) #, # созыв 4 +
#     range(3140, 3530) #, # созыв 5 +
#     range(5040, 5360) #, # созыв 6 +
    range(6540, 6720) #, # созыв 7 
#     range(7470, 7780), # созыв 8 +
#     range(8240, 8420), # созыв 9 +
#     range(9100, 9400), # созыв 10 +
#     range(9800, 10040) # созыв 11 +
):
    link = 'https://vk.com/wall-33327655_' + str(num)

    test_dict = vk_post_info_by_link(link, 'georgian')
    
#     поправка из-за коммента с доп.кандидатами
    if 'https://vk.com/wall-33327655_2232' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_2232']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_2232']['content_subtype'] = 'announcement'
#     поправка из-за коммента с доп.кандидатами
    if 'https://vk.com/wall-33327655_2305' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_2305']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_2305']['content_subtype'] = 'announcement'
#     поправка из-за отсутствия кодовой фразы
    if 'https://vk.com/wall-33327655_2230' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_2230']['content_subtype'] = 'announcement'
#     поправка из-за отсутствия выборного хэштега
    if 'https://vk.com/wall-33327655_7509' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_7509']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_7509']['content_subtype'] = 'result'
#     поправка из-за отсутствия кодовой фразы
    if 'https://vk.com/wall-33327655_7657' in test_dict.keys():
        test_dict['https://vk.com/wall-33327655_7657']['content_type'] = 'election'
        test_dict['https://vk.com/wall-33327655_7657']['content_subtype'] = 'announcement'
    
    print('{0} : {1} \t\t/ {2} \t\t/ {3}'.format(link, test_dict[link]['link_type'], test_dict[link]['content_type'], test_dict[link]['content_subtype']))

    for d in test_dict.values():
        if d['content_type'] == 'election' and d['content_subtype'] == 'announcement':
            announcement_links = {**announcement_links, **test_dict}
        if d['content_type'] == 'election' and d['content_subtype'] == 'result':
            result_links = {**result_links, **test_dict}


for link in announcement_links:
    announcement_links[link].update({'nominated_info': stream_nomination_info_by_dict(announcement_links[link]['list_of_lines'])})
    del announcement_links[link]['list_of_lines']
    
for link in result_links:
    result_links[link].update({'stream_election_info': stream_election_info_by_dict(result_links[link]['list_of_lines'])})
    del result_links[link]['list_of_lines']

# print(announcement_links)
# print(result_links)

# поправки из-за единичных нестандартных случаев

if 'https://vk.com/wall-33327655_2232' in announcement_links.keys():
    announcement_links['https://vk.com/wall-33327655_2232']['nominated_info']['year_stream_no'] = '1.2'
    announcement_links['https://vk.com/wall-33327655_2232']['nominated_info']['year_no'] = 1
    announcement_links['https://vk.com/wall-33327655_2232']['nominated_info']['stream_no'] = 2
if 'https://vk.com/wall-33327655_2305' in announcement_links.keys():
    announcement_links['https://vk.com/wall-33327655_2305']['nominated_info']['year_stream_no'] = '3.1'
    announcement_links['https://vk.com/wall-33327655_2305']['nominated_info']['year_no'] = 3
    announcement_links['https://vk.com/wall-33327655_2305']['nominated_info']['stream_no'] = 1
if 'https://vk.com/wall-33327655_7695' in result_links.keys():
    result_links['https://vk.com/wall-33327655_7695']['stream_election_info']['year_stream_no'] = 'm1'
    result_links['https://vk.com/wall-33327655_7695']['stream_election_info']['year_no'] = 1
if 'https://vk.com/wall-33327655_9205' in result_links.keys():
    result_links['https://vk.com/wall-33327655_9205']['stream_election_info']['year_stream_no'] = '6.3'
    result_links['https://vk.com/wall-33327655_9205']['stream_election_info']['year_no'] = 6
    result_links['https://vk.com/wall-33327655_9205']['stream_election_info']['stream_no'] = 3
if 'https://vk.com/wall-33327655_9267' in result_links.keys():
    result_links['https://vk.com/wall-33327655_9267']['stream_election_info']['year_stream_no'] = '6.1'
    result_links['https://vk.com/wall-33327655_9267']['stream_election_info']['year_no'] = 6
    result_links['https://vk.com/wall-33327655_9267']['stream_election_info']['stream_no'] = 1
# Out:
# https://vk.com/wall-33327655_6540 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6541 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6542 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6543 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6544 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6545 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6546 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6547 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6548 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6549 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6550 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6551 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6552 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6553 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6554 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6555 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6556 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6557 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6558 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6559 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6560 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6561 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6562 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6563 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6564 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6565 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6566 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6567 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6568 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6569 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6570 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6571 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6572 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6573 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6574 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6575 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6576 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6577 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6578 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6579 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6580 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6581 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6582 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6583 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6584 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6585 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6586 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6587 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6588 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6589 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6590 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6591 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6592 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6593 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6594 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6595 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6596 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6597 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6598 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6599 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6600 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6601 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6602 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6603 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6604 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6605 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6606 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6607 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6608 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6609 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6610 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6611 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6612 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6613 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6614 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6615 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6616 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6617 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6618 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6619 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6620 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6621 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6622 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6623 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6624 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6625 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6626 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6627 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6628 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6629 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6630 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6631 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6632 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6633 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6634 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6635 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6636 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6637 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6638 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6639 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6640 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6641 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6642 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6643 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6644 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6645 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6646 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6647 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6648 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6649 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6650 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6651 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6652 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6653 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6654 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6655 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6656 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6657 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6658 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6659 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6660 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6661 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6662 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6663 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6664 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6665 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6666 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6667 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6668 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6669 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6670 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6671 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6672 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6673 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6674 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6675 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6676 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6677 : repost 		/ text 		/ other
# https://vk.com/wall-33327655_6678 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6679 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6680 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6681 : post 		/ election 		/ announcement
# https://vk.com/wall-33327655_6682 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6683 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6684 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6685 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6686 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6687 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6688 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6689 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6690 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6691 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6692 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6693 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6694 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6695 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6696 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6697 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6698 : post 		/ election 		/ other
# https://vk.com/wall-33327655_6699 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6700 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6701 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6702 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6703 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6704 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6705 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6706 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6707 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6708 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6709 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6710 : post 		/ text 		/ other
# https://vk.com/wall-33327655_6711 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6712 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6713 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6714 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6715 : comment 		/ text 		/ other
# https://vk.com/wall-33327655_6716 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6717 : post 		/ election 		/ result
# https://vk.com/wall-33327655_6718 : page not found 		/ no text 		/ other
# https://vk.com/wall-33327655_6719 : comment 		/ text 		/ other

# %%
# announcement_links['https://vk.com/wall-33327655_9858']

# %% [markdown]
# ### creating tables about candidates and streams

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО ПОТОКАМ

announcement_streams = {}
for link in announcement_links.keys():
    announcement_streams[link] = {
        'year_x_year_stream': str(announcement_links[link]['link_year_no']) + '_' + announcement_links[link]['nominated_info']['year_stream_no'],
        'link_date': announcement_links[link]['link_date'],
        'link_year_no': announcement_links[link]['link_year_no'], 
        'link_month_no': announcement_links[link]['link_month_no'], 
        'link_day_no': announcement_links[link]['link_day_no'], 
        'link_time': announcement_links[link]['link_time'], 
        'year_stream_no': announcement_links[link]['nominated_info']['year_stream_no'], 
        'year_no': announcement_links[link]['nominated_info']['year_no'], 
        'stream_no': announcement_links[link]['nominated_info']['stream_no']
    }
# announcement_streams

announcement_streams_df =  pd.DataFrame(announcement_streams.items(), columns=['link', 'params'])
announcement_streams_df_2 = pd.concat([announcement_streams_df.drop(['params'], axis=1), announcement_streams_df['params'].apply(pd.Series)], axis=1)
announcement_streams_df_3 = announcement_streams_df_2.sort_values(['year_stream_no', 'link'],
              ascending = [True, True]).reset_index().drop(['index'], axis=1)
announcement_streams_df_3
# Out:
#                                  link year_x_year_stream   link_date  \
# 0   https://vk.com/wall-33327655_7621           2018_1.1  2018-10-23
# 1   https://vk.com/wall-33327655_7479           2018_1.2  2018-10-12
# 2   https://vk.com/wall-33327655_7645           2018_1.3  2018-10-23
# 3   https://vk.com/wall-33327655_7622           2018_2.1  2018-10-23
# 4   https://vk.com/wall-33327655_7644           2018_2.3  2018-10-23
# 5   https://vk.com/wall-33327655_7619           2018_3.1  2018-10-21
# 6   https://vk.com/wall-33327655_7657           2018_3.2  2018-10-25
# 7   https://vk.com/wall-33327655_7552           2018_3.3  2018-10-17
# 8   https://vk.com/wall-33327655_7623           2018_3.4  2018-10-23
# 9   https://vk.com/wall-33327655_7667           2018_4.1  2018-10-25
# 10  https://vk.com/wall-33327655_7735           2018_4.2  2018-11-15
# 11  https://vk.com/wall-33327655_7602           2018_4.3  2018-10-18
# 12  https://vk.com/wall-33327655_7656           2018_5.3  2018-10-25
# 13  https://vk.com/wall-33327655_7620           2018_5.4  2018-10-21
# 14  https://vk.com/wall-33327655_7610           2018_6.1  2018-10-18
# 15  https://vk.com/wall-33327655_7606           2018_6.2  2018-10-18
# 16  https://vk.com/wall-33327655_7518            2018_m1  2018-10-16
#
#     link_year_no  link_month_no  link_day_no link_time year_stream_no  \
# 0           2018             10           23      0:00            1.1
# 1           2018             10           12     21:45            1.2
# 2           2018             10           23     23:38            1.3
# 3           2018             10           23      0:03            2.1
# 4           2018             10           23     23:19            2.3
# 5           2018             10           21     23:45            3.1
# 6           2018             10           25      0:10            3.2
# 7           2018             10           17     23:27            3.3
# 8           2018             10           23      0:06            3.4
# 9           2018             10           25     21:44            4.1
# 10          2018             11           15      0:02            4.2
# 11          2018             10           18     21:37            4.3
# 12          2018             10           25      0:01            5.3
# 13          2018             10           21     23:49            5.4
# 14          2018             10           18     23:17            6.1
# 15          2018             10           18     22:09            6.2
# 16          2018             10           16     21:30             m1
#
#     year_no  stream_no
# 0         1          1
# 1         1          2
# 2         1          3
# 3         2          1
# 4         2          3
# 5         3          1
# 6         3          2
# 7         3          3
# 8         3          4
# 9         4          1
# 10        4          2
# 11        4          3
# 12        5          3
# 13        5          4
# 14        6          1
# 15        6          2
# 16        1          0

# %%
# !!!! РАЗОБРАТЬСЯ С ПОВТОРНЫМИ ПОСТАМИ ВНУТРИ ОДНОГО ПОТОКА

# %%
announcement_streams_df_3.to_csv('ssmm_announcement_info_conv6.csv', sep='\t', encoding='utf-8', index=False)

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО КАНДИДАТАМ

announcement_names = {}
for link in announcement_links.keys():
    for name in announcement_links[link]['nominated_info']['dict_nominations'].keys():
        announcement_names[fix_name(name)] = {
            'link_year_no_x_name': str(announcement_links[link]['link_year_no']) + "_" + "_".join(fix_name(name).split()),
            'link_year_no': announcement_links[link]['link_year_no'], 
            'year_stream_no': announcement_links[link]['nominated_info']['year_stream_no'], 
            'year_no': announcement_links[link]['nominated_info']['year_no'], 
            'stream_no': announcement_links[link]['nominated_info']['stream_no'], 
            'academic_group_no': announcement_links[link]['nominated_info']['dict_nominations'][name]['academic_group_no'], 
            'program_txt': announcement_links[link]['nominated_info']['dict_nominations'][name]['program_txt'],
            'link': link
        }
# announcement_names

announcement_names_df =  pd.DataFrame(announcement_names.items(), columns=['name', 'params'])
announcement_names_df_2 = pd.concat([announcement_names_df.drop(['params'], axis=1), announcement_names_df['params'].apply(pd.Series)], axis=1)
announcement_names_df_2[:60]
# .head(10)
# Out:
#                                   name  \
# 0                Савин Павел Андреевич
# 1         Бекбулатов Рамзан Ломалиевич
# 2         Рогачёв Александр Викторович
# 3          Савченко Анастасия Игоревна
# 4           Хасанов Рафаэль Ильгизович
# 5   Тонконогов Александр Владиславович
# 6           Коновалов Дмитрий Игоревич
# 7                Денисов Илья Олегович
# 8        Порфирьева Наталия Алексеевна
# 9             Сакаев Роберт Марселевич
# 10        Татаринцева Мария Валерьевна
# 11          Малания Георгий Муртазович
# 12          Третьяков Артём Алексеевич
# 13            Муравьёва Анна Сергеевна
# 14          Сенотов Валерий Дмитриевич
# 15    Краснова Анастасия Александровна
# 16         Жуковский Никита Алексеевич
# 17        Кудасов Матвей Джамалханович
# 18         Волкова Дарья Александровна
# 19       Фиткович Валерия Владимировна
# 20       Зарубин Николай Александрович
# 21           Батутина Мария Алексеевна
# 22                Гигин Иван Сергеевич
# 23           Малахов Николай Сергеевич
# 24        Воробьёва Наталья Дмитриевна
# 25       Змиевский Леонид Вячеславович
# 26             Кухарчук Иван Андреевич
# 27         Салимгереев Махач Арсенович
# 28         Гусейнов Сэймур Элданизович
# 29       Малиновский Георгий Андреевич
# 30              Бузенков Олег Игоревич
# 31            Филатов Кирилл Андреевич
# 32               Корж Даниил Сергеевич
# 33         Вихорева Надежда Дмитриевна
# 34       Федотов Константин Алексеевич
# 35        Мазитова Вероника Рустэмовна
# 36             Хахова Мария Алексеевна
# 37       Митрофанов Дмитрий Георгиевич
#
#                         link_year_no_x_name  link_year_no year_stream_no  \
# 0                2017_Савин_Павел_Андреевич          2017            6.2
# 1         2017_Бекбулатов_Рамзан_Ломалиевич          2017            6.2
# 2         2017_Рогачёв_Александр_Викторович          2017            6.3
# 3          2017_Савченко_Анастасия_Игоревна          2017            6.3
# 4           2017_Хасанов_Рафаэль_Ильгизович          2017            6.4
# 5   2017_Тонконогов_Александр_Владиславович          2017            5.1
# 6           2017_Коновалов_Дмитрий_Игоревич          2017            5.2
# 7                2017_Денисов_Илья_Олегович          2017            5.2
# 8        2017_Порфирьева_Наталия_Алексеевна          2017            4.2
# 9             2017_Сакаев_Роберт_Марселевич          2017            5.3
# 10        2017_Татаринцева_Мария_Валерьевна          2017            5.3
# 11          2017_Малания_Георгий_Муртазович          2017            4.3
# 12          2017_Третьяков_Артём_Алексеевич          2017            4.3
# 13            2017_Муравьёва_Анна_Сергеевна          2017            4.3
# 14          2017_Сенотов_Валерий_Дмитриевич          2017            4.3
# 15    2017_Краснова_Анастасия_Александровна          2017            4.4
# 16         2017_Жуковский_Никита_Алексеевич          2017            4.1
# 17        2017_Кудасов_Матвей_Джамалханович          2017            3.3
# 18         2017_Волкова_Дарья_Александровна          2017            3.3
# 19       2017_Фиткович_Валерия_Владимировна          2017            2.2
# 20       2017_Зарубин_Николай_Александрович          2017            2.2
# 21           2017_Батутина_Мария_Алексеевна          2017            2.2
# 22                2017_Гигин_Иван_Сергеевич          2017            3.1
# 23           2017_Малахов_Николай_Сергеевич          2017            3.1
# 24        2017_Воробьёва_Наталья_Дмитриевна          2017            3.1
# 25       2017_Змиевский_Леонид_Вячеславович          2017            3.1
# 26             2017_Кухарчук_Иван_Андреевич          2017            1.1
# 27         2017_Салимгереев_Махач_Арсенович          2017            1.1
# 28         2017_Гусейнов_Сэймур_Элданизович          2017            1.1
# 29       2017_Малиновский_Георгий_Андреевич          2017            1.1
# 30              2017_Бузенков_Олег_Игоревич          2017            1.1
# 31            2017_Филатов_Кирилл_Андреевич          2017            2.3
# 32               2017_Корж_Даниил_Сергеевич          2017            2.3
# 33         2017_Вихорева_Надежда_Дмитриевна          2017            2.3
# 34       2017_Федотов_Константин_Алексеевич          2017            2.3
# 35        2017_Мазитова_Вероника_Рустэмовна          2017            2.1
# 36             2017_Хахова_Мария_Алексеевна          2017            2.1
# 37       2017_Митрофанов_Дмитрий_Георгиевич          2017            1.3
#
#     year_no  stream_no  academic_group_no  \
# 0         6          2                608
# 1         6          2                610
# 2         6          3                621
# 3         6          3                623
# 4         6          4                632
# 5         5          1                506
# 6         5          2                509
# 7         5          2                508
# 8         4          2                411
# 9         5          3                521
# 10        5          3                523
# 11        4          3                424
# 12        4          3                423
# 13        4          3                421
# 14        4          3                422
# 15        4          4                432
# 16        4          1                404
# 17        3          3                326
# 18        3          3                325
# 19        2          2                210
# 20        2          2                212
# 21        2          2                212
# 22        3          1                305
# 23        3          1                301
# 24        3          1                305
# 25        3          1                301
# 26        1          1                106
# 27        1          1                103
# 28        1          1                105
# 29        1          1                105
# 30        1          1                103
# 31        2          3                225
# 32        2          3                225
# 33        2          3                221
# 34        2          3                224
# 35        2          1                203
# 36        2          1                202
# 37        1          3                126
#
#                                           program_txt  \
# 0   "Рамзан сказал, что я нужен студсовету. А вы с...
# 1   "Моргнуть не успел как из зеленого первокура п...
# 2   "С каждым годом студсовет всё крепче встаёт на...
# 3   "Я в студенческом совете уже 4 года и каждый г...
# 4   "Добрый день!\nРаботая в студенческом совете я...
# 5   "Здравствуйте!\nИзбираюсь в студенческий совет...
# 6   "Всем привет!\nКак и все мехматяне я хочу виде...
# 7   "Привет, друзья!\nЯ был председателем Студсове...
# 8   "Всем привет!\nЯ люблю наш мехмат за его вдохн...
# 9   "Начну с распространения мемасов в оповещении,...
# 10  "Привет!\nПопав в студенческий совет, покинуть...
# 11  "Здравствуйте, меня зовут Малания Георгий. Я б...
# 12  "Я человек простой, в студсовете ранее не рабо...
# 13  "Буря эмоций? Пусть всегда будет ураган!\nВсем...
# 14  " Привет, друзья! Я выбираюсь в студсовет втор...
# 15  "Всем привет!\nВ студсовете я давно, в основно...
# 16  "Всем привет!\nЯ очень люблю олимпиадную матем...
# 17  "Всем привет!\nДо этого в студсовете не состоя...
# 18  "Привет! Меня зовут Даша. Всегда было интересн...
# 19  "Доброго времени суток, друзья. Меня зовут Лер...
# 20  "Я буду краток, так как считаю, что за год сов...
# 21  "Общественная деятельность привлекла меня ещё ...
# 22  "Всем привет. В прошлом созыве я активно заним...
# 23  "Привет, в Студенческий Совет я избираюсь во в...
# 24  "Всем привет!\nИзбираюсь в студенческий совет ...
# 25  "Доброго времени суток!\nВ студенческий совет ...
# 26  "Всем привет!\nЯ давно активно занимаюсь общес...
# 27  "Первокурсник. Нравится организаторская деятел...
# 28  "Здравствуйте, я являюсь одним из админов пабл...
# 29  "Всем привет! Был осведомлён о работе Студсове...
# 30  "Студенческий совет всегда работает над улучше...
# 31  "Хочу изменить мир к лучшему! И начну с мехмат...
# 32  "Приближается (а может наступила) дата выборов...
# 33  "Честно сказать,мои интерес к студенческому со...
# 34  "Всем привет!\nЗа прошедший год на мехмате я н...
# 35  "Почему я хочу участвовать в деятельности студ...
# 36  "Ох уж эта школа актива. Вынуждена признаться,...
# 37  "Добрый день. Нравится организаторская деятель...
#
#                                  link
# 0   https://vk.com/wall-33327655_6562
# 1   https://vk.com/wall-33327655_6562
# 2   https://vk.com/wall-33327655_6564
# 3   https://vk.com/wall-33327655_6564
# 4   https://vk.com/wall-33327655_6572
# 5   https://vk.com/wall-33327655_6574
# 6   https://vk.com/wall-33327655_6576
# 7   https://vk.com/wall-33327655_6576
# 8   https://vk.com/wall-33327655_6581
# 9   https://vk.com/wall-33327655_6585
# 10  https://vk.com/wall-33327655_6585
# 11  https://vk.com/wall-33327655_6586
# 12  https://vk.com/wall-33327655_6586
# 13  https://vk.com/wall-33327655_6586
# 14  https://vk.com/wall-33327655_6586
# 15  https://vk.com/wall-33327655_6595
# 16  https://vk.com/wall-33327655_6603
# 17  https://vk.com/wall-33327655_6637
# 18  https://vk.com/wall-33327655_6637
# 19  https://vk.com/wall-33327655_6643
# 20  https://vk.com/wall-33327655_6643
# 21  https://vk.com/wall-33327655_6643
# 22  https://vk.com/wall-33327655_6645
# 23  https://vk.com/wall-33327655_6645
# 24  https://vk.com/wall-33327655_6645
# 25  https://vk.com/wall-33327655_6645
# 26  https://vk.com/wall-33327655_6656
# 27  https://vk.com/wall-33327655_6656
# 28  https://vk.com/wall-33327655_6656
# 29  https://vk.com/wall-33327655_6656
# 30  https://vk.com/wall-33327655_6656
# 31  https://vk.com/wall-33327655_6658
# 32  https://vk.com/wall-33327655_6658
# 33  https://vk.com/wall-33327655_6658
# 34  https://vk.com/wall-33327655_6658
# 35  https://vk.com/wall-33327655_6680
# 36  https://vk.com/wall-33327655_6680
# 37  https://vk.com/wall-33327655_6681

# %%
# присвоить ssmm_id в порядке публикации постов (дата, время)
# ИЛИ другим способом ОТСОРТИРОВАТЬ КАНДИДАТОВ (сейчас они в порядке появления в постах в порядке выхода постов, вроде норм)

# %%
announcement_names_df_2.to_csv('ssmm_candidates_info_conv7.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
#  ### creating tables about results

# %%
'''
БАГ:
- https://vk.com/wall-33327655_7695 - не считывается поток 
'''

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО ПОТОКАМ

result_streams = {}
for link in result_links.keys():
    result_streams[link] = {
        'year_x_year_stream': str(result_links[link]['link_year_no']) + '_' + result_links[link]['stream_election_info']['year_stream_no'],
        'link_date': result_links[link]['link_date'],
        'link_year_no': result_links[link]['link_year_no'], 
        'link_month_no': result_links[link]['link_month_no'], 
        'link_day_no': result_links[link]['link_day_no'], 
        'link_time': result_links[link]['link_time'], 
        'year_stream_no': result_links[link]['stream_election_info']['year_stream_no'], 
        'year_no': result_links[link]['stream_election_info']['year_no'], 
        'stream_no': result_links[link]['stream_election_info']['stream_no'], 
        'stream_size': result_links[link]['stream_election_info']['stream_size'], 
        'voted_cnt': result_links[link]['stream_election_info']['voted_cnt'], 
        'invalid_cnt': result_links[link]['stream_election_info']['invalid_cnt'], 
        'NOTA_cnt': result_links[link]['stream_election_info']['NOTA_cnt'], 
        'organizers': result_links[link]['stream_election_info']['organizers']
    }
# announcement_streams

result_streams_df =  pd.DataFrame(result_streams.items(), columns=['link', 'params'])
result_streams_df_2 = pd.concat([result_streams_df.drop(['params'], axis=1), result_streams_df['params'].apply(pd.Series)], axis=1)
result_streams_df_3 = result_streams_df_2.sort_values(['year_stream_no', 'link'],
              ascending = [True, True]).reset_index().drop(['index'], axis=1)
result_streams_df_3
# Out:
#                                  link year_x_year_stream   link_date  \
# 0   https://vk.com/wall-33327655_7676           2018_1.1  2018-10-26
# 1   https://vk.com/wall-33327655_7509           2018_1.2  2018-10-14
# 2   https://vk.com/wall-33327655_7685           2018_1.3  2018-10-27
# 3   https://vk.com/wall-33327655_7677           2018_2.1  2018-10-26
# 4   https://vk.com/wall-33327655_7684           2018_2.3  2018-10-27
# 5   https://vk.com/wall-33327655_7675           2018_3.1  2018-10-26
# 6   https://vk.com/wall-33327655_7728           2018_3.2  2018-11-12
# 7   https://vk.com/wall-33327655_7670           2018_3.3  2018-10-25
# 8   https://vk.com/wall-33327655_7681           2018_3.4  2018-10-27
# 9   https://vk.com/wall-33327655_7694           2018_4.1  2018-11-02
# 10  https://vk.com/wall-33327655_7741           2018_4.2  2018-11-15
# 11  https://vk.com/wall-33327655_7674           2018_4.3  2018-10-26
# 12  https://vk.com/wall-33327655_7696           2018_5.3  2018-11-02
# 13  https://vk.com/wall-33327655_7707           2018_5.4  2018-11-10
# 14  https://vk.com/wall-33327655_7766           2018_6.1  2018-11-22
# 15  https://vk.com/wall-33327655_7704           2018_6.2  2018-11-09
# 16  https://vk.com/wall-33327655_7695            2018_m1  2018-11-02
#
#     link_year_no  link_month_no  link_day_no link_time year_stream_no  \
# 0           2018             10           26     17:00            1.1
# 1           2018             10           14     21:00            1.2
# 2           2018             10           27     14:00            1.3
# 3           2018             10           26     19:00            2.1
# 4           2018             10           27     12:00            2.3
# 5           2018             10           26     14:00            3.1
# 6           2018             11           12     22:56            3.2
# 7           2018             10           25     23:52            3.3
# 8           2018             10           27     10:00            3.4
# 9           2018             11            2     22:25            4.1
# 10          2018             11           15     20:20            4.2
# 11          2018             10           26     10:00            4.3
# 12          2018             11            2     22:39            5.3
# 13          2018             11           10     14:00            5.4
# 14          2018             11           22     22:15            6.1
# 15          2018             11            9     20:00            6.2
# 16          2018             11            2     22:33             m1
#
#     year_no  stream_no  stream_size  voted_cnt invalid_cnt NOTA_cnt  \
# 0         1          1          168        117           7        4
# 1         1          2          151        104           2        8
# 2         1          3          123         98           3        5
# 3         2          1          134         81           5        1
# 4         2          3          107         75           1        4
# 5         3          1          107         58           3       11
# 6         3          2           94         49           1        4
# 7         3          3          103         55           0        8
# 8         3          4           40         25           0        0
# 9         4          1           86         45           2       11
# 10        4          2           76         40           1        0
# 11        4          3           81         42           0        2
# 12        5          3           89         45           1        0
# 13        5          4           35         18           0        1
# 14        6          1           90         45           2        0
# 15        6          2           77         40           0        3
# 16        1          0           29         20           0        0
#
#                                         organizers
# 0        [Георгием Малиновским, Олегом Бузенковым]
# 1       [Георгием Малиновским, Кириллом Филатовым]
# 2       [Сенотовым Валерием, Малиновским Георгием]
# 3          [Валерией Фиткович, Николаем Малаховым]
# 4       [Сенотовым Валерием, Малиновским Георгием]
# 5   [Валерием Сенотовым, Александром Тонконоговым]
# 6               [Ильёй Денисовым, Дарьей Волковой]
# 7   [Валерием Сенотовым, Александром Тонконоговым]
# 8   [Валерием Сенотовым, Александром Тонконоговым]
# 9           [Денисовым Ильей, Воробьевой Наталией]
# 10      [Валерием Сенотовым, Анастасией Красновой]
# 11       [Вероникой Мазитовой, Николаем Малаховым]
# 12          [Георгием Малиновским, Марией Хаховой]
# 13         [Матвеем Кудасовым, Валерием Сенотовым]
# 14             [Валерием Сенотовым, Марией Корней]
# 15             [Марией Корней, Валерием Сенотовым]
# 16  [Сенотовым Валерием, Тонконоговым Александром]

# %%
result_streams_df_3.to_csv('ssmm_results_info_conv8.csv', sep='\t', encoding='utf-8', index=False)

# %%
# ОТДЕЛЬНАЯ ТАБЛИЦА ПО ОРГАНИЗАТОРАМ

organizers_df = result_streams_df_3[['year_x_year_stream','organizers']].apply(lambda x: x.explode()).reset_index().drop(['index'], axis=1)
# organizers_df

# %%
organizers_df.to_csv('ssmm_organizers_info_conv8.csv', sep='\t', encoding='utf-8', index=False)

# %%
# БОЛЬШАЯ ТАБЛИЦА ПО КАНДИДАТАМ

result_names = {}
for link in result_links.keys():
    for name in result_links[link]['stream_election_info']['dict_nominated_with_votes'].keys():
        result_names[fix_name(name)] = {
            'link_year_no_x_name': str(result_links[link]['link_year_no']) + "_" + "_".join(fix_name(name).split()),
            'link_year_no': result_links[link]['link_year_no'], 
            'year_stream_no': result_links[link]['stream_election_info']['year_stream_no'], 
            'year_no': result_links[link]['stream_election_info']['year_no'], 
            'stream_no': result_links[link]['stream_election_info']['stream_no'], 
            'votes_cnt': result_links[link]['stream_election_info']['dict_nominated_with_votes'][name]['votes_cnt'],
            'elected_flg': result_links[link]['stream_election_info']['dict_nominated_with_votes'][name]['elected_flg'],
            'link': link
        }

result_names_df =  pd.DataFrame(result_names.items(), columns=['name', 'params'])
result_names_df_2 = pd.concat([result_names_df.drop(['params'], axis=1), result_names_df['params'].apply(pd.Series)], axis=1)
result_names_df_2
# .head(10)
# Out:
#                                   name  \
# 0   Тонконогов Александр Владиславович
# 1           Коновалов Дмитрий Игоревич
# 2                Денисов Илья Олегович
# 3        Порфирьева Наталия Алексеевна
# 4           Малания Георгий Муртазович
# 5           Третьяков Артём Алексеевич
# 6             Муравьёва Анна Сергеевна
# 7           Сенотов Валерий Дмитриевич
# 8             Сакаев Роберт Марселевич
# 9         Татаринцева Мария Валерьевна
# 10    Краснова Анастасия Александровна
# 11         Жуковский Никита Алексеевич
# 12        Кудасов Матвей Джамалханович
# 13         Волкова Дарья Александровна
# 14                Гигин Иван Сергеевич
# 15           Малахов Николай Сергеевич
# 16        Воробьёва Наталья Дмитриевна
# 17       Змиевский Леонид Вячеславович
# 18       Фиткович Валерия Владимировна
# 19       Зарубин Николай Александрович
# 20           Батутина Мария Алексеевна
# 21             Кухарчук Иван Андреевич
# 22         Салимгереев Махач Арсенович
# 23       Малиновский Георгий Андреевич
# 24         Гусейнов Сэймур Элданизович
# 25              Бузенков Олег Игоревич
# 26            Филатов Кирилл Андреевич
# 27               Корж Даниил Сергеевич
# 28         Вихорева Надежда Дмитриевна
# 29       Федотов Константин Алексеевич
# 30       Митрофанов Дмитрий Георгиевич
# 31         Савченко Анастасия Игоревна
# 32        Рогачёв Александр Викторович
# 33          Хасанов Рафаэль Ильгизович
# 34        Мазитова Вероника Рустэмовна
# 35             Хахова Мария Алексеевна
# 36               Савин Павел Андреевич
# 37        Бекбулатов Рамзан Ломалиевич
#
#                         link_year_no_x_name  link_year_no year_stream_no  \
# 0   2017_Тонконогов_Александр_Владиславович          2017            5.1
# 1           2017_Коновалов_Дмитрий_Игоревич          2017            5.2
# 2                2017_Денисов_Илья_Олегович          2017            5.2
# 3        2017_Порфирьева_Наталия_Алексеевна          2017            4.2
# 4           2017_Малания_Георгий_Муртазович          2017            4.3
# 5           2017_Третьяков_Артём_Алексеевич          2017            4.3
# 6             2017_Муравьёва_Анна_Сергеевна          2017            4.3
# 7           2017_Сенотов_Валерий_Дмитриевич          2017            4.3
# 8             2017_Сакаев_Роберт_Марселевич          2017            5.3
# 9         2017_Татаринцева_Мария_Валерьевна          2017            5.3
# 10    2017_Краснова_Анастасия_Александровна          2017            4.4
# 11         2017_Жуковский_Никита_Алексеевич          2017            4.1
# 12        2017_Кудасов_Матвей_Джамалханович          2017            3.3
# 13         2017_Волкова_Дарья_Александровна          2017            3.3
# 14                2017_Гигин_Иван_Сергеевич          2017            3.1
# 15           2017_Малахов_Николай_Сергеевич          2017            3.1
# 16        2017_Воробьёва_Наталья_Дмитриевна          2017            3.1
# 17       2017_Змиевский_Леонид_Вячеславович          2017            3.1
# 18       2017_Фиткович_Валерия_Владимировна          2017            2.2
# 19       2017_Зарубин_Николай_Александрович          2017            2.2
# 20           2017_Батутина_Мария_Алексеевна          2017            2.2
# 21             2017_Кухарчук_Иван_Андреевич          2017            1.1
# 22         2017_Салимгереев_Махач_Арсенович          2017            1.1
# 23       2017_Малиновский_Георгий_Андреевич          2017            1.1
# 24         2017_Гусейнов_Сэймур_Элданизович          2017            1.1
# 25              2017_Бузенков_Олег_Игоревич          2017            1.1
# 26            2017_Филатов_Кирилл_Андреевич          2017            2.3
# 27               2017_Корж_Даниил_Сергеевич          2017            2.3
# 28         2017_Вихорева_Надежда_Дмитриевна          2017            2.3
# 29       2017_Федотов_Константин_Алексеевич          2017            2.3
# 30       2017_Митрофанов_Дмитрий_Георгиевич          2017            1.3
# 31         2017_Савченко_Анастасия_Игоревна          2017            6.3
# 32        2017_Рогачёв_Александр_Викторович          2017            6.3
# 33          2017_Хасанов_Рафаэль_Ильгизович          2017            6.4
# 34        2017_Мазитова_Вероника_Рустэмовна          2017            2.1
# 35             2017_Хахова_Мария_Алексеевна          2017            2.1
# 36               2017_Савин_Павел_Андреевич          2017            6.2
# 37        2017_Бекбулатов_Рамзан_Ломалиевич          2017            6.2
#
#     year_no  stream_no votes_cnt  elected_flg  \
# 0         5          1        44            1
# 1         5          2        32            1
# 2         5          2        33            1
# 3         4          2        43            1
# 4         4          3        33            1
# 5         4          3        15            0
# 6         4          3        25            1
# 7         4          3        37            1
# 8         5          3        35            1
# 9         5          3        39            1
# 10        4          4        23            1
# 11        4          1        34            1
# 12        3          3        29            1
# 13        3          3        38            1
# 14        3          1        25            1
# 15        3          1        25            1
# 16        3          1        26            1
# 17        3          1        30            1
# 18        2          2        65            1
# 19        2          2        63            1
# 20        2          2        41            1
# 21        1          1        51            1
# 22        1          1        31            0
# 23        1          1        55            1
# 24        1          1        26            0
# 25        1          1        53            1
# 26        2          3        19            1
# 27        2          3        19            1
# 28        2          3        29            1
# 29        2          3        22            1
# 30        1          3        69            1
# 31        6          3        29            1
# 32        6          3        38            1
# 33        6          4        28            1
# 34        2          1        30            1
# 35        2          1        41            1
# 36        6          2        42            1
# 37        6          2        37            1
#
#                                  link
# 0   https://vk.com/wall-33327655_6619
# 1   https://vk.com/wall-33327655_6620
# 2   https://vk.com/wall-33327655_6620
# 3   https://vk.com/wall-33327655_6624
# 4   https://vk.com/wall-33327655_6625
# 5   https://vk.com/wall-33327655_6625
# 6   https://vk.com/wall-33327655_6625
# 7   https://vk.com/wall-33327655_6625
# 8   https://vk.com/wall-33327655_6628
# 9   https://vk.com/wall-33327655_6628
# 10  https://vk.com/wall-33327655_6632
# 11  https://vk.com/wall-33327655_6639
# 12  https://vk.com/wall-33327655_6647
# 13  https://vk.com/wall-33327655_6647
# 14  https://vk.com/wall-33327655_6651
# 15  https://vk.com/wall-33327655_6651
# 16  https://vk.com/wall-33327655_6651
# 17  https://vk.com/wall-33327655_6651
# 18  https://vk.com/wall-33327655_6654
# 19  https://vk.com/wall-33327655_6654
# 20  https://vk.com/wall-33327655_6654
# 21  https://vk.com/wall-33327655_6665
# 22  https://vk.com/wall-33327655_6665
# 23  https://vk.com/wall-33327655_6665
# 24  https://vk.com/wall-33327655_6665
# 25  https://vk.com/wall-33327655_6665
# 26  https://vk.com/wall-33327655_6668
# 27  https://vk.com/wall-33327655_6668
# 28  https://vk.com/wall-33327655_6668
# 29  https://vk.com/wall-33327655_6668
# 30  https://vk.com/wall-33327655_6683
# 31  https://vk.com/wall-33327655_6689
# 32  https://vk.com/wall-33327655_6689
# 33  https://vk.com/wall-33327655_6693
# 34  https://vk.com/wall-33327655_6702
# 35  https://vk.com/wall-33327655_6702
# 36  https://vk.com/wall-33327655_6717
# 37  https://vk.com/wall-33327655_6717

# %%
result_names_df_2.to_csv('ssmm_votes_info_conv7.csv', sep='\t', encoding='utf-8', index=False)

# %%
# full table for 4-11 convocations:

def united_table_for_4_11(name):
    list_of_df = []
    for i in range(4,11+1):
        df = pd.read_csv('ssmm_'+name+'_info_conv'+str(i)+'.csv', sep='\t', encoding='utf-8')
        list_of_df.append(df)
    kek = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
    kek.to_csv('ssmm_'+name+'_info_conv_4_11.csv', sep='\t', encoding='utf-8', index=False)
    return None

names = ['announcement','candidates','results','organizers','votes']

for name in names:
    united_table_for_4_11(name)

# %% [markdown]
# ## Completeness testing

# %%
# ПОПРИДЖОЙНИВАТЬ АНОНСЫ НА РЕЗУЛЬТАТЫ, ЧТОБЫ ПОНЯТЬ, КАКИЕ ПОСТЫ С РЕЗУЛЬТАТАМИ НЕ РАСПОЗНАЛИСЬ

# - по созывам, внутри созывов:
#     - по потокам
#     - по кандидатам

# %%
ssmm_announcements_info = pd.read_csv('ssmm_announcement_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_candidates_info = pd.read_csv('ssmm_candidates_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_results_info = pd.read_csv('ssmm_results_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_organizers_info = pd.read_csv('ssmm_organizers_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_votes_info = pd.read_csv('ssmm_votes_info_conv_4_11.csv', sep='\t', encoding='utf-8')

# %%
list(ssmm_candidates_info)
# Out:
# ['name',
#  'link_year_no_x_name',
#  'link_year_no',
#  'year_stream_no',
#  'year_no',
#  'stream_no',
#  'academic_group_no',
#  'program_txt',
#  'link']

# %%
list(ssmm_votes_info)
# Out:
# ['name',
#  'link_year_no_x_name',
#  'link_year_no',
#  'year_stream_no',
#  'year_no',
#  'stream_no',
#  'votes_cnt',
#  'elected_flg',
#  'link']

# %%
df1 = ssmm_announcements_info[['year_x_year_stream','link']]
df2 = ssmm_results_info[['year_x_year_stream','link']]

df1_x_d2 = df1.merge(df2, left_on='year_x_year_stream', right_on='year_x_year_stream',how='outer')
# df1_x_d2[120:180]

# всё ок, кроме:
# 2014_m2 - нет в ssmm_announcements_info - не было анонса

# %%
# ssmm_announcements_info[ssmm_announcements_info['link'] == 'https://vk.com/wall-33327655_2218']

# %%
df1 = ssmm_candidates_info[['link_year_no_x_name','link']]
df2 = ssmm_votes_info[['link_year_no_x_name','link']]

df1_x_d2 = df1.merge(df2, left_on='link_year_no_x_name', right_on='link_year_no_x_name',how='outer')
df1_x_d2_nan = df1_x_d2[df1_x_d2['link_x'].isna()]
# df1_x_d2_nan = df1_x_d2[df1_x_d2['link_y'].isna()]

# df1_x_d2_nan = df1_x_d2[df1_x_d2[kkk].isna() for any(kkk in ['link_x', 'link_y'])]
# df1_x_d2_nan = df1_x_d2[df1_x_d2.isnull()[['link_x', 'link_y']].any()]

df1_x_d2_nan
# df1_x_d2[120:180]

# ОСТАВШИЕСЯ ПРОБЛЕМЫ:

# 131	2016_Думаревский_Александр_Дмитриевич	https://vk.com/wall-33327655_5144	NaN	 - СНЯЛСЯ
# 248	2019_Воронин_Вадим_Юрьевич	https://vk.com/wall-33327655_8323	NaN - СНЯЛСЯ
# 344	2021_Витковский_Андрей_Владиславович	https://vk.com/wall-33327655_9894	NaN - случайный ЭНТЕР (https://vk.com/wall-33327655_10007)

# 367	2014_Вергазов_Марат_Марсович	NaN	https://vk.com/wall-33327655_2313 - НЕ БЫЛО АНОНСА
# 381	2018_Шишкин_Игнат_Владимирович	NaN	https://vk.com/wall-33327655_7685 - ИЗ_ЗА ПАРНОЙ ЗАЯВКИ https://vk.com/wall-33327655_8330
# 397	2020_Устинов_Никита_Евгеньевич	NaN	https://vk.com/wall-33327655_9317 - ЗАБЫЛИ ТИРЕ В НАЧАЛЕ СТРОКИ (https://vk.com/wall-33327655_9212)
# Out:
#                 link_year_no_x_name link_x                             link_y
# 388    2014_Вергазов_Марат_Марсович    NaN  https://vk.com/wall-33327655_2313
# 389  2018_Шишкин_Игнат_Владимирович    NaN  https://vk.com/wall-33327655_7685
# 390  2020_Устинов_Никита_Евгеньевич    NaN  https://vk.com/wall-33327655_9317

# %% [markdown]
# ### finding similar names

# %%
# найти группы имен с минимальным расхождением по расстоянию левенштайна
# найти имена, являющиеся началом других имен (когда забыли про отчество)

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

string1 = "abc"
string2 = "aef"

print(levenshtein(string1, string2))

# %%
names = list(ssmm_candidates_info['name']) + list(ssmm_votes_info['name'])
# print(names)

from collections import Counter

names_stat = Counter(names) #.most_common()
# names_stat

# names_uniq = list(set(names))
# names_uniq

# %%
# выявляем похожие имена, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a, b) <= 4 and names_stat[a] >= names_stat[b]:
            print(levenshtein(a, b), ' - ', a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# 1  -  Муравьёва Анна Сергеевна 8  :  4 Муравьева Анна Сергеевна
# 1  -  Третьяков Артём Алексеевич 3  :  1 Третьяков Артем Алексеевич
# 1  -  Рогачёв Александр Викторович 3  :  1 Рогачев Александр Викторович
# 1  -  Порфирьева Наталия Алексеевна 1  :  1 Порфирьева Наталья Алексеевна
# 1  -  Гусейнов Сеймур Элданизович 2  :  2 Гусейнов Сэймур Элданизович
# 1  -  Гусейнов Сэймур Элданизович 2  :  2 Гусейнов Сеймур Элданизович
# 1  -  Третьяков Пётр Максимович 4  :  2 Третьяков Петр Максимович
# 1  -  Пушкарева Анна Константиновна 3  :  1 Пушкарёва Анна Константиновна
# 2  -  Лобанова Елена Валерьевна 3  :  3 Лобанова Алёна Валерьевна
# 1  -  Илизаров Год Эмануилович 1  :  1 Иллизаров Год Эмануилович
# 2  -  Лобанова Алёна Валерьевна 3  :  3 Лобанова Елена Валерьевна
# 1  -  Порфирьева Наталья Алексеевна 1  :  1 Порфирьева Наталия Алексеевна
# 1  -  Иллизаров Год Эмануилович 1  :  1 Илизаров Год Эмануилович

# %%
# выявляем имена без отчества, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if len(a) > len(b) and levenshtein(a[:len(b)], b) <= 4:
            print(a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# Лапина Софья Михайловна 4  :  2 Лапина София
# Иллизаров Год Эмануилович 1  :  1 Илизаров Год Эмануилович

# %%
# выявляем имена с перепутанными отчествами, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a[:12], b[:12]) <= 2 and names_stat[a] >= names_stat[b]:
            print(a, names_stat[a], ' : ', names_stat[b], b)

# Сакаев Роберт Марселевич 5  :  1 Сакаев Роберт Викторович
# Out:
# Муравьёва Анна Сергеевна 8  :  4 Муравьева Анна Сергеевна
# Лапина Софья Михайловна 4  :  2 Лапина София
# Сакаев Роберт Марселевич 5  :  1 Сакаев Роберт Викторович
# Третьяков Артём Алексеевич 3  :  1 Третьяков Артем Алексеевич
# Третьяков Артём Алексеевич 3  :  2 Третьяков Петр Максимович
# Рогачёв Александр Викторович 3  :  1 Рогачев Александр Викторович
# Порфирьева Наталия Алексеевна 1  :  1 Порфирьева Наталья Алексеевна
# Гусейнов Сеймур Элданизович 2  :  2 Гусейнов Сэймур Элданизович
# Федотов Константин Алексеевич 2  :  2 Фёдоров Константин Дмитриевич
# Алиев Рамиль Камиль Оглы 2  :  2 Алеев Дамиль Павлович
# Гусейнов Сэймур Элданизович 2  :  2 Гусейнов Сеймур Элданизович
# Перфильева Нелли Андреевна 2  :  1 Порфирьева Наталия Алексеевна
# Перфильева Нелли Андреевна 2  :  1 Порфирьева Наталья Алексеевна
# Фёдоров Константин Дмитриевич 2  :  2 Федотов Константин Алексеевич
# Третьяков Пётр Максимович 4  :  3 Третьяков Артём Алексеевич
# Третьяков Пётр Максимович 4  :  1 Третьяков Артем Алексеевич
# Третьяков Пётр Максимович 4  :  2 Третьяков Петр Максимович
# Пушкарева Анна Константиновна 3  :  1 Пушкарёва Анна Константиновна
# Лобанова Елена Валерьевна 3  :  3 Лобанова Алёна Валерьевна
# Илизаров Год Эмануилович 1  :  1 Иллизаров Год Эмануилович
# Третьяков Петр Максимович 2  :  1 Третьяков Артем Алексеевич
# Лобанова Алёна Валерьевна 3  :  3 Лобанова Елена Валерьевна
# Лобанова Алёна Валерьевна 3  :  2 Лобанова Анастасия Алексеевна
# Алеев Дамиль Павлович 2  :  2 Алиев Рамиль Камиль Оглы
# Порфирьева Наталья Алексеевна 1  :  1 Порфирьева Наталия Алексеевна
# Иллизаров Год Эмануилович 1  :  1 Илизаров Год Эмануилович

# %%
# incorrect: correct
correct_names_dict = {
#     из-за Е/Ё:
    'Муравьева Анна Сергеевна': 'Муравьёва Анна Сергеевна',
    'Третьяков Артем Алексеевич': 'Третьяков Артём Алексеевич',
    'Рогачев Александр Викторович': 'Рогачёв Александр Викторович',
    'Третьяков Петр Максимович': 'Третьяков Пётр Максимович',
    'Пушкарева Анна Константиновна': 'Пушкарёва Анна Константиновна',
#     из-за других букв:
    'Порфирьева Наталья Алексеевна': 'Порфирьева Наталия Алексеевна',
    'Лобанова Елена Валерьевна': 'Лобанова Алёна Валерьевна',
    'Иллизаров Год Эмануилович': 'Илизаров Год Эмануилович',
    'Гусейнов Сеймур Элданизович': 'Гусейнов Сэймур Элданизович',
#     из-за пропущенного отчества:
    'Лапина София': 'Лапина Софья Михайловна',   
#     из-за перепутанного отчества:
    'Сакаев Роберт Викторович': 'Сакаев Роберт Марселевич',   
}
# correct_names_dict

correct_names_df =  pd.DataFrame(correct_names_dict.items(), columns=['incorrect_name', 'correct_name'])
correct_names_df
# Out:
#                    incorrect_name                   correct_name
# 0        Муравьева Анна Сергеевна       Муравьёва Анна Сергеевна
# 1      Третьяков Артем Алексеевич     Третьяков Артём Алексеевич
# 2    Рогачев Александр Викторович   Рогачёв Александр Викторович
# 3       Третьяков Петр Максимович      Третьяков Пётр Максимович
# 4   Пушкарева Анна Константиновна  Пушкарёва Анна Константиновна
# 5   Порфирьева Наталья Алексеевна  Порфирьева Наталия Алексеевна
# 6       Лобанова Елена Валерьевна      Лобанова Алёна Валерьевна
# 7       Иллизаров Год Эмануилович       Илизаров Год Эмануилович
# 8     Гусейнов Сеймур Элданизович    Гусейнов Сэймур Элданизович
# 9                    Лапина София        Лапина Софья Михайловна
# 10       Сакаев Роберт Викторович       Сакаев Роберт Марселевич

# %%
# def replace_pseudonym(final_df, pseudo_word, correct_word):
#     final_df2 = final_df.copy(deep=True)
#     final_df2.loc[final_df2['word'] == pseudo_word, 'word'] = correct_word
#     final_df2 = final_df2.groupby('word', as_index=False).agg({'full_counter':'sum', 'special_counter':'sum'})
#     final_df = pd.merge(final_df2, final_df[['word','special_view']], on='word', how='outer')   
#     final_df.drop(final_df[final_df['word'] == pseudo_word].index, inplace=True)
#     return final_df

# replace_couples = [
#     ['strider','aragorn'],
#     ['mithrandir','gandalf'],
#     ['peregrin','pippin'],
#     ['sméagol','gollum'],
#     ['meriadoc','merry'],
#     ['elessar','aragorn']
# ]
