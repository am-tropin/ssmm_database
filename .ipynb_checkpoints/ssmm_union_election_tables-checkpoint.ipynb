# %%
import pandas as pd

# %% [markdown]
# # 1. To fix CANDIDATE tables

# %%
ssmm_announcement_conv_1_3 = pd.read_csv('ssmm_announcement_info_conv_1_3.csv', sep='\t', encoding='utf-8')
candidates_conv_1_3 = ssmm_announcement_conv_1_3[['name','convocation_no','year_stream_no','year_no','stream_no','academic_group_no','program_txt','link_date','link_time','link']]

candidates_conv_1_3
# Out:
#                               name  convocation_no year_stream_no  year_no  \
# 0                     Левин Андрей               1            1.1        1
# 1    Матвеев Дмитрий Александрович               1            1.1        1
# 2           Власов Артем Андреевич               1            1.2        1
# 3                 Кириллова Полина               1            1.2        1
# 4                    Семенов Павел               1            1.2        1
# ..                             ...             ...            ...      ...
# 126    Сапунов Кирилл Вячеславович               3            5.3        5
# 127  Самонов Алексей Александрович               3            5.3        5
# 128  Короткин Виталий Владимирович               3             m1        1
# 129           Буряк Анна Андреевна               3             m1        1
# 130       Морозов Сергей Сергеевич               3             m2        2
#
#      stream_no  academic_group_no  \
# 0            1              101.0
# 1            1              101.0
# 2            2              107.0
# 3            2              112.0
# 4            2              112.0
# ..         ...                ...
# 126          3              525.0
# 127          3              526.0
# 128          0                NaN
# 129          0                NaN
# 130          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 126                                                NaN  2013-11-17     14:21
# 127  "Я студент 5 курса, есть опыт в организации ра...  2013-11-17     14:21
# 128  "с сентября 2012-н.в. являюсь председателем СК...  2013-11-17     14:16
# 129  "Состояла в студсовете в 2010-2011 годах, на п...  2013-11-17     14:16
# 130                                                NaN  2013-11-17     14:13
#
#                                        link
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 126  https://vk.com/topic-33327655_29117817
# 127  https://vk.com/topic-33327655_29117817
# 128  https://vk.com/topic-33327655_29117788
# 129  https://vk.com/topic-33327655_29117788
# 130  https://vk.com/topic-33327655_29117770
#
# [131 rows x 10 columns]

# %%
ssmm_announcements_conv_4_11 = pd.read_csv('ssmm_announcement_info_conv_4_11.csv', sep='\t', encoding='utf-8')
# ssmm_announcements_conv_4_11.head()

# %%
def conv_no_by_year(year):
    if year >= 2013:
        return year-2010
    else:
        return -1

candidates_conv_4_11 = pd.read_csv('ssmm_candidates_info_conv_4_11.csv', sep='\t', encoding='utf-8')
candidates_conv_4_11['convocation_no'] = candidates_conv_4_11['link_year_no'].apply(lambda x: conv_no_by_year(x))
candidates_conv_4_11 = candidates_conv_4_11.merge(ssmm_announcements_conv_4_11[['link','link_date','link_time']], left_on='link',right_on='link',how='left')
candidates_conv_4_11 = candidates_conv_4_11[['name','convocation_no','year_stream_no','year_no','stream_no','academic_group_no','program_txt','link_date','link_time','link']]

candidates_conv_4_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0               Суркова Анастасия Юрьевна               4            2.2
# 1                   Денисов Илья Олегович               4            2.2
# 2                 Тюрина Татьяна Игоревна               4            2.2
# 3               Дорман Елена Вячеславовна               4            2.3
# 4              Оськин Александр Андреевич               4            2.3
# ..                                    ...             ...            ...
# 385              Терехов Михаил Сергеевич              11            6.1
# 386       Поликарпов Александр Валерьевич              11            6.3
# 387            Каляев Тимур Джанбулатович              11             m1
# 388  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 389       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          2          2              209.0
# 1          2          2              207.0
# 2          2          2              209.0
# 3          2          3              226.0
# 4          2          3              225.0
# ..       ...        ...                ...
# 385        6          1              602.0
# 386        6          3              621.0
# 387        1          0                NaN
# 388        1          0                NaN
# 389        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    «Подавая заявку в прошлом году в студсовет, яв...  2014-11-13     21:39
# 1    «Вечер добрый, коллеги!\nЯ бы хотел подать зая...  2014-11-13     21:39
# 2    «Уже во второй раз избираюсь в студенческий со...  2014-11-13     21:39
# 3    «По моему мнению, за прошедший год я не плохо ...  2014-11-13     21:40
# 4    «Прежде всего здравствуйте:)\nНа протяжении по...  2014-11-13     21:40
# ..                                                 ...         ...       ...
# 385                                         За правду!  2021-10-16     10:25
# 386  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 387  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 388  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 389  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                   link
# 0    https://vk.com/wall-33327655_2202
# 1    https://vk.com/wall-33327655_2202
# 2    https://vk.com/wall-33327655_2202
# 3    https://vk.com/wall-33327655_2203
# 4    https://vk.com/wall-33327655_2203
# ..                                 ...
# 385  https://vk.com/wall-33327655_9978
# 386  https://vk.com/wall-33327655_9982
# 387  https://vk.com/wall-33327655_9983
# 388  https://vk.com/wall-33327655_9983
# 389  https://vk.com/wall-33327655_9983
#
# [390 rows x 10 columns]

# %%
# ssmm_announcements_conv_1_3 = pd.read_csv('ssmm_announcement_info_conv_1_3.csv', sep='\t', encoding='utf-8')
# ssmm_announcements_conv_1_3.head()

# %%
list_of_df = [candidates_conv_1_3,candidates_conv_4_11]
candidates_conv_1_11 = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
candidates_conv_1_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0                            Левин Андрей               1            1.1
# 1           Матвеев Дмитрий Александрович               1            1.1
# 2                  Власов Артем Андреевич               1            1.2
# 3                        Кириллова Полина               1            1.2
# 4                           Семенов Павел               1            1.2
# ..                                    ...             ...            ...
# 516              Терехов Михаил Сергеевич              11            6.1
# 517       Поликарпов Александр Валерьевич              11            6.3
# 518            Каляев Тимур Джанбулатович              11             m1
# 519  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 520       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          1          1              101.0
# 1          1          1              101.0
# 2          1          2              107.0
# 3          1          2              112.0
# 4          1          2              112.0
# ..       ...        ...                ...
# 516        6          1              602.0
# 517        6          3              621.0
# 518        1          0                NaN
# 519        1          0                NaN
# 520        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 516                                         За правду!  2021-10-16     10:25
# 517  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 518  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 519  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 520  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                        link
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 516       https://vk.com/wall-33327655_9978
# 517       https://vk.com/wall-33327655_9982
# 518       https://vk.com/wall-33327655_9983
# 519       https://vk.com/wall-33327655_9983
# 520       https://vk.com/wall-33327655_9983
#
# [521 rows x 10 columns]

# %%
def key_by_2_fields(f1, f2):
    return str(f1)+'_'+'_'.join(str(f2).split())

# %%
candidates_conv_1_11['conv_x_name'] = candidates_conv_1_11.apply(lambda x: key_by_2_fields(x['convocation_no'],x['name']), axis=1)
candidates_conv_1_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0                            Левин Андрей               1            1.1
# 1           Матвеев Дмитрий Александрович               1            1.1
# 2                  Власов Артем Андреевич               1            1.2
# 3                        Кириллова Полина               1            1.2
# 4                           Семенов Павел               1            1.2
# ..                                    ...             ...            ...
# 516              Терехов Михаил Сергеевич              11            6.1
# 517       Поликарпов Александр Валерьевич              11            6.3
# 518            Каляев Тимур Джанбулатович              11             m1
# 519  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 520       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          1          1              101.0
# 1          1          1              101.0
# 2          1          2              107.0
# 3          1          2              112.0
# 4          1          2              112.0
# ..       ...        ...                ...
# 516        6          1              602.0
# 517        6          3              621.0
# 518        1          0                NaN
# 519        1          0                NaN
# 520        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 516                                         За правду!  2021-10-16     10:25
# 517  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 518  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 519  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 520  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                        link  \
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 516       https://vk.com/wall-33327655_9978
# 517       https://vk.com/wall-33327655_9982
# 518       https://vk.com/wall-33327655_9983
# 519       https://vk.com/wall-33327655_9983
# 520       https://vk.com/wall-33327655_9983
#
#                                  conv_x_name
# 0                             1_Левин_Андрей
# 1            1_Матвеев_Дмитрий_Александрович
# 2                   1_Власов_Артем_Андреевич
# 3                         1_Кириллова_Полина
# 4                            1_Семенов_Павел
# ..                                       ...
# 516              11_Терехов_Михаил_Сергеевич
# 517       11_Поликарпов_Александр_Валерьевич
# 518            11_Каляев_Тимур_Джанбулатович
# 519  11_Маммагаджиев_Руслан_Гаджимагомедович
# 520       11_Третьякова_Екатерина_Алексеевна
#
# [521 rows x 11 columns]

# %%
candidates_conv_1_11.to_csv('ssmm_candidates_info_conv_1_11.csv', sep='\t', encoding='utf-8', index=False)

# ПЕРВАЯ ГЛАВНАЯ ТАБЛИЦА

# %% [markdown]
# # 2. To fix VOTES tables

# %%
ssmm_votes_conv_1 = pd.read_csv('ssmm_votes_info_conv_1.csv', sep='\t', encoding='utf-8')
ssmm_votes_conv_2 = pd.read_csv('ssmm_votes_info_conv_2.csv', sep='\t', encoding='utf-8')
ssmm_votes_conv_3 = pd.read_csv('ssmm_votes_info_conv_3.csv', sep='\t', encoding='utf-8')
ssmm_votes_conv_4_11 = pd.read_csv('ssmm_votes_info_conv_4_11.csv', sep='\t', encoding='utf-8')

# %%
ssmm_votes_conv_4_11.head()
# Out:
#                link_year_no_x_name                        name  link_year_no  \
# 0   2014_Суркова_Анастасия_Юрьевна   Суркова Анастасия Юрьевна          2014
# 1       2014_Денисов_Илья_Олегович       Денисов Илья Олегович          2014
# 2     2014_Тюрина_Татьяна_Игоревна     Тюрина Татьяна Игоревна          2014
# 3   2014_Дорман_Елена_Вячеславовна   Дорман Елена Вячеславовна          2014
# 4  2014_Оськин_Александр_Андреевич  Оськин Александр Андреевич          2014
#
#   year_stream_no  year_no  stream_no  votes_cnt  elected_flg  \
# 0            2.2        2          2         53            1
# 1            2.2        2          2         61            1
# 2            2.2        2          2         48            1
# 3            2.3        2          3         71            1
# 4            2.3        2          3         45            1
#
#                                 link  convocation_no
# 0  https://vk.com/wall-33327655_2215               4
# 1  https://vk.com/wall-33327655_2215               4
# 2  https://vk.com/wall-33327655_2215               4
# 3  https://vk.com/wall-33327655_2216               4
# 4  https://vk.com/wall-33327655_2216               4

# %%
ssmm_results_conv_4_11 = pd.read_csv('ssmm_results_info_conv_4_11.csv', sep='\t', encoding='utf-8')
ssmm_results_conv_4_11.head()
# Out:
#                                 link year_x_year_stream   link_date  \
# 0  https://vk.com/wall-33327655_2250           2014_1.1  2014-11-21
# 1  https://vk.com/wall-33327655_2252           2014_1.2  2014-11-21
# 2  https://vk.com/wall-33327655_2254           2014_1.3  2014-11-21
# 3  https://vk.com/wall-33327655_2329           2014_2.1  2014-11-27
# 4  https://vk.com/wall-33327655_2215           2014_2.2  2014-11-17
#
#    link_year_no  link_month_no  link_day_no link_time year_stream_no  year_no  \
# 0          2014             11           21     22:15            1.1        1
# 1          2014             11           21     22:25            1.2        1
# 2          2014             11           21     22:35            1.3        1
# 3          2014             11           27     23:15            2.1        2
# 4          2014             11           17     21:06            2.2        2
#
#    stream_no  stream_size  voted_cnt  invalid_cnt  NOTA_cnt  \
# 0          1          166        129           10         5
# 1          2          136         95            4         6
# 2          3          138         83            1         2
# 3          1          135         89            1         1
# 4          2          135         87            0         7
#
#                                       organizers
# 0     ['Ильёй Денисовым', 'Анастасией Сурковой']
# 1  ['Ираклием Глунчадзе', 'Анастасией Сурковой']
# 2  ['Ираклием Глунчадзе', 'Анастасией Савченко']
# 3  ['Ираклием Глунчадзе', 'Анастасией Сурковой']
# 4                         ['Глунчадзе Ираклием']

# %%
ssmm_votes_conv_1.head()

temp_df = ssmm_votes_conv_1

temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg','link_date','link_time','link']] # , 'link'
temp_votes_conv_1 = temp_df

temp_votes_conv_1.head()
# Out:
#    convocation_no                           name  year_stream_no  votes_cnt  \
# 0               1  Матвеев Дмитрий Александрович             1.1         49
# 1               1                   Левин Андрей             1.1         48
# 2               1               Кириллова Полина             1.2         40
# 3               1         Власов Артем Андреевич             1.2         36
# 4               1                Кузнецова Алёна             1.2         28
#
#    elected_flg   link_date link_time                                    link
# 0          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4          1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953

# %%
def full_name_by_short_name1(short_name):
#     ЗАВИСИТ ОТ ВНЕШНЕЙ ТАБЛИЦЫ candidates_conv_1_11
    names_conv3 = list(candidates_conv_1_11['name'][candidates_conv_1_11['convocation_no']==1])
    for full_name in names_conv3:
        if short_name in full_name:
            return full_name

temp_df = temp_votes_conv_1
temp_df['full_name'] = temp_df['name'].apply(lambda x: full_name_by_short_name1(x))
temp_df['max_name'] = temp_df['full_name'].combine_first(temp_df['name'])
temp_df = temp_df.drop(['full_name','name'],axis=1).rename(columns={'max_name':'name'})
# temp_df[:20]

temp_votes_conv_1_upd = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg','link_date','link_time','link']] # , 'link'
temp_votes_conv_1_upd
# Out:
# /var/folders/zh/mnvg84rj3_7413ycjzpn5y8r0000gp/T/ipykernel_44908/3982715174.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['full_name'] = temp_df['name'].apply(lambda x: full_name_by_short_name1(x))
# /var/folders/zh/mnvg84rj3_7413ycjzpn5y8r0000gp/T/ipykernel_44908/3982715174.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['max_name'] = temp_df['full_name'].combine_first(temp_df['name'])
#     convocation_no                           name  year_stream_no  votes_cnt  \
# 0                1  Матвеев Дмитрий Александрович             1.1         49
# 1                1                   Левин Андрей             1.1         48
# 2                1               Кириллова Полина             1.2         40
# 3                1         Власов Артем Андреевич             1.2         36
# 4                1                Кузнецова Алёна             1.2         28
# 5                1                  Семенов Павел             1.2         20
# 6                1       Тишин Павел Владимирович             1.3         51
# 7                1          Сафина Диана Ураловна             1.3         44
# 8                1      Медведева Яна Григорьевна             1.3         23
# 9                1                 Кунденко Вадим             1.3         21
# 10               1              Скобенникова Юлия             1.3         17
# 11               1    Шариков Алексей Анатольевич             2.1         58
# 12               1     Матвеев Алексей Викторович             2.1         54
# 13               1       Гильманов Роман Павлович             2.1         26
# 14               1      Валиев Зураб Владимирович             2.1         23
# 15               1  Костицын Александр Алексеевич             2.2         23
# 16               1       Осин Руслан Владимирович             2.2         22
# 17               1      Асташов Дмитрий Сергеевич             2.2         20
# 18               1         Глухова Алёна Олеговна             2.3         39
# 19               1    Харлашин Владимир Сергеевич             2.3         35
# 20               1        Аканаев Тимур Рашитович             2.3         32
# 21               1  Оджаев Рахмет Курбандурдыевич             2.3         18
# 22               1         Попов Леонид Андреевич             3.1         43
# 23               1  Владыкина Вероника Евгеньевна             3.1         38
# 24               1  Коновалов Антон Александрович             3.2         45
# 25               1               Малхасян Арамаис             3.2         27
# 26               1    Тропин Александр Михайлович             3.2         20
# 27               1   Ласкин Алексей Александрович             3.3         26
# 28               1    Сапунов Кирилл Вячеславович             3.3         16
# 29               1  Самонов Алексей Александрович             3.3         16
# 30               1        Цылин Иван Вячеславович             4.1         49
# 31               1  Абдуллаева Эмилия Табриз кызы             4.1         41
# 32               1  Артамонова Мария Владимировна             4.1         35
# 33               1             Ульмаскулов Рамиль             4.1         19
# 34               1        Савелов Максим Павлович             4.2         42
# 35               1       Удимов Даниил Алексеевич             4.2         31
# 36               1   Котляров Никита Владимирович             4.2         24
# 37               1        Чернодед Антон Игоревич             4.3         29
# 38               1         Громов Иван Михайлович             4.3         31
# 39               1        Федорова Елена Игоревна             4.4         20
#
#     elected_flg   link_date link_time                                    link
# 0           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 5           0.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 6           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 7           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 8           1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 9           0.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 10          0.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 11          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 12          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 13          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 14          0.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 15          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 16          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 17          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 18          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 19          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 20          1.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 21          0.0  2012-02-28     22:34  https://vk.com/topic-33327655_26089854
# 22          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 23          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 24          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 25          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 26          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 27          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 28          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 29          1.0  2012-03-07      2:03  https://vk.com/topic-33327655_26089737
# 30          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 31          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 32          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 33          0.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 34          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 35          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 36          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 37          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 38          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874
# 39          1.0  2012-03-07     18:55  https://vk.com/topic-33327655_26089874

# %%
ssmm_votes_conv_2.head()

temp_df = ssmm_votes_conv_2

temp_df['votes_cnt'] = temp_df.apply(lambda x: None)
temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]
temp_votes_conv_2 = temp_df

temp_votes_conv_2.head()
# Out:
#    convocation_no                             name year_stream_no votes_cnt  \
# 0               2  Остроухова Наталья Владимировна            1.1       NaN
# 1               2      Габидов Александр Сергеевич            1.1       NaN
# 2               2           Дяченко Мария Игоревна            1.1       NaN
# 3               2     Ватутин Кирилл Александрович            1.3       NaN
# 4               2        Никифоров Сергей Игоревич            1.3       NaN
#
#    elected_flg   link_date link_time                              link
# 0            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 1            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 2            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 3            1  2012-11-19     16:13  https://vk.com/wall-33327655_725
# 4            1  2012-11-19     16:13  https://vk.com/wall-33327655_725

# %%
# ssmm_votes_conv_3.head()

temp_df = ssmm_votes_conv_3

temp_df['votes_cnt'] = temp_df.apply(lambda x: None)
temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]
temp_votes_conv_3 = temp_df

temp_votes_conv_3.head()
# Out:
#    convocation_no       name year_stream_no votes_cnt  elected_flg  \
# 0               3  Алекберов            1.1       NaN            1
# 1               3     Бурнус            1.1       NaN            1
# 2               3    Денисов            1.2       NaN            1
# 3               3    Суркова            1.2       NaN            1
# 4               3     Тюрина            1.2       NaN            1
#
#     link_date link_time                               link
# 0  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 1  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 2  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 3  2013-12-10      1:46  https://vk.com/wall-33327655_1600
# 4  2013-12-10      1:46  https://vk.com/wall-33327655_1600

# %%
def full_name_by_short_name3(short_name):
#     ЗАВИСИТ ОТ ВНЕШНЕЙ ТАБЛИЦЫ candidates_conv_1_11
    names_conv3 = list(candidates_conv_1_11['name'][candidates_conv_1_11['convocation_no']==3])
    for full_name in names_conv3:
        if short_name in full_name:
            return full_name

temp_votes_conv_3_upd = temp_votes_conv_3
temp_votes_conv_3_upd['full_name'] = temp_votes_conv_3_upd['name'].apply(lambda x: full_name_by_short_name3(x))
temp_votes_conv_3_upd['max_name'] = temp_votes_conv_3_upd['full_name'].combine_first(temp_votes_conv_3_upd['name'])
temp_votes_conv_3_upd = temp_votes_conv_3_upd[['convocation_no', 'max_name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']].rename(columns={'max_name':'name'})
temp_votes_conv_3_upd
# Out:
# /var/folders/zh/mnvg84rj3_7413ycjzpn5y8r0000gp/T/ipykernel_44908/3196974900.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_votes_conv_3_upd['full_name'] = temp_votes_conv_3_upd['name'].apply(lambda x: full_name_by_short_name3(x))
#     convocation_no                                  name year_stream_no  \
# 0                3                             Алекберов            1.1
# 1                3             Бурнус Артём Владимирович            1.1
# 2                3                 Денисов Илья Олегович            1.2
# 3                3             Суркова Анастасия Юрьевна            1.2
# 4                3               Тюрина Татьяна Игоревна            1.2
# 5                3  Ариас-Альварес Владимир Владимирович            1.3
# 6                3              Григорьев Иван Сергеевич            1.3
# 7                3             Дорман Елена Вячеславовна            1.3
# 8                3                Дяченко Мария Игоревна            2.1
# 9                3            Локтионов Фёдор Михайлович            2.1
# 10               3       Остроухова Наталья Владимировна            2.1
# 11               3         Глунчадзе Ираклий Вахтангович            2.2
# 12               3          Ватутин Кирилл Александрович            2.3
# 13               3           Савченко Анастасия Игоревна            2.3
# 14               3          Андреев Максим Александрович            3.1
# 15               3         Матвеев Дмитрий Александрович            3.1
# 16               3         Борисов Василий Александрович            3.2
# 17               3               Бунеев Артём Валерьевич            3.2
# 18               3          Хамматова Гульназ Марселевна            3.2
# 19               3        Быстрицкая Василина Васильевна            3.3
# 20               3             Медведева Яна Григорьевна            3.3
# 21               3            Хасанов Рафаэль Ильгизович            3.4
# 22               3          Куркотов Вадим Александрович            4.1
# 23               3         Матвеев Дмитрий Александрович            4.1
# 24               3              Осин Руслан Владимирович            4.1
# 25               3           Антонов Сергей Валентинович            4.2
# 26               3          Митькина Мария Александровна            4.2
# 27               3            Ольшевская Полина Игоревна            4.3
# 28               3            Садрисламов Алмаз Уралович            4.3
# 29               3       Селиверстова Елизавета Павловна            4.3
# 30               3           Шариков Алексей Анатольевич            4.4
# 31               3                Антонова Ольга Юрьевна            5.1
# 32               3         Владыкина Вероника Евгеньевна            5.1
# 33               3                Попов Леонид Андреевич            5.1
# 34               3          Сергеева Элина Александровна            5.2
# 35               3          Ласкин Алексей Александрович            5.3
# 36               3           Сапунов Кирилл Вячеславович            5.3
# 37               3         Самонов Алексей Александрович            5.3
# 38               3                    Тен Анна Бенхиевна            5.3
# 39               3                  Буряк Анна Андреевна             m1
# 40               3         Короткин Виталий Владимирович             m1
# 41               3              Морозов Сергей Сергеевич             m2
#
#    votes_cnt  elected_flg   link_date link_time  \
# 0        NaN            1  2013-12-10      1:46
# 1        NaN            1  2013-12-10      1:46
# 2        NaN            1  2013-12-10      1:46
# 3        NaN            1  2013-12-10      1:46
# 4        NaN            1  2013-12-10      1:46
# 5        NaN            1  2013-12-10      1:46
# 6        NaN            1  2013-12-10      1:46
# 7        NaN            1  2013-12-10      1:46
# 8        NaN            1  2013-12-10      1:46
# 9        NaN            1  2013-12-10      1:46
# 10       NaN            1  2013-12-10      1:46
# 11       NaN            1  2013-12-10      1:46
# 12       NaN            1  2013-12-10      1:46
# 13       NaN            1  2013-12-10      1:46
# 14       NaN            1  2013-12-10      1:46
# 15       NaN            1  2013-12-10      1:46
# 16       NaN            1  2013-12-10      1:46
# 17       NaN            1  2013-12-10      1:46
# 18       NaN            1  2013-12-10      1:46
# 19       NaN            1  2013-12-10      1:46
# 20       NaN            1  2013-12-10      1:46
# 21       NaN            1  2013-12-10      1:46
# 22       NaN            1  2013-12-10      1:46
# 23       NaN            1  2013-12-10      1:46
# 24       NaN            1  2013-12-10      1:46
# 25       NaN            1  2013-12-10      1:46
# 26       NaN            1  2013-12-10      1:46
# 27       NaN            1  2013-12-10      1:46
# 28       NaN            1  2013-12-10      1:46
# 29       NaN            1  2013-12-10      1:46
# 30       NaN            1  2013-12-10      1:46
# 31       NaN            1  2013-12-10      1:46
# 32       NaN            1  2013-12-10      1:46
# 33       NaN            1  2013-12-10      1:46
# 34       NaN            1  2013-12-10      1:46
# 35       NaN            1  2013-12-10      1:46
# 36       NaN            1  2013-12-10      1:46
# 37       NaN            1  2013-12-10      1:46
# 38       NaN            1  2013-12-10      1:46
# 39       NaN            1  2013-12-10      1:46
# 40       NaN            1  2013-12-10      1:46
# 41       NaN            1  2013-12-10      1:46
#
#                                  link
# 0   https://vk.com/wall-33327655_1600
# 1   https://vk.com/wall-33327655_1600
# 2   https://vk.com/wall-33327655_1600
# 3   https://vk.com/wall-33327655_1600
# 4   https://vk.com/wall-33327655_1600
# 5   https://vk.com/wall-33327655_1600
# 6   https://vk.com/wall-33327655_1600
# 7   https://vk.com/wall-33327655_1600
# 8   https://vk.com/wall-33327655_1600
# 9   https://vk.com/wall-33327655_1600
# 10  https://vk.com/wall-33327655_1600
# 11  https://vk.com/wall-33327655_1600
# 12  https://vk.com/wall-33327655_1600
# 13  https://vk.com/wall-33327655_1600
# 14  https://vk.com/wall-33327655_1600
# 15  https://vk.com/wall-33327655_1600
# 16  https://vk.com/wall-33327655_1600
# 17  https://vk.com/wall-33327655_1600
# 18  https://vk.com/wall-33327655_1600
# 19  https://vk.com/wall-33327655_1600
# 20  https://vk.com/wall-33327655_1600
# 21  https://vk.com/wall-33327655_1600
# 22  https://vk.com/wall-33327655_1600
# 23  https://vk.com/wall-33327655_1600
# 24  https://vk.com/wall-33327655_1600
# 25  https://vk.com/wall-33327655_1600
# 26  https://vk.com/wall-33327655_1600
# 27  https://vk.com/wall-33327655_1600
# 28  https://vk.com/wall-33327655_1600
# 29  https://vk.com/wall-33327655_1600
# 30  https://vk.com/wall-33327655_1600
# 31  https://vk.com/wall-33327655_1600
# 32  https://vk.com/wall-33327655_1600
# 33  https://vk.com/wall-33327655_1600
# 34  https://vk.com/wall-33327655_1600
# 35  https://vk.com/wall-33327655_1600
# 36  https://vk.com/wall-33327655_1600
# 37  https://vk.com/wall-33327655_1600
# 38  https://vk.com/wall-33327655_1600
# 39  https://vk.com/wall-33327655_1600
# 40  https://vk.com/wall-33327655_1600
# 41  https://vk.com/wall-33327655_1600

# %%
list_of_df = [temp_votes_conv_1_upd,temp_votes_conv_2,temp_votes_conv_3_upd]
temp_votes_conv_1_3 = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)
temp_votes_conv_1_3 = temp_votes_conv_1_3[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]

final_votes_conv_1_3 = temp_votes_conv_1_3
final_votes_conv_1_3
# Out:
#      convocation_no                           name year_stream_no votes_cnt  \
# 0                 1  Матвеев Дмитрий Александрович            1.1        49
# 1                 1                   Левин Андрей            1.1        48
# 2                 1               Кириллова Полина            1.2        40
# 3                 1         Власов Артем Андреевич            1.2        36
# 4                 1                Кузнецова Алёна            1.2        28
# ..              ...                            ...            ...       ...
# 112               3  Самонов Алексей Александрович            5.3       NaN
# 113               3             Тен Анна Бенхиевна            5.3       NaN
# 114               3           Буряк Анна Андреевна             m1       NaN
# 115               3  Короткин Виталий Владимирович             m1       NaN
# 116               3       Морозов Сергей Сергеевич             m2       NaN
#
#      elected_flg   link_date link_time                                    link
# 0            1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 1            1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 2            1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 3            1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# 4            1.0  2012-03-07     20:55  https://vk.com/topic-33327655_26089953
# ..           ...         ...       ...                                     ...
# 112          1.0  2013-12-10      1:46       https://vk.com/wall-33327655_1600
# 113          1.0  2013-12-10      1:46       https://vk.com/wall-33327655_1600
# 114          1.0  2013-12-10      1:46       https://vk.com/wall-33327655_1600
# 115          1.0  2013-12-10      1:46       https://vk.com/wall-33327655_1600
# 116          1.0  2013-12-10      1:46       https://vk.com/wall-33327655_1600
#
# [117 rows x 8 columns]

# %%
# reorder

temp_df = ssmm_votes_conv_4_11.merge(ssmm_results_conv_4_11[['link','link_date','link_time']], left_on='link', right_on='link',how='outer')
# temp_df

temp_df['convocation_no'] = temp_df['link_year_no'].apply(lambda x: conv_no_by_year(x))
temp_df = temp_df[['convocation_no', 'name', 'year_stream_no', 'votes_cnt', 'elected_flg', 'link_date', 'link_time', 'link']]
final_votes_conv_4_11 = temp_df

final_votes_conv_4_11
# Out:
#      convocation_no                                  name year_stream_no  \
# 0                 4             Суркова Анастасия Юрьевна            2.2
# 1                 4                 Денисов Илья Олегович            2.2
# 2                 4               Тюрина Татьяна Игоревна            2.2
# 3                 4             Дорман Елена Вячеславовна            2.3
# 4                 4            Оськин Александр Андреевич            2.3
# ..              ...                                   ...            ...
# 384              11  Маммагаджиев Руслан Гаджимагомедович             m1
# 385              11       Третьякова Екатерина Алексеевна             m1
# 386              11          Мазитова Вероника Рустэмовна            6.1
# 387              11              Терехов Михаил Сергеевич            6.1
# 388              11       Поликарпов Александр Валерьевич            6.3
#
#      votes_cnt  elected_flg   link_date link_time  \
# 0           53            1  2014-11-17     21:06
# 1           61            1  2014-11-17     21:06
# 2           48            1  2014-11-17     21:06
# 3           71            1  2014-11-17     21:21
# 4           45            1  2014-11-17     21:21
# ..         ...          ...         ...       ...
# 384         10            1  2021-10-20     20:21
# 385         19            1  2021-10-20     20:21
# 386         27            1  2021-10-21     15:44
# 387         16            1  2021-10-21     15:44
# 388         43            1  2021-10-21     22:02
#
#                                    link
# 0     https://vk.com/wall-33327655_2215
# 1     https://vk.com/wall-33327655_2215
# 2     https://vk.com/wall-33327655_2215
# 3     https://vk.com/wall-33327655_2216
# 4     https://vk.com/wall-33327655_2216
# ..                                  ...
# 384  https://vk.com/wall-33327655_10018
# 385  https://vk.com/wall-33327655_10018
# 386  https://vk.com/wall-33327655_10026
# 387  https://vk.com/wall-33327655_10026
# 388  https://vk.com/wall-33327655_10031
#
# [389 rows x 8 columns]

# %%
list_of_df = [final_votes_conv_1_3,final_votes_conv_4_11]
final_votes_conv_1_11 = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)

final_votes_conv_1_11['conv_x_name'] = final_votes_conv_1_11.apply(lambda x: key_by_2_fields(x['convocation_no'],x['name']), axis=1)
final_votes_conv_1_11
# Out:
#      convocation_no                                  name year_stream_no  \
# 0                 1         Матвеев Дмитрий Александрович            1.1
# 1                 1                          Левин Андрей            1.1
# 2                 1                      Кириллова Полина            1.2
# 3                 1                Власов Артем Андреевич            1.2
# 4                 1                       Кузнецова Алёна            1.2
# ..              ...                                   ...            ...
# 501              11  Маммагаджиев Руслан Гаджимагомедович             m1
# 502              11       Третьякова Екатерина Алексеевна             m1
# 503              11          Мазитова Вероника Рустэмовна            6.1
# 504              11              Терехов Михаил Сергеевич            6.1
# 505              11       Поликарпов Александр Валерьевич            6.3
#
#     votes_cnt  elected_flg   link_date link_time  \
# 0          49          1.0  2012-03-07     20:55
# 1          48          1.0  2012-03-07     20:55
# 2          40          1.0  2012-03-07     20:55
# 3          36          1.0  2012-03-07     20:55
# 4          28          1.0  2012-03-07     20:55
# ..        ...          ...         ...       ...
# 501        10          1.0  2021-10-20     20:21
# 502        19          1.0  2021-10-20     20:21
# 503        27          1.0  2021-10-21     15:44
# 504        16          1.0  2021-10-21     15:44
# 505        43          1.0  2021-10-21     22:02
#
#                                        link  \
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 501      https://vk.com/wall-33327655_10018
# 502      https://vk.com/wall-33327655_10018
# 503      https://vk.com/wall-33327655_10026
# 504      https://vk.com/wall-33327655_10026
# 505      https://vk.com/wall-33327655_10031
#
#                                  conv_x_name
# 0            1_Матвеев_Дмитрий_Александрович
# 1                             1_Левин_Андрей
# 2                         1_Кириллова_Полина
# 3                   1_Власов_Артем_Андреевич
# 4                          1_Кузнецова_Алёна
# ..                                       ...
# 501  11_Маммагаджиев_Руслан_Гаджимагомедович
# 502       11_Третьякова_Екатерина_Алексеевна
# 503          11_Мазитова_Вероника_Рустэмовна
# 504              11_Терехов_Михаил_Сергеевич
# 505       11_Поликарпов_Александр_Валерьевич
#
# [506 rows x 9 columns]

# %%
final_votes_conv_1_11.to_csv('ssmm_votes_info_conv_1_11.csv', sep='\t', encoding='utf-8', index=False)

# ВТОРАЯ ГЛАВНАЯ ТАБЛИЦА

# %% [markdown]
# # ОСНОВНЫЕ ТАБЛИЦЫ ПО КАНДИДАТАМ

# %%
ssmm_candidates_info_conv_1_11 = pd.read_csv('ssmm_candidates_info_conv_1_11.csv', sep='\t', encoding='utf-8')
ssmm_candidates_info_conv_1_11
# Out:
#                                      name  convocation_no year_stream_no  \
# 0                            Левин Андрей               1            1.1
# 1           Матвеев Дмитрий Александрович               1            1.1
# 2                  Власов Артем Андреевич               1            1.2
# 3                        Кириллова Полина               1            1.2
# 4                           Семенов Павел               1            1.2
# ..                                    ...             ...            ...
# 516              Терехов Михаил Сергеевич              11            6.1
# 517       Поликарпов Александр Валерьевич              11            6.3
# 518            Каляев Тимур Джанбулатович              11             m1
# 519  Маммагаджиев Руслан Гаджимагомедович              11             m1
# 520       Третьякова Екатерина Алексеевна              11             m1
#
#      year_no  stream_no  academic_group_no  \
# 0          1          1              101.0
# 1          1          1              101.0
# 2          1          2              107.0
# 3          1          2              112.0
# 4          1          2              112.0
# ..       ...        ...                ...
# 516        6          1              602.0
# 517        6          3              621.0
# 518        1          0                NaN
# 519        1          0                NaN
# 520        1          0                NaN
#
#                                            program_txt   link_date link_time  \
# 0    Активный участник и организатор различных меро...  2012-02-26      0:16
# 1                                                  NaN  2012-02-26      0:16
# 2                                                  NaN  2012-02-26      0:16
# 3    Мне нравится заниматься общественной деятельно...  2012-02-26      0:16
# 4    "Здравствуйте. Я так понимаю, что я уже поздно...  2012-02-26      0:16
# ..                                                 ...         ...       ...
# 516                                         За правду!  2021-10-16     10:25
# 517  Был одним из основателей бегового клуба MSU RU...  2021-10-16     10:50
# 518  Всем привет! Я только недавно на мехмате, но х...  2021-10-16     11:20
# 519  Долгое время был пикчером профкома мехмата. Се...  2021-10-16     11:20
# 520  Я как человек с немалым опытом в делах организ...  2021-10-16     11:20
#
#                                        link  \
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 516       https://vk.com/wall-33327655_9978
# 517       https://vk.com/wall-33327655_9982
# 518       https://vk.com/wall-33327655_9983
# 519       https://vk.com/wall-33327655_9983
# 520       https://vk.com/wall-33327655_9983
#
#                                  conv_x_name
# 0                             1_Левин_Андрей
# 1            1_Матвеев_Дмитрий_Александрович
# 2                   1_Власов_Артем_Андреевич
# 3                         1_Кириллова_Полина
# 4                            1_Семенов_Павел
# ..                                       ...
# 516              11_Терехов_Михаил_Сергеевич
# 517       11_Поликарпов_Александр_Валерьевич
# 518            11_Каляев_Тимур_Джанбулатович
# 519  11_Маммагаджиев_Руслан_Гаджимагомедович
# 520       11_Третьякова_Екатерина_Алексеевна
#
# [521 rows x 11 columns]

# %%
ssmm_votes_info_conv_1_11 = pd.read_csv('ssmm_votes_info_conv_1_11.csv', sep='\t', encoding='utf-8')
ssmm_votes_info_conv_1_11
# Out:
#      convocation_no                                  name year_stream_no  \
# 0                 1         Матвеев Дмитрий Александрович            1.1
# 1                 1                          Левин Андрей            1.1
# 2                 1                      Кириллова Полина            1.2
# 3                 1                Власов Артем Андреевич            1.2
# 4                 1                       Кузнецова Алёна            1.2
# ..              ...                                   ...            ...
# 501              11  Маммагаджиев Руслан Гаджимагомедович             m1
# 502              11       Третьякова Екатерина Алексеевна             m1
# 503              11          Мазитова Вероника Рустэмовна            6.1
# 504              11              Терехов Михаил Сергеевич            6.1
# 505              11       Поликарпов Александр Валерьевич            6.3
#
#      votes_cnt  elected_flg   link_date link_time  \
# 0         49.0          1.0  2012-03-07     20:55
# 1         48.0          1.0  2012-03-07     20:55
# 2         40.0          1.0  2012-03-07     20:55
# 3         36.0          1.0  2012-03-07     20:55
# 4         28.0          1.0  2012-03-07     20:55
# ..         ...          ...         ...       ...
# 501       10.0          1.0  2021-10-20     20:21
# 502       19.0          1.0  2021-10-20     20:21
# 503       27.0          1.0  2021-10-21     15:44
# 504       16.0          1.0  2021-10-21     15:44
# 505       43.0          1.0  2021-10-21     22:02
#
#                                        link  \
# 0    https://vk.com/topic-33327655_26089953
# 1    https://vk.com/topic-33327655_26089953
# 2    https://vk.com/topic-33327655_26089953
# 3    https://vk.com/topic-33327655_26089953
# 4    https://vk.com/topic-33327655_26089953
# ..                                      ...
# 501      https://vk.com/wall-33327655_10018
# 502      https://vk.com/wall-33327655_10018
# 503      https://vk.com/wall-33327655_10026
# 504      https://vk.com/wall-33327655_10026
# 505      https://vk.com/wall-33327655_10031
#
#                                  conv_x_name
# 0            1_Матвеев_Дмитрий_Александрович
# 1                             1_Левин_Андрей
# 2                         1_Кириллова_Полина
# 3                   1_Власов_Артем_Андреевич
# 4                          1_Кузнецова_Алёна
# ..                                       ...
# 501  11_Маммагаджиев_Руслан_Гаджимагомедович
# 502       11_Третьякова_Екатерина_Алексеевна
# 503          11_Мазитова_Вероника_Рустэмовна
# 504              11_Терехов_Михаил_Сергеевич
# 505       11_Поликарпов_Александр_Валерьевич
#
# [506 rows x 9 columns]

# %%
df1 = ssmm_candidates_info_conv_1_11[['conv_x_name','name']]
df2 = ssmm_votes_info_conv_1_11[['conv_x_name','name']]

df1_x_d2 = df1.merge(df2, left_on='conv_x_name', right_on='conv_x_name',how='outer')
df1_x_d2_nan = df1_x_d2[df1_x_d2.isna().any(axis=1)]
df1_x_d2_nan
# Out:
#                             conv_x_name                            name_x  \
# 39      1_Хисматуллина_Марина_Рашитовна     Хисматуллина Марина Рашитовна
# 40          1_Штейников_Юрий_Николаевич         Штейников Юрий Николаевич
# 41         1_Савушкин_Никита_Максимович        Савушкин Никита Максимович
# 42           1_Миценко_Вадим_Валериевич          Миценко Вадим Валериевич
# 43               1_Буряк_Анна_Андреевна              Буряк Анна Андреевна
# 44      1_Дубровин_Григорий_Анатольевич     Дубровин Григорий Анатольевич
# 46       2_Николаева_Наталия_Михайловна      Николаева Наталия Михайловна
# 49            2_Ванунц_Арсений_Ашотович           Ванунц Арсений Ашотович
# 56          2_Медведева_Яна_Григорьевна         Медведева Яна Григорьевна
# 60              2_Сафина_Диана_Ураловна             Сафина Диана Ураловна
# 74       2_Ласкин_Алексей_Александрович      Ласкин Алексей Александрович
# 89            3_Корно_Дмитрий_Сергеевич           Корно Дмитрий Сергеевич
# 90          3_Изимова_Анна_Мирбулатовна         Изимова Анна Мирбулатовна
# 91          3_Чистяков_Михаил_Сергеевич         Чистяков Михаил Сергеевич
# 110     3_Заболотский_Леонид_Дмитриевич     Заболотский Леонид Дмитриевич
# 111    3_Скопинцев_Алексей_Владимирович    Скопинцев Алексей Владимирович
# 114        3_Матвеев_Алексей_Викторович        Матвеев Алексей Викторович
# 263  6_Думаревский_Александр_Дмитриевич  Думаревский Александр Дмитриевич
# 397             9_Воронин_Вадим_Юрьевич             Воронин Вадим Юрьевич
# 522           1_Федорова_Елена_Игоревна                               NaN
# 523                         3_Алекберов                               NaN
# 524           4_Вергазов_Марат_Марсович                               NaN
#
#                       name_y
# 39                       NaN
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43                       NaN
# 44                       NaN
# 46                       NaN
# 49                       NaN
# 56                       NaN
# 60                       NaN
# 74                       NaN
# 89                       NaN
# 90                       NaN
# 91                       NaN
# 110                      NaN
# 111                      NaN
# 114                      NaN
# 263                      NaN
# 397                      NaN
# 522  Федорова Елена Игоревна
# 523                Алекберов
# 524  Вергазов Марат Марсович

# %%
# СОСТАВИТЬ СПИСОК ИМЕН (ИЗ КАНДИДАТОВ И (трех) РЕЗУЛЬТАТОВ)

# %%
list_of_df = [ssmm_candidates_info_conv_1_11[['name']],ssmm_votes_info_conv_1_11[['name']]]
ssmm_full_candidates_df = pd.concat(list_of_df).reset_index().drop(['index'], axis=1)

ssmm_candidates_core = ssmm_full_candidates_df.drop_duplicates().reset_index().drop(['index'], axis=1)
ssmm_candidates_core

# Алекберов Ибрагим Рустамович
# Out:
#                                      name
# 0                            Левин Андрей
# 1           Матвеев Дмитрий Александрович
# 2                  Власов Артем Андреевич
# 3                        Кириллова Полина
# 4                           Семенов Павел
# ..                                    ...
# 315            Каляев Тимур Джанбулатович
# 316  Маммагаджиев Руслан Гаджимагомедович
# 317       Третьякова Екатерина Алексеевна
# 318                             Алекберов
# 319               Вергазов Марат Марсович
#
# [320 rows x 1 columns]

# %%
ssmm_candidates_core.to_csv('ssmm_candidates_core.csv', sep='\t', encoding='utf-8', index=False)

# %%
# А ТЕПЕРЬ УПОРЯДОЧИТЬ ПО ПУБЛИКАЦИИ - протянуть дату и время (и ссылки на посты в тредах) для всех таблиц
# и можно нанизывать флаги
# - сколько раз подавался
# - сколько раз избирался
# - первый созыв
# - последний созыв

# %%
# конвертнуть date_time в формат времени, если такое есть
# найти минимальную дату-время для каждого name в каждой из двух главных таблице, 
# потом найти минимум из обоих, 
# потом добавить поле min_date_time в core

# ssmm_candidates_info_conv_1_11
# ssmm_votes_info_conv_1_11

# %% [markdown]
# # ПРОВЕРКИ

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

string1 = "abc"
string2 = "aef"

print(levenshtein(string1, string2))
# Out:
# 2

# %%
names = list(candidates_conv_1_11_upd['name']) + list(temp_votes_conv_1_3['name']) + list(final_votes_conv_4_11['name'])

from collections import Counter

names_stat = Counter(names) #.most_common()
# names_stat

# names_uniq = list(set(names))
# names_uniq

# %%
# выявляем похожие имена, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a, b) <= 4 and names_stat[a] >= names_stat[b]:
            print(levenshtein(a, b), ' - ', a, names_stat[a], ' : ', names_stat[b], b)

# %%
# выявляем имена без отчества, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if len(a) > len(b) and levenshtein(a[:len(b)], b) <= 4:
            print(a, names_stat[a], ' : ', names_stat[b], b)
# Out:
# Семенюк Павел Игоревич 4  :  2 Семенов Павел
# Белан Андрей Владимирович 2  :  2 Левин Андрей

# %%
# выявляем имена с перепутанными отчествами, чтобы потом заменить РУКАМИ

for a in names_stat.keys():
    for b in names_stat.keys():
        if a != b and levenshtein(a[:12], b[:12]) <= 2 and names_stat[a] >= names_stat[b]:
            print(a, names_stat[a], ' : ', names_stat[b], b)

# Сакаев Роберт Марселевич 5  :  1 Сакаев Роберт Викторович
# Out:
# Коновалов Антон Александрович 2  :  1 Коновалов Дмитрий Игоревич
# Семенюк Павел Игоревич 2  :  1 Семенов Павел
# Порфирьева Наталия Алексеевна 1  :  1 Перфильева Нелли Андреевна
# Федотов Константин Алексеевич 1  :  1 Фёдоров Константин Дмитриевич
# Алиев Рамиль Камиль Оглы 1  :  1 Алеев Дамиль Павлович
# Перфильева Нелли Андреевна 1  :  1 Порфирьева Наталия Алексеевна
# Фёдоров Константин Дмитриевич 1  :  1 Федотов Константин Алексеевич
# Третьяков Пётр Максимович 3  :  2 Третьяков Артём Алексеевич
# Саметов Максим Алексеевич 2  :  1 Савелов Максим Павлович
# Лобанова Алёна Валерьевна 3  :  1 Лобанова Анастасия Алексеевна
# Алеев Дамиль Павлович 1  :  1 Алиев Рамиль Камиль Оглы
