# %%
#     В ЭТОМ КОДЕ:

# вытащим отчеты о собраниях 1-2-3-4 созывов из обсуждений группы

# %%
# https://vk.com/topic-33327655_25816532

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
import re
from datetime import datetime, date, time

# %%
# выкачать список ссылок на треды со страницы с тредами, чтобы потом по ним качать треды

# %%
# https://vk.com/board33327655

# req_announcement = requests.get('https://vk.com/board33327655')
# html_doc = req_announcement.text
# print(html_doc)

# только верхние 20 тем

# %%
# req_announcement = requests.get('https://vk.com/board33327655?offset=20') # так можно листать по 20 тем, норм
# html_doc = req_announcement.text
# print(html_doc)

# %%
# список ссылок на треды и число сообщений в них

# про каждый тред:
# <div class="topic_item">
#   <a class="ti_title" href="/topic-33327655_30624962" rel="noopener">[2014, осень], Повышенные стипендии</a>
#   <div class="ti_count"><b>7</b> сообщений</div>
#   <a class="ti_info" href="/topic-33327655_30624962?offset=last#last" rel="noopener">Алексей Матвеев ответил 7 окт 2014</a>
# </div>

def vk_threads_list_by_link(link_vk):
    req_link = requests.get(link_vk)
    html_doc = req_link.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    
    topics = soup.find_all('div', attrs={'class': 'topic_item'})
    
    thread_dict = {}
    
    for element in topics:
        title = element.find('a', attrs={'class': 'ti_title'})
        thread_link = title['href']
        text_title = [line for line in title.stripped_strings]
        thread_title = text_title[0]
        
        count = element.find('div', attrs={'class': 'ti_count'})
        text_count = [line for line in count.stripped_strings]
        thread_message_count = int(text_count[0])
        
        info = element.find('a', attrs={'class': 'ti_info'})
        text_info = [line for line in info.stripped_strings]
        thread_last_info = text_info[0]
        
#         print(thread_link, thread_title, thread_message_count, thread_last_info)
        
        thread_dict[thread_link] = {
            'thread_link': 'https://vk.com' + thread_link,
            'thread_title': thread_title,
            'thread_message_count': thread_message_count,
            'thread_last_info': thread_last_info
                             }
    
    return thread_dict

# %%
# 1. количество тем
# <meta name="description" content="Обсуждения сообщества Студенческий совет мехмата МГУ — 144 темы." />

vk_group_id = '33327655'
thread_link = 'https://vk.com/board' + vk_group_id

req_link = requests.get(thread_link)
html_doc = req_link.text
soup = BeautifulSoup(html_doc, 'html.parser')
meta = soup.find('meta', attrs={'name': 'description'})
# print(meta)
# print(meta['content'])
threads_cnt = int(re.findall(r' — ([\d]+) тем', meta['content'])[-1])
# print(threads_cnt)


# 2. список всех обсуждений (блоками по 20)

thread_dict = {}

for sheet in range(threads_cnt//20 + 1):
    thread_dict = {**thread_dict, **vk_threads_list_by_link(thread_link + '?offset=' + str(sheet*20))}

print(thread_dict)
# vk_threads_list_by_link('https://vk.com/board33327655?offset=20')
# Out:
# {'/topic-33327655_47378210': {'thread_link': 'https://vk.com/topic-33327655_47378210', 'thread_title': 'Протоколы собраний', 'thread_message_count': 6, 'thread_last_info': 'Администратор ответил 30 дек в 14:44'}, '/topic-33327655_48164294': {'thread_link': 'https://vk.com/topic-33327655_48164294', 'thread_title': 'Расписание', 'thread_message_count': 5, 'thread_last_info': 'Администратор ответил 19 дек в 21:57'}, '/topic-33327655_26170
ирилл Сапунов ответил 27\xa0апр\xa02015'}, '/topic-33327655_31781905': {'thread_link': 'https://vk.com/topic-33327655_31781905', 'thread_title': 'Собрания комитета по КзКО Студовета МГУ', 'thread_message_count': 4, 'thread_last_info': 'Алексей Ламтюгин ответил 8\xa0апр\xa02015'}, '/topic-33327655_31531846': {'thread_link': 'https://vk.com/topic-33327655_31531846', 'thread_title': '[2015, весна], Повышенные стипендии', 'thread_message_count': 5, 'thread_last_info': 'Ираклий Глунчадзе ответил 19\xa0мар\xa02015'}, '/topic-33327655_26563678': {'t ...

# %%
# req_announcement = requests.get('https://vk.com/topic-33327655_47378210')
# html_doc = req_announcement.text
# print(html_doc)

# %%
# структура блока с прикреплениями файлов к посту в треде:

<div class="pi_body">
    <div class="pi_text">Протоколы XI созыва.</div>
    <div class="pi_medias">
        <div class="medias_row attachment_type_doc">
            <a class="mr_label medias_link" href="/doc121940016_623506345?hash=afd3d6f83d8a7965c1&dl=b90467708edfdaeabb" rel="noopener" target="_blank">
                <span class="medias_link_icon">
                    <i class="i_icon i_doc"></i>
                </span>
                <span class="medias_link_texts">
                    <span class="medias_link_label">Файл</span>
                    <span class="medias_link_labeled medias_link_title"> Протокол первого собрания Студсовета мехмата от 30.10.2021.pdf</span>
                    <span class="medias_link_desc">Файл PDF, 3.2 МБ</span>
                </span>
            </a>
        </div>

        <div class="medias_row attachment_type_doc">
            <a class="mr_label medias_link" href="/doc121940016_623506344?hash=569eaa7ddc53007e0a&dl=0396fbdf0ba492d36b" rel="noopener" target="_blank">
                <span class="medias_link_icon">
                    <i class="i_icon i_doc"></i>
                </span>
                <span class="medias_link_texts">
                    <span class="medias_link_label">Файл</span>
                    <span class="medias_link_labeled medias_link_title"> Протокол второго собрания Студсовета мехмата от 25.11.2021.pdf</span>
                    <span class="medias_link_desc">Файл PDF, 1.6 МБ</span>
                </span>
            </a>
        </div>

    </div>
</div>

# %%
# attr = 'a'
# class_name = 'item_date'

def vk_thread_date(pi_info, attr, class_name):
    months = ['янв', 'фев', 'мар', 'апр', 'мая', 'июн', 'июл', 'авг', 'сен', 'окт', 'ноя', 'дек']
    if pi_info:
        wi_date = pi_info.find(attr, attrs={'class': class_name})
        date_list = [date for date in wi_date.stripped_strings]
        link_year_no = int(re.findall(r'[\d]{4}', date_list[0])[0])
        link_month_no = months.index(re.findall(r'[\w]{3}', date_list[0])[0]) + 1
        link_day_no = int((re.findall(r'[\d]+\s', date_list[0])[0]).strip())
        link_date = date(link_year_no, link_month_no, link_day_no)
        link_date_time = date_list[0]
        link_time = re.findall(r'[\d]+\:[\d]+', date_list[0])[0]
    else:
        link_year_no = 0
        link_month_no = 0
        link_day_no = 0
        link_date = date(1970, 1, 1)
        link_date_time = ''
        link_time = ''
        
    return link_year_no, link_month_no, link_day_no, link_date, link_date_time, link_time

# %%
# СЛОВАРИК ИНФОРМАЦИИ ИЗ ОБСУЖДЕНИЯ (считывает по 20 постов)

#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/am_tropin" rel="noopener">Александр Тропин</a> </div>
#         </div>
#         <div class="pi_body">
#                 <div class="pi_text">На собрании присутствовало 9 представителей студсовета. Модерировал собрание Никита Котл

# <div class="pi_info"><a class="item_date" href="/topic-33327655_25816532?post=104#post104" rel="noopener">10 янв 2012 в 21:49</a></div>
    
def vk_thread_info_by_link(link_vk):
    req_link = requests.get(link_vk)
    html_doc = req_link.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    
    # ВЫТАСКИВАЮ БЛОК С ТЕКСТОМ ПОСТА ПОСТРОЧНО    
    # <div class="pi_body">
    #     <div class="pi_text">
    
    pi_body = soup.find_all('div', attrs={'class': 'pi_cont'})
#     print(pi_body)
    
    dict_el = {}
    
    for el in pi_body:
        text = el.find('div', attrs={'class': 'pi_text'})
#         print(text)
        if text:
            text_lines = [line for line in text.stripped_strings]
        else:
            text_lines = []
#         date = pi_info.find('a', attrs={'class': 'item_date'})
        link_year_no, link_month_no, link_day_no, link_date, link_date_time, link_time = vk_thread_date(el, 'a', 'item_date')
    
        author = el.find('a', attrs={'class': 'pi_author'})
        author_line = [line for line in author.stripped_strings]
        
        dict_el[pi_body.index(el)] = {
#             'post_no': pi_body.index(el),
            'link_date': link_date, 
            'link_year_no': link_year_no, 
            'link_month_no': link_month_no, 
            'link_day_no': link_day_no, 
            'link_date_time': link_date_time, 
            'link_time': link_time,
            'author': author_line[0],
            'list_of_lines': text_lines
                             }

    dict_link = {}
    dict_link[link_vk] = {
        'list_of_posts': dict_el
                         }
    
    return dict_link

# %%
# print(vk_thread_info_by_link('https://vk.com/topic-33327655_26170925'))
print(vk_thread_info_by_link('https://vk.com/topic-33327655_47378210'))
# Out:
# {'https://vk.com/topic-33327655_47378210': {'list_of_posts': {0: {'link_date': datetime.date(2021, 3, 10), 'link_year_no': 2021, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2021 в 11:08', 'link_time': '11:08', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Здесь находятся протоколы собраний Студенческого совета мехмата, начиная с X созыва.']}, 1: {'link_date': datetime.date(2021, 3, 10), 'link_year_no': 2021, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2021 в 11:09', 'link_time': '11:09', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 2: {'link_date': datetime.date(2021, 3, 29), 'link_year_no': 2021, 'link_month_no': 3, 'link_day_no': 29, 'link_date_time': '29 мар 2021 в 23:21', 'link_time': '23:21', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 3: {'link_date': datetime.date(2021, 9, 4), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 4, 'link_date_time': '4 сен 2021 в 15:43', 'link_time': '15:43', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 4: {'link_date': datetime.date(2021, 9, 23), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 23, 'link_date_time': '23 сен 2021 в 11:37', 'link_time': '11:37', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 5: {'link_date': datetime.date(2021, 12, 30), 'link_year_no': 2021, 'link_month_no': 12, 'link_day_no': 30, 'link_date_time': '30 дек 2021 в 14:44', 'link_time': '14:44', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Протоколы XI созыва.']}}}}

# %%
for link in thread_dict:
    print(thread_dict[link]['thread_title'])
    for sheet in range(thread_dict[link]['thread_message_count']//20 + 1):
        print(thread_dict[link]['thread_link'] + '?offset=' + str(sheet*20))
        print(vk_thread_info_by_link(thread_dict[link]['thread_link'] + '?offset=' + str(sheet*20)))
        
# ОШИБКА: В ЭТОМ ТРЕДЕ НЕТ БЛОКОВ С ТЕКСТОМ
# Out:
# Протоколы собраний
# https://vk.com/topic-33327655_47378210?offset=0
# {'https://vk.com/topic-33327655_47378210?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2021, 3, 10), 'link_year_no': 2021, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2021 в 11:08', 'link_time': '11:08', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Здесь находятся протоколы собраний Студенческого совета мехмата, начиная с X созыва.']}, 1: {'link_date': datetime.date(2021, 3, 10), 'link_year_no': 2021, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2021 в 11:09', 'link_time': '11:09', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 2: {'link_date': datetime.date(2021, 3, 29), 'link_year_no': 2021, 'link_month_no': 3, 'link_day_no': 29, 'link_date_time': '29 мар 2021 в 23:21', 'link_time': '23:21', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 3: {'link_date': datetime.date(2021, 9, 4), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 4, 'link_date_time': '4 сен 2021 в 15:43', 'link_time': '15:43', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 4: {'link_date': datetime.date(2021, 9, 23), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 23, 'link_date_time': '23 сен 2021 в 11:37', 'link_time': '11:37', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 5: {'link_date': datetime.date(2021, 12, 30), 'link_year_no': 2021, 'link_month_no': 12, 'link_day_no': 30, 'link_date_time': '30 дек 2021 в 14:44', 'link_time': '14:44', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Протоколы XI созыва.']}}}}
# Расписание
# https://vk.com/topic-33327655_48164294?offset=0
# {'https://vk.com/topic-33327655_48164294?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2021, 9, 3), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2021 в 13:07', 'link_time': '13:07', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['В этой теме будет публиковаться актуальное расписание занятий, пересдач и др.']}, 1: {'link_date': datetime.date(2021, 9, 3), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2021 в 13:10', 'link_time': '13:10', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 2: {'link_date': datetime.date(2021, 9, 8), 'link_year_no': 2021, 'link_month_no': 9, 'link_day_no': 8, 'link_date_time': '8 сен 2021 в 15:53', 'link_time': '15:53', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': []}, 3: {'link_date': datetime.date(2021, 10, 5), 'link_year_no': 2021, 'link_month_no': 10, 'link_day_no': 5, 'link_date_time': '5 окт 2021 в 19:53', 'link_time': '19:53', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Расписание комиссии по студенческим делам:', '6 курс, 2 курс магистратуры: 6 октября 17:00, ауд. 15-03.', '4 курс: 7 октября 15:00, ауд. 15-02.', '2 курс: 13 октября, ауд. 12-12.', '15:00 – группы 201-206;', '16:00 – группы 207-212;', '17:00 –группы 221-226, кроме 222.', '3 курс: 14 октября, ауд.15-02.', 'По группам прошлого года.', '15:00 – группы 201-206;', '16:30 – группы 207-212;', '18:00 – группы 221-226.', '5 курс: 22 октября 15:00, ауд. 12-12.', '222 группа: 8 ноября 16:00, дистанционно.']}, 4: {'link_date': datetime.date(2021, 12, 19), 'link_year_no': 2021, 'link_month_no': 12, 'link_day_no': 19, 'link_date_time': '19 дек 2021 в 21:57', 'link_time': '21:57', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Расписание зачётной сессии:', 'https://math.msu.ru/schedule_of_tests_and_exams']}}}}
# "БЫТОВЫЕ ВОПРОСЫ" - рабочая группа
# https://vk.com/topic-33327655_26170925?offset=0
# {'https://vk.com/topic-33327655_26170925?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2012, 3, 10), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2012 в 21:15', 'link_time': '21:15', 'author': 'Антон Чернодед', 'list_of_lines': ['Предназначена для технического функционирования рабочей группы, проведения голосований и обсуждения текущих вопросов.']}, 1: {'link_date': datetime.date(2012, 3, 10), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2012 в 21:15', 'link_time': '21:15', 'author': 'Антон Чернодед', 'list_of_lines': ['Участники рабочей группы:', 'Митькина Мария, 412 (координатор)', 'Буряк Анна, М1', 'Денисов Илья, 107', 'Осин Руслан, 402', 'Хасанов Рафаэль, 331', 'Тема была подчищена, теперь она более компактная, и рекомендуется ее прочесть, чтобы быть в курсе основных проблем и задач в прошлые годы.', 'Но нужно начинать составлять список целей и задач на предстоящий год, так что давайте отписываться у кого какие идеи. Не забываем о новом направлении - экологии!']}, 2: {'link_date': datetime.date(2012, 3, 10), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2012 в 21:21', 'link_time': '21:21', 'author': 'Александр Тропин', 'list_of_lines': ['и сюда подписываюсь.', 'пока это самая малочисленная группа, так что присоединяйтесь активнее.', 'об особенностях работы в этой рабгруппе. скорее всего нас по большинству вопросов администрация будет отпинывать к ОСК либо к факультетскому студкому, который представляет некто Тощаков Алексей. возможно, имеет смысл ликвидировать студкомовскую ячейку на мехмате, раз про неё ничего не слышно, связаться с ней проблематично, а за своё ничегонеделание они ещё и в асперках в ГЗ живут.']}, 3: {'link_date': datetime.date(2012, 3, 10), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 10, 'link_date_time': '10 мар 2012 в 22:20', 'link_time': '22:20', 'author': 'Александр Тропин', 'list_of_lines': ['21 апреля состоится отчётно-выборная конференция ОСК, в связи с чем на факультетах должны пройти открытые собрания, на которых факультетские студкомы выдвигают делегата на эту конференцию. предлагаю проследить за тем, чтобы на мехмате это собрание действительно проводилось, и исключительно силами студкома (если он такой сильный). если собрания не будет, то нам стоит заявить о том, что делегат выбран нелегитимно, и поставить вопрос о необходимости существования студкома вообще.']}, 4: {'link_date': datetime.date(2012, 3, 11), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 11, 'link_date_time': '11 мар 2012 в 0:23', 'link_time': '0:23', 'author': 'Александр Костицын', 'list_of_lines': ['переход А-Б здесь будет?']}, 5: {'link_date': datetime.date(2012, 3, 11), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 11, 'link_date_time': '11 мар 2012 в 0:27', 'link_time': '0:27', 'author': 'Александр Тропин', 'list_of_lines': ['а где же ещё']}, 6: {'link_date': datetime.date(2012, 3, 14), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 14, 'link_date_time': '14 мар 2012 в 21:54', 'link_time': '21:54', 'author': 'Артем Власов', 'list_of_lines': ['такой вопрос. на собрании говорили про постановление для фдсов, в котором говориться , что можно использовать электроприборы? А то сегодня ходила комендантша и  почти что отбирала чайники.']}, 7: {'link_date': datetime.date(2012, 3, 14), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 14, 'link_date_time': '14 мар 2012 в 22:00', 'link_time': '22:00', 'author': 'Александр Тропин', 'list_of_lines': ['если я не ошибаюсь, то некоторое разъяснение вопросов с электроприборами можно найти на стене вот этой группы:', 'http://vk.com/fdsmsu']}, 8: {'link_date': datetime.date(2012, 3, 14), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 14, 'link_date_time': '14 мар 2012 в 22:14', 'link_time': '22:14', 'author': 'Артем Власов', 'list_of_lines': ['спасибо. но то что там написано не является оф. доку ...
# https://vk.com/topic-33327655_26170925?offset=20
# {'https://vk.com/topic-33327655_26170925?offset=20': {'list_of_posts': {0: {'link_date': datetime.date(2012, 3, 21), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 21, 'link_date_time': '21 мар 2012 в 11:43', 'link_time': '11:43', 'author': 'Александр Тропин', 'list_of_lines': ['у встреч рабгрупп сейчас есть один общий недостаток - всем удобно собираться по вторникам в одно и то же время)', 'предлагаю составлять текст обращения к ректору по открытию перехода. я узнаю подробности, как действовала ИГ зимой 2010-го, когда открыли. то есть, если что, предупредить ректора, что будут сотни подписей мехматян, если одного письма от студсовета будет недостаточно.']}, 1: {'link_date': datetime.date(2012, 3, 30), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 30, 'link_date_time': '30 мар 2012 в 1:10', 'link_time': '1:10', 'author': 'Александр Тропин', 'list_of_lines': ['кстати, в продолжение темы.', 'в архивах форумлокала наткнулся сегодня на забавный пост: стенограмма встречи ректора с мехматом в феврале 2007 года. цитирую следующий кусок:', 'Q: Почему переход на 13 этаже открывают всего на несколько часов в день.', 'Водолазский: Он открыт с 8 до 11, захватывает даже начало второй пары. Вообще общага — это одно, учебный корпус — совсем другое. Не должно быть свобоного прохода туда-сюда. Далее, у каждого сектора (Б, В) 8 выходов. Вам вот удобно на фак-т, физикам во внутренний дворик (ближе к физфаку). Кому еще куда. Что же, все 8 открыть?', 'Из зала: Я не понял, ну откроете вы все 8 и что? Все умрут?', 'Водолазский: Все зайдут!', 'Садовничий: вот вы все говорите дай-дай-дай. А за счет чего? Это же надо оборудовать посты, поставить круглосуточную серьезную охрану.', 'Так что пробивание перехода будет очень сложным. Отпишитесь здесь, кто хочет в команде заниматься этой проблемой (Никита, я и Александр, как я понимаю, в команде).']}, 2: {'link_date': datetime.date(2012, 3, 30), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 30, 'link_date_time': '30 мар 2012 в 1:14', 'link_time': '1:14', 'author': 'Александр Тропин', 'list_of_lines': ['вот ссылка, кого заинтересовало. речь и ответы на вопросы. надо знать историю проблем, потому что они, как и ответы на вопросы, остались прежними.', 'http://www.forumbgz.ru/ashowthreaded.php?Cat=&Boa..']}, 3: {'link_date': datetime.date(2012, 4, 1), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 1, 'link_date_time': '1 апр 2012 в 21:39', 'link_time': '21:39', 'author': 'Вероника Владыкина', 'list_of_lines': ['Промежуточный отчет по проблеме тренажерки фдс-3:', 'Ответственный за тренажерку Колосков Александр сказал, что собирать деньги с проживающих в 3м фдсе не имеют право. все они могут посещать тренажерку бесплатно. если вдруг кто-то станет требовать деньги можно прямо ссылаться на Колоскова, он разрешил. Просил довести это до сведения всех студентов.', 'Деньги же по всей видимости незаконно собирал бывший ответственный. С чем мы в данный момент и разбираемся.']}, 4: {'link_date': datetime.date(2012, 4, 4), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 4, 'link_date_time': '4 апр 2012 в 14:07', 'link_time': '14:07', 'author': 'Никита Котляров', 'list_of_lines': ['Ура, наконец-то я поговорил с Колпаковым. Итак, по поводу туалетов: на 14-ом этаже ремонт запланирован на лето, на 15-ом ремонт пока не планируется. Насчет крючков для сумок: перегородки в туалетах тонкие, поэтому не понятно, как их можно закрепить вообще.', 'По поводу мела: на всех этаж мел такой же, как и раньше был. На 16-ом некоторое время был отстойный мел, неделю назад его заменили на нормальный.', 'По поводу перегоревших лампочек, холодных аудиторий, штор, шпингалетов и прочей мелочи: пишите в эту тему проблемы с указанием аудитории, через неделю отнесу Колпакову список.']}, 5: {'link_date': datetime.date(2012, 4, 4), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 4, 'link_date_time': '4 апр 2012 в 14:44', 'link_time': '14:44', 'author': 'Павел Тишин', 'list_of_lines': ['Шторы, ла ...
# https://vk.com/topic-33327655_26170925?offset=40
# {'https://vk.com/topic-33327655_26170925?offset=40': {'list_of_posts': {0: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 0:02', 'link_time': '0:02', 'author': 'Кирилл Сапунов', 'list_of_lines': ['Allen', ', а зачем? вот ни для кого не секрет, что со стороны холла 12 этажа с розетками (кстати их тоже было бы неплохо увеличить, как и покрытие сети интернет) курят на лестнице, сквозняк задувает это в холл и никак не способствует учебе и работе.', 'Я считаю, что курение вообще стоит запретить на территории сектора А. Но это лично мое мнение.']}, 1: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 0:03', 'link_time': '0:03', 'author': 'Вероника Владыкина', 'list_of_lines': ['Кирилл', ', Да ты что. Молодцов курит. нам этого не дадут=)']}, 2: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 0:03', 'link_time': '0:03', 'author': 'Allen Campbell', 'list_of_lines': ['Кирилл', ', отличный вариант - на 13 этаже, там где переходы между секторами - открыть их для курильщиков, на лестнице где-нибудь там можно.', 'Про wi-fi +1']}, 3: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 0:07', 'link_time': '0:07', 'author': 'Вероника Владыкина', 'list_of_lines': ['ох. нужно сказать, чтобы разобрались со специально отведенными местами. а где, пусть Колпаков решает.']}, 4: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 0:08', 'link_time': '0:08', 'author': 'Кирилл Сапунов', 'list_of_lines': ['Allen', ', ну про лестницы Б и В я знаю. И лестницы там устроены по другому, как и система вентиляции. Давайте выбьем полнодневной проход в сектор Б на 13-ом этаже, и курите сколько влезет в секторе Б прямо на лестницы сразу после охранников.']}, 5: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 7:31', 'link_time': '7:31', 'author': 'Allen Campbell', 'list_of_lines': ['Кирилл', ', отлично, по-моему.']}, 6: {'link_date': datetime.date(2012, 4, 8), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 8, 'link_date_time': '8 апр 2012 в 8:37', 'link_time': '8:37', 'author': 'Дмитрий Степчков', 'list_of_lines': ['В тамбуре ауд. 1208 перегорели обе лампы, когда приемной комиссии нужен сейф, стоящий в коридоре, работать с ним невозможно, т.к. ничего не видно.']}, 7: {'link_date': datetime.date(2012, 4, 13), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 13, 'link_date_time': '13 апр 2012 в 22:49', 'link_time': '22:49', 'author': 'DELETED', 'list_of_lines': ['Достали доски, на которых невозможно писать, потому что все отсвечивает. Как минимум в 14-08  и 16-08, но подозреваю, что повсеместно. Я понимаю, что менять доски дорого, но вообще-то их достаточно покрасить нормальной краской. По поводу мела уже написали, а вот тряпки везде такие, что нормальному человеку их в руки брать противно.', 'В идеале - во всех лекционных аудиториях иметь нормальный экран и встроенный проектор. При необходимости показать что-то на слайдах сделать это в одиночку почти нереально, а таскать одной комп-проектор-экран-провода... Извините, это издевательство над здравым смыслом.']}, 8: {'link_date': datetime.date(2012, 4, 17), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 17, 'link_date_time': '17 апр 2012 в 18:44', 'link_time': '18:44', 'author': 'Никита Котляров', 'list_of_lines': ['Сегодня я обсудил некоторые вопросы с зам.деканом Колпаковым:', '1) Аудитория 01 - она не мехматовская, поэтому надо обращаться в службу эксплуатации МГУ', '2) 12-08, перегоревшие лампочки - электрикам сказали, они сейчас разбираются', '3) Забитые в подоконники гвозди - это сделано, чтобы ...
# https://vk.com/topic-33327655_26170925?offset=60
# {'https://vk.com/topic-33327655_26170925?offset=60': {'list_of_posts': {0: {'link_date': datetime.date(2013, 12, 15), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 15, 'link_date_time': '15 дек 2013 в 22:58', 'link_time': '22:58', 'author': 'Рафаэль Хасанов', 'list_of_lines': ['Наладить работу лифтов)']}, 1: {'link_date': datetime.date(2013, 12, 15), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 15, 'link_date_time': '15 дек 2013 в 23:00', 'link_time': '23:00', 'author': 'Маша Митькина', 'list_of_lines': ['Помещение для музыкальных репетиций']}, 2: {'link_date': datetime.date(2013, 12, 15), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 15, 'link_date_time': '15 дек 2013 в 23:21', 'link_time': '23:21', 'author': 'Вероника Владыкина', 'list_of_lines': ['Маша', ', в корпусе А? не дадут. в корбусе Б - не проблема, но это к Виталику.', 'предлагаю еще проблему - разобраться с окнами в холодных аудиториях. и разобраться с забиванием окон, ибо летом сдохнуть можно в 1224']}, 3: {'link_date': datetime.date(2013, 12, 16), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 16, 'link_date_time': '16 дек 2013 в 1:49', 'link_time': '1:49', 'author': 'Руслан Осин', 'list_of_lines': ['Маша', ', Смотря для каких и кто репетирует) лучше обговорить с теми, кому это нужно)']}, 4: {'link_date': datetime.date(2013, 12, 16), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 16, 'link_date_time': '16 дек 2013 в 9:11', 'link_time': '9:11', 'author': 'Алексей Ласкин', 'list_of_lines': ['а ЦС по регби, точнее  мехматяне в ее составе, могут рассчитывать на помощь? например покрыть затраты на дорогу и проживание при выездах']}, 5: {'link_date': datetime.date(2013, 12, 16), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 16, 'link_date_time': '16 дек 2013 в 20:56', 'link_time': '20:56', 'author': 'Маша Митькина', 'list_of_lines': ['Алексей', ', а это точно для рабочей группы "Бытовые вопросы"? Мы можем наверно покрыть ваши затраты на мыло и туалетку, а в остальном лучше в группу спорта']}, 6: {'link_date': datetime.date(2013, 12, 16), 'link_year_no': 2013, 'link_month_no': 12, 'link_day_no': 16, 'link_date_time': '16 дек 2013 в 20:56', 'link_time': '20:56', 'author': 'Маша Митькина', 'list_of_lines': ['Рафаэль', ', они вроде пока все работают или отключаются планово']}, 7: {'link_date': datetime.date(2014, 1, 22), 'link_year_no': 2014, 'link_month_no': 1, 'link_day_no': 22, 'link_date_time': '22 янв 2014 в 16:52', 'link_time': '16:52', 'author': 'Илья Денисов', 'list_of_lines': ['Предлагаю ещё одно дело, с актуальностью которого, думаю, многие согласятся-туалетная бумага  и мыло в туалетах вмк на этажах мехмата.']}, 8: {'link_date': datetime.date(2014, 3, 2), 'link_year_no': 2014, 'link_month_no': 3, 'link_day_no': 2, 'link_date_time': '2 мар 2014 в 0:56', 'link_time': '0:56', 'author': 'Сергей Морозов', 'list_of_lines': ['У меня идея фикс - изменить правила посещения и, возможно, расписание читального зала на этажах мехмата в ГЗ, плюс по возможности привести его в порядок. Видели же его? Он же суперкрутой! Я бы ботал в 2 раза больше, если бы ботал там. Да и просто он может стать приятным тихим местом для времяпрепровождения. Только туда совершенно неудобно ходить из-за бредовых правил и того, что он довольно рано закрывается.']}, 9: {'link_date': datetime.date(2014, 3, 2), 'link_year_no': 2014, 'link_month_no': 3, 'link_day_no': 2, 'link_date_time': '2 мар 2014 в 11:25', 'link_time': '11:25', 'author': 'Алексей Матвеев', 'list_of_lines': ['Сергѣй', ', а какие там правила? там вот лампочек не хватает. и время бы сделали как в сессию.']}, 10: {'link_date': datetime.date(2014, 3, 2), 'link_year_no': 2014, 'link_month_no': 3, 'link_day_no': 2, 'link_date_time': '2 мар 2014 в 14:07', 'link_time': '14:07', 'author': 'Сергей Морозов', 'list_of_lines': ['Алексей', ', там нужен читательский билет, нельзя со своими книгами, все книги надо брать заново там, вещи надо сдавать в камеру хранения, расположенну ...
# https://vk.com/topic-33327655_26170925?offset=80
# {'https://vk.com/topic-33327655_26170925?offset=80': {'list_of_posts': {0: {'link_date': datetime.date(2014, 3, 11), 'link_year_no': 2014, 'link_month_no': 3, 'link_day_no': 11, 'link_date_time': '11 мар 2014 в 21:35', 'link_time': '21:35', 'author': 'Шоди Салиев', 'list_of_lines': ['Товарищи!', 'Я уже два раза обращался по данному вопросу в электронную приемную, однако оба раза получал не более чем  отписки в качестве ответа.', 'Так вот.', 'Хотелось бы решить как-нибудь проблему освещения в читальном зале на 14-м этаже. Это отличное место, где можно было бы в тишине и спокойной обстановке заниматься.', 'Однако это делать довольно непросто ввиду недостаточного освещения. Например, там не работает НИ ОДНА из имеющихся настольных ламп.', 'Вот что мне ответили в электронной приемной:', 'Здравствуйте. Некоторое время назад я задавал вопрос про читальный зал на мехмате, на 14-м этаже.', 'Думаю, что мне стоит поставить вопрос более конкретно: 1) Когда будет решена проблема с освещением в читальном зале? 2) Когда будут починены настольные лампы? 3) Когда появятся розетки и адекватный wifi? 4) Можно ли сделать так, чтобы разрешался вход со своими учебниками? Если администрация опасается хищения фондов, то можно, например, записывать у дежурного книги, с которыми входит посетитель, а на выходе сверять список с выносимыми книгами. Совершенно не может быть никаких сомнений, что от этого всем будет только лучше. Сейчас читальным залом почти никто не пользуется. Думаю, что с решением указанных выше проблем ситуация изменится. Уверен, что очень многие студенты будут благодарны. Спасибо.', 'На ваш вопрос отвечает Директор научной библиотеки МГУ, Вячеслав Викторович Мосягин:', 'Уважаемый Shodi!', 'Вход в читальный зал с литературой, которой нет в фондах Научной библиотеки, разрешен. Соответствующая запись об этом делается в контрольном листке читателя.', 'Полагаем, что письмо должно быть  также направлено главному инженеру МГУ для ответа на вопрос об освещении и декану механико-математического факультета для ответа на вопрос о функционировании Wi-Fi.', 'Директор Научной библиотеки МГУ                                           В.В.Мосягин', 'Разве это не прямая обязанность администрации?!', 'Прошу СтудСовет заняться этим вопросом.', 'Уверен, что это крайне будет крайне полезным для большого числа студентов.', 'Спасибо.']}, 1: {'link_date': datetime.date(2014, 4, 1), 'link_year_no': 2014, 'link_month_no': 4, 'link_day_no': 1, 'link_date_time': '1 апр 2014 в 6:00', 'link_time': '6:00', 'author': 'Маша Митькина', 'list_of_lines': ['Повестка прошедшего 29.03 собрания рабочей группы:', 'Бытовые вопросы:', '-туалетная бумага и мыло', '-решение проблем в читальном зале на 14 этаже', '-организация буккроссинга на этажах мехмата', 'Вопросы общеуниверситетского уровня:', '-возможность установки кулера в трехзальном корпусе', '-возможность заселения москвичей в общежития за доп. плату', 'Проблемы общежития:', '-организация боталки', 'Вопросы экологии/прочее', '-установка контейнера для сбора тетрапака на мехмате', '-организация сбора одежды для последующей передачи нуждающимся', '-организация приема батареек на постоянной основе', '-организация дня донора на мехмате (все-таки предлагаю отказаться от этой идеи)']}, 2: {'link_date': datetime.date(2015, 11, 2), 'link_year_no': 2015, 'link_month_no': 11, 'link_day_no': 2, 'link_date_time': '2 ноя 2015 в 22:53', 'link_time': '22:53', 'author': 'Илья Денисов', 'list_of_lines': ['Давно здесь не писали. Надо бы возобновить.', 'Прошло собрание рабочей группы в пн, 02.11', '1. Лифты в ГЗ', 'Решено было сделать список того, что мы хотим изменить. Далее этот список я передам начальнику СВТ, когда тот выйдет с отпуска.', 'Давайте неделю засечем и будем сюда кидать все то, что хотим/нам не нравится в лифтах', 'Желательно поконкретнее писать (номера лифтов приветствуются)', '2. Условия проживания в ФДСе-6', 'Поскольку ему стоять еще больше, чем его собратьям, то стоит заняться улучшением условий проживания.', 'Поднимал ...
# [2017, Осень], повышенные стипендии
# https://vk.com/topic-33327655_35904375?offset=0
# {'https://vk.com/topic-33327655_35904375?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2017, 9, 3), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2017 в 14:39', 'link_time': '14:39', 'author': 'Илья Денисов', 'list_of_lines': ['Публикуем список подавших заявки']}, 1: {'link_date': datetime.date(2017, 9, 3), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2017 в 16:12', 'link_time': '16:12', 'author': 'Илья Денисов', 'list_of_lines': ['5 курс', 'Алексеенко', 'Артемова', 'Арчакова(Ипатова?)', 'Березнюк(7а)', 'Брсоян', 'Быховский', 'Газизова', 'Грицких', 'Девятко(также на 7а)', 'Думанский', 'Евланичев', 'Ерёмина', 'Ермохин', 'Заславский', 'Зорина (также на 7а)', 'Ильичева', 'Кабанова', 'Кадышев', 'Кеда', 'Коновец', 'Конохова', 'Краснов', 'Кузнецова', 'Куценко(7а)', 'Лимонова(7а)', 'Мищенко', 'Минаев', 'Морозов', 'Никитин (также по 7а)', 'Оганесян', 'Орлов', 'Осипова', 'Полещук', 'Провидухина', 'Прохорчик', 'Семенюк', 'Серов', 'Стасенко(также по 7а)', 'Талгарбаев', 'Татаринцева', 'Тагирова', 'Торлопов', 'Тюрина', 'Уланов', 'Фадеева', 'Федченко', 'Шайхеева(также на 7а)', 'Шишунов']}, 2: {'link_date': datetime.date(2017, 9, 3), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2017 в 16:17', 'link_time': '16:17', 'author': 'Илья Денисов', 'list_of_lines': ['2 курс', 'Антонов', 'Гулюкина(также на 7а)', 'Егорова (также на 7а)', 'Коновалов', 'Кошелев', 'Мартьянов(7а)', 'Михеев', 'Савенков', 'Страхов(7а)', 'Тароян', 'Чуфаровский', 'Мосси-Гарба', 'Ежикова', 'Мазитова', 'Новикова(7а)', 'Курбанов(7а)', 'Подпружников', 'Шелонина(7а)', 'Янковский']}, 3: {'link_date': datetime.date(2017, 9, 3), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2017 в 20:18', 'link_time': '20:18', 'author': 'Илья Денисов', 'list_of_lines': ['4 курс', 'Аверьянова', 'Акшонов', 'Гареев(также на 7а)', 'Годенко', 'Давудова', 'Джунусов', 'Зайцева(также на 7а)', 'Зененкова', 'Иванюшкин', 'Муравьева', 'Нигметзянова', 'Похачевский', 'Прудников(7а)', 'Рембовская', 'Сивкин(7а)', 'Соколов', 'Улюмджиев(также на 7а)', 'Харчева', 'Каширин', 'Костяшин', 'Струментов', 'Фёдоров(7а)', 'Чернова']}, 4: {'link_date': datetime.date(2017, 9, 3), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 3, 'link_date_time': '3 сен 2017 в 20:29', 'link_time': '20:29', 'author': 'Илья Денисов', 'list_of_lines': ['6 курс', 'Астрелина', 'Ахмеджанова', 'Болелов', 'Горячкин', 'Глунчадзе', 'Кибкало', 'Савин(также на 7а)', 'Назмутдинов', 'Максаев(также не 7а)', 'Дуков', 'Димитров', 'Дыкусар(также на 7а)', 'Ефанов', 'Запрягаев(7а)', 'Земцова', 'Климов', 'Коробко', 'Лебедева(также на 7а)', 'Орлова', 'Порошина', 'Потапова', 'Рухович(7а)', 'Саая', 'Савченко', 'Сагдеев', 'Саулин', 'Степанова(7а)', 'Тихонова (также на 7а)', 'Баранова (также на 7а)', 'Дяченко', 'Дмитриева', 'Земцова (7а)', 'Карпенко', 'Лахтанов', 'Медведь', 'Подкользина', 'Подопросветов', 'Родькин', 'Харламова (также на 7а)', 'Фельдман', 'Тильга(также на 7а)']}, 5: {'link_date': datetime.date(2017, 9, 4), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 4, 'link_date_time': '4 сен 2017 в 17:58', 'link_time': '17:58', 'author': 'Илья Денисов', 'list_of_lines': ['3 курс', 'Апарин', 'Валиуллин (7а)', 'Воробьева', 'Гарбуз', 'Дворкин(также на 7а)', 'Забродина', 'Зайцева(также на 7а)', 'Ипатов(также на 7а)', 'Киракосян(также на 7а)', 'Козлова', 'Комокина', 'Корольков', 'Косарев', 'Костромин', 'Красовицкий', 'Кудрявцев', 'Николаев (7а)', 'Нуждов', 'Федоров', 'Шишков']}, 6: {'link_date': datetime.date(2017, 9, 8), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 8, 'link_date_time': '8 сен 2017 в 12:17', 'link_time': '12:17', 'author': 'Алексей Кремер', 'list_of_lines': ['Магистратура 2 курс', 'Бадгаева (также на 7а)']}, 7: {'link_date': datetime.date(2017, 9, 10), 'link_year_no': 2017, 'link_month_no': 9, 'link_day_no': 10, 'link_date_time': '10 сен 2017 в 13:42', 'l ...
 'link_year_no': 2016, 'link_month_no': 6, 'link_day_no': 28, 'link_date_time': '28 июн 2016 в 14:01', 'link_time': '14:01', 'author': 'Артур Вердян', 'list_of_lines': ['Вердян Артур Генриевич, 3 курс, 113 б, ФДС - 6.']}, 9: {'link_date': datetime.date(2016, 7, 5), 'link_year_no': 2016, 'link_month_no': 7, 'link_day_no': 5, 'link_date_time': '5 июл 2016 в 13:00', 'link_time': '13:00', 'author': 'Георгий Борисенко', 'list_of_lines': ['Борисенко Георгий Николаевич, перешел на 3 курс, фдс-6, 541']}}}}
# Обмен комнатами ГЗ-НО.
# https://vk.com/topic-33327655_34017388?offset=0
# {'https://vk.com/topic-33327655_34017388?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2016, 6, 25), 'link_year_no': 2016, 'link_month_no': 6, 'link_day_no': 25, 'link_date_time': '25 июн 2016 в 22:54', 'link_time': '22:54', 'author': 'Студенческий совет мехмата МГУ', 'list_of_lines': ['Для желающих жить вместо ГЗ в НО, и наоборот, есть возможность решить этот вопрос в личном порядке. Для этого вам необходимо найти людей (обмен возможен только двое на двое), готовых поменяться с вами комнатой, и совместно написать заявление на отказ и обмен. С заявлениями нужно подойти в отдел расселения на мехмате (801 каб. ГЗ).', 'Эта тема создана для поиска людей, с которыми вы  сможете обменяться. Пишите свои ФИО, курс, общежитие и номер комнаты. Если вы уже нашли человека для обмена, не поленитесь удалить свою заявку.', 'Хотим уточнить, что могут возникнуть сложности с обменом аспирантской комнаты в ГЗ на место в двушке или трешке в НО. А также, что вам могут отказать в обмене.']}}}}
# Встреча с В.Т. Трофимовым и Г.В. Иващенко по поводу правил прохода в общежития после 23:00, 26.05.2014
# https://vk.com/topic-33327655_30241332?offset=0
# ...
# Новое собрание и темы для повестки
# https://vk.com/topic-33327655_25720003?offset=0
# {'https://vk.com/topic-33327655_25720003?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2011, 12, 22), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 22, 'link_date_time': '22 дек 2011 в 11:30', 'link_time': '11:30', 'author': 'Александр Костицын', 'list_of_lines': ['Сегодня было принято разумное решение отложить общее собрание до начала весеннего семестра. Как стало известно, выбранные сейчас представители должны стать своего рода "Учредительным Собранием", то есть самостоятельно придумать зачем они собрались и что им делать дальше. Первые пункты банальны, что-то вроде:', '* Разработка правил и проведение по ним честных выборов', '* Нужно понять что и как мы можем сделать на факультете', '* Взаимодействие со студсоветами других факультетов и создание общеуниверситетского органа', '* Наше СМИ', 'итд, дополняем. По срокам предлагаю провести собрание на второй учебной неделе февраля (13-18 числа).']}, 1: {'link_date': datetime.date(2011, 12, 22), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 22, 'link_date_time': '22 дек 2011 в 12:12', 'link_time': '12:12', 'author': 'Алексей Богомолов', 'list_of_lines': ['Полностью поддерживаю данное начинание, так как сессия может стать серьезной помехой.', 'Разработка правил и проведение выборов - самое доступное из всего, что мы пока можем сделать. Но пункт про СМИ не менее важен. Не только группы в этом злосчастном контакте. Не газеты - их никто не читает толком. Иное. Иначе на эти выборы никто не пойдет, сужу по своей группе, например. Мы должны донести, в т.ч. устно, тот факт, что мы можем что-то сделать и студенты в целом могут тоже,  кто мы есть, что, собственно, нужно делать, как они сами могут повлиять на происходящее. Не многие думают, что мы будем решать какие-то проблемы, в основном мысли о том, что мы существуем "для галочки". Как профком, который при всех льготах привлекает небольшое число народу. Устное разъяснение.']}, 2: {'link_date': datetime.date(2011, 12, 22), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 22, 'link_date_time': '22 дек 2011 в 17:53', 'link_time': '17:53', 'author': 'Дмитрий Асташов', 'list_of_lines': ['Насчет газет - не согласен. Если сделать газету интересной, а не серой и унылой, то ее будут брать и читать, и возможно это может стать основным источником информации для студентов. К тому же если у организации будет своя газета, которая будет просвещать всех о нашей деятельности, то к студсовету уже будет отношение выше, чем как к организации "для галочки"']}, 3: {'link_date': datetime.date(2011, 12, 22), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 22, 'link_date_time': '22 дек 2011 в 20:21', 'link_time': '20:21', 'author': 'Александр Костицын', 'list_of_lines': ['Дмитрий', ', да, газета это довольно круто (на физфаке есть своя газета например и довольно много людей её читают, она в довольно стебном стиле пишется, "пипл хавает"), но и довольно сложно. Как технически, так и идейно.']}, 4: {'link_date': datetime.date(2011, 12, 22), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 22, 'link_date_time': '22 дек 2011 в 21:24', 'link_time': '21:24', 'author': 'Никита Котляров', 'list_of_lines': ['Кстати, у нас есть стенд на 13-ом этаже, но он 2-хлетней давности)']}, 5: {'link_date': datetime.date(2012, 1, 10), 'link_year_no': 2012, 'link_month_no': 1, 'link_day_no': 10, 'link_date_time': '10 янв 2012 в 22:12', 'link_time': '22:12', 'author': 'Кирилл Сапунов', 'list_of_lines': ['Кстати, можно в МГУшной газете сделать отдельную колонку для всего студсовета МГУ. Её читают многие МГУшники.']}, 6: {'link_date': datetime.date(2012, 1, 10), 'link_year_no': 2012, 'link_month_no': 1, 'link_day_no': 10, 'link_date_time': '10 янв 2012 в 22:25', 'link_time': '22:25', 'author': 'Александр Тропин', 'list_of_lines': ['Кирилл', ', мгушные газеты неплохо цензурируемые. Не все действия нашего студсовета могут согласиться там печатать.']}, 7: {'link_date': datetime.date(2012, 1, 10), 'link_year_no': 2012, 'link_m ...
# Протокол 2 собрания студсовета мехмата, 10.01.2012
# https://vk.com/topic-33327655_25816532?offset=0
# {'https://vk.com/topic-33327655_25816532?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2012, 1, 10), 'link_year_no': 2012, 'link_month_no': 1, 'link_day_no': 10, 'link_date_time': '10 янв 2012 в 21:49', 'link_time': '21:49', 'author': 'Александр Тропин', 'list_of_lines': ['На собрании присутствовало 9 представителей студсовета. Модерировал собрание Никита Котляров, выбранный председателем на экстренном собрании в декабре. Собрание длилось около 3 часов, модерирование было затруднено в связи с большим желанием участников обсудить следующие пункты повестки:', '1) формат собрания.', 'Обсудили, как будут проходить наши собрания в будущем. Модератор объявляет повестку собрания, далее по пунктам участники высказываются в порядке очереди по поднятой руке. На собраниях могут присутствовать все желающие (не только студсоветовцы, но и остальные студенты), а преподаватели и представители администрации - либо по приглашению студсоветовцев, либо при отсутствии возражений у присутствующих на собрании студсоветовцев.', '2) Устав.', 'а) выборы.', 'Уже в феврале-марте нужно организовать перевыборы ССовета мехмата. Единогласно были приняты следующие пункты:', '- перевыборы проходят ежегодно, в феврале-марте (первокурсники успеют познакомиться, сдать первую сессию).', '- выборы проводятся на каждом курсе, кроме последнего (пока это 5-й, через несколько лет станет 6-й).', '- выборы проходят по потокам в целях равномерного представительства студентов в ССовете.', '- от каждого потока выбираются 3 человека, кроме экономпотока - от них 1.', '- кандидатуры выдвигаются заранее, возможно, с кратким описанием себя или своей программы. Выборы проходят открыто, в аудитории после какой-то лекции (к примеру). Студенты подписываются под выбранным ими кандидатом, указывая ФИО и номер группы. За представителей потоков могут голосовать только студенты из этого потока.', 'В феврале ССовет объявит о начале сбора заявок в кандидаты, проведем с ними собрание, чтобы рассказать о ССовете, в марте - сами выборы. За выборы на каждом потоке будет ответственным один человек из состава нынешнего ССовета с одним условием - он не проводит выборы на том потоке, на котором учится сам.', 'б) устав, он же - "цели и задачи"', 'Некоторое время назад в этой группе был выложен проект устава, который следует доработать. Создали рабочую группу по уставу в составе 7 человек (из числа присутствовавших сегодня), они собираются отдельно, после чего выложат свой проект на обсуждение студентов (в этой группе), и с учетом всех замечаний устав будет принят на следующем собрании ССовета.', 'в) структура ССовета.', 'Одобрили создание т.н. "рабочих групп" ССовета, которые будут заниматься конкретными проблемами (пример - рабочая группа по правилам прохода в общежитие, рабочая группа по организации мероприятий). В рабочую группу обязательно входит хотя бы один представитель ССовета, который является ответственным за рабочую группу, а также все желающие студенты, аспиранты, сотрудники факультета. ССовет пишет документ о том, что рабочая группа будет действовать от его имени. ССовет может распустить рабочую группу по своему желанию.', 'Прежний студсовет, который занимался организацией мероприятий на мехмате ранее, решено пригласить для участия в рабочей группе по организации мероприятий (она будет создана ближе к самим мероприятиям).', 'г) Председателем был во второй раз выбран Никита Котляров (из 8 человек присутствовавших на тот момент: 6 - за, 1 - против, сам он не голосовал). Новые выборы председателя будут проведены после перевыборов ССовета в марте. Было решено должность заместителя председателя сделать не выборной, а назначаемой председателем. Был назначен Дмитрий Асташов. Секретарем выбран я (7 голосов "за").', 'д) ССовет и политика.', 'Студсовет как орган самоуправления не должен поддерживать или не поддерживать какую-либо партию или движение, однако оставляет за собой право выражать мнение учащихся по вопросам, касающихся обучения, проживания в общежития и т.д. (пример - р ...
# О созданном студсовете мехмата
# https://vk.com/topic-33327655_25712121?offset=0
# {'https://vk.com/topic-33327655_25712121?offset=0': {'list_of_posts': {0: {'link_date': datetime.date(2011, 12, 20), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 20, 'link_date_time': '20 дек 2011 в 21:46', 'link_time': '21:46', 'author': 'Александр Тропин', 'list_of_lines': ['Как я понимаю, группа рассчитана на все курсы, поэтому опишу ситуацию по факультету.', 'На пятом курсе выборы не проводятся по причине "вы скоро уйдёте".', 'На первом курсе Семёнов справедливо счёл выборы фарсом, не стал в этом участвовать и пообещал провести нормальные выборы весной.', 'На третьем курсе во имя заботы о нашей успеваемости решили, что каждая группа подпишет согласие о представлении наших интересов старостами, и уже эти 20 старост выберут из себя 7 окончательных, после чего в апреле всё равно будут перевыборы с требуемой квотой в 50%+1.', 'Как прошло на четвертом курсе, расскажут, наверно, избранные там.', 'А на втором было решено выбрать всех 11 студентов, которые и были выдвинуты группами, включая двух третьекурсников (меня и Кирилла). Соответственно, система тоже неидеальна - пришлось назначать кандидата от каждой группы, хотя не исключен вариант, что желающих теоретически может быть больше. Или станет больше в течение года. В связи с сессией обеспечить 50%-ное присутствие не получилось.', 'Таким образом, раз уже на двух курсах из четырёх на весну обещаны открытые выборы без спешки, следует на собраниях уже созданных студсоветов поднимать перед ректоратом/деканатом/администрацией вопрос об их проведении (весной) для всех курсов. У начкурсов мехмата, по сравнению с остальными факультетами, на удивление адекватная общественная позиция, и у нас есть возможность локально создать реальное студенческое самоуправление.', 'кто что думает?)']}, 1: {'link_date': datetime.date(2011, 12, 20), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 20, 'link_date_time': '20 дек 2011 в 22:09', 'link_time': '22:09', 'author': 'Никита Котляров', 'list_of_lines': ['На 4-ом курсе целью студсовета было заявлено распределение дополнительных стипендий отличникам и победителям олимпиад. Но, скорее всего, круг наших задач и возможностей будет существенно расширен (на других факультетах студсовет избирался как орган студенческого самоуправления, ответственный за проведения различных мероприятий и решения разных вопросов с администрацией). Поэтому предлагаю узнать побольше друг о друге и о целях, которые каждый хотел бы поставить перед студсоветом.', 'Для меня основными задачами сейчас являются:', '1) Проведение честных выборов студенческого союза МГУ;', '2) Выход студсоюза МГУ из Народного фронта Путина (так как МГУ позиционирует себя вне политики);', '3) Окончательное решение вопроса о проходах в общежития ГЗ (в прошлом году усилиями ИГ и студентов было отложено ввод системы электронных пропусков на год. В марте систему хотят опять вводить, и неизвестно, получат ли МГУушники, не проживающие в ГЗ, свободный доступ в общежития ГЗ)', 'Также сегодня на собрании ИГ было озвучено, что 23-ого числа пройдет заседание Ученого Совета МГУ. Из только что выбранных студсоветов выделяют по одному человеку для участия в этом заседании (насколько мне известно, на нашем факультете еще об этом не извещали). Поэтому от нашего студсовета, скорее всего, тоже потребуется человек. Выдвигайте кандидатуры. Лично я готов пойти.', 'P.S.: на 4-ом курсе выборы прошли демократично - провели опросы по группам']}, 2: {'link_date': datetime.date(2011, 12, 21), 'link_year_no': 2011, 'link_month_no': 12, 'link_day_no': 21, 'link_date_time': '21 дек 2011 в 0:13', 'link_time': '0:13', 'author': 'Александр Костицын', 'list_of_lines': ['Никита', ', думаю, что пункты 2 и 3 вне компетенции студенческого СОВЕТА кстати. Студсоюз должен быть отодвинут в сторону, мы участвовали в выборах абсолютно НОВОЙ организации. Главное, чего нельзя допускать (и Швец об этом тоже говорил) — использования для "подпирания" студсоюза (продажной организации Андриянова) студсоветом. Ну и вообще блокировать ...

# %%
# В ЭТОМ ТРЕДЕ НЕТ БЛОКОВ С ТЕКСТОМ
req_announcement = requests.get('https://vk.com/topic-33327655_47378210')
html_doc = req_announcement.text
print(html_doc)

# МОЖНО ВЫТАЩИТЬ АДРЕС ССЫЛКИ НА ФАЙЛ, ОН РАБОТАЕТ
# /doc121940016_590903120?hash=44d29fbd96c2702270&dl=b1be48be63b6777292
# Out:
#             <!DOCTYPE html>
#       <html lang="ru" class="vk vk_js_no vk_1x vk_flex_no r d h  vk_appAuth_no n vk_old  vk_schemes_no   ">
#       <head>
#               <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, minimal-ui, user-scalable=no" />
#         <meta name="format-detection" content="telephone=no" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <meta name="MobileOptimized" content="176" />
#         <meta name="HandheldFriendly" content="True" />
#         <base id="base">
#
#         <meta name="description" content="Здесь находятся протоколы собраний Студенческого совета мехмата, начиная с X созыва." />
#         <meta property="og:description" content="Здесь находятся протоколы собраний Студенческого совета мехмата, начиная с X созыва." />
#         <link rel="shortcut icon" href="/images/icons/favicons/fav_logo.ico?8"></link>
#             <meta name="theme-color" content="#ffffff" />
#     <link rel="icon" type="image/png" sizes="32x32" href="/images/icons/pwa/favicon_32.png?12">
#     <link rel="apple-touch-icon" href="/images/icons/pwa/apple/default.png?14">
#     <meta name="apple-mobile-web-app-title" content="ВКонтакте">
#     <meta name="application-name" content="ВКонтакте">
#     <meta name="mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#         <title>Протоколы собраний | Студенческий совет мехмата МГУ | ВКонтакте</title>
#         <meta http-equiv="origin-trial" content="Av8ECqeAAIiC9bF3N7aq2M/TaxNzzpPcFXnw0rRb9KRUQlbyHKYmPj6KeVUFVDk+S7W9RfJH2GsEOS8G99uJvgcAAABaeyJvcmlnaW4iOiJodHRwczovL3ZrLmNvbTo0NDMiLCJmZWF0dXJlIjoiQmFkZ2luZyIsImV4cGlyeSI6MTU2MTY2MTkxNCwiaXNTdWJkb21haW4iOnRydWV9">
#
#         <script>
#           (function() {
#             window.vk = {"id":0,"__debug":false,"__dev":false,"wsTransport":"https:\/\/stats.vk-portal.net","statsMeta":{"platform":"mvk","st":false,"time":1642277580,"hash":"9PGwvHCRiO8gzuBFON6gJ5A9qwkhubMHWyFCEqlrpZH"},"tnsPixelType":"unauth","tnsPixelSocdem":"13","platform":"mvk","liteMode":false,"apiConfigDomains":{"apiDomain":"api.vk.com","loginDomain":"login.vk.com","connectDomain":"id.vk.com"},"rv":"109902","ts":1642277580,"sw":null,"stFiles":{"https:\/\/st.vk.com\/css\/mobile\/legacy_fallback.a1549d2bd9d60febef88.css":"","https:\/\/st.vk.com\/css\/mobile\/common_fallback.790a710526d78abfec46.css":"","https:\/\/st.vk.com\/css\/mobile\/audio_fallback.24652eeb7632cbfd7923.css":"","https:\/\/st.vk.com\/css\/mobile\/unauthorized_fallback.b2edcb2b089eeb21855e.css":"","https:\/\/st.vk.com\/css\/mobile\/owner_photo_upload_fallback.8da356181df38be2a4c9.css":"","https:\/\/st.vk.com\/dist\/mobile\/runtime.e1a1a3f4b6fd030db752.js":"f32381bd69e0318730ecd678c8a03c3b69d4087a6a4258cd49188720788da4be","https:\/\/st.vk.com\/dist\/mobile\/vendor.fea640d4ced51f974ff5.js":"517621348e0ce4eaea7f17e2f94542a94b115f94e8e895650bc173bc2ab606d4","https:\/\/st.vk.com\/dist\/mobile\/vendor~vkjs.1be5d729b3da4732d109.js":"71c5dc213731f34beef1d2b56c6e420de73a9c99272e0300990e5cc970430276","https:\/\/st
6d5f7b1a7.js","https:\/\/st.vk.com\/dist\/mobile\/join.aaff835b5242a7dfebc7.js","https:\/\/st.vk.com\/css\/mobile\/join.b520bf3da70ec08b1ef1.css"],"promocode(\\\/([0-9a-zA-Z-]+))?":["https:\/\/st.vk.com\/dist\/mobile\/runtime.e1a1a3f4b6fd030db752.js","https:\/\/st.vk.com\/dist\/mobile\/vendor.fea640d4ced51f974ff5.js", ...
#             window.isMVK = true;
#             window.isNewMail = false;
#             window.isNewLongpoll = false;
#             window.audioSubscribe = false;
#             window.isArticleWebView = false;
#
#             var vkElem = document.querySelector('.vk');
#             var vkClass = vkElem.getAttribute('class');
#
#             function cssPropertySupported(pNames) {
#               var element = document.createElement('a');
#               var index = pNames.length;
#               try {
#                 while (index--) {
#                   var name = pNames[index];
#
#                   element.style.display = name;
#                   if (element.style.display === name) {
#                     return true;
#                   }
#                 }
#               } catch (pError) {}
#
#               return false;
#             }
#             var supports = {
#               js: true,
#               flex: cssPropertySupported('flex -webkit-flex -ms-flexbox -moz-box -webkit-box'.split(' ')),
#             };
#
#             supports.js && (vkClass = vkClass.replace('vk_js_no', 'vk_js_yes'));
#             supports.flex && (vkClass = vkClass.replace('vk_flex_no', 'vk_flex_yes'));
#             vkElem.setAttribute('class', vkClass);
#           })();
#         </script>
#
#
#         <script type="text/javascript">
# <!--
# ;/*top_script*/(function(){"use strict";function e(e){t(e),e.hash_redirect&&o(e),e.al_ver&&(window.al={ver:e.al_ver}),document.addEventListener("DOMContentLoaded",(function(){e.help_hints&&window.helpHints&&window.helpHints.initHelpHints&&window.helpHints.initHelpHints(e.help_hints),e.detect_broken_static&&i()}))}function t(e){var t=e.iospwa_cookie,o=e.device_cookie,i=e.cookie_secure,n=e.cookie_samesite,a=e.cookie_path,r=e.cookie_domain,c=e.need_reload,s=new Date((new Date).getTime()+7776e6).toUTCString();!0===navigator.standalone&&-1===document.cookie.indexOf(t+"=1")&&(document.cookie=t+"=1; expires="+s+";"+i+n+" path="+a+"; domain="+r);var d=document,u=window,p="undefined",l="!",h="-",f=u.screen,m=f.width||0,w=f.height||0,v=u.devicePixelRatio||1,y=new RegExp("(^|;\\s+)"+o+"=([^;]+)"),g=(d.cookie.match(y)||[])[2]||"",_=g.split("/");if(g&&m==_[0]&&w==_[1]&&v==_[2]&&7===_[3].length);else{var k=[m,w,v,M()].join("/");d.cookie=o+"=; expires="+new Date(0).toUTCString()+";"+i+n+" path="+a,d.cookie=o+"="+k+"; expires="+s+";"+i+n+" path="+a+"; domain="+r,""!==d.cookie&&c&&location.reload()}function M(){var e=(function(){var e;try{e=new XMLHttpRequest}catch(t){try{e=new ActiveXObject("Msxml2.XMLHTTP")}catch(t){try{e=new ActiveXObject("Microsoft.XMLHTTP")}catch(e){}}}return e?"!":"-"})(),t=((o=d.createElement("div")).innerHTML='<input type="file" />',"file"!==(o=o.getElementsByTagName("input")[0]).type||o.disabled?"-":"!"),o,i="ontouchstart"in u?"!":"-",n="-",a,r,c;try{(typeof navigator.geolocation!==p||typeof u.google!==p&&typeof google.gears!==p||typeof device!==p&&typeof device.getServiceObject!==p||typeof Mojo!==p&&"Mojo.Service.Request"!=typeof Mojo.Service.Request)&&(n="!")}catch(e){}return[e,t,i,n,(function(e){try{var t=u.Audio?new Audio:d.createElement("audio");if(t.canPlayType&&t.canPlayType(e)&&"no"!==t.canPlayType(e))return"!"}catch(e){}return"-"})("audio/mpeg"),(function(e){try{for(var t=d.createElement("div"),o=["","webkit","Moz","ms","O"],i=0,n=o.length;i<n;i++){var a=o[i],r=a?a+e:e.toLowerCase();if(typeof t.style[r]!==p)return"!"}return"-"}catch(e){return"-"}})("Transform"),(u.XMLHttpRequest||u.XDomainRequest)&&(u.FormData||u.FileReader&&(u.XMLHttpRequest&&XMLHttpRequest.sendAsBinary||u.ArrayBuffer&&u.Uint8Array&&(u.MozBlobBuilder||u.WebKitBlobBuilder||u.BlobBuilder)))?"!":"-"].join("")}}function o(e){var t=e.cookie_secure,o=e.cookie_samesite,i=location,n=i.hash||"",a=n.substr(2);if("#/"===n.substr(0,2)){var r=window.locDomain,c=new Date;c.setTime(c.getTime()+864e5);var s="; expires="+c.toGMTString();document.cookie=["remixtmp_hash_nav","=",escape(i.href),s,"; path=/",""+t,""+o,r?"; domain=."+r:""].join(""),a.match(/^\/*(away|login)(\.php)?([^a-z0-9\.]|$)/)&&(a=""),i.replace(i.protocol+"//"+i.host+"/"+a)}}function i(){try{window.onDOMReady((function(){})),window.extend({},{})}catch(t){var e=new XMLHttpRequest;e.open("POST","/?act=broken_static_log&err="+encodeURIComponent(t.message),!0),e.send()}}return e})()({"hash_redirect":true,"device_cookie":"remixmdevice","iospwa_cookie":"remixmiospwa","cookie_path":"\/","cookie_domain":".vk.com","cookie_samesite":"","cookie_secure":" Secure;","need_reload":true,"help_hints":{"mvk:video_filters":{"id":"mvk:video_filters","active":false,"hash":null},"feed:textlive_hide":{"id":"feed:textlive_hide","active":false,"hash":null},"narratives:add_tooltip":{"id":"narratives:add_tooltip","active":false,"hash":null},"community:textlives_counter":{"id":"community:textlives_counter","active":false,"hash":null},"mvk:stories_archive:privacy_hint":{"id":"mvk:stories_archive:privacy_hint","active":false,"hash":null},"mvk:stories_archive:actions_hint":{"id":"mvk:stories_archive:actions_hint","active":false,"hash":null},"friends:best_friends_posting":{"id":"friends:best_friends_posting","active":false,"hash":null},"mini_apps:button_mvk_profile":{"id":"mini_apps:button_mvk_profile","active":false,"hash":null},"mini_apps:button_mvk_app_menu":{"id":"mini_apps:button_mvk_app_menu","active":false,"hash":nu ...
# //-->
# </script>
#         <link rel="stylesheet" href="https://st.vk.com/css/mobile/legacy_fallback.a1549d2bd9d60febef88.css?">
# <link rel="stylesheet" href="https://st.vk.com/css/mobile/common_fallback.790a710526d78abfec46.css?">
# <link rel="stylesheet" href="https://st.vk.com/css/mobile/audio_fallback.24652eeb7632cbfd7923.css?">
# <link rel="stylesheet" href="https://st.vk.com/css/mobile/unauthorized_fallback.b2edcb2b089eeb21855e.css?">
# <link rel="stylesheet" href="https://st.vk.com/css/mobile
# ;/*body*/(function(){"use strict";function e(e){var o=e.colorSchemeMode,c=e.isForcedColorSchemeMode,r=e.isDarkSchemeGuideHidden,s=e.colorSchemesMap;if(window.colorScheme){var t=o;try{var i=sessionStorage.getItem("colorScheme");i&&(t=i,window.colorScheme.isModeSavingAllowed=!1),c&&(t=o,window.colorScheme.isModeSavingAllowed=!1,sessionStorage.setItem("colorScheme",o))}catch(e){}window.colorScheme.init({mode:t,schemesMap:s});var d=document.querySelector(".vk"),n=d.getAttribute("class");window.isSchemesSupported()&&(n=n.replace("vk_schemes_no","vk_schemes_yes")),d.setAttribute("class",n),window.isSchemesSupported()&&!r&&onDOMReady((function(){window.DarkSchemeModal.open()}))}var m=document.getElementById("color-scheme-script");m.parentNode.removeChild(m)}return e})()({"colorSchemeMode":"auto","isForcedColorSchemeMode":false,"isDarkSchemeGuideHidden":true,"colorSchemesMap":null});
# //-->
# </script>
#
#             <div class="layout">
#
#           <div class="layout__header mhead" id="vk_head">
#       <div class="hb_wrap">
#         <div class="hb_btn">&nbsp;</div>
#       </div>
#     </div>
#       <div class="layout__body " id="vk_wrap">
#         <div class="layout__leftMenu" id="l">
#
#         </div>
#         <div class="layout__basis" id="m" role="main">
#               <div class="basis">
#       <div class="basis__header mhead basis__header_noBottomMenu basis__header_noshadow basis__header_noshadowAnim basis__header_unauthorized basis__header_unauthorized_actions basis__header_nohide" id="mhead"><div class="UnauthorizedHeader"><div class="UnauthorizedHeader__row"><div class="UnauthorizedHeader__logoWrapper UnauthorizedHeader__logoWrapper--toEdge"><div><div class="mhi_logo hb_btn new_year_icon_with_snowflakes"><div aria-hidden="true" class="svgIcon svgIcon-logo_snow_with_text_40h"><svg fill="none" height="40" viewBox="0 0 136 40" width="136" xmlns="http://www.w3.org/2000/svg"><clipPath id="id-logo_snow_with_text_40h__a"><path d="M0 0h136v40H0z"/></clipPath><clipPath id="id-logo_snow_with_text_40h__b"><path d="M25.36-6h104.08v45.94H25.36z"/></clipPath><g clip-path="url(#id-logo_snow_with_text_40h__a)"><path clip-rule="evenodd" d="M67 20.5c0 3.34-2.43 5.5-5.88 5.5-3.45 0-5.88-2.16-5.88-5.5s2.43-5.5 5.88-5.5c3.45 0 5.88 2.16 5.88 5.5zm-9.22 0c0 2.07 1.35 3.5 3.34 3.5s3.34-1.43 3.34-3.5-1.35-3.45-3.34-3.45-3.34 1.38-3.34 3.45zm-17.03-.21c.95-.44 1.56-1.18 1.56-2.33 0-1.73-1.58-2.96-3.87-2.96h-5.27v11h5.5c2.37 0 4.02-1.29 4.02-3.05 0-1.33-.86-2.32-1.94-2.66zM35.6 17h2.83c.85 0 1.44.5 1.44 1.2s-.6 1.2-1.44 1.2h-2.83zM38.67 24h-3.06V21.3h3.06c.96 0 1.59.55 1.59 1.36s-.63 1.33-1.59 1.33zM51.84 26h3.19l-5.05-5.71L54.6 15h-2.9l-3.68 4.27h-.6V15H45v11h2.44v-4.38h.59zm24.63-11v4.34h-4.93V15H69.1v11h2.43v-4.44h4.93V26h2.43V15zM86.9 26h-2.44v-8.78h-3.8V15H90.7v2.22h-3.8zm9.7-11c-2.14 0-4.02.89-4.57 2.8l2.24.37a2.38 2.38 0 012.2-1.25c1.33 0 2.12.9 2.22 2.33h-2.37c-3.23 0-4.84 1.42
.23.2c.06 0 .12-.03.17-.08l1.03-.96.08.38a.76.76 0 00.34 1.43h.04a.76.76 0 00.11-1.52l-.1-.4 1.36.4a.23.23 0 00.17-.02.24.24 0 00.13-.27l-.32-1.37.4.12a.76.76 0 00.44.62c.1.04.2.06.3.06h.02a.76.76 0 00.55-1.28zm-2.1-.15l-1.22-.36.93-.87 1.21.36zm.58-2.77a.28.28 0 01.34-.02.27.27 0 01-.27.48.28.28 0 01-.14-.37.28.28 0 01.07-.09zm-1.5-.05l.3 1.23-.93.87-.3-1.23zm-1. ...
#       <div class="basis__menu"><div class="VideoFilterBadgeFiller"></div></div>
#
#       <div class="basis__content mcont " id="mcont" data-canonical="https://vk.com/topic-33327655_47378210"><div class="pcont bl_cont">
#   <div class="PageBlock">
#   <div class="Separator Separator--hideOnDesktop"><div></div></div>
#
#   <div class="topic_head_panel">
#   <div class="topic_header">
#     <h2 class="hp_header">Протоколы собраний</h2>
#   </div>
#   <div class="topic_group"><a href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a></div>
# </div>
#
#   <h3 class="slim_header">6 сообщений</h3>
#   <div class="wall_replies bl_cont">
#         <div class="post_item "  >
#       <a name="post4196" class="anchor"></a>
#       <a href="/stud_mm" rel="noopener"><div class="pi_img"><div href="" class="Avatar Avatar--mode-image Avatar--images-1 Avatar--borderRadius-full Avatar--size-44" role="img"   alt="Студенческий совет мехмата МГУ" aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun9-8.userapi.com/sun9-7/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&amp;quality=96&amp;crop=0,0,827,827&amp;ava=1&#39;)"><div></div></div></div></div></div></a>
#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a> </div>
#         </div>
#         <div class="pi_body">
#                 <div class="pi_text">Здесь находятся протоколы собраний Студенческого совета мехмата, начиная с X созыва.</div>
#
#
#           <div class="pi_info"><a class="item_date" href="/topic-33327655_47378210?post=4196#post4196" rel="noopener">10 мар 2021 в 11:08</a></div>
#
#
#           <div class="pi_links"><div class="like_wrap"><a class="pi_link" href="/like?act=add&object=topic_comment-33327655_4196&from=topic-33327655_47378210&hash=48b4d29893cf270d8a" rel="noopener">Нравится</a></div></div>
#
#
#         </div>
#       </div>
#
#
#     </div>    <div class="post_item "  >
#       <a name="post4197" class="anchor"></a>
#       <a href="/stud_mm" rel="noopener"><div class="pi_img"><div href="" class="Avatar Avatar--mode-image Avatar--images-1 Avatar--borderRadius-full Avatar--size-44" role="img"   alt="Студенческий совет мехмата МГУ" aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun9-8.userapi.com/sun9-7/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&amp;quality=96&amp;crop=0,0,827,827&amp;ava=1&#39;)"><div></div></div></div></div></div></a>
#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a> </div>
#         </div>
#         <div class="pi_body">
#
#     <div class="pi_medias"><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_590903094?hash=a4d8c2a5fb17734b71&dl=7576b09eb6fa1887a0" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол первого собрания Студсовета мехмата от 21.11.2020.pdf</span><span class="medias_link_desc">Файл PDF, 268 КБ</span></span></a></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_590903096?hash=9dd558f56f9a99681d&dl=ea2f27f4f192a5cfc1" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол второго собрания Студсовета мехмата от 18.12.2020.pdf</span><span class="medias_link_desc">Файл PDF, 265 КБ</span></span></a></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_590903108?hash=7a5796f7638dbee7d8&dl=464f3d603df4de4c8b" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол третьего собрания Студсовета мехмата от 27.01.2021.pdf</span><span class="medias_link_desc">Файл PDF, 252 КБ</span></span></a></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_590903120?hash=44d29fbd96c2702270&dl=b1be48be63b6777292" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол четвёртого собрания Студсовета мехмата от 24.02.2021.pdf</span><span class="medias_link_desc">Файл PDF, 254 КБ</span></span></a></div></div>
#
#           <div class="pi_info"><a class="item_date" href="/topic-33327655_47378210?post=4197#post4197" rel="noopener">10 мар 2021 в 11:09</a><a class="item_like is_empty _i" href="/like?act=members&object=topic_comment-33327655_4197" rel="noopener"aria-label="2 Нравится" aria-pressed="false" role="button"><i class="i_like"></i><b class="v_like" aria-hidden="true">2</b></a></div>
#
#
#           <div class="pi_links"><div class="like_wrap"><a class="pi_link" href="/like?act=add&object=topic_comment-33327655_4197&from=topic-33327655_47378210&hash=bf829ee57eb8b49934" rel="noopener">Нравится</a></div></div>
#
#
#         </div>
#       </div>
#
#
#     </div>    <div class="post_item "  >
#       <a name="post4198" class="anchor"></a>
#       <a href="/stud_mm" rel="noopener"><div class="pi_img"><div href="" class="Avatar Avatar--mode-image Avatar--images-1 Avatar--borderRadius-full Avatar--size-44" role="img"   alt="Студенческий совет мехмата МГУ" aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun9-8.userapi.com/sun9-7/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&amp;quality=96&amp;crop=0,0,827,827&amp;ava=1&#39;)"><div></div></div></div></div></div></a>
#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a> </div>
#         </div>
#         <div class="pi_body">
#
#     <div class="pi_medias"><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_593220213?hash=70417b77eca0cb05d1&dl=6db7a749119f5c67a6" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол пятого собрания Студсовета мехмата от 24.03.2021.pdf</span><span class="medias_link_desc">Файл PDF, 2.8 МБ</span></span></a></div></div>
#
#           <div class="pi_info"><a class="item_date" href="/topic-33327655_47378210?post=4198#post4198" rel="noopener">29 мар 2021 в 23:21</a><a class="item_like is_empty _i" href="/like?act=members&object=topic_comment-33327655_4198" rel="noopener"aria-label="2 Нравится" aria-pressed="false" role="button"><i class="i_like"></i><b class="v_like" aria-hidden="true">2</b></a></div>
#
#
#           <div class="pi_links"><div class="like_wrap"><a class="pi_link" href="/like?act=add&object=topic_comment-33327655_4198&from=topic-33327655_47378210&hash=f4dbfeee713b1e7533" rel="noopener">Нравится</a></div></div>
#
#
#         </div>
#       </div>
#
#
#     </div>    <div class="post_item "  >
#       <a name="post4202" class="anchor"></a>
#       <a href="/stud_mm" rel="noopener"><div class="pi_img"><div href="" class="Avatar Avatar--mode-image Avatar--images-1 Avatar--borderRadius-full Avatar--size-44" role="img"   alt="Студенческий совет мехмата МГУ" aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun9-8.userapi.com/sun9-7/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&amp;quality=96&amp;crop=0,0,827,827&amp;ava=1&#39;)"><div></div></div></div></div></div></a>
#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a> </div>
#         </div>
#         <div class="pi_body">
#
#     <div class="pi_medias"><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_610867643?hash=75d6a3d43c3d0bb504&dl=fd9d04b274cbb71755" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол шестого собрания Студсовета мехмата от 29.04.2021.pdf</span><span class="medias_link_desc">Файл PDF, 406 КБ</span></span></a></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_610867567?hash=2786aa8be574a38c91&dl=eaf0a860fbde3f1a1f" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол седьмого собрания Студсовета мехмата от 22.05.2021.pdf</span><span class="medias_link_desc">Файл PDF, 1 МБ</span></span></a></div></div>
#
#           <div class="pi_info"><a class="item_date" href="/topic-33327655_47378210?post=4202#post4202" rel="noopener">4 сен 2021 в 15:43</a><a class="item_like is_empty _i" href="/like?act=members&object=topic_comment-33327655_4202" rel="noopener"aria-label="1 Нравится" aria-pressed="false" role="button"><i class="i_like"></i><b class="v_like" aria-hidden="true">1</b></a></div>
#
#
#           <div class="pi_links"><div class="like_wrap"><a class="pi_link" href="/like?act=add&object=topic_comment-33327655_4202&from=topic-33327655_47378210&hash=df21df99bcf1720a12" rel="noopener">Нравится</a></div></div>
#
#
#         </div>
#       </div>
#
#
#     </div>    <div class="post_item "  >
#       <a name="post4206" class="anchor"></a>
#       <a href="/stud_mm" rel="noopener"><div class="pi_img"><div href="" class="Avatar Avatar--mode-image Avatar--images-1 Avatar--borderRadius-full Avatar--size-44" role="img"   alt="Студенческий совет мехмата МГУ" aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun9-8.userapi.com/sun9-7/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&amp;quality=96&amp;crop=0,0,827,827&amp;ava=1&#39;)"><div></div></div></div></div></div></a>
#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a> </div>
#         </div>
#         <div class="pi_body">
#
#     <div class="pi_medias"><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_612957950?hash=420681e01c5dcfc84e&dl=ab33e2b614cd252560" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол восьмого собрания Студсовета мехмата от 13.09.2021.pdf</span><span class="medias_link_desc">Файл PDF, 1.6 МБ</span></span></a></div></div>
#
#           <div class="pi_info"><a class="item_date" href="/topic-33327655_47378210?post=4206#post4206" rel="noopener">23 сен 2021 в 11:37</a><a class="item_like is_empty _i" href="/like?act=members&object=topic_comment-33327655_4206" rel="noopener"aria-label="1 Нравится" aria-pressed="false" role="button"><i class="i_like"></i><b class="v_like" aria-hidden="true">1</b></a></div>
#
#
#           <div class="pi_links"><div class="like_wrap"><a class="pi_link" href="/like?act=add&object=topic_comment-33327655_4206&from=topic-33327655_47378210&hash=cc74858356b31f55cd" rel="noopener">Нравится</a></div></div>
#
#
#         </div>
#       </div>
#
#
#     </div>    <div class="post_item "  >
#       <a name="last" class="anchor"></a><a name="post4212" class="anchor"></a>
#       <a href="/stud_mm" rel="noopener"><div class="pi_img"><div href="" class="Avatar Avatar--mode-image Avatar--images-1 Avatar--borderRadius-full Avatar--size-44" role="img"   alt="Студенческий совет мехмата МГУ" aria-label="stud_mm"><div class="Avatar__content"><div class="Avatar__image Avatar__image-1" style="background-image: url(&#39;https://sun9-8.userapi.com/sun9-7/s/v1/if1/yYS3iJL8waDpQKIhpb8F5q52TGHtgUQywoMfI9ns1NArEO0wqsAgN1Gtwm4SAAlUeRA3RA3m.jpg?size=50x50&amp;quality=96&amp;crop=0,0,827,827&amp;ava=1&#39;)"><div></div></div></div></div></div></a>
#       <div class="pi_cont">
#         <div class="pi_head">
#               <div><a class="pi_author" href="/stud_mm" rel="noopener">Студенческий совет мехмата МГУ</a> </div>
#         </div>
#         <div class="pi_body">
#                 <div class="pi_text">Протоколы XI созыва.</div>
#     <div class="pi_medias"><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_623506345?hash=423856be4a2715f8ba&dl=9aaa5ee58d8a2f3902" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол первого собрания Студсовета мехмата от 30.10.2021.pdf</span><span class="medias_link_desc">Файл PDF, 3.2 МБ</span></span></a></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_623506344?hash=a15050656c4825853d&dl=e28f39d90e317041de" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол второго собрания Студсовета мехмата от 25.11.2021.pdf</span><span class="medias_link_desc">Файл PDF, 1.6 МБ</span></span></a></div><div class="medias_row attachment_type_doc"><a class="mr_label medias_link" href="/doc121940016_623506347?hash=c9f6c154fd13388136&dl=c09bc86a718151d0ae" rel="noopener" target="_blank"><span class="medias_link_icon"><i class="i_icon i_doc"></i></span><span class="medias_link_texts"><span class="medias_link_label">Файл</span><span class="medias_link_labeled medias_link_title"> Протокол третьего собрания Студсовета мехмата от 16.12.2021.pdf</span><span class="medias_link_desc">Файл PDF, 1.1 МБ</span></span></a></div></div>
#
#           <div class="pi_info"><a class="item_date" href="/topic-33327655_47378210?post=4212#post4212" rel="noopener">30 дек 2021 в 14:44</a></div>
#
#
#           <div class="pi_links"><div class="like_wrap"><a class="pi_link" href="/like?act=add&object=topic_comment-33327655_4212&from=topic-33327655_47378210&hash=f2f18f0497bbe9d652" rel="noopener">Нравится</a></div></div>
#
#
#         </div>
#       </div>
#
#
#     </div>
#
#
#   </div>
#
#   </div>
# </div></div>
#
#
#           <div aria-hidden="true" class="_cntrs" style="height:0;overflow:hidden;">
#           <img width="1" height="1" src="https://sb.scorecardresearch.com/p?c1=2&c2=13765216&c3=&c4=https%3A%2F%2Fm.vk.com%2Ftopic-33327655_47378210&c5=&c9=&c15=&cv=2.0&cj=1&rn=1984894" alt="">
#
#       <noscript><img src="//top-fwz1.mail.ru/counter?id=2579437;pid=0;r=" style="border:0;" height="1" width="1" /></noscript>
#     </div>
#     </div>
#         </div>
#       </div>
#     </div>
#
#         <noscript><img style='display: none' src='/?act=no_js&hash=f6609d08541cc8672a' /></noscript>
#         <script type="text/javascript">
# <!--
# parent&&parent!=window&&(document.getElementsByTagName('body')[0].innerHTML='');try{sessionStorage.set('is_mvk_tab', 1)}catch(e){};try {window.store.stickers = {"url_template":"https:\/\/vk.com\/sticker\/1-%id%-%size%"}}catch(e){};;(function (d, w) {
# var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true;
# ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
# var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
# if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window);
# //-->
# </script>
#         <div id="vk_utils"></div>
#         <div id="z"></div>
#         <div id="MediaView_container"></div>
#         <div id="vk_bottom"></div>
#         <div id="theme_color_shim"></div>
#
#
#       </body>
#     </html>

# %%
test_link = 'https://vk.com/topic-33327655_26170925?offset=20'

test_dict = vk_thread_info_by_link(test_link)
print(test_dict)
# Out:
# {'https://vk.com/topic-33327655_26170925?offset=20': {'list_of_posts': {0: {'link_date': datetime.date(2012, 3, 21), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 21, 'link_date_time': '21 мар 2012 в 11:43', 'link_time': '11:43', 'author': 'Александр Тропин', 'list_of_lines': ['у встреч рабгрупп сейчас есть один общий недостаток - всем удобно собираться по вторникам в одно и то же время)', 'предлагаю составлять текст обращения к ректору по открытию перехода. я узнаю подробности, как действовала ИГ зимой 2010-го, когда открыли. то есть, если что, предупредить ректора, что будут сотни подписей мехматян, если одного письма от студсовета будет недостаточно.']}, 1: {'link_date': datetime.date(2012, 3, 30), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 30, 'link_date_time': '30 мар 2012 в 1:10', 'link_time': '1:10', 'author': 'Александр Тропин', 'list_of_lines': ['кстати, в продолжение темы.', 'в архивах форумлокала наткнулся сегодня на забавный пост: стенограмма встречи ректора с мехматом в феврале 2007 года. цитирую следующий кусок:', 'Q: Почему переход на 13 этаже открывают всего на несколько часов в день.', 'Водолазский: Он открыт с 8 до 11, захватывает даже начало второй пары. Вообще общага — это одно, учебный корпус — совсем другое. Не должно быть свобоного прохода туда-сюда. Далее, у каждого сектора (Б, В) 8 выходов. Вам вот удобно на фак-т, физикам во внутренний дворик (ближе к физфаку). Кому еще куда. Что же, все 8 открыть?', 'Из зала: Я не понял, ну откроете вы все 8 и что? Все умрут?', 'Водолазский: Все зайдут!', 'Садовничий: вот вы все говорите дай-дай-дай. А за счет чего? Это же надо оборудовать посты, поставить круглосуточную серьезную охрану.', 'Так что пробивание перехода будет очень сложным. Отпишитесь здесь, кто хочет в команде заниматься этой проблемой (Никита, я и Александр, как я понимаю, в команде).']}, 2: {'link_date': datetime.date(2012, 3, 30), 'link_year_no': 2012, 'link_month_no': 3, 'link_day_no': 30, 'link_date_time': '30 мар 2012 в 1:14', 'link_time': '1:14', 'author': 'Александр Тропин', 'list_of_lines': ['вот ссылка, кого заинтересовало. речь и ответы на вопросы. надо знать историю проблем, потому что они, как и ответы на вопросы, остались прежними.', 'http://www.forumbgz.ru/ashowthreaded.php?Cat=&Boa..']}, 3: {'link_date': datetime.date(2012, 4, 1), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 1, 'link_date_time': '1 апр 2012 в 21:39', 'link_time': '21:39', 'author': 'Вероника Владыкина', 'list_of_lines': ['Промежуточный отчет по проблеме тренажерки фдс-3:', 'Ответственный за тренажерку Колосков Александр сказал, что собирать деньги с проживающих в 3м фдсе не имеют право. все они могут посещать тренажерку бесплатно. если вдруг кто-то станет требовать деньги можно прямо ссылаться на Колоскова, он разрешил. Просил довести это до сведения всех студентов.', 'Деньги же по всей видимости незаконно собирал бывший ответственный. С чем мы в данный момент и разбираемся.']}, 4: {'link_date': datetime.date(2012, 4, 4), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 4, 'link_date_time': '4 апр 2012 в 14:07', 'link_time': '14:07', 'author': 'Никита Котляров', 'list_of_lines': ['Ура, наконец-то я поговорил с Колпаковым. Итак, по поводу туалетов: на 14-ом этаже ремонт запланирован на лето, на 15-ом ремонт пока не планируется. Насчет крючков для сумок: перегородки в туалетах тонкие, поэтому не понятно, как их можно закрепить вообще.', 'По поводу мела: на всех этаж мел такой же, как и раньше был. На 16-ом некоторое время был отстойный мел, неделю назад его заменили на нормальный.', 'По поводу перегоревших лампочек, холодных аудиторий, штор, шпингалетов и прочей мелочи: пишите в эту тему проблемы с указанием аудитории, через неделю отнесу Колпакову список.']}, 5: {'link_date': datetime.date(2012, 4, 4), 'link_year_no': 2012, 'link_month_no': 4, 'link_day_no': 4, 'link_date_time': '4 апр 2012 в 14:44', 'link_time': '14:44', 'author': 'Павел Тишин', 'list_of_lines': ['Шторы, ла ...

# %%
link_vk = 'https://vk.com/topic-33327655_25816532'
req_link = requests.get(link_vk)
html_doc = req_link.text
soup = BeautifulSoup(html_doc, 'html.parser')

wi_body = soup.find_all('div', attrs={'class': 'pi_body'})
# print(wi_body)

for el in wi_body:
    text = el.find('div', attrs={'class': 'pi_text'})
#     print(text)
    text_lines = [line for line in text.stripped_strings]
    print(text_lines)
    
    date =
# Out:
# ['На собрании присутствовало 9 представителей студсовета. Модерировал собрание Никита Котляров, выбранный председателем на экстренном собрании в декабре. Собрание длилось около 3 часов, модерирование было затруднено в связи с большим желанием участников обсудить следующие пункты повестки:', '1) формат собрания.', 'Обсудили, как будут проходить наши собрания в будущем. Модератор объявляет повестку собрания, далее по пунктам участники высказываются в порядке очереди по поднятой руке. На собраниях могут присутствовать все желающие (не только студсоветовцы, но и остальные студенты), а преподаватели и представители администрации - либо по приглашению студсоветовцев, либо при отсутствии возражений у присутствующих на собрании студсоветовцев.', '2) Устав.', 'а) выборы.', 'Уже в феврале-марте нужно организовать перевыборы ССовета мехмата. Единогласно были приняты следующие пункты:', '- перевыборы проходят ежегодно, в феврале-марте (первокурсники успеют познакомиться, сдать первую сессию).', '- выборы проводятся на каждом курсе, кроме последнего (пока это 5-й, через несколько лет станет 6-й).', '- выборы проходят по потокам в целях равномерного представительства студентов в ССовете.', '- от каждого потока выбираются 3 человека, кроме экономпотока - от них 1.', '- кандидатуры выдвигаются заранее, возможно, с кратким описанием себя или своей программы. Выборы проходят открыто, в аудитории после какой-то лекции (к примеру). Студенты подписываются под выбранным ими кандидатом, указывая ФИО и номер группы. За представителей потоков могут голосовать только студенты из этого потока.', 'В феврале ССовет объявит о начале сбора заявок в кандидаты, проведем с ними собрание, чтобы рассказать о ССовете, в марте - сами выборы. За выборы на каждом потоке будет ответственным один человек из состава нынешнего ССовета с одним условием - он не проводит выборы на том потоке, на котором учится сам.', 'б) устав, он же - "цели и задачи"', 'Некоторое время назад в этой группе был выложен проект устава, который следует доработать. Создали рабочую группу по уставу в составе 7 человек (из числа присутствовавших сегодня), они собираются отдельно, после чего выложат свой проект на обсуждение студентов (в этой группе), и с учетом всех замечаний устав будет принят на следующем собрании ССовета.', 'в) структура ССовета.', 'Одобрили создание т.н. "рабочих групп" ССовета, которые будут заниматься конкретными проблемами (пример - рабочая группа по правилам прохода в общежитие, рабочая группа по организации мероприятий). В рабочую группу обязательно входит хотя бы один представитель ССовета, который является ответственным за рабочую группу, а также все желающие студенты, аспиранты, сотрудники факультета. ССовет пишет документ о том, что рабочая группа будет действовать от его имени. ССовет может распустить рабочую группу по своему желанию.', 'Прежний студсовет, который занимался организацией мероприятий на мехмате ранее, решено пригласить для участия в рабочей группе по организации мероприятий (она будет создана ближе к самим мероприятиям).', 'г) Председателем был во второй раз выбран Никита Котляров (из 8 человек присутствовавших на тот момент: 6 - за, 1 - против, сам он не голосовал). Новые выборы председателя будут проведены после перевыборов ССовета в марте. Было решено должность заместителя председателя сделать не выборной, а назначаемой председателем. Был назначен Дмитрий Асташов. Секретарем выбран я (7 голосов "за").', 'д) ССовет и политика.', 'Студсовет как орган самоуправления не должен поддерживать или не поддерживать какую-либо партию или движение, однако оставляет за собой право выражать мнение учащихся по вопросам, касающихся обучения, проживания в общежития и т.д. (пример - реформа образования).']
# ['3) Студсовет МГУ.', 'Студсовет МГУ состоит из председателей ССоветов факультетов (по одному человеку от факультета). На ближайшем его собрании (21.01) председатель ССовета мехмата будет отстаивать следующие предложения:', '- проект Устава Студсовета МГУ следует не принимать в спешке 21 января, а выносить на обсуждение на собраниях ССоветов факультетов.', '- пропорциональная система голосования в Студсовете МГУ. В соседней теме состоялся срач по этому вопросу, но вкратце ситуация такая: Численность разных факультетов МГУ сильно разбросана от 150 на малых факультетах до 2500 на физфаке и юрфаке. При нынешней системе голосования "1 факультет= 1 представитель = 1 голос" происходит ущемление прав отдельно взятого студента большинства факультетов. К примеру, мнение 2000 студентов факультета А приравнивается к мнению 200 студентов факультета Б. Таким образом, 2 голоса представителей двух факультетов по 200 человек могут вкупе заглушить 1 голос представителя факультета из 2000, в то время как аудитория, ради которой решается какой-либо вопрос, представлена по численности в корне наоборот. Идея - разделить все факультеты на 3 группы (большие, средние, малые), определить число голосов для каждого представителя факультетов каждой группы одинаковым (например, 5 у крупных, 3 у средних, 1 у малых).', '- создать рабочую группу по обсуждению новых правил прохода в общежитие ГЗ из числа председателей студсоветов факультетов, проживающих в общежитиях ГЗ. Предложить добавить в рабочую группу одного представителя Инициативной группы на правах представителя самоорганизации студентов, аспирантов, сотрудников, занимающихся этим вопросом уже более 2 лет.', '4) текущие проблемы.', 'Сходу было выявлено две - правила прохода в общежитие и открытие до 22 часов перехода А13-Б19. Они будут рассматриваться после обсуждения вопроса с рабочей группой из факультетов, живущих в ГЗ. Остальные проблемы можно сообщать нам, они будут рассмотрены на следующем собрании ССовета мехмата.', 'Информирование студентов о проблемах и собраниях будет осуществляться через стенд ССовета (13 этаж, холл, ближний к сектору Б), а также через группу вконтакте и емейл. Была поддержана идея создания ящика под стендом и емейла для сбора жалоб и предложений.', 'СЛЕДУЮЩЕЕ СОБРАНИЕ Студсовета мехмата будет проведено скорее всего на третьей неделе февраля. Дата, время и место будет сообщено позже. Приглашаются все желающие.']

# %%
# если ссылка некорректная, то происходит переадрессация на https://vk.com/board33327655

# req_announcement = requests.get('https://vk.com/topic-33327655_25816533')
# html_doc = req_announcement.text
# print(html_doc)
